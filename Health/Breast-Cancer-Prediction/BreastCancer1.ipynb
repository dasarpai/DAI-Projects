# %%
# performing linear algebra 
import numpy as np  
  
# data processing 
import pandas as pd 
  
# visualisation 
import matplotlib.pyplot as plt

# %%
# cols= ['ID', 'Outcome', 'Time', 'radius', 'texture' , 'perimeter', 'area', 'smoothness', 'compactness', 'concavity', 'concave-points', 'symmetry', 'fractal dimension']
# df = pd.read_csv("wdbc.csv",header= None) 
  
# df.head()

# %%
from sklearn.datasets import load_breast_cancer
data = load_breast_cancer()

# %%
data.values
# Out:
# <function Bunch.values>

# %%
df=pd.DataFrame(data.data, columns=data.feature_names)

# %%
df['target'] = data.target

# %%
df
# Out:
#      mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0          17.99         10.38          122.80     1001.0          0.11840
# 1          20.57         17.77          132.90     1326.0          0.08474
# 2          19.69         21.25          130.00     1203.0          0.10960
# 3          11.42         20.38           77.58      386.1          0.14250
# 4          20.29         14.34          135.10     1297.0          0.10030
# ..           ...           ...             ...        ...              ...
# 564        21.56         22.39          142.00     1479.0          0.11100
# 565        20.13         28.25          131.20     1261.0          0.09780
# 566        16.60         28.08          108.30      858.1          0.08455
# 567        20.60         29.33          140.10     1265.0          0.11780
# 568         7.76         24.54           47.92      181.0          0.05263
#
# ...

# %%
#df.drop(['Unnamed: 32', 'id'], axis = 1, inplace=True) 
print(df.shape)
# Out:
# (569, 31)

# %%
df.head()
# Out:
#    mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0        17.99         10.38          122.80     1001.0          0.11840
# 1        20.57         17.77          132.90     1326.0          0.08474
# 2        19.69         21.25          130.00     1203.0          0.10960
# 3        11.42         20.38           77.58      386.1          0.14250
# 4        20.29         14.34          135.10     1297.0          0.10030
#
#    mean compactness  mean concavity  mean concave points  mean symmetry  \
# 0           0.27760          0.3001              0.14710         0.2419
# 1           0.07864          0.0869              0.07017         0.1812
# 2           0.15990          0.1974              0.12790         0.2069
# 3           0.28390          0.2414              0.10520         0.2597
# 4           0.13280          0.1980              0.10430         0.1809
#
#    mean fractal dimension  ...  worst texture  worst perimeter  worst area  \
# ...

# %%
def diagnosis_value(diagnosis): 
    if diagnosis == 'M': 
        return 1
    else: 
        return 0
  
df['target'] = df['target'].apply(diagnosis_value)

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.lmplot(x = 'radius_mean', y = 'texture_mean', hue = 'target', data = df) 
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_20912/1832531899.py in <module>
#       1 import seaborn as sns
#       2 import matplotlib.pyplot as plt
# ----> 3 sns.lmplot(x = 'radius_mean', y = 'texture_mean', hue = 'target', data = df)
#       4 plt.show()
#
# d:\Users\admin\anaconda3\envs\myenv\lib\site-packages\seaborn\_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# ...

# %%
sns.lmplot(x ='smoothness_mean', y = 'compactness_mean',  
           data = df, hue = 'diagnosis')

# %%
X = np.array(df.iloc[:, 1:]) 
X_cols = df.iloc[:, 1:].columns
y = np.array(df['diagnosis'])

# %%
from sklearn.model_selection import train_test_split 
X_train, X_test, y_train, y_test = train_test_split( 
    X, y, test_size = 0.33, random_state = 42)

# %% [raw]
# pkg= ['linear_model','feature_selection','model_selection','preprocessing','metrics','neighbors','re','svm']
#
# for p in pkg:
#     print (p,"\n",dir(p),"\n" )

# %%
from sklearn.neighbors import KNeighborsClassifier 
knn = KNeighborsClassifier(n_neighbors = 13) 
knn.fit(X_train, y_train)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=None, n_neighbors=13, p=2,
#            weights='uniform')

# %%
knn.score(X_test, y_test)
# Out:
# 0.9627659574468085

# %%
neighbors = [] 
cv_scores = [] 
  
from sklearn.model_selection import cross_val_score 
# perform 10 fold cross validation 
for k in range(1, 51, 2): 
    neighbors.append(k) 
    knn = KNeighborsClassifier(n_neighbors = k) 
    scores = cross_val_score( 
        knn, X_train, y_train, cv = 10, scoring = 'accuracy') 
    cv_scores.append(scores.mean())

# %%
MSE = [1-x for x in cv_scores] 
  
# determining the best k 
optimal_k = neighbors[MSE.index(min(MSE))] 
print('The optimal number of neighbors is % d ' % optimal_k) 
  
# plot misclassification error versus k 
plt.figure(figsize = (10, 6)) 
plt.plot(neighbors, MSE) 
plt.xlabel('Number of neighbors') 
plt.ylabel('Misclassification Error') 
plt.show()
# Out:
# The optimal number of neighbors is  13
