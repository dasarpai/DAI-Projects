# %%
# SIMPLE NLP ANALYSIS USING HUGGINGFACE

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# %%
url = 'https://github.com/dasarpai/DAI-Datasets/blob/main/zomato_reviews.csv'
url = "https://raw.githubusercontent.com/dasarpai/DAI-Datasets/main/zomato_reviews.csv"

# Read the CSV file directly from GitHub
df = pd.read_csv(url, index_col="Unnamed: 0")

# %%
df.head()
# Out:
#    rating                                             review
# 0       5                                               nice
# 1       5  best biryani , so supportive staff of outlet ,...
# 2       4     delivery boy was very decent and supportive.👌👍
# 3       1  worst biryani i have tasted in my life, half o...
# 4       5  all food is good and tasty . will order again ...

# %%
# !nvcc --version
# Out:
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2024 NVIDIA Corporation
# Built on Thu_Jun__6_03:03:05_Pacific_Daylight_Time_2024
# Cuda compilation tools, release 12.5, V12.5.82
# Build cuda_12.5.r12.5/compiler.34385749_0

# %%
# !nvidia-smi
# Out:
# Fri Nov  8 21:13:44 2024
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 560.81                 Driver Version: 560.81         CUDA Version: 12.6     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                  Driver-Model | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA GeForce RTX 4070 ...  WDDM  |   00000000:01:00.0 Off |                  N/A |
# | N/A   53C    P8              8W /   40W |       0MiB /   8188MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI        PID   Type   Process name                              GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |  No running processes found                                                             |
# +-----------------------------------------------------------------------------------------+

# %%
import torch
print(torch.cuda.is_available())  # Should print True if GPU is available
print(torch.cuda.device_count())  # Should print number of GPUs available
# Out:
# False
# 0

# %%
from transformers import pipeline
classifier = pipeline("text-classification", model="j-hartmann/emotion-english-distilroberta-base", return_all_scores=True)
example_results = classifier("I love this!")
# Out:
# c:\Python312\Lib\site-packages\transformers\pipelines\text_classification.py:106: UserWarning: `return_all_scores` is now deprecated,  if want a similar functionality use `top_k=None` instead of `return_all_scores=True` or `top_k=1` instead of `return_all_scores=False`.
#   warnings.warn(

# %%
# classifier = classifier.model.to('cuda')

# %%
example_results
# Out:
# [[{'label': 'anger', 'score': 0.004419790115207434},
#   {'label': 'disgust', 'score': 0.001611992483958602},
#   {'label': 'fear', 'score': 0.0004138525982853025},
#   {'label': 'joy', 'score': 0.9771687984466553},
#   {'label': 'neutral', 'score': 0.005764586851000786},
#   {'label': 'sadness', 'score': 0.002092392183840275},
#   {'label': 'surprise', 'score': 0.008528688922524452}]]

# %%
example_best = 0
example_best_score = 0 

# Access the first element (the list) in example_results
for idx, e in enumerate(example_results[0]):  # Access the first element of the outer list
    if e['score'] > example_best_score:
        example_best_score = e['score']
        example_best = idx

# Output the best result (the dictionary with the highest score)
print(example_results[0][example_best])
# Out:
# {'label': 'joy', 'score': 0.9771687984466553}

# %%
reviews = df['review']

# %%
df['review'] = df['review'].fillna('Null filled with this placeholder message.')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5479 entries, 0 to 5478
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   rating  5479 non-null   int64
#  1   review  5479 non-null   object
# dtypes: int64(1), object(1)
# memory usage: 128.4+ KB

# %%
best_score = 0
best_idx = 0
for idx, r in enumerate(result[0]):
    if isinstance(r, dict) and 'score' in r:  # if r is a dictionary and has the 'score' key
        if r['score'] > best_score:
            best_score = r['score']
            best_idx = idx
    elif isinstance(r, list) or isinstance(r, tuple):  # if r is a list/tuple
        # Modify the index based on where the 'score' is in your list/tuple
        if r[1] > best_score:  # assuming score is at index 1
            best_score = r[1]
            best_idx = idx

print(result[0][best_idx])  # Print the best result
# Out:
# {'label': 'neutral', 'score': 0.7410889863967896}

# %%
review_sentiments = []
for rev in reviews:
    best_idx = 0
    best_score = 0
#     print(rev)
    result = classifier(rev)
    for idx,r in enumerate(result[0]):
#         print(r)
        if r['score']>best_score:
            best_score = r['score']
            best_idx = idx
            
    review_sentiments.append(result[0][best_idx])

# %%
r
# Out:
# {'label': 'surprise', 'score': 0.014902020804584026}

# %%
review_sentiments
# Out:
# [{'label': 'neutral', 'score': 0.7410889863967896},
#  {'label': 'neutral', 'score': 0.2890426516532898},
#  {'label': 'joy', 'score': 0.5907884240150452},
#  {'label': 'disgust', 'score': 0.9389179944992065},
#  {'label': 'joy', 'score': 0.7750592231750488},
#  {'label': 'joy', 'score': 0.5231075882911682},
#  {'label': 'neutral', 'score': 0.7880570292472839},
#  {'label': 'joy', 'score': 0.4599943161010742},
#  {'label': 'neutral', 'score': 0.5484577417373657},
#  {'label': 'joy', 'score': 0.8362355828285217},
#  {'label': 'neutral', 'score': 0.3215256333351135},
#  {'label': 'joy', 'score': 0.985458493232727},
#  {'label': 'joy', 'score': 0.9684831500053406},
#  {'label': 'joy', 'score': 0.7866860628128052},
#  {'label': 'joy', 'score': 0.9407974481582642},
#  {'label': 'joy', 'score': 0.6331069469451904},
#  {'label': 'sadness', 'score': 0.949017345905304},
#  {'label': 'sadness', 'score': 0.7905277609825134},
#  {'label': 'joy', 'score': 0.6387940049171448},
#  {'label': 'joy', 'score': 0.772070050239563},
#  {'label': 'fear', 'score': 0.37133997678756714},
#  {'label': 'neutral', 'score': 0.755165159702301},
#  {'label': 'joy', 'score': 0.9050306677818298},
#  {'label': 'neutral', 'score': 0.4826529622077942},
#  {'label': 'neutral', 'score': 0.41446059942245483},
#  {'label': 'sadness', 'score': 0.234047994017601},
#  {'label': 'joy', 'score': 0.6146057844161987},
#  {'label': 'joy', 'score': 0.8230355381965637},
#  {'label': 'joy', 'score': 0.9055185317993164},
#  {'label': 'neutral', 'score': 0.4828138053417206},
#  {'label': 'joy', 'score': 0.9346694946289062},
#  {'label': 'sadness', 'score': 0.47705426812171936},
#  {'label': 'sadness', 'score': 0.8063422441482544},
#  {'label': 'joy', 'score': 0.5416012406349182},
#  {'label': 'neutral', 'score': 0.6118858456611633},
#  {'label': 'disgust', 'score': 0.8003057241439819},
#  {'label': 'anger', 'score': 0.46176567673683167},
#  {'label': 'disgust', 'score': 0.4272998869419098},
#  {'label': 'neutral', 'score': 0.49122247099876404},
#  {'label': 'neutral', 'score': 0.6000525951385498},
#  {'label': 'neutral', 'score': 0.5258987545967102},
#  {'label': 'neutral', 'score': 0.7518018484115601},
#  {'label': 'neutral', 'score': 0.7837948203086853},
#  {'label': 'sadness', 'score': 0.7711202502250671},
#  {'label': 'disgust', 'score': 0.32909223437309265},
#  {'label': 'disgust', 'score': 0.6333981156349182},
#  {'label': 'surprise', 'score': 0.47544753551483154},
#  {'label': 'disgust', 'score': 0.8134287595748901},
#  {'label': 'surprise', 'score': 0.40015920996665955},
#  {'label': 'neutral', 'score': 0.4976580739021301},
#  {'label': 'sadness', 'score': 0.44041210412979126},
#  {'label': 'sadness', 'score': 0.8166630268096924},
#  {'label': 'neutral', 'score': 0.6250438094139099},
#  {'label': 'neutral', 'score': 0.8968018889427185},
#  {'label': 'fear', 'score': 0.8766070604324341},
#  {'label': 'sadness', 'score': 0.9321154952049255},
#  {'label': 'neutral', 'score': 0.49650847911834717},
#  {'label': 'neutral', 'score': 0.32025983929634094},
#  {'label': 'joy', 'score': 0.2840620279312134},
#  {'label': 'sadness', 'score': 0.5398878455162048},
#  {'label': 'joy', 'score': 0.4520079791545868},
#  {'label': 'neutral', 'score': 0.8221659064292908},
#  {'label': 'neutral', 'score': 0.9351816177368164},
#  {'label': 'sadness', 'score': 0.7660790085792542},
#  {'label': 'anger', 'score': 0.46508723497390747},
#  {'label': 'neutral', 'score': 0.6503212451934814},
#  {'label': 'joy', 'score': 0.9548633098602295},
#  {'label': 'neutral', 'score': 0.7671159505844116},
#  {'label': 'joy', 'score': 0.6579392552375793},
#  {'label': 'disgust', 'score': 0.4989055097103119},
#  {'label': 'joy', 'score': 0.978416919708252},
#  {'label': 'disgust', 'score': 0.9478074908256531},
#  {'label': 'disgust', 'score': 0.8664153218269348},
#  {'label': 'neutral', 'score': 0.8281866312026978},
#  {'label': 'disgust', 'score': 0.8749837279319763},
#  {'label': 'neutral', 'score': 0.6764789819717407},
#  {'label': 'neutral', 'score': 0.8028427362442017},
#  {'label': 'surprise', 'score': 0.6079720854759216},
#  {'label': 'disgust', 'score': 0.7073546648025513},
#  {'label': 'anger', 'score': 0.4916813373565674},
#  {'label': 'surprise', 'score': 0.6538859009742737},
#  {'label': 'disgust', 'score': 0.5239861011505127},
#  {'label': 'neutral', 'score': 0.48015356063842773},
#  {'label': 'neutral', 'score': 0.48015356063842773},
#  {'label': 'sadness', 'score': 0.7663946747779846},
#  {'label': 'disgust', 'score': 0.3457741439342499},
#  {'label': 'anger', 'score': 0.7631063461303711},
#  {'label': 'neutral', 'score': 0.7877389192581177},
#  {'label': 'neutral', 'score': 0.6358044147491455},
#  {'label': 'neutral', 'score': 0.4556353688240051},
#  {'label': 'disgust', 'score': 0.5752773880958557},
#  {'label': 'joy', 'score': 0.5484948754310608},
#  {'label': 'disgust', 'score': 0.4919907748699188},
#  {'label': 'neutral', 'score': 0.9528585076332092},
#  {'label': 'joy', 'score': 0.5426479578018188},
#  {'label': 'sadness', 'score': 0.9620054960250854},
#  {'label': 'joy', 'score': 0.9175027012825012},
#  {'label': 'disgust', 'score': 0.800175130367279},
#  {'label': 'neutral', 'score': 0.5105909705162048},
#  {'label': 'joy', 'score': 0.8358176946640015},
#  {'label': 'disgust', 'score': 0.41130533814430237},
#  {'label': 'neutral', 'score': 0.7118456363677979},
#  {'label': 'fear', 'score': 0.4717544913291931},
#  {'label': 'disgust', 'score': 0.9070340991020203},
#  {'label': 'neutral', 'score': 0.8678597211837769},
#  {'label': 'neutral', 'score': 0.49375808238983154},
#  {'label': 'neutral', 'score': 0.5706609487533569},
#  {'label': 'fear', 'score': 0.686599612236023},
#  {'label': 'neutral', 'score': 0.5738663077354431},
#  {'label': 'joy', 'score': 0.8555716276168823},
#  {'label': 'sadness', 'score': 0.6539377570152283},
#  {'label': 'sadness', 'score': 0.7381470203399658},
#  {'label': 'neutral', 'score': 0.7410889863967896},
#  {'label': 'fear', 'score': 0.34500548243522644},
#  {'label': 'disgust', 'score': 0.31554099917411804},
#  {'label': 'neutral', 'score': 0.7306472659111023},
#  {'label': 'anger', 'score': 0.7458322644233704},
#  {'label': 'disgust', 'score': 0.44441482424736023},
#  {'label': 'neutral', 'score': 0.6455782651901245},
#  {'label': 'neutral', 'score': 0.4878515303134918},
#  {'label': 'neutral', 'score': 0.594098687171936},
#  {'label': 'fear', 'score': 0.27903130650520325},
#  {'label': 'neutral', 'score': 0.3831896185874939},
#  {'label': 'neutral', 'score': 0.885142982006073},
#  {'label': 'anger', 'score': 0.8759996891021729},
#  {'label': 'fear', 'score': 0.4979275166988373},
#  {'label': 'neutral', 'score': 0.8359701633453369},
#  {'label': 'neutral', 'score': 0.7978031635284424},
#  {'label': 'surprise', 'score': 0.8712062239646912},
#  {'label': 'neutral', 'score': 0.42880481481552124},
#  {'label': 'disgust', 'score': 0.6949710845947266},
#  {'label': 'joy', 'score': 0.9160249829292297},
#  {'label': 'joy', 'score': 0.2840620279312134},
#  {'label': 'neutral', 'score': 0.7975447773933411},
#  {'label': 'neutral', 'score': 0.562997579574585},
#  {'label': 'neutral', 'score': 0.8115996718406677},
#  {'label': 'neutral', 'score': 0.8460693955421448},
#  {'label': 'neutral', 'score': 0.8187075853347778},
#  {'label': 'neutral', 'score': 0.4433756172657013},
#  {'label': 'neutral', 'score': 0.8994752764701843},
#  {'label': 'fear', 'score': 0.29988500475883484},
#  {'label': 'neutral', 'score': 0.7075976133346558},
#  {'label': 'disgust', 'score': 0.9575304985046387},
#  {'label': 'joy', 'score': 0.7738215327262878},
#  {'label': 'neutral', 'score': 0.41322699189186096},
#  {'label': 'disgust', 'score': 0.8829123973846436},
#  {'label': 'sadness', 'score': 0.5594832897186279},
#  {'label': 'joy', 'score': 0.929451048374176},
#  {'label': 'neutral', 'score': 0.7186983823776245},
#  {'label': 'joy', 'score': 0.4942891597747803},
#  {'label': 'joy', 'score': 0.6885135173797607},
#  {'label': 'neutral', 'score': 0.7855732440948486},
#  {'label': 'disgust', 'score': 0.8653042316436768},
#  {'label': 'disgust', 'score': 0.9131706357002258},
#  {'label': 'joy', 'score': 0.9248465299606323},
#  {'label': 'neutral', 'score': 0.632514238357544},
#  {'label': 'neutral', 'score': 0.47983214259147644},
#  {'label': 'sadness', 'score': 0.7812666296958923},
#  {'label': 'joy', 'score': 0.2840620279312134},
#  {'label': 'neutral', 'score': 0.632514238357544},
#  {'label': 'fear', 'score': 0.672526478767395},
#  {'label': 'neutral', 'score': 0.6999823451042175},
#  {'label': 'disgust', 'score': 0.44789376854896545},
#  {'label': 'neutral', 'score': 0.7928448915481567},
#  {'label': 'joy', 'score': 0.4947199523448944},
#  {'label': 'fear', 'score': 0.4938109815120697},
#  {'label': 'neutral', 'score': 0.29711923003196716},
#  {'label': 'neutral', 'score': 0.4559304118156433},
#  {'label': 'fear', 'score': 0.6388313174247742},
#  {'label': 'neutral', 'score': 0.5156090259552002},
#  {'label': 'neutral', 'score': 0.7570295333862305},
#  {'label': 'anger', 'score': 0.262268990278244},
#  {'label': 'joy', 'score': 0.9277120232582092},
#  {'label': 'disgust', 'score': 0.8729992508888245},
#  {'label': 'disgust', 'score': 0.658234715461731},
#  {'label': 'neutral', 'score': 0.48953694105148315},
#  {'label': 'neutral', 'score': 0.7224975824356079},
#  {'label': 'neutral', 'score': 0.6636657118797302},
#  {'label': 'neutral', 'score': 0.8356677889823914},
#  {'label': 'disgust', 'score': 0.5724433064460754},
#  {'label': 'fear', 'score': 0.5445979833602905},
#  {'label': 'neutral', 'score': 0.632514238357544},
#  {'label': 'sadness', 'score': 0.6701787114143372},
#  {'label': 'neutral', 'score': 0.6452931761741638},
#  {'label': 'neutral', 'score': 0.6368731260299683},
#  {'label': 'neutral', 'score': 0.38622260093688965},
#  {'label': 'neutral', 'score': 0.49310508370399475},
#  {'label': 'neutral', 'score': 0.6692436933517456},
#  {'label': 'neutral', 'score': 0.7410889863967896},
#  {'label': 'fear', 'score': 0.41964900493621826},
#  {'label': 'neutral', 'score': 0.7383178472518921},
#  {'label': 'neutral', 'score': 0.6995288729667664},
#  {'label': 'neutral', 'score': 0.849929690361023},
#  {'label': 'joy', 'score': 0.5356603264808655},
#  {'label': 'neutral', 'score': 0.8105039596557617},
#  {'label': 'neutral', 'score': 0.8560331463813782},
#  {'label': 'fear', 'score': 0.4027574360370636},
#  {'label': 'sadness', 'score': 0.8796951174736023},
#  {'label': 'neutral', 'score': 0.8557676076889038},
#  {'label': 'neutral', 'score': 0.7778644561767578},
#  {'label': 'joy', 'score': 0.5389130711555481},
#  {'label': 'neutral', 'score': 0.383759081363678},
#  {'label': 'anger', 'score': 0.5102052688598633},
#  {'label': 'joy', 'score': 0.39246925711631775},
#  {'label': 'sadness', 'score': 0.5699116587638855},
#  {'label': 'sadness', 'score': 0.5108510255813599},
#  {'label': 'anger', 'score': 0.3968530297279358},
#  {'label': 'joy', 'score': 0.9675288796424866},
#  {'label': 'neutral', 'score': 0.41322699189186096},
#  {'label': 'neutral', 'score': 0.874142587184906},
#  {'label': 'joy', 'score': 0.9793888926506042},
#  {'label': 'neutral', 'score': 0.5356167554855347},
#  {'label': 'neutral', 'score': 0.3191607594490051},
#  {'label': 'sadness', 'score': 0.527693510055542},
#  {'label': 'neutral', 'score': 0.748566746711731},
#  {'label': 'neutral', 'score': 0.38962501287460327},
#  {'label': 'disgust', 'score': 0.5863181352615356},
#  {'label': 'neutral', 'score': 0.43074482679367065},
#  {'label': 'joy', 'score': 0.2840620279312134},
#  {'label': 'neutral', 'score': 0.8495245575904846},
#  {'label': 'neutral', 'score': 0.4052387475967407},
#  {'label': 'disgust', 'score': 0.5683002471923828},
#  {'label': 'fear', 'score': 0.5135054588317871},
#  {'label': 'fear', 'score': 0.37175723910331726},
#  {'label': 'joy', 'score': 0.9727262258529663},
#  {'label': 'neutral', 'score': 0.910710871219635},
#  {'label': 'neutral', 'score': 0.632514238357544},
#  {'label': 'surprise', 'score': 0.5978131890296936},
#  {'label': 'neutral', 'score': 0.7410889863967896},
#  {'label': 'joy', 'score': 0.7878864407539368},
#  {'label': 'disgust', 'score': 0.6360359787940979},
#  {'label': 'neutral', 'score': 0.505155622959137},
#  {'label': 'anger', 'score': 0.6578984260559082},
#  {'label': 'anger', 'score': 0.38785621523857117},
#  {'label': 'neutral', 'score': 0.8116766810417175},
#  {'label': 'neutral', 'score': 0.632514238357544},
#  {'label': 'joy', 'score': 0.8648760914802551},
#  {'label': 'surprise', 'score': 0.47197213768959045},
#  {'label': 'neutral', 'score': 0.7648719549179077},
#  {'label': 'neutral', 'score': 0.8861557245254517},
#  {'label': 'neutral', 'score': 0.6694088578224182},
#  {'label': 'sadness', 'score': 0.42844370007514954},
#  {'label': 'fear', 'score': 0.5425087809562683},
#  {'label': 'fear', 'score': 0.5046107769012451},
#  {'label': 'neutral', 'score': 0.7410889863967896},
#  {'label': 'neutral', 'score': 0.632514238357544},
#  {'label': 'neutral', 'score': 0.8675577044487},
#  {'label': 'neutral', 'score': 0.9280027747154236},
#  {'label': 'joy', 'score': 0.9403794407844543},
#  {'label': 'joy', 'score': 0.5389130711555481},
#  {'label': 'surprise', 'score': 0.9606483578681946},
#  {'label': 'disgust', 'score': 0.43644094467163086},
#  {'label': 'neutral', 'score': 0.7298377156257629},
#  {'label': 'neutral', 'score': 0.8665104508399963},
#  {'label': 'neutral', 'score': 0.772049069404602},
#  {'label': 'surprise', 'score': 0.9606483578681946},
#  {'label': 'neutral', 'score': 0.4618646800518036},
#  {'label': 'fear', 'score': 0.9783218502998352},
#  {'label': 'neutral', 'score': 0.7410889863967896},
#  {'label': 'neutral', 'score': 0.6321806311607361},
#  {'label': 'neutral', 'score': 0.7664960026741028},
#  {'label': 'sadness', 'score': 0.4878127872943878},
#  {'label': 'disgust', 'score': 0.6965565085411072},
#  {'label': 'neutral', 'score': 0.6651735901832581},
#  {'label': 'sadness', 'score': 0.7462572455406189},
#  {'label': 'sadness', 'score': 0.45576295256614685},
#  {'label': 'joy', 'score': 0.9744315147399902},
#  {'label': 'fear', 'score': 0.5569756031036377},
#  {'label': 'fear', 'score': 0.43282350897789},
#  {'label': 'neutral', 'score': 0.6407904028892517},
#  {'label': 'neutral', 'score': 0.48015356063842773},
#  {'label': 'neutral', 'score': 0.6148931384086609},
#  {'label': 'joy', 'score': 0.9617006778717041},
#  {'label': 'neutral', 'score': 0.6219123005867004},
#  {'label': 'neutral', 'score': 0.8746882677078247},
#  {'label': 'joy', 'score': 0.2840620279312134},
#  {'label': 'disgust', 'score': 0.9123898148536682},
#  {'label': 'neutral', 'score': 0.312970906496048},
#  {'label': 'joy', 'score': 0.9175027012825012},
#  {'label': 'joy', 'score': 0.9536477327346802},
#  {'label': 'anger', 'score': 0.34127745032310486},
#  {'label': 'joy', 'score': 0.5304549932479858},
#  {'label': 'neutral', 'score': 0.7410889863967896},
#  {'label': 'neutral', 'score': 0.9184966683387756},
#  {'label': 'joy', 'score': 0.5792438983917236},
#  {'label': 'anger', 'score': 0.3289787173271179},
#  {'label': 'joy', 'score': 0.9833213090896606},
#  {'label': 'neutral', 'score': 0.6510506868362427},
#  {'label': 'disgust', 'score': 0.5824331045150757},
#  {'label': 'neutral', 'score': 0.49310508370399475},
#  {'label': 'neutral', 'score': 0.7842873930931091},
#  {'label': 'joy', 'score': 0.3133527338504791},
#  {'label': 'neutral', 'score': 0.39626461267471313},
#  {'label': 'joy', 'score': 0.6147463321685791},
#  {'label': 'neutral', 'score': 0.5624383687973022},
#  {'label': 'sadness', 'score': 0.5277854800224304},
#  {'label': 'neutral', 'score': 0.8336292505264282},
#  {'label': 'sadness', 'score': 0.5930143594741821},
#  {'label': 'sadness', 'score': 0.6532326340675354},
#  {'label': 'joy', 'score': 0.8285588026046753},
#  {'label': 'sadness', 'score': 0.5108510255813599},
#  {'label': 'neutral', 'score': 0.7076075673103333},
#  {'label': 'joy', 'score': 0.5196472406387329},
#  {'label': 'neutral', 'score': 0.47937899827957153},
#  {'label': 'neutral', 'score': 0.7782406210899353},
#  {'label': 'sadness', 'score': 0.4915481209754944},
#  {'label': 'sadness', 'score': 0.7393976449966431},
#  {'label': 'disgust', 'score': 0.7948399186134338},
#  {'label': 'joy', 'score': 0.2840620279312134},
#  {'label': 'joy', 'score': 0.5196472406387329},
#  {'label': 'sadness', 'score': 0.6367078423500061},
#  {'label': 'joy', 'score': 0.6450584530830383},
#  {'label': 'neutral', 'score': 0.9209882616996765},
#  {'label': 'neutral', 'score': 0.632514238357544},
#  {'label': 'sadness', 'score': 0.9291139841079712},
#  {'label': 'fear', 'score': 0.37224191427230835},
#  {'label': 'fear', 'score': 0.7558175921440125},
#  {'label': 'disgust', 'score': 0.8854153156280518},
#  {'label': 'anger', 'score': 0.7476836442947388},
#  {'label': 'joy', 'score': 0.2840620279312134},
#  {'label': 'anger', 'score': 0.5528469085693359},
#  {'label': 'neutral', 'score': 0.74184250831604},
#  {'label': 'fear', 'score': 0.41964900493621826},
#  {'label': 'fear', 'score': 0.3906269669532776},
#  {'label': 'sadness', 'score': 0.41158097982406616},
#  {'label': 'joy', 'score': 0.8592586517333984},
#  {'label': 'sadness', 'score': 0.7688614130020142},
#  {'label': 'joy', 'score': 0.2840620279312134},
#  {'label': 'sadness', 'score': 0.6502283811569214},
#  {'label': 'neutral', 'score': 0.8884463906288147},
#  {'label': 'disgust', 'score': 0.43795162439346313},
#  {'label': 'joy', 'score': 0.2840620279312134},
#  {'label': 'joy', 'score': 0.2840620279312134},
#  {'label': 'neutral', 'score': 0.7353694438934326},
#  {'label': 'fear', 'score': 0.4704399108886719},
#  {'label': 'joy', 'score': 0.8592586517333984},
#  {'label': 'joy', 'score': 0.5196472406387329},
#  {'label': 'joy', 'score': 0.2840620279312134},
#  {'label': 'neutral', 'score': 0.9310743808746338},
#  {'label': 'sadness', 'score': 0.9620054960250854},
#  {'label': 'fear', 'score': 0.6455019116401672},
#  {'label': 'neutral', 'score': 0.7911725044250488},
#  {'label': 'neutral', 'score': 0.9123635292053223},
#  {'label': 'neutral', 'score': 0.9410104155540466},
#  {'label': 'sadness', 'score': 0.6880470514297485},
#  {'label': 'disgust', 'score': 0.38271811604499817},
#  {'label': 'neutral', 'score': 0.7278067469596863},
#  {'label': 'joy', 'score': 0.39039552211761475},
#  {'label': 'neutral', 'score': 0.6243981122970581},
#  {'label': 'sadness', 'score': 0.8272231221199036},
#  {'label': 'fear', 'score': 0.4246538579463959},
#  {'label': 'joy', 'score': 0.8195319771766663},
#  {'label': 'fear', 'score': 0.3648856282234192},
#  {'label': 'fear', 'score': 0.5474533438682556},
#  {'label': 'joy', 'score': 0.2840620279312134},
#  {'label': 'joy', 'score': 0.8659210801124573},
#  {'label': 'neutral', 'score': 0.9016252756118774},
#  {'label': 'neutral', 'score': 0.7950647473335266},
#  {'label': 'joy', 'score': 0.2840620279312134},
#  {'label': 'disgust', 'score': 0.40536603331565857},
#  {'label': 'neutral', 'score': 0.848355233669281},
#  {'label': 'joy', 'score': 0.5713069438934326},
#  {'label': 'fear', 'score': 0.3904455304145813},
#  {'label': 'neutral', 'score': 0.4786365330219269},
#  {'label': 'joy', 'score': 0.2840620279312134},
#  {'label': 'fear', 'score': 0.614935576915741},
#  {'label': 'neutral', 'score': 0.632514238357544},
#  {'label': 'fear', 'score': 0.5525078177452087},
#  {'label': 'fear', 'score': 0.8575271964073181},
#  {'label': 'neutral', 'score': 0.6985765099525452},
#  {'label': 'neutral', 'score': 0.8845001459121704},
#  {'label': 'disgust', 'score': 0.9265799522399902},
#  {'label': 'joy', 'score': 0.6580877900123596},
#  {'label': 'sadness', 'score': 0.49604782462120056},
#  {'label': 'sadness', 'score': 0.7931821346282959},
#  {'label': 'neutral', 'score': 0.2924535274505615},
#  {'label': 'neutral', 'score': 0.6776701807975769},
#  {'label': 'sadness', 'score': 0.5702508091926575},
#  {'label': 'neutral', 'score': 0.5494670271873474},
#  {'label': 'fear', 'score': 0.37708720564842224},
#  {'label': 'joy', 'score': 0.851371169090271},
#  {'label': 'joy', 'score': 0.8183029890060425},
#  {'label': 'joy', 'score': 0.9174248576164246},
#  {'label': 'surprise', 'score': 0.43723031878471375},
#  {'label': 'neutral', 'score': 0.6416633725166321},
#  {'label': 'neutral', 'score': 0.5684427618980408},
#  {'label': 'neutral', 'score': 0.599116325378418},
#  {'label': 'neutral', 'score': 0.838959813117981},
#  {'label': 'neutral', 'score': 0.7651852965354919},
#  {'label': 'neutral', 'score': 0.8929551243782043},
#  {'label': 'neutral', 'score': 0.896599292755127},
#  {'label': 'sadness', 'score': 0.6235682368278503},
#  {'label': 'neutral', 'score': 0.632514238357544},
#  {'label': 'joy', 'score': 0.2840620279312134},
#  {'label': 'neutral', 'score': 0.6489648222923279},
#  {'label': 'neutral', 'score': 0.9480749368667603},
#  {'label': 'joy', 'score': 0.5787932276725769},
#  {'label': 'neutral', 'score': 0.9302940964698792},
#  {'label': 'joy', 'score': 0.8647305369377136},
#  {'label': 'joy', 'score': 0.5206739902496338},
#  {'label': 'neutral', 'score': 0.48189762234687805},
#  {'label': 'joy', 'score': 0.915749192237854},
#  {'label': 'joy', 'score': 0.8863418698310852},
#  {'label': 'neutral', 'score': 0.7410889863967896},
#  {'label': 'fear', 'score': 0.8264806866645813},
#  {'label': 'disgust', 'score': 0.3457741439342499},
#  {'label': 'disgust', 'score': 0.9390069246292114},
#  {'label': 'fear', 'score': 0.3896583318710327},
#  {'label': 'joy', 'score': 0.6293344497680664},
#  {'label': 'fear', 'score': 0.33734315633773804},
#  {'label': 'disgust', 'score': 0.8053421974182129},
#  {'label': 'neutral', 'score': 0.5228208899497986},
#  {'label': 'neutral', 'score': 0.49310508370399475},
#  {'label': 'joy', 'score': 0.9756499528884888},
#  {'label': 'neutral', 'score': 0.7897840142250061},
#  {'label': 'neutral', 'score': 0.8178667426109314},
#  {'label': 'neutral', 'score': 0.5811599493026733},
#  {'label': 'anger', 'score': 0.624175488948822},
#  {'label': 'joy', 'score': 0.9405011534690857},
#  {'label': 'sadness', 'score': 0.6758126020431519},
#  {'label': 'neutral', 'score': 0.5470547080039978},
#  {'label': 'joy', 'score': 0.6027798056602478},
#  {'label': 'sadness', 'score': 0.92665034532547},
#  {'label': 'neutral', 'score': 0.897493302822113},
#  {'label': 'joy', 'score': 0.7022817134857178},
#  {'label': 'neutral', 'score': 0.47937899827957153},
#  {'label': 'sadness', 'score': 0.9138854742050171},
#  {'label': 'joy', 'score': 0.9489690065383911},
#  {'label': 'neutral', 'score': 0.3349844813346863},
#  {'label': 'disgust', 'score': 0.9329201579093933},
#  {'label': 'sadness', 'score': 0.9511628746986389},
#  {'label': 'sadness', 'score': 0.4434524476528168},
#  {'label': 'joy', 'score': 0.2840620279312134},
#  {'label': 'fear', 'score': 0.4730520248413086},
#  {'label': 'joy', 'score': 0.2840620279312134},
#  {'label': 'joy', 'score': 0.2840620279312134},
#  {'label': 'neutral', 'score': 0.8722352385520935},
#  {'label': 'neutral', 'score': 0.761522114276886},
#  {'label': 'joy', 'score': 0.2840620279312134},
#  {'label': 'neutral', 'score': 0.32121846079826355},
#  {'label': 'joy', 'score': 0.8195319771766663},
#  {'label': 'neutral', 'score': 0.45876941084861755},
#  {'label': 'neutral', 'score': 0.811637282371521},
#  {'label': 'joy', 'score': 0.5196472406387329},
#  {'label': 'joy', 'score': 0.5765203237533569},
#  {'label': 'surprise', 'score': 0.7826715707778931},
#  {'label': 'sadness', 'score': 0.5636694431304932},
#  {'label': 'neutral', 'score': 0.7604607939720154},
#  {'label': 'neutral', 'score': 0.7334688305854797},
#  {'label': 'fear', 'score': 0.6114668846130371},
#  {'label': 'joy', 'score': 0.8669068217277527},
#  {'label': 'joy', 'score': 0.9815349578857422},
#  {'label': 'neutral', 'score': 0.4173951745033264},
#  {'label': 'neutral', 'score': 0.6695525050163269},
#  {'label': 'neutral', 'score': 0.9094805121421814},
#  {'label': 'neutral', 'score': 0.908202052116394},
#  {'label': 'fear', 'score': 0.7951744794845581},
#  {'label': 'neutral', 'score': 0.6149543523788452},
#  {'label': 'sadness', 'score': 0.8252043128013611},
#  {'label': 'neutral', 'score': 0.787913978099823},
#  {'label': 'joy', 'score': 0.9012637734413147},
#  {'label': 'anger', 'score': 0.6825891137123108},
#  {'label': 'anger', 'score': 0.3765793740749359},
#  {'label': 'fear', 'score': 0.9514067769050598},
#  {'label': 'neutral', 'score': 0.5632782578468323},
#  {'label': 'fear', 'score': 0.9601520895957947},
#  {'label': 'anger', 'score': 0.3050200045108795},
#  {'label': 'neutral', 'score': 0.6003222465515137},
#  {'label': 'anger', 'score': 0.33937379717826843},
#  {'label': 'neutral', 'score': 0.5882167816162109},
#  {'label': 'fear', 'score': 0.4755755066871643},
#  {'label': 'joy', 'score': 0.9175027012825012},
#  {'label': 'disgust', 'score': 0.39384353160858154},
#  {'label': 'disgust', 'score': 0.4842390716075897},
#  {'label': 'neutral', 'score': 0.8241151571273804},
#  {'label': 'neutral', 'score': 0.2906249761581421},
#  {'label': 'sadness', 'score': 0.48595353960990906},
#  {'label': 'neutral', 'score': 0.632514238357544},
#  {'label': 'neutral', 'score': 0.8298803567886353},
#  {'label': 'disgust', 'score': 0.7293111085891724},
#  {'label': 'fear', 'score': 0.3447086811065674},
#  {'label': 'sadness', 'score': 0.8090987205505371},
#  {'label': 'neutral', 'score': 0.5031226277351379},
#  {'label': 'disgust', 'score': 0.4242432415485382},
#  {'label': 'neutral', 'score': 0.9131953716278076},
#  {'label': 'neutral', 'score': 0.7841828465461731},
#  {'label': 'joy', 'score': 0.2840620279312134},
#  {'label': 'fear', 'score': 0.5414689183235168},
#  {'label': 'sadness', 'score': 0.37612131237983704},
#  {'label': 'neutral', 'score': 0.7870169281959534},
#  {'label': 'sadness', 'score': 0.6291566491127014},
#  {'label': 'anger', 'score': 0.5969738364219666},
#  {'label': 'joy', 'score': 0.9485663771629333},
#  {'label': 'disgust', 'score': 0.46280932426452637},
#  {'label': 'disgust', 'score': 0.8737002015113831},
#  {'label': 'disgust', 'score': 0.3457741439342499},
#  {'label': 'sadness', 'score': 0.8916826248168945},
#  {'label': 'disgust', 'score': 0.9724301099777222},
#  {'label': 'neutral', 'score': 0.8798847198486328},
#  {'label': 'joy', 'score': 0.2840620279312134},
#  {'label': 'disgust', 'score': 0.619101345539093},
#  {'label': 'fear', 'score': 0.8735885620117188},
#  {'label': 'sadness', 'score': 0.6301802396774292},
#  {'label': 'joy', 'score': 0.4529300630092621},
#  {'label': 'neutral', 'score': 0.9487263560295105},
#  {'label': 'disgust', 'score': 0.9768772125244141},
#  {'label': 'disgust', 'score': 0.9563316106796265},
#  {'label': 'neutral', 'score': 0.658685564994812},
#  {'label': 'neutral', 'score': 0.8064737915992737},
#  {'label': 'neutral', 'score': 0.8461759090423584},
#  {'label': 'neutral', 'score': 0.5292285680770874},
#  {'label': 'neutral', 'score': 0.50328129529953},
#  {'label': 'neutral', 'score': 0.632514238357544},
#  {'label': 'disgust', 'score': 0.6341574788093567},
#  {'label': 'disgust', 'score': 0.35472726821899414},
#  {'label': 'neutral', 'score': 0.7187138199806213},
#  {'label': 'neutral', 'score': 0.7863340973854065},
#  {'label': 'neutral', 'score': 0.49310508370399475},
#  {'label': 'joy', 'score': 0.979759156703949},
#  {'label': 'joy', 'score': 0.9522721171379089},
#  {'label': 'sadness', 'score': 0.5093205571174622},
#  {'label': 'neutral', 'score': 0.7701136469841003},
#  {'label': 'fear', 'score': 0.5833179354667664},
#  {'label': 'neutral', 'score': 0.8509349822998047},
#  {'label': 'neutral', 'score': 0.9100550413131714},
#  {'label': 'neutral', 'score': 0.632514238357544},
#  {'label': 'fear', 'score': 0.9868567585945129},
#  {'label': 'sadness', 'score': 0.7998872399330139},
#  {'label': 'joy', 'score': 0.9048558473587036},
#  {'label': 'neutral', 'score': 0.4903774857521057},
#  {'label': 'fear', 'score': 0.9781980514526367},
#  {'label': 'fear', 'score': 0.8286817073822021},
#  {'label': 'joy', 'score': 0.7563745379447937},
#  {'label': 'neutral', 'score': 0.632514238357544},
#  {'label': 'joy', 'score': 0.679806649684906},
#  {'label': 'neutral', 'score': 0.597821056842804},
#  {'label': 'neutral', 'score': 0.632514238357544},
#  {'label': 'disgust', 'score': 0.39992475509643555},
#  {'label': 'sadness', 'score': 0.48027560114860535},
#  {'label': 'joy', 'score': 0.8828936219215393},
#  {'label': 'surprise', 'score': 0.9691253900527954},
#  {'label': 'neutral', 'score': 0.9224861264228821},
#  {'label': 'joy', 'score': 0.3842982053756714},
#  {'label': 'anger', 'score': 0.5394340753555298},
#  {'label': 'neutral', 'score': 0.7824754118919373},
#  {'label': 'neutral', 'score': 0.9060007333755493},
#  {'label': 'fear', 'score': 0.978478193283081},
#  {'label': 'joy', 'score': 0.5484948754310608},
#  {'label': 'neutral', 'score': 0.5409254431724548},
#  {'label': 'disgust', 'score': 0.895708441734314},
#  {'label': 'neutral', 'score': 0.41322699189186096},
#  {'label': 'neutral', 'score': 0.4867773652076721},
#  {'label': 'neutral', 'score': 0.9342851042747498},
#  {'label': 'fear', 'score': 0.4583542048931122},
#  {'label': 'sadness', 'score': 0.8858485817909241},
#  {'label': 'neutral', 'score': 0.5145447254180908},
#  {'label': 'joy', 'score': 0.7703162431716919},
#  {'label': 'neutral', 'score': 0.23155981302261353},
#  {'label': 'neutral', 'score': 0.5214511156082153},
#  {'label': 'fear', 'score': 0.6670269966125488},
#  {'label': 'joy', 'score': 0.9530779719352722},
#  {'label': 'neutral', 'score': 0.8887121081352234},
#  {'label': 'joy', 'score': 0.8744420409202576},
#  {'label': 'neutral', 'score': 0.9244799613952637},
#  {'label': 'neutral', 'score': 0.6490814685821533},
#  {'label': 'anger', 'score': 0.2989466190338135},
#  {'label': 'disgust', 'score': 0.6617245674133301},
#  {'label': 'disgust', 'score': 0.9012651443481445},
#  {'label': 'sadness', 'score': 0.5473731756210327},
#  {'label': 'joy', 'score': 0.9832965135574341},
#  {'label': 'neutral', 'score': 0.4552454352378845},
#  {'label': 'neutral', 'score': 0.3273693025112152},
#  {'label': 'joy', 'score': 0.8592586517333984},
#  {'label': 'neutral', 'score': 0.45298629999160767},
#  {'label': 'neutral', 'score': 0.382631778717041},
#  {'label': 'neutral', 'score': 0.6920446157455444},
#  {'label': 'neutral', 'score': 0.46855610609054565},
#  {'label': 'neutral', 'score': 0.6995924115180969},
#  {'label': 'neutral', 'score': 0.7717480659484863},
#  {'label': 'disgust', 'score': 0.4791816771030426},
#  {'label': 'surprise', 'score': 0.9434762597084045},
#  {'label': 'sadness', 'score': 0.8926953077316284},
#  {'label': 'fear', 'score': 0.35874807834625244},
#  {'label': 'joy', 'score': 0.5580534338951111},
#  {'label': 'sadness', 'score': 0.8874913454055786},
#  {'label': 'neutral', 'score': 0.3485420346260071},
#  {'label': 'joy', 'score': 0.4969126582145691},
#  {'label': 'anger', 'score': 0.47976064682006836},
#  {'label': 'neutral', 'score': 0.6251662373542786},
#  {'label': 'neutral', 'score': 0.907874345779419},
#  {'label': 'neutral', 'score': 0.7943267822265625},
#  {'label': 'neutral', 'score': 0.6345788240432739},
#  {'label': 'neutral', 'score': 0.6545494198799133},
#  {'label': 'disgust', 'score': 0.9572467803955078},
#  {'label': 'sadness', 'score': 0.5088340640068054},
#  {'label': 'neutral', 'score': 0.8994907140731812},
#  {'label': 'disgust', 'score': 0.7106922268867493},
#  {'label': 'joy', 'score': 0.571448802947998},
#  {'label': 'neutral', 'score': 0.6666795015335083},
#  {'label': 'joy', 'score': 0.5196472406387329},
#  {'label': 'sadness', 'score': 0.5108510255813599},
#  {'label': 'neutral', 'score': 0.8949504494667053},
#  {'label': 'neutral', 'score': 0.6810237169265747},
#  {'label': 'neutral', 'score': 0.8257967829704285},
#  {'label': 'joy', 'score': 0.9204741716384888},
#  {'label': 'sadness', 'score': 0.9324296712875366},
#  {'label': 'joy', 'score': 0.9214110374450684},
#  {'label': 'sadness', 'score': 0.3314543664455414},
#  {'label': 'neutral', 'score': 0.7568200826644897},
#  {'label': 'sadness', 'score': 0.5104708671569824},
#  {'label': 'fear', 'score': 0.6258928775787354},
#  {'label': 'sadness', 'score': 0.8450825810432434},
#  {'label': 'disgust', 'score': 0.9867501854896545},
#  {'label': 'joy', 'score': 0.2840620279312134},
#  {'label': 'neutral', 'score': 0.5364874005317688},
#  {'label': 'neutral', 'score': 0.8298803567886353},
#  {'label': 'neutral', 'score': 0.7350811958312988},
#  {'label': 'joy', 'score': 0.6147463321685791},
#  {'label': 'sadness', 'score': 0.8138517737388611},
#  {'label': 'joy', 'score': 0.5680323243141174},
#  {'label': 'neutral', 'score': 0.7227295637130737},
#  {'label': 'neutral', 'score': 0.7518143057823181},
#  {'label': 'surprise', 'score': 0.5945366024971008},
#  {'label': 'neutral', 'score': 0.37663906812667847},
#  {'label': 'neutral', 'score': 0.8092660307884216},
#  {'label': 'anger', 'score': 0.554604709148407},
#  {'label': 'joy', 'score': 0.5117484927177429},
#  {'label': 'joy', 'score': 0.6082156896591187},
#  {'label': 'neutral', 'score': 0.7077013254165649},
#  {'label': 'neutral', 'score': 0.8602045178413391},
#  {'label': 'sadness', 'score': 0.5033491849899292},
#  {'label': 'disgust', 'score': 0.49217939376831055},
#  {'label': 'neutral', 'score': 0.632514238357544},
#  {'label': 'neutral', 'score': 0.6323013305664062},
#  {'label': 'sadness', 'score': 0.6810830235481262},
#  {'label': 'sadness', 'score': 0.9185727834701538},
#  {'label': 'fear', 'score': 0.3846587836742401},
#  {'label': 'neutral', 'score': 0.6870602369308472},
#  {'label': 'disgust', 'score': 0.46997514367103577},
#  {'label': 'sadness', 'score': 0.44232532382011414},
#  {'label': 'neutral', 'score': 0.9480749368667603},
#  {'label': 'sadness', 'score': 0.5321344137191772},
#  {'label': 'fear', 'score': 0.2800084054470062},
#  {'label': 'neutral', 'score': 0.911198079586029},
#  {'label': 'neutral', 'score': 0.6849175095558167},
#  {'label': 'neutral', 'score': 0.3516572415828705},
#  {'label': 'neutral', 'score': 0.6267417073249817},
#  {'label': 'disgust', 'score': 0.5423840880393982},
#  {'label': 'joy', 'score': 0.5532535910606384},
#  {'label': 'neutral', 'score': 0.4188404977321625},
#  {'label': 'surprise', 'score': 0.738959550857544},
#  {'label': 'anger', 'score': 0.850460946559906},
#  {'label': 'disgust', 'score': 0.6005167961120605},
#  {'label': 'anger', 'score': 0.384127676486969},
#  {'label': 'neutral', 'score': 0.452836275100708},
#  {'label': 'disgust', 'score': 0.6905576586723328},
#  {'label': 'neutral', 'score': 0.8285258412361145},
#  {'label': 'joy', 'score': 0.2840620279312134},
#  {'label': 'neutral', 'score': 0.36281493306159973},
#  {'label': 'neutral', 'score': 0.6278233528137207},
#  {'label': 'joy', 'score': 0.3510822653770447},
#  {'label': 'neutral', 'score': 0.47146591544151306},
#  {'label': 'neutral', 'score': 0.4861014485359192},
#  {'label': 'sadness', 'score': 0.9337731599807739},
#  {'label': 'neutral', 'score': 0.5909700393676758},
#  {'label': 'joy', 'score': 0.6075000166893005},
#  {'label': 'sadness', 'score': 0.42424285411834717},
#  {'label': 'joy', 'score': 0.8557749390602112},
#  {'label': 'joy', 'score': 0.9290928840637207},
#  {'label': 'joy', 'score': 0.955528974533081},
#  {'label': 'joy', 'score': 0.9543930292129517},
#  {'label': 'sadness', 'score': 0.7924038767814636},
#  {'label': 'neutral', 'score': 0.7076449394226074},
#  {'label': 'disgust', 'score': 0.6045674085617065},
#  {'label': 'fear', 'score': 0.5726385712623596},
#  {'label': 'disgust', 'score': 0.8466284275054932},
#  {'label': 'neutral', 'score': 0.6704328060150146},
#  {'label': 'neutral', 'score': 0.6650971174240112},
#  {'label': 'disgust', 'score': 0.963945209980011},
#  {'label': 'neutral', 'score': 0.8679571747779846},
#  {'label': 'neutral', 'score': 0.6430800557136536},
#  {'label': 'anger', 'score': 0.5705661773681641},
#  {'label': 'neutral', 'score': 0.7410889863967896},
#  {'label': 'neutral', 'score': 0.7410889863967896},
#  {'label': 'neutral', 'score': 0.790945827960968},
#  {'label': 'anger', 'score': 0.6377116441726685},
#  {'label': 'neutral', 'score': 0.861823558807373},
#  {'label': 'neutral', 'score': 0.7368530035018921},
#  {'label': 'neutral', 'score': 0.9093145728111267},
#  {'label': 'neutral', 'score': 0.5529412627220154},
#  {'label': 'neutral', 'score': 0.6109333038330078},
#  {'label': 'anger', 'score': 0.42232733964920044},
#  {'label': 'disgust', 'score': 0.5022072196006775},
#  {'label': 'neutral', 'score': 0.8118348121643066},
#  {'label': 'sadness', 'score': 0.6145585179328918},
#  {'label': 'disgust', 'score': 0.639032244682312},
#  {'label': 'neutral', 'score': 0.7975298762321472},
#  {'label': 'neutral', 'score': 0.674242377281189},
#  {'label': 'sadness', 'score': 0.5984033346176147},
#  {'label': 'fear', 'score': 0.37103092670440674},
#  {'label': 'sadness', 'score': 0.755702018737793},
#  {'label': 'fear', 'score': 0.44726666808128357},
#  {'label': 'neutral', 'score': 0.43133628368377686},
#  {'label': 'neutral', 'score': 0.5938199162483215},
#  {'label': 'disgust', 'score': 0.5481770038604736},
#  {'label': 'anger', 'score': 0.5093229413032532},
#  {'label': 'neutral', 'score': 0.4238383173942566},
#  {'label': 'disgust', 'score': 0.4672980308532715},
#  {'label': 'disgust', 'score': 0.4863901734352112},
#  {'label': 'sadness', 'score': 0.4068540036678314},
#  {'label': 'joy', 'score': 0.4969126582145691},
#  {'label': 'neutral', 'score': 0.3916991949081421},
#  {'label': 'sadness', 'score': 0.37434810400009155},
#  {'label': 'joy', 'score': 0.2840620279312134},
#  {'label': 'sadness', 'score': 0.4364875555038452},
#  {'label': 'neutral', 'score': 0.733242928981781},
#  {'label': 'neutral', 'score': 0.89628666639328},
#  {'label': 'neutral', 'score': 0.8414798974990845},
#  {'label': 'disgust', 'score': 0.2784825265407562},
#  {'label': 'sadness', 'score': 0.5108510255813599},
#  {'label': 'sadness', 'score': 0.6694493889808655},
#  {'label': 'joy', 'score': 0.7130101323127747},
#  {'label': 'neutral', 'score': 0.5728421211242676},
#  {'label': 'neutral', 'score': 0.7410889863967896},
#  {'label': 'neutral', 'score': 0.9026544690132141},
#  {'label': 'sadness', 'score': 0.8975105881690979},
#  {'label': 'neutral', 'score': 0.4513174593448639},
#  {'label': 'neutral', 'score': 0.7897547483444214},
#  {'label': 'sadness', 'score': 0.7227328419685364},
#  {'label': 'sadness', 'score': 0.8785272836685181},
#  {'label': 'neutral', 'score': 0.6064212322235107},
#  {'label': 'neutral', 'score': 0.6230501532554626},
#  {'label': 'anger', 'score': 0.5898059010505676},
#  {'label': 'neutral', 'score': 0.7004833817481995},
#  {'label': 'joy', 'score': 0.5196472406387329},
#  {'label': 'disgust', 'score': 0.7227141261100769},
#  {'label': 'fear', 'score': 0.8031576871871948},
#  {'label': 'neutral', 'score': 0.9296626448631287},
#  {'label': 'disgust', 'score': 0.5268041491508484},
#  {'label': 'neutral', 'score': 0.5015184283256531},
#  {'label': 'anger', 'score': 0.6128605008125305},
#  {'label': 'fear', 'score': 0.7360529899597168},
#  {'label': 'neutral', 'score': 0.6000525951385498},
#  {'label': 'neutral', 'score': 0.7255938649177551},
#  {'label': 'joy', 'score': 0.2840620279312134},
#  {'label': 'fear', 'score': 0.4583515524864197},
#  {'label': 'neutral', 'score': 0.43258973956108093},
#  {'label': 'neutral', 'score': 0.8291787505149841},
#  {'label': 'sadness', 'score': 0.9620054960250854},
#  {'label': 'joy', 'score': 0.9567710757255554},
#  {'label': 'joy', 'score': 0.9277120232582092},
#  {'label': 'sadness', 'score': 0.5465913414955139},
#  {'label': 'fear', 'score': 0.4364297688007355},
#  {'label': 'joy', 'score': 0.34966084361076355},
#  {'label': 'joy', 'score': 0.5861875414848328},
#  {'label': 'neutral', 'score': 0.7246472835540771},
#  {'label': 'neutral', 'score': 0.7410889863967896},
#  {'label': 'fear', 'score': 0.6580542325973511},
#  {'label': 'neutral', 'score': 0.4481968879699707},
#  {'label': 'neutral', 'score': 0.7292340397834778},
#  {'label': 'joy', 'score': 0.9533030390739441},
#  {'label': 'neutral', 'score': 0.6832054257392883},
#  {'label': 'disgust', 'score': 0.3457741439342499},
#  {'label': 'neutral', 'score': 0.8740228414535522},
#  {'label': 'disgust', 'score': 0.3457741439342499},
#  {'label': 'neutral', 'score': 0.7376347184181213},
#  {'label': 'disgust', 'score': 0.3457741439342499},
#  {'label': 'neutral', 'score': 0.8960472345352173},
#  {'label': 'disgust', 'score': 0.4144187569618225},
#  {'label': 'neutral', 'score': 0.632514238357544},
#  {'label': 'neutral', 'score': 0.632514238357544},
#  {'label': 'neutral', 'score': 0.9226788878440857},
#  {'label': 'fear', 'score': 0.3768500089645386},
#  {'label': 'neutral', 'score': 0.41592466831207275},
#  {'label': 'neutral', 'score': 0.48015356063842773},
#  {'label': 'neutral', 'score': 0.8174427151679993},
#  {'label': 'sadness', 'score': 0.9457854628562927},
#  {'label': 'neutral', 'score': 0.6852046251296997},
#  {'label': 'disgust', 'score': 0.395022988319397},
#  {'label': 'neutral', 'score': 0.7635191679000854},
#  {'label': 'neutral', 'score': 0.8134706616401672},
#  {'label': 'joy', 'score': 0.9229259490966797},
#  {'label': 'neutral', 'score': 0.632514238357544},
#  {'label': 'neutral', 'score': 0.6570649147033691},
#  {'label': 'joy', 'score': 0.4620376527309418},
#  {'label': 'neutral', 'score': 0.919934868812561},
#  {'label': 'fear', 'score': 0.4484390616416931},
#  {'label': 'anger', 'score': 0.7631051540374756},
#  {'label': 'disgust', 'score': 0.9674301147460938},
#  {'label': 'neutral', 'score': 0.6129665970802307},
#  {'label': 'neutral', 'score': 0.6470600962638855},
#  {'label': 'neutral', 'score': 0.39664366841316223},
#  {'label': 'fear', 'score': 0.5295184254646301},
#  {'label': 'neutral', 'score': 0.8802921772003174},
#  {'label': 'sadness', 'score': 0.7952562570571899},
#  {'label': 'sadness', 'score': 0.5881907343864441},
#  {'label': 'disgust', 'score': 0.6104934811592102},
#  {'label': 'neutral', 'score': 0.6989728808403015},
#  {'label': 'joy', 'score': 0.8312596082687378},
#  {'label': 'neutral', 'score': 0.8924623727798462},
#  {'label': 'neutral', 'score': 0.4878515303134918},
#  {'label': 'joy', 'score': 0.7429249882698059},
#  {'label': 'neutral', 'score': 0.9092457890510559},
#  {'label': 'fear', 'score': 0.5586916208267212},
#  {'label': 'neutral', 'score': 0.5417531132698059},
#  {'label': 'sadness', 'score': 0.4510083794593811},
#  {'label': 'sadness', 'score': 0.43250858783721924},
#  {'label': 'sadness', 'score': 0.5234529972076416},
#  {'label': 'joy', 'score': 0.5830467939376831},
#  {'label': 'neutral', 'score': 0.39307793974876404},
#  {'label': 'disgust', 'score': 0.3669067919254303},
#  {'label': 'fear', 'score': 0.3318469226360321},
#  {'label': 'disgust', 'score': 0.7072359323501587},
#  {'label': 'disgust', 'score': 0.8016466498374939},
#  {'label': 'fear', 'score': 0.4968827962875366},
#  {'label': 'neutral', 'score': 0.8104289174079895},
#  {'label': 'sadness', 'score': 0.6469456553459167},
#  {'label': 'disgust', 'score': 0.8775978684425354},
#  {'label': 'neutral', 'score': 0.7366675138473511},
#  {'label': 'disgust', 'score': 0.7165441513061523},
#  {'label': 'neutral', 'score': 0.7846918106079102},
#  {'label': 'joy', 'score': 0.3694850504398346},
#  {'label': 'neutral', 'score': 0.6359968781471252},
#  {'label': 'neutral', 'score': 0.7255296111106873},
#  {'label': 'neutral', 'score': 0.7410889863967896},
#  {'label': 'joy', 'score': 0.9466286897659302},
#  {'label': 'disgust', 'score': 0.47227180004119873},
#  {'label': 'joy', 'score': 0.2840620279312134},
#  {'label': 'neutral', 'score': 0.8915791511535645},
#  {'label': 'disgust', 'score': 0.30885130167007446},
#  {'label': 'neutral', 'score': 0.8296230435371399},
#  {'label': 'fear', 'score': 0.7632176280021667},
#  {'label': 'sadness', 'score': 0.6134849786758423},
#  {'label': 'sadness', 'score': 0.4868645966053009},
#  {'label': 'anger', 'score': 0.47913283109664917},
#  {'label': 'surprise', 'score': 0.4257746934890747},
#  {'label': 'neutral', 'score': 0.7599733471870422},
#  {'label': 'joy', 'score': 0.9276163578033447},
#  {'label': 'sadness', 'score': 0.4404025971889496},
#  {'label': 'joy', 'score': 0.48446783423423767},
#  {'label': 'neutral', 'score': 0.878486156463623},
#  {'label': 'disgust', 'score': 0.8540452122688293},
#  {'label': 'disgust', 'score': 0.9754359722137451},
#  {'label': 'joy', 'score': 0.8836454749107361},
#  {'label': 'disgust', 'score': 0.8005203604698181},
#  {'label': 'joy', 'score': 0.9185701012611389},
#  {'label': 'joy', 'score': 0.5686274170875549},
#  {'label': 'disgust', 'score': 0.7326703667640686},
#  {'label': 'fear', 'score': 0.5485345125198364},
#  {'label': 'neutral', 'score': 0.4052838385105133},
#  {'label': 'neutral', 'score': 0.6830146312713623},
#  {'label': 'sadness', 'score': 0.6657273769378662},
#  {'label': 'disgust', 'score': 0.8551087975502014},
#  {'label': 'neutral', 'score': 0.7523908615112305},
#  {'label': 'joy', 'score': 0.7137572765350342},
#  {'label': 'disgust', 'score': 0.32747697830200195},
#  {'label': 'neutral', 'score': 0.45758703351020813},
#  {'label': 'sadness', 'score': 0.491243451833725},
#  {'label': 'sadness', 'score': 0.3487633466720581},
#  {'label': 'sadness', 'score': 0.3768639862537384},
#  {'label': 'neutral', 'score': 0.7410889863967896},
#  {'label': 'disgust', 'score': 0.9624442458152771},
#  {'label': 'disgust', 'score': 0.5148428678512573},
#  {'label': 'neutral', 'score': 0.4677700996398926},
#  {'label': 'neutral', 'score': 0.4361284077167511},
#  {'label': 'neutral', 'score': 0.6639869809150696},
#  {'label': 'sadness', 'score': 0.5036523938179016},
#  {'label': 'neutral', 'score': 0.7937234044075012},
#  {'label': 'disgust', 'score': 0.8583820462226868},
#  {'label': 'neutral', 'score': 0.8465992212295532},
#  {'label': 'neutral', 'score': 0.6217570900917053},
#  {'label': 'disgust', 'score': 0.5638432502746582},
#  {'label': 'joy', 'score': 0.2840620279312134},
#  {'label': 'sadness', 'score': 0.45447206497192383},
#  {'label': 'neutral', 'score': 0.7240684032440186},
#  {'label': 'neutral', 'score': 0.9160740971565247},
#  {'label': 'neutral', 'score': 0.7692172527313232},
#  {'label': 'fear', 'score': 0.3433782756328583},
#  {'label': 'sadness', 'score': 0.4303891062736511},
#  {'label': 'fear', 'score': 0.3529268503189087},
#  {'label': 'joy', 'score': 0.2840620279312134},
#  {'label': 'neutral', 'score': 0.7311287522315979},
#  {'label': 'joy', 'score': 0.6824395060539246},
#  {'label': 'neutral', 'score': 0.6037307977676392},
#  {'label': 'joy', 'score': 0.32360413670539856},
#  {'label': 'sadness', 'score': 0.5856872200965881},
#  {'label': 'joy', 'score': 0.6761617660522461},
#  {'label': 'neutral', 'score': 0.43509405851364136},
#  {'label': 'sadness', 'score': 0.5775450468063354},
#  {'label': 'sadness', 'score': 0.8713380694389343},
#  {'label': 'sadness', 'score': 0.8360735774040222},
#  {'label': 'sadness', 'score': 0.6596463322639465},
#  {'label': 'neutral', 'score': 0.5990289449691772},
#  {'label': 'sadness', 'score': 0.883721113204956},
#  {'label': 'neutral', 'score': 0.6535961031913757},
#  {'label': 'neutral', 'score': 0.8708512783050537},
#  {'label': 'fear', 'score': 0.33734315633773804},
#  {'label': 'neutral', 'score': 0.598979651927948},
#  {'label': 'neutral', 'score': 0.631537139415741},
#  {'label': 'neutral', 'score': 0.631537139415741},
#  {'label': 'neutral', 'score': 0.6332051157951355},
#  {'label': 'joy', 'score': 0.8195319771766663},
#  {'label': 'anger', 'score': 0.9123998880386353},
#  {'label': 'disgust', 'score': 0.6227725148200989},
#  {'label': 'fear', 'score': 0.7542207837104797},
#  {'label': 'joy', 'score': 0.9662129878997803},
#  {'label': 'disgust', 'score': 0.5231348872184753},
#  {'label': 'anger', 'score': 0.33899539709091187},
#  {'label': 'neutral', 'score': 0.830172061920166},
#  {'label': 'joy', 'score': 0.8961927890777588},
#  {'label': 'neutral', 'score': 0.49310508370399475},
#  {'label': 'fear', 'score': 0.6151880025863647},
#  {'label': 'neutral', 'score': 0.8291787505149841},
#  {'label': 'sadness', 'score': 0.6719523072242737},
#  {'label': 'fear', 'score': 0.28654947876930237},
#  {'label': 'neutral', 'score': 0.742476761341095},
#  {'label': 'neutral', 'score': 0.8433248400688171},
#  {'label': 'joy', 'score': 0.6569864749908447},
#  {'label': 'joy', 'score': 0.9519391655921936},
#  {'label': 'joy', 'score': 0.9143895506858826},
#  {'label': 'neutral', 'score': 0.848325252532959},
#  {'label': 'disgust', 'score': 0.46663838624954224},
#  {'label': 'joy', 'score': 0.9532655477523804},
#  {'label': 'sadness', 'score': 0.7596533894538879},
#  {'label': 'joy', 'score': 0.7909072041511536},
#  {'label': 'neutral', 'score': 0.6032523512840271},
#  {'label': 'joy', 'score': 0.8423699736595154},
#  {'label': 'joy', 'score': 0.9839714765548706},
#  {'label': 'neutral', 'score': 0.8298803567886353},
#  {'label': 'joy', 'score': 0.7429249882698059},
#  {'label': 'neutral', 'score': 0.8335870504379272},
#  {'label': 'disgust', 'score': 0.9634956121444702},
#  {'label': 'neutral', 'score': 0.8920864462852478},
#  {'label': 'joy', 'score': 0.5633646845817566},
#  {'label': 'joy', 'score': 0.9480363726615906},
#  {'label': 'neutral', 'score': 0.632514238357544},
#  {'label': 'neutral', 'score': 0.7410889863967896},
#  {'label': 'neutral', 'score': 0.5590269565582275},
#  {'label': 'neutral', 'score': 0.731522798538208},
#  {'label': 'anger', 'score': 0.35402607917785645},
#  {'label': 'neutral', 'score': 0.6773577928543091},
#  {'label': 'neutral', 'score': 0.632514238357544},
#  {'label': 'neutral', 'score': 0.632514238357544},
#  {'label': 'neutral', 'score': 0.632514238357544},
#  {'label': 'fear', 'score': 0.2929694652557373},
#  {'label': 'neutral', 'score': 0.49310508370399475},
#  {'label': 'neutral', 'score': 0.6250438094139099},
#  {'label': 'neutral', 'score': 0.632514238357544},
#  {'label': 'neutral', 'score': 0.7497259974479675},
#  {'label': 'neutral', 'score': 0.632514238357544},
#  {'label': 'joy', 'score': 0.5984039306640625},
#  {'label': 'neutral', 'score': 0.6250438094139099},
#  {'label': 'joy', 'score': 0.2840620279312134},
#  {'label': 'disgust', 'score': 0.8020986318588257},
#  {'label': 'anger', 'score': 0.7319835424423218},
#  {'label': 'neutral', 'score': 0.632514238357544},
#  {'label': 'neutral', 'score': 0.5409254431724548},
#  {'label': 'fear', 'score': 0.3932934105396271},
#  {'label': 'neutral', 'score': 0.6527429223060608},
#  {'label': 'neutral', 'score': 0.48426440358161926},
#  {'label': 'neutral', 'score': 0.4368235468864441},
#  {'label': 'neutral', 'score': 0.632514238357544},
#  {'label': 'neutral', 'score': 0.8804931640625},
#  {'label': 'neutral', 'score': 0.6399521827697754},
#  {'label': 'neutral', 'score': 0.7410889863967896},
#  {'label': 'joy', 'score': 0.2840620279312134},
#  {'label': 'neutral', 'score': 0.6516730189323425},
#  {'label': 'neutral', 'score': 0.49804264307022095},
#  {'label': 'neutral', 'score': 0.632514238357544},
#  {'label': 'neutral', 'score': 0.8146529793739319},
#  {'label': 'neutral', 'score': 0.7482782602310181},
#  {'label': 'sadness', 'score': 0.3915451467037201},
#  {'label': 'neutral', 'score': 0.5494670271873474},
#  {'label': 'neutral', 'score': 0.4911819100379944},
#  {'label': 'fear', 'score': 0.7951744794845581},
#  {'label': 'fear', 'score': 0.6378005146980286},
#  {'label': 'anger', 'score': 0.9228695034980774},
#  {'label': 'sadness', 'score': 0.8063405752182007},
#  {'label': 'fear', 'score': 0.6143547892570496},
#  {'label': 'joy', 'score': 0.5196472406387329},
#  {'label': 'sadness', 'score': 0.37473660707473755},
#  {'label': 'fear', 'score': 0.31923094391822815},
#  {'label': 'neutral', 'score': 0.6797284483909607},
#  {'label': 'sadness', 'score': 0.6182575225830078},
#  {'label': 'neutral', 'score': 0.4267504811286926},
#  {'label': 'neutral', 'score': 0.3247489333152771},
#  {'label': 'neutral', 'score': 0.43578553199768066},
#  {'label': 'joy', 'score': 0.9277120232582092},
#  {'label': 'neutral', 'score': 0.6752687096595764},
#  {'label': 'neutral', 'score': 0.40345919132232666},
#  {'label': 'joy', 'score': 0.9175027012825012},
#  {'label': 'neutral', 'score': 0.9055707454681396},
#  {'label': 'neutral', 'score': 0.8057858943939209},
#  {'label': 'neutral', 'score': 0.8269491195678711},
#  {'label': 'sadness', 'score': 0.2834392189979553},
#  {'label': 'joy', 'score': 0.7776004076004028},
#  {'label': 'joy', 'score': 0.5354229807853699},
#  {'label': 'neutral', 'score': 0.5453646779060364},
#  {'label': 'anger', 'score': 0.35316506028175354},
#  {'label': 'neutral', 'score': 0.4884556829929352},
#  ...]

# %%
sentiments = []
scores = []

for rev_sent in review_sentiments:
    sentiments.append(rev_sent['label'])
    scores.append(rev_sent['score'])

# %%
df['sentiment'] = sentiments
df['scores'] = scores

# %%
df.head()
# Out:
#    rating                                             review sentiment  \
# 0       5                                               nice   neutral
# 1       5  best biryani , so supportive staff of outlet ,...   neutral
# 2       4     delivery boy was very decent and supportive.👌👍       joy
# 3       1  worst biryani i have tasted in my life, half o...   disgust
# 4       5  all food is good and tasty . will order again ...       joy
#
#      scores
# 0  0.741089
# 1  0.289043
# 2  0.590788
# 3  0.938918
# 4  0.775059

# %%
# the count of rows where we have a rating of 5 but our sentiment analysis isn't joy
df[(df['rating']==5) & (df['sentiment']!='joy')]['rating'].count()
# Out:
# 1776

# %%
# the count of rows where we have a rating of 5 and our sentiment analysis is joy
df[(df['rating']==5) & (df['sentiment']=='joy')]['rating'].count()
# Out:
# 512

# %%
df[df['rating']==5]['rating'].count()
# Out:
# 2288

# %%
# as we can see above only 512 of our 1776 results are marked as joy which is quite low
df[(df['rating']==5) & (df['sentiment']!='joy')].head(20)
# Out:
#     rating                                             review sentiment  \
# 0        5                                               nice   neutral
# 1        5  best biryani , so supportive staff of outlet ,...   neutral
# 6        5         overall good experience . will order again   neutral
# 8        5          tasty food . homestyle tasty prepration.    neutral
# 20       5  tasteis best , zabardast mouthwatering . must ...      fear
# 23       5           bawarchi satisfied there customer needs🤩   neutral
# 24       5             Too Helping nature of resturent owners   neutral
# 25       5  i have tried many items from bawarchi , these ...   sadness
# 29       5  Free pizza was not given to me. Pizza hut does...   neutral
# 35       5  Very bad. Waste of money Pizza Hut no more lik...   disgust
# 36       5              pizza got cold........waste of money      anger
# 37       5                                       rotten pizza   disgust
# 43       5  Pizza hut vari bad bro😡😡😡😡😡<br/>All pablik piz...   sadness
# 53       5                                There is no ketchup   neutral
# 61       5  HAD GIVEN VERY VERY VERY VERY LESS CHILLI FLAK...   neutral
# 67       5                                          good test   neutral
# 73       5                                       Quality food   neutral
# 76       5                                                  😊   neutral
# 77       5                           Pepsi not available why?  surprise
# 78       5                         worst just wasted my money   disgust
#
#       scores
# 0   0.741089
# 1   0.289043
# 6   0.788057
# 8   0.548458
# 20  0.371340
# 23  0.482653
# 24  0.414461
# 25  0.234048
# 29  0.482814
# 35  0.800306
# 36  0.461766
# 37  0.427300
# 43  0.771120
# 53  0.896802
# 61  0.822166
# 67  0.767116
# 73  0.828187
# 76  0.802843
# 77  0.607972
# 78  0.707355

# %%
# the reason for the problematic findings like that is the randomly rated columns
# let's check these 2 rows

df.iloc[[35,36]]
# Out:
#     rating                                             review sentiment  \
# 35       5  Very bad. Waste of money Pizza Hut no more lik...   disgust
# 36       5              pizza got cold........waste of money      anger
#
#       scores
# 35  0.800306
# 36  0.461766

# %%
# these 2 rows above obviously are negative results and sentiment analysis results 
# are also showing that finding

# %%
# THE TAKEAWAY IS WE CAN NOT TRUST MERE RATINGS FROM THE USERS AND WE ALSO NEED TO CHECK 
# WHAT THEY REALLY MEANT IF THEY PROVIDED A COMMENT :D
