# %% [markdown]
# # Predicting the Dow Jones with News

# %% [markdown]
# ## General Data flow for a Text Related Business Problem

# %% [markdown]
# # Problem Statement & Reference Architecture
#
# * **Aim**: Use Reddit News Headlines to predict the movement of Dow Jones Industrial Average.
#
#
# * **Data Source**: https://www.kaggle.com/aaron7sun/stocknews
#
#
# * **Data Description**: Dow Jones details on Open, High, Low and Close for each day from 2008-08-08 to 2016-07-01 and headlines for those dates from Reddit News.
#
#
# * **Methodology**: For this project, we will use GloVe to create our word embeddings and CNNs followed by LSTMs to build our model. This model is based off the work done in this paper https://www.aclweb.org/anthology/C/C16/C16-1229.pdf.

# %% [markdown]
# # Installation Prerequisites

# %%
# !apt-get update  && apt-get install -y --allow-downgrades --no-install-recommends git wget

# %%
# !apt-get -y install graphviz

# %%
# !pip install nltk keras

# %%
# !pip install pydot

# %%
# !pip install graphviz

# %%
# !wget http://nlp.stanford.edu/data/glove.840B.300d.zip
# Out:
# --2024-11-10 12:25:14--  http://nlp.stanford.edu/data/glove.840B.300d.zip
# Resolving nlp.stanford.edu (nlp.stanford.edu)... 171.64.67.140
# Connecting to nlp.stanford.edu (nlp.stanford.edu)|171.64.67.140|:80... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://nlp.stanford.edu/data/glove.840B.300d.zip [following]
# --2024-11-10 12:25:14--  https://nlp.stanford.edu/data/glove.840B.300d.zip
# Connecting to nlp.stanford.edu (nlp.stanford.edu)|171.64.67.140|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://downloads.cs.stanford.edu/nlp/data/glove.840B.300d.zip [following]
# --2024-11-10 12:25:14--  https://downloads.cs.stanford.edu/nlp/data/glove.840B.300d.zip
# Resolving downloads.cs.stanford.edu (downloads.cs.stanford.edu)... 171.64.64.22
# Connecting to downloads.cs.stanford.edu (downloads.cs.stanford.edu)|171.64.64.22|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2176768927 (2.0G) [application/zip]
# Saving to: ‘glove.840B.300d.zip’
#
# glove.840B.300d.zip 100%[===================>]   2.03G  5.00MB/s    in 6m 50s
#
# 2024-11-10 12:32:04 (5.06 MB/s) - ‘glove.840B.300d.zip’ saved [2176768927/2176768927]

# %%
# !unzip glove.840B.300d.zip
# Out:
# Archive:  glove.840B.300d.zip
#   inflating: glove.840B.300d.txt

# %% [markdown]
# # Imports

# %%
import pandas as pd
import numpy as np
import tensorflow as tf
import re
import nltk
from nltk.corpus import stopwords
from sklearn.model_selection import train_test_split
from sklearn.metrics import median_absolute_error as mae
from sklearn.metrics import mean_squared_error as mse
import matplotlib.pyplot as plt

# %%
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %%
# # Keras Imports
# from keras.models import Sequential
# from keras import initializers
# from keras.layers import Dropout, Activation, Embedding, Convolution1D, MaxPooling1D, Input, Dense, add, \
#                          BatchNormalization, Flatten, Reshape, Concatenate
# from keras.layers.recurrent import LSTM, GRU
# from keras.callbacks import Callback, ModelCheckpoint, EarlyStopping, ReduceLROnPlateau
# from keras.models import Model
# from keras.optimizers import Adam, SGD, RMSprop
# from keras import regularizers
# from keras.utils.vis_utils import plot_model
# import re

# %%
# Keras Imports
from keras.models import Sequential
from keras import initializers
from keras.layers import Dropout, Activation, Embedding, Convolution1D, MaxPooling1D, Input, Dense, add, \
                         BatchNormalization, Flatten, Reshape, Concatenate, LSTM, GRU # Import LSTM and GRU directly from keras.layers
from keras.callbacks import Callback, ModelCheckpoint, EarlyStopping, ReduceLROnPlateau
from keras.models import Model
from keras.optimizers import Adam, SGD, RMSprop
from keras import regularizers
import tensorflow as tf # Import tensorflow
from tensorflow.keras.utils import plot_model # Import plot_model from the new location
import re

# %%
#!/bin/bash
# !kaggle datasets download lykin22/stock-headlines
# !kaggle datasets download aaron7sun/stocknews
# Out:
# Dataset URL: https://www.kaggle.com/datasets/aaron7sun/stocknews
# License(s): CC-BY-NC-SA-4.0
# Downloading stocknews.zip to /content
#   0% 0.00/5.82M [00:00<?, ?B/s]
# 100% 5.82M/5.82M [00:00<00:00, 89.0MB/s]

# %%
# !unzip stocknews.zip
# Out:
# Archive:  stocknews.zip
#   inflating: Combined_News_DJIA.csv
#   inflating: RedditNews.csv
#   inflating: upload_DJIA_table.csv

# %%
# dj = pd.read_csv("dowjones-news-data/DowJones.csv")
# news = pd.read_csv("dowjones-news-data/News.csv")

dj = pd.read_csv("upload_DJIA_table.csv")
news = pd.read_csv("RedditNews.csv", encoding='latin-1')

# %% [markdown]
# ## Inspect the data

# %%
dj.head()
# Out:
#          Date          Open          High           Low         Close  \
# 0  2016-07-01  17924.240234  18002.380859  17916.910156  17949.369141
# 1  2016-06-30  17712.759766  17930.609375  17711.800781  17929.990234
# 2  2016-06-29  17456.019531  17704.509766  17456.019531  17694.679688
# 3  2016-06-28  17190.509766  17409.720703  17190.509766  17409.720703
# 4  2016-06-27  17355.210938  17355.210938  17063.080078  17140.240234
#
#       Volume     Adj Close
# 0   82160000  17949.369141
# 1  133030000  17929.990234
# 2  106380000  17694.679688
# 3  112190000  17409.720703
# 4  138740000  17140.240234

# %%
dj.isnull().sum() #No missing data
# Out:
# Date         0
# Open         0
# High         0
# Low          0
# Close        0
# Volume       0
# Adj Close    0
# dtype: int64

# %%
news.isnull().sum() #No missing data
# Out:
# Date    0
# News    0
# dtype: int64

# %%
news.head(2)
# Out:
#          Date                                               News
# 0  2016-07-01  A 117-year-old woman in Mexico City finally re...
# 1  2016-07-01   IMF chief backs Athens as permanent Olympic host

# %%
# Convert 'Date' column to datetime objects
dj['Date'] = pd.to_datetime(dj['Date'])
news['Date'] = pd.to_datetime(news['Date'])

# %%
print(dj.shape)
print(news.shape)
# Out:
# (1989, 7)
# (73608, 2)

# %%
# Compare the number of unique dates. We want matching values.
print(len(set(dj.Date)))
print(len(set(news.Date)))
# Out:
# 1989
# 2943

# %%
# Remove the extra dates that are in news
news = news[news.Date.isin(dj.Date)]

# %%
print(len(set(dj.Date)))
print(len(set(news.Date)))
# Out:
# 1989
# 1989

# %%
dj.columns
# Out:
# Index(['Date', 'Open', 'High', 'Low', 'Close', 'Volume', 'Adj Close'], dtype='object')

# %%
# Convert 'Open' column to numeric, coercing errors to NaN
# dj['Open'] = pd.to_numeric(pd.to_numeric(dj['Open'].str.replace(',',''), errors='coerce'), errors='coerce')

# %%
dj.columns
# Out:
# Index(['Date', 'Open', 'High', 'Low', 'Close', 'Volume', 'Adj Close'], dtype='object')

# %%
# Remove unwanted features - keep the 'Open' price only
dj = dj.drop(['High', 'Low', 'Close', 'Volume', 'Adj Close'], axis=1) # Replace 1 with axis=1 or columns=
dj.head()
# Out:
#         Date          Open
# 0 2016-07-01  17924.240234
# 1 2016-06-30  17712.759766
# 2 2016-06-29  17456.019531
# 3 2016-06-28  17190.509766
# 4 2016-06-27  17355.210938

# %%
# Calculate the difference in opening prices between the following and current day.
# The model will try to predict the change in Open value based on the today's news.
dj = dj.set_index('Date')
dj.head()
# Out:
#                     Open
# Date
# 2016-07-01  17924.240234
# 2016-06-30  17712.759766
# 2016-06-29  17456.019531
# 2016-06-28  17190.509766
# 2016-06-27  17355.210938

# %%
# Target variable = Tomorrow's Open Price - Today's Open Price
dj = -1 * dj.diff(periods=1)

# %%
dj
# Out:
#                   Open
# Date
# 2016-07-01         NaN
# 2016-06-30  211.480468
# 2016-06-29  256.740235
# 2016-06-28  265.509765
# 2016-06-27 -164.701172
# ...                ...
# 2008-08-14   79.139649
# 2008-08-13 -100.739258
# 2008-08-12 -148.890625
# 2008-08-11   52.030273
# 2008-08-08  297.580078
#
# [1989 rows x 1 columns]

# %%
# Remove top row since it has a null value.
dj = dj[dj.Open.notnull()]

# %%
# Check if there are any more null values.
dj.isnull().sum()
# Out:
# Open    0
# dtype: int64

# %% [markdown]
# ## Combine the two datasets - For each date, get all the headlines and the price

# %%
dj.reset_index(inplace=True)

# %%
# Create a list of the opening prices and their corresponding daily headlines from the news
# Define/Initialize the variables
price = []
headlines = []

# For all the rows in the dataframe
for row in dj.iterrows():
    # define a new variable to store all the headlines for the day
    daily_headlines = []
    # Spot the date in the given row
    date = row[1]['Date']
    # Store the price for the date
    price.append(row[1]['Open'])
    for row_ in news[news.Date==date].iterrows():
        daily_headlines.append(row_[1]['News'])

    # Append the headlines for the date
    headlines.append(daily_headlines)
    # Track progress
    if len(price) % 500 == 0:
        print(len(price))
# Out:
# 500
# 1000
# 1500

# %% [markdown]
# <table size="100">
#     <tr>
#         <td>headlines</td>
#         <td>price</td>
#     </tr>
#     <tr>
#         <td>headline-1, headline-2 ..., headline-n</td>
#         <td>211.48</td>
#     </tr>
# </table>

# %%
news
# Out:
#             Date                                               News
# 0     2016-07-01  A 117-year-old woman in Mexico City finally re...
# 1     2016-07-01   IMF chief backs Athens as permanent Olympic host
# 2     2016-07-01  The president of France says if Brexit won, so...
# 3     2016-07-01  British Man Who Must Give Police 24 Hours' Not...
# 4     2016-07-01  100+ Nobel laureates urge Greenpeace to stop o...
# ...          ...                                                ...
# 72078 2008-08-08  b'Why the Pentagon Thinks Attacking Iran is a ...
# 72079 2008-08-08  b'Caucasus in crisis: Georgia invades South Os...
# 72080 2008-08-08  b'Indian shoe manufactory  - And again in a se...
# 72081 2008-08-08  b'Visitors Suffering from Mental Illnesses Ban...
# 72082 2008-08-08           b"No Help for Mexico's Kidnapping Surge"
#
# [49718 rows x 2 columns]

# %%
# Check how headlines look like
headlines[:3], price[:3]
# Out:
# ([['Jamaica proposes marijuana dispensers for tourists at airports following legalisation: The kiosks and desks would give people a license to purchase up to 2 ounces of the drug to use during their stay',
#    "Stephen Hawking says pollution and 'stupidity' still biggest threats to mankind: we have certainly not become less greedy or less stupid in our treatment of the environment over the past decade",
#    'Boris Johnson says he will not run for Tory party leadership',
#    'Six gay men in Ivory Coast were abused and forced to flee their homes after they were pictured signing a condolence book for victims of the recent attack on a gay nightclub in Florida',
#    'Switzerland denies citizenship to Muslim immigrant girls who refused to swim with boys: report',
#    'Palestinian terrorist stabs israeli teen girl to death in her bedroom',
#    'Puerto Rico will default on $1 billion of debt on Friday',
#    'Republic of Ireland fans to be awarded medal for sportsmanship by Paris mayor.',
#    "Afghan suicide bomber 'kills up to 40' - BBC News",
#    'US airstrikes kill at least 250 ISIS fighters in convoy outside Fallujah, official says',
#    'Turkish Cop Who Took Down Istanbul Gunman Hailed a Hero',
#    "Cannabis compounds could treat Alzheimer's by removing plaque-forming proteins from brain cells, research suggests",
#    "Japan's top court has approved blanket surveillance of the country's Muslims: 'They made us terrorist suspects, we never did anything wrong,' says Japanese Muslim, Mohammed Fujita",
#    'CIA Gave Romania Millions to Host Secret Prisons',
#    'Groups urge U.N. to suspend Saudi Arabia from rights council',
#    'Googles free wifi at Indian railway stations is better than most of the countrys paid services',
#    "Mounting evidence suggests 'hobbits' were wiped out by modern humans' ancestors 50,000 years ago.",
#    "The men who carried out Tuesday's terror attack at Istanbul's Ataturk Airport were from Russia, Uzbekistan and Kyrgyzstan, a Turkish offical said.",
#    'Calls to suspend Saudi Arabia from UN Human Rights Council because of military aggresion in Yemen',
#    'More Than 100 Nobel Laureates Call Out Greenpeace For Anti-GMO Obstruction In Developing World',
#    'British pedophile sentenced to 85 years in US for trafficking child abuse images: Domminich Shaw, a kingpin of sexual violence against children, sent dozens of images online and discussed plans to assault and kill a child while on probation',
#    'US permitted 1,200 offshore fracks in Gulf of Mexico between 2010 and 2014 and allowed 72 billion gallons of chemical discharge in 2014.',
#    'We will be swimming in ridicule - French beach police to carry guns while in swimming trunks: Police lifeguards on Frances busiest beaches will carry guns and bullet-proof vests for the first time this summer amid fears that terrorists could target holidaymakers.',
#    "UEFA says no minutes of silence for Istanbul victims at Euro 2016 because 'Turkey have already been eliminated'",
#    'Law Enforcement Sources: Gun Used in Paris Terrorist Attacks Came from Phoenix'],
#   ['Explosion At Airport In Istanbul',
#    'Yemeni former president: Terrorism is the offspring of Wahhabism of Al Saud regime',
#    'UK must accept freedom of movement to access EU Market',
#    'Devastated: scientists too late to captive breed mammal lost to climate change - Australian conservationists spent 5 months obtaining permissions &amp; planning for a captive breeding program. But when they arrived on the rodents tiny island, they they were too late.',
#    'British Labor Party leader Jeremy Corbyn loses a no-confidence vote but refuses to resign',
#    'A Muslim Shop in the UK Was Just Firebombed While People Were Inside',
#    'Mexican Authorities Sexually Torture Women in Prison',
#    'UK shares and pound continue to recover',
#    'Iceland historian Johannesson wins presidential election',
#    '99-Million-Yr-Old Bird Wings Found Encased in Amber - Finding things trapped in amber is far from rare. But when researchers in Burma found a pair of tiny bird-like wings frozen inside, they knew they had something special.',
#    'A chatbot programmed by a British teenager has successfully challenged 160,000 parking tickets since its launch last year.',
#    'The Philippine president-elect said Monday he would aggressively promote artificial birth control in the country even at the risk of getting in a fight with the dominant Catholic church, which staunchly opposes the use of contraceptives.',
#    'Former Belgian Prime Minister ridicules Nigel Farage and accuses Ukip leader of lying in EU referendum campaign',
#    "Brexiteer Nigel Farage To EU: 'You're Not Laughing Now, Are You?'",
#    'Islamic State bombings in southern Yemen kill 38 people',
#    'Escape Tunnel, Dug by Hand, Is Found at Holocaust Massacre Site',
#    'The land under Beijing is sinking by as much as four inches per year because of the overconsumption of groundwater, according to new research.',
#    'Car bomb and Anti-Islamic attack on Mosque in Perth, Australia',
#    'Emaciated lions in Taiz Zoo are trapped in blood-soaked cages and left to starve for months due to the Yemeni civil war',
#    "Rupert Murdoch describes Brexit as 'wonderful'. The media mogul likened leaving the EU to a prison break and shared his view of Donald Trump as a very able man.",
#    'More than 40 killed in Yemen suicide attacks',
#    "Google Found Disastrous Symantec and Norton Vulnerabilities That Are 'As Bad As It Gets",
#    'Extremist violence on the rise in Germany: Domestic intelligence agency says far-right, far-left and Islamist radical groups gaining membership in country',
#    'BBC News: Labour MPs pass Corbyn no-confidence motion',
#    "Tiny New Zealand town with 'too many jobs' launches drive to recruit outsiders"],
#   ['2,500 Scientists To Australia: If You Want To Save The Great Barrier Reef, Stop Supporting Coal',
#    'The personal details of 112,000 French police officers have been uploaded to Google Drive in a security breach just a fortnight after two officers were murdered at their home by a jihadist.',
#    "S&amp;P cuts United Kingdom sovereign credit rating to 'AA' from 'AAA'",
#    'Huge helium deposit found in Africa',
#    'CEO of the South African state broadcaster quits shortly after negative news about president is banned.',
#    'Brexit cost investors $2 trillion, the worst one day drop ever',
#    'Hong Kong democracy activists call for return to British rule as first step to independence',
#    "Brexit: Iceland president says UK can join 'triangle' of non-EU countries",
#    "UK's Osborne: 'Absolutely' going to have to cut spending, raise taxes",
#    "'Do not let Scotland down now' : Scottish MEP Alyn Smith has urged members of the European Parliament to stand by his country following the UK referendum on EU membership.",
#    'British pound could hit history-making dollar parity by end of 2016',
#    "Merkel vows to strengthen EU, tells UK no 'cherry-picking'",
#    '"Ryanair will not deploy new aircraft on routes to and from the UK [United Kingdom] next year [2017], following the Brexit vote, and will instead focus on the European Union [EU]."',
#    'People, ever more greedy and stupid, destroy the world - Stephen Hawking to Larry King',
#    'Siemens freezes new UK wind power investment following Brexit vote',
#    'US, Canada and Mexico pledge 50% of power from clean energy by 2025',
#    'There is increasing evidence that Australia is torturing refugees, medical experts claim',
#    'Richard Branson, the founder of Virgin Group, said Tuesday that the company has lost about a third of its value since the U.K. voted to leave the European Union last week.',
#    '37,000-yr-old skull from Borneo reveals surprise for scientists - Study of the "Deep Skull" - oldest modern human discovered in SE Asia - reveals this ancient person was not related to Indigenous Australians, as originally thought. "Our discovery is a game changer."',
#    'Palestinians stone Western Wall worshipers; police shut Temple Mount to non-Muslims',
#    'Jean-Claude Juncker asks Farage: Why are you here?',
#    '"Romanians for Remainians" offering a new home to the 48% of Britons who voted to stay in the EU | Bucharest newspaper\'s app connects loving Romanian families with needy Brits, allowing people to offer to help would-be immigrants apply for a Romanian ID',
#    'Brexit: Gibraltar in talks with Scotland to stay in EU',
#    '8 Suicide Bombers Strike Lebanon',
#    "Mexico's security forces routinely use 'sexual torture' against women: Rights group Amnesty International has compiled testimonies of sexual violence used as torture by Mexican security forces. Despite thousands of complaints, only 15 probes have led to criminal convictions since 1991."]],
#  [211.48046800000157, 256.7402349999975, 265.5097650000025])

# %% [markdown]
# ## Clean up the price list

# %%
price[:2]
# Out:
# [211.48046800000157, 256.7402349999975]

# %%
# Normalize opening prices (target values)
max_price = max(price)
min_price = min(price)
mean_price = np.mean(price)
def normalize(price):
    return ((price-min_price)/(max_price-min_price))

# %%
norm_price = []
for p in price:
    norm_price.append(normalize(p))

# %%
# Check that normalization worked well
print(min(norm_price))
print(max(norm_price))
print(np.mean(norm_price))
# Out:
# 0.0
# 1.0
# 0.4551577545098642

# %%
# Compare the number of headlines for each day
print(max(len(i) for i in headlines))
print(min(len(i) for i in headlines))
print(np.mean([len(i) for i in headlines]))
# Out:
# 25
# 22
# 24.996478873239436

# %%
norm_price[:2]
# Out:
# [0.5780280759194737, 0.6047364662478155]

# %% [markdown]
# ## Clean up the headlines list

# %%
# remove contractions
def decontracted(phrase):
    if "'" in phrase:
        # specific
        phrase = re.sub(r"won't", "will not", phrase)
        phrase = re.sub(r"can\'t", "can not", phrase)

        # general
        phrase = re.sub(r"n\'t", " not", phrase)
        phrase = re.sub(r"\'re", " are", phrase)
        phrase = re.sub(r"\'s", " is", phrase)
        phrase = re.sub(r"\'d", " would", phrase)
        phrase = re.sub(r"\'ll", " will", phrase)
        phrase = re.sub(r"\'t", " not", phrase)
        phrase = re.sub(r"\'ve", " have", phrase)
        phrase = re.sub(r"\'m", " am", phrase)
    return phrase

text = "I should've gone to dentist so my teeth wouldn't hurt"
text1 = "But I am good now"
print(decontracted(text))
print(decontracted(text1))
# Out:
# I should have gone to dentist so my teeth would not hurt
# But I am good now

# %%
def clean_text(text):
    '''Remove unwanted characters and format the text to create fewer nulls word embeddings'''

    # Convert words to lower case
    text = text.lower()

    # Replace contractions with their longer forms
    if True:
        text = text.split()
        new_text = []
        # Remove the contractions
        for word in text:
            new_text.append(decontracted(word))
        # Recreate the sentence
        text = " ".join(new_text)

    # Format words and remove unwanted characters
    text = re.sub(r'&amp;', '', text)
    text = re.sub(r'0,0', '00', text)
    text = re.sub(r'[_"\-;%()|.,+&=*%.,!?:#@\[\]]', ' ', text)
    text = re.sub(r'\'', ' ', text)
    text = re.sub(r'\$', ' $ ', text)
    text = re.sub(r'u s ', ' united states ', text)
    text = re.sub(r'u n ', ' united nations ', text)
    text = re.sub(r'u k ', ' united kingdom ', text)
    text = re.sub(r'j k ', ' jk ', text)
    text = re.sub(r' s ', ' ', text)
    text = re.sub(r' yr ', ' year ', text)
    text = re.sub(r' l g b t ', ' lgbt ', text)
    text = re.sub(r'0km ', '0 km ', text)

    # Remove stop words
    text = text.split()
    stops = set(stopwords.words("english"))
    text = [w for w in text if not w in stops]
    text = " ".join(text)

    return text

# %%
# Clean the headlines
clean_headlines = []

for daily_headlines in headlines:
    clean_daily_headlines = []
    for headline in daily_headlines:
        clean_daily_headlines.append(clean_text(headline))
    clean_headlines.append(clean_daily_headlines)

# %%
# Take a look at some headlines to ensure everything was cleaned well
clean_headlines[:2]
# Out:
# [['jamaica proposes marijuana dispensers tourists airports following legalisation kiosks desks would give people license purchase 2 ounces drug use stay',
#   'stephen hawking says pollution istupidity still biggest threats mankind certainly become less greedy less stupid treatment environment past decade',
#   'boris johnson says run tory party leadership',
#   'six gay men ivory coast abused forced flee homes pictured signing condolence book victims recent attack gay nightclub florida',
#   'switzerland denies citizenship muslim immigrant girls refused swim boys report',
#   'palestinian terrorist stabs israeli teen girl death bedroom',
#   'puerto rico default $ 1 billion debt friday',
#   'republic ireland fans awarded medal sportsmanship paris mayor',
#   'afghan suicide bomber kills 40 bbc news',
#   'us airstrikes kill least 250 isis fighters convoy outside fallujah official says',
#   'turkish cop took istanbul gunman hailed hero',
#   'cannabis compounds could treat alzheimer removing plaque forming proteins brain cells research suggests',
#   'japan top court approved blanket surveillance country muslims nothey made us terrorist suspects never anything wrong says japanese muslim mohammed fujita',
#   'cia gave romania millions host secret prisons',
#   'groups urge united nations suspend saudi arabia rights council',
#   'googles free wifi indian railway stations better countrys paid services',
#   'mounting evidence suggests hobbits wiped modern humans ancestors 50000 years ago',
#   'men carried tuesday terror attack istanbul ataturk airport russia uzbekistan kyrgyzstan turkish offical said',
#   'calls suspend saudi arabia un human rights council military aggresion yemen',
#   '100 nobel laureates call greenpeace anti gmo obstruction developing world',
#   'british pedophile sentenced 85 years us trafficking child abuse images domminich shaw kingpin sexual violence children sent dozens images online discussed plans assault kill child probation',
#   'us permitted 1 200 offshore fracks gulf mexico 2010 2014 allowed 72 billion gallons chemical discharge 2014',
#   'swimming ridicule french beach police carry guns swimming trunks police lifeguards frances busiest beaches carry guns bullet proof vests first time summer amid fears terrorists could target holidaymakers',
#   'uefa says minutes silence istanbul victims euro 2016 noturkey already eliminated',
#   'law enforcement sources gun used paris terrorist attacks came phoenix'],
#  ['explosion airport istanbul',
#   'yemeni former president terrorism offspring wahhabism al saud regime',
#   'uk must accept freedom movement access eu market',
#   'devastated scientists late captive breed mammal lost climate change australian conservationists spent 5 months obtaining permissions planning captive breeding program arrived rodents tiny island late',
#   'british labor party leader jeremy corbyn loses confidence vote refuses resign',
#   'muslim shop uk firebombed people inside',
#   'mexican authorities sexually torture women prison',
#   'uk shares pound continue recover',
#   'iceland historian johannesson wins presidential election',
#   '99 million year old bird wings found encased amber finding things trapped amber far rare researchers burma found pair tiny bird like wings frozen inside knew something special',
#   'chatbot programmed british teenager successfully challenged 160000 parking tickets since launch last year',
#   'philippine president elect said monday would aggressively promote artificial birth control country even risk getting fight dominant catholic church staunchly opposes use contraceptives',
#   'former belgian prime minister ridicules nigel farage accuses ukip leader lying eu referendum campaign',
#   'brexiteer nigel farage eu laughing',
#   'islamic state bombings southern yemen kill 38 people',
#   'escape tunnel dug hand found holocaust massacre site',
#   'land beijing sinking much four inches per year overconsumption groundwater according new research',
#   'car bomb anti islamic attack mosque perth australia',
#   'emaciated lions taiz zoo trapped blood soaked cages left starve months due yemeni civil war',
#   'rupert murdoch describes brexit wonderful media mogul likened leaving eu prison break shared view donald trump able man',
#   '40 killed yemen suicide attacks',
#   'google found disastrous symantec norton vulnerabilities bad gets',
#   'extremist violence rise germany domestic intelligence agency says far right far left islamist radical groups gaining membership country',
#   'bbc news labour mps pass corbyn confidence motion',
#   'tiny new zealand town notoo many jobs launches drive recruit outsiders']]

# %%
# prompt: unique words and number of times they occur in headlines

from collections import Counter

def unique_words_count(headlines):
  """
  Calculates the frequency of unique words in a list of headlines.

  Args:
    headlines: A list of strings, where each string is a headline.

  Returns:
    A Counter object where keys are unique words and values are their frequencies.
  """
  word_counts = Counter()
  for daily_headlines in headlines:
    for headline in daily_headlines:
      words = headline.split()
      word_counts.update(words)
  return word_counts

unique_word_counts = unique_words_count(clean_headlines)
unique_word_counts
# Out:
# Counter({'jamaica': 23,
#          'proposes': 65,
#          'marijuana': 216,
#          'dispensers': 1,
#          'tourists': 95,
#          'airports': 33,
#          'following': 219,
#          'legalisation': 4,
#          'kiosks': 2,
#          'desks': 1,
#          'would': 888,
#          'give': 289,
#          'people': 1887,
#          'license': 21,
#          'purchase': 26,
#          '2': 733,
#          'ounces': 2,
#          'drug': 648,
#          'use': 605,
#          'stay': 107,
#          'stephen': 59,
#          'hawking': 23,
#          'says': 2563,
#          'pollution': 135,
#          'istupidity': 2,
#          'still': 326,
#          'biggest': 331,
#          'threats': 118,
#          'mankind': 13,
#          'certainly': 12,
#          'become': 314,
#          'less': 204,
#          'greedy': 6,
#          'stupid': 27,
#          'treatment': 133,
#          'environment': 96,
#          'past': 242,
#          'decade': 109,
#          'boris': 23,
#          'johnson': 24,
#          'run': 291,
#          'tory': 24,
#          'party': 512,
#          'leadership': 54,
#          'six': 295,
#          'gay': 444,
#          'men': 520,
#          'ivory': 106,
#          'coast': 209,
#          'abused': 54,
#          'forced': 334,
#          'flee': 91,
#          'homes': 199,
#          'pictured': 4,
#          'signing': 23,
#          'condolence': 2,
#          'book': 90,
#          'victims': 240,
#          'recent': 177,
#          'attack': 951,
#          'nightclub': 11,
#          'florida': 11,
#          'switzerland': 111,
#          'denies': 113,
#          'citizenship': 77,
#          'muslim': 504,
#          'immigrant': 28,
#          'girls': 230,
#          'refused': 96,
#          'swim': 18,
#          'boys': 94,
#          'report': 869,
#          'palestinian': 638,
#          'terrorist': 242,
#          'stabs': 9,
#          'israeli': 1322,
#          'teen': 65,
#          'girl': 361,
#          'death': 953,
#          'bedroom': 4,
#          'puerto': 19,
#          'rico': 17,
#          'default': 32,
#          '$': 1569,
#          '1': 935,
#          'billion': 597,
#          'debt': 192,
#          'friday': 162,
#          'republic': 114,
#          'ireland': 222,
#          'fans': 31,
#          'awarded': 43,
#          'medal': 20,
#          'sportsmanship': 1,
#          'paris': 228,
#          'mayor': 145,
#          'afghan': 420,
#          'suicide': 329,
#          'bomber': 100,
#          'kills': 309,
#          '40': 247,
#          'bbc': 517,
#          'news': 1003,
#          'us': 3030,
#          'airstrikes': 69,
#          'kill': 444,
#          'least': 473,
#          '250': 38,
#          'isis': 702,
#          'fighters': 164,
#          'convoy': 35,
#          'outside': 183,
#          'fallujah': 12,
#          'official': 489,
#          'turkish': 383,
#          'cop': 45,
#          'took': 153,
#          'istanbul': 54,
#          'gunman': 57,
#          'hailed': 21,
#          'hero': 50,
#          'cannabis': 117,
#          'compounds': 1,
#          'could': 978,
#          'treat': 26,
#          'alzheimer': 5,
#          'removing': 29,
#          'plaque': 2,
#          'forming': 14,
#          'proteins': 4,
#          'brain': 58,
#          'cells': 51,
#          'research': 170,
#          'suggests': 101,
#          'japan': 791,
#          'top': 525,
#          'court': 1034,
#          'approved': 108,
#          'blanket': 13,
#          'surveillance': 288,
#          'country': 1218,
#          'muslims': 285,
#          'nothey': 27,
#          'made': 410,
#          'suspects': 92,
#          'never': 221,
#          'anything': 53,
#          'wrong': 125,
#          'japanese': 323,
#          'mohammed': 46,
#          'fujita': 1,
#          'cia': 294,
#          'gave': 95,
#          'romania': 53,
#          'millions': 223,
#          'host': 70,
#          'secret': 435,
#          'prisons': 34,
#          'groups': 245,
#          'urge': 57,
#          'united': 2402,
#          'nations': 570,
#          'suspend': 35,
#          'saudi': 765,
#          'arabia': 408,
#          'rights': 859,
#          'council': 185,
#          'googles': 2,
#          'free': 470,
#          'wifi': 7,
#          'indian': 397,
#          'railway': 33,
#          'stations': 42,
#          'better': 121,
#          'countrys': 100,
#          'paid': 149,
#          'services': 122,
#          'mounting': 28,
#          'evidence': 305,
#          'hobbits': 1,
#          'wiped': 36,
#          'modern': 99,
#          'humans': 87,
#          'ancestors': 9,
#          '50000': 51,
#          'years': 1544,
#          'ago': 255,
#          'carried': 77,
#          'tuesday': 280,
#          'terror': 316,
#          'ataturk': 1,
#          'airport': 188,
#          'russia': 1701,
#          'uzbekistan': 10,
#          'kyrgyzstan': 27,
#          'offical': 2,
#          'said': 1185,
#          'calls': 585,
#          'un': 1015,
#          'human': 817,
#          'military': 1114,
#          'aggresion': 1,
#          'yemen': 190,
#          '100': 354,
#          'nobel': 151,
#          'laureates': 7,
#          'call': 323,
#          'greenpeace': 46,
#          'anti': 825,
#          'gmo': 17,
#          'obstruction': 3,
#          'developing': 85,
#          'world': 2245,
#          'british': 861,
#          'pedophile': 36,
#          'sentenced': 258,
#          '85': 32,
#          'trafficking': 99,
#          'child': 479,
#          'abuse': 354,
#          'images': 117,
#          'domminich': 1,
#          'shaw': 3,
#          'kingpin': 14,
#          'sexual': 202,
#          'violence': 351,
#          'children': 773,
#          'sent': 166,
#          'dozens': 142,
#          'online': 271,
#          'discussed': 15,
#          'plans': 427,
#          'assault': 123,
#          'probation': 2,
#          'permitted': 20,
#          '200': 173,
#          'offshore': 74,
#          'fracks': 1,
#          'gulf': 116,
#          'mexico': 550,
#          '2010': 124,
#          '2014': 108,
#          'allowed': 163,
#          '72': 34,
#          'gallons': 13,
#          'chemical': 154,
#          'discharge': 6,
#          'swimming': 16,
#          'ridicule': 8,
#          'french': 652,
#          'beach': 47,
#          'police': 1963,
#          'carry': 77,
#          'guns': 58,
#          'trunks': 3,
#          'lifeguards': 1,
#          'frances': 22,
#          'busiest': 3,
#          'beaches': 22,
#          'bullet': 28,
#          'proof': 52,
#          'vests': 10,
#          'first': 1338,
#          'time': 762,
#          'summer': 58,
#          'amid': 215,
#          'fears': 177,
#          'terrorists': 171,
#          'target': 110,
#          'holidaymakers': 2,
#          'uefa': 3,
#          'minutes': 89,
#          'silence': 53,
#          'euro': 165,
#          '2016': 57,
#          'noturkey': 17,
#          'already': 168,
#          'eliminated': 10,
#          'law': 882,
#          'enforcement': 45,
#          'sources': 90,
#          'gun': 101,
#          'used': 429,
#          'attacks': 509,
#          'came': 87,
#          'phoenix': 3,
#          'explosion': 120,
#          'yemeni': 45,
#          'former': 637,
#          'president': 1422,
#          'terrorism': 205,
#          'offspring': 2,
#          'wahhabism': 3,
#          'al': 646,
#          'saud': 7,
#          'regime': 203,
#          'uk': 1427,
#          'must': 374,
#          'accept': 80,
#          'freedom': 230,
#          'movement': 101,
#          'access': 225,
#          'eu': 675,
#          'market': 189,
#          'devastated': 14,
#          'scientists': 401,
#          'late': 73,
#          'captive': 26,
#          'breed': 7,
#          'mammal': 10,
#          'lost': 231,
#          'climate': 423,
#          'change': 423,
#          'australian': 566,
#          'conservationists': 17,
#          'spent': 101,
#          '5': 575,
#          'months': 366,
#          'obtaining': 10,
#          'permissions': 1,
#          'planning': 142,
#          'breeding': 7,
#          'program': 179,
#          'arrived': 27,
#          'rodents': 2,
#          'tiny': 49,
#          'island': 154,
#          'labor': 91,
#          'leader': 609,
#          'jeremy': 21,
#          'corbyn': 15,
#          'loses': 96,
#          'confidence': 28,
#          'vote': 290,
#          'refuses': 129,
#          'resign': 75,
#          'shop': 31,
#          'firebombed': 7,
#          'inside': 186,
#          'mexican': 278,
#          'authorities': 309,
#          'sexually': 67,
#          'torture': 263,
#          'women': 869,
#          'prison': 459,
#          'shares': 37,
#          'pound': 30,
#          'continue': 136,
#          'recover': 15,
#          'iceland': 197,
#          'historian': 10,
#          'johannesson': 1,
#          'wins': 142,
#          'presidential': 133,
#          'election': 325,
#          '99': 46,
#          'million': 894,
#          'year': 1680,
#          'old': 916,
#          'bird': 37,
#          'wings': 8,
#          'found': 987,
#          'encased': 3,
#          'amber': 3,
#          'finding': 57,
#          'things': 67,
#          'trapped': 70,
#          'far': 276,
#          'rare': 135,
#          'researchers': 132,
#          'burma': 55,
#          'pair': 15,
#          'like': 569,
#          'frozen': 44,
#          'knew': 65,
#          'something': 85,
#          'special': 126,
#          'chatbot': 1,
#          'programmed': 2,
#          'teenager': 63,
#          'successfully': 60,
#          'challenged': 15,
#          '160000': 6,
#          'parking': 18,
#          'tickets': 11,
#          'since': 538,
#          'launch': 174,
#          'last': 696,
#          'philippine': 44,
#          'elect': 16,
#          'monday': 260,
#          'aggressively': 7,
#          'promote': 36,
#          'artificial': 29,
#          'birth': 95,
#          'control': 309,
#          'even': 458,
#          'risk': 161,
#          'getting': 153,
#          'fight': 357,
#          'dominant': 6,
#          'catholic': 221,
#          'church': 323,
#          'staunchly': 3,
#          'opposes': 21,
#          'contraceptives': 7,
#          'belgian': 61,
#          'prime': 547,
#          'minister': 1064,
#          'ridicules': 2,
#          'nigel': 10,
#          'farage': 10,
#          'accuses': 120,
#          'ukip': 6,
#          'lying': 35,
#          'referendum': 102,
#          'campaign': 237,
#          'brexiteer': 1,
#          'laughing': 9,
#          'islamic': 587,
#          'state': 1243,
#          'bombings': 52,
#          'southern': 158,
#          '38': 32,
#          'escape': 82,
#          'tunnel': 52,
#          'dug': 7,
#          'hand': 130,
#          'holocaust': 96,
#          'massacre': 200,
#          'site': 216,
#          'land': 321,
#          'beijing': 172,
#          'sinking': 30,
#          'much': 312,
#          'four': 387,
#          'inches': 10,
#          'per': 200,
#          'overconsumption': 3,
#          'groundwater': 12,
#          'according': 345,
#          'new': 2425,
#          'car': 233,
#          'bomb': 345,
#          'mosque': 123,
#          'perth': 8,
#          'australia': 559,
#          'emaciated': 4,
#          'lions': 29,
#          'taiz': 1,
#          'zoo': 43,
#          'blood': 123,
#          'soaked': 4,
#          'cages': 9,
#          'left': 285,
#          'starve': 17,
#          'due': 221,
#          'civil': 191,
#          'war': 1593,
#          'rupert': 81,
#          'murdoch': 171,
#          'describes': 26,
#          'brexit': 23,
#          'wonderful': 5,
#          'media': 461,
#          'mogul': 7,
#          'likened': 7,
#          'leaving': 117,
#          'break': 134,
#          'shared': 28,
#          'view': 77,
#          'donald': 27,
#          'trump': 43,
#          'able': 103,
#          'man': 928,
#          'killed': 1326,
#          'google': 324,
#          'disastrous': 12,
#          'symantec': 2,
#          'norton': 3,
#          'vulnerabilities': 2,
#          'bad': 139,
#          'gets': 271,
#          'extremist': 56,
#          'rise': 233,
#          'germany': 780,
#          'domestic': 68,
#          'intelligence': 334,
#          'agency': 271,
#          'right': 555,
#          'islamist': 139,
#          'radical': 84,
#          'gaining': 22,
#          'membership': 48,
#          'labour': 86,
#          'mps': 87,
#          'pass': 63,
#          'motion': 23,
#          'zealand': 233,
#          'town': 219,
#          'notoo': 17,
#          'many': 450,
#          'jobs': 102,
#          'launches': 131,
#          'drive': 85,
#          'recruit': 21,
#          'outsiders': 7,
#          '500': 193,
#          'want': 365,
#          'save': 177,
#          'great': 231,
#          'barrier': 82,
#          'reef': 93,
#          'stop': 443,
#          'supporting': 51,
#          'coal': 151,
#          'personal': 132,
#          'details': 87,
#          '112': 12,
#          '000': 804,
#          'officers': 217,
#          'uploaded': 10,
#          'security': 613,
#          'breach': 47,
#          'fortnight': 3,
#          'two': 1149,
#          'murdered': 119,
#          'home': 423,
#          'jihadist': 24,
#          'sp': 16,
#          'cuts': 166,
#          'kingdom': 148,
#          'sovereign': 40,
#          'credit': 85,
#          'rating': 39,
#          'aa': 1,
#          'aaa': 9,
#          'huge': 213,
#          'helium': 6,
#          'deposit': 10,
#          'africa': 428,
#          'ceo': 72,
#          'south': 929,
#          'african': 287,
#          'broadcaster': 18,
#          'quits': 41,
#          'shortly': 20,
#          'negative': 34,
#          'banned': 300,
#          'cost': 159,
#          'investors': 43,
#          'trillion': 85,
#          'worst': 193,
#          'one': 1415,
#          'day': 528,
#          'drop': 100,
#          'ever': 301,
#          'hong': 170,
#          'kong': 163,
#          'democracy': 218,
#          'activists': 285,
#          'return': 210,
#          'rule': 119,
#          'step': 129,
#          'independence': 117,
#          'join': 190,
#          'notriangle': 1,
#          'non': 168,
#          'countries': 537,
#          'osborne': 7,
#          'absolutely': 26,
#          'going': 260,
#          'cut': 272,
#          'spending': 88,
#          'raise': 104,
#          'taxes': 93,
#          'wouldo': 12,
#          'let': 160,
#          'scotland': 134,
#          'scottish': 68,
#          'mep': 7,
#          'alyn': 1,
#          'smith': 12,
#          'urged': 70,
#          'members': 262,
#          'european': 598,
#          'parliament': 457,
#          'stand': 109,
#          'hit': 380,
#          'history': 271,
#          'making': 240,
#          'dollar': 107,
#          'parity': 4,
#          'end': 515,
#          'merkel': 143,
#          'vows': 103,
#          'strengthen': 18,
#          'tells': 235,
#          'cherry': 3,
#          'picking': 11,
#          'ryanair': 8,
#          'deploy': 33,
#          'aircraft': 128,
#          'routes': 18,
#          'next': 318,
#          '2017': 17,
#          'instead': 136,
#          'focus': 32,
#          'union': 270,
#          'destroy': 116,
#          'larry': 4,
#          'king': 164,
#          'siemens': 5,
#          'freezes': 19,
#          'wind': 115,
#          'power': 593,
#          'investment': 59,
#          'canada': 679,
#          'pledge': 54,
#          '50': 308,
#          'clean': 122,
#          'energy': 350,
#          '2025': 10,
#          'increasing': 58,
#          'torturing': 26,
#          'refugees': 218,
#          'medical': 167,
#          'experts': 164,
#          'claim': 215,
#          'richard': 53,
#          'branson': 12,
#          'founder': 183,
#          'virgin': 27,
#          'group': 591,
#          'company': 351,
#          'third': 193,
#          'value': 53,
#          'voted': 91,
#          'leave': 228,
#          'week': 362,
#          '37': 28,
#          'skull': 16,
#          'borneo': 11,
#          'reveals': 199,
#          'surprise': 56,
#          'study': 301,
#          'deep': 94,
#          'oldest': 71,
#          'discovered': 209,
#          'se': 11,
#          'asia': 129,
#          'ancient': 170,
#          'person': 127,
#          'related': 78,
#          'indigenous': 84,
#          'australians': 38,
#          'originally': 16,
#          'thought': 159,
#          'discovery': 72,
#          'game': 91,
#          'changer': 6,
#          'palestinians': 375,
#          'stone': 46,
#          'western': 288,
#          'wall': 126,
#          'worshipers': 3,
#          'shut': 146,
#          'temple': 53,
#          'mount': 48,
#          'jean': 20,
#          'claude': 3,
#          'juncker': 3,
#          'asks': 130,
#          'romanians': 7,
#          'remainians': 1,
#          'offering': 32,
#          '48': 50,
#          'britons': 41,
#          'bucharest': 8,
#          'newspaper': 182,
#          'app': 30,
#          'connects': 5,
#          'loving': 5,
#          'romanian': 28,
#          'families': 141,
#          'needy': 4,
#          'brits': 17,
#          'allowing': 103,
#          'offer': 78,
#          'help': 436,
#          'immigrants': 67,
#          'apply': 31,
#          'id': 43,
#          'gibraltar': 8,
#          'talks': 244,
#          '8': 311,
#          'bombers': 81,
#          'strike': 416,
#          'lebanon': 118,
#          'forces': 654,
#          'routinely': 18,
#          'isexual': 3,
#          'amnesty': 112,
#          'international': 681,
#          'compiled': 3,
#          'testimonies': 5,
#          'despite': 301,
#          'thousands': 544,
#          'complaints': 38,
#          '15': 299,
#          'probes': 14,
#          'led': 197,
#          'criminal': 206,
#          'convictions': 12,
#          '1991': 5,
#          'barclays': 23,
#          'rbs': 14,
#          'suspended': 74,
#          'trading': 49,
#          'tanking': 5,
#          'pope': 343,
#          'ask': 98,
#          'forgiveness': 6,
#          'gays': 60,
#          'poland': 155,
#          'ishocked': 3,
#          'xenophobic': 5,
#          'poles': 9,
#          'second': 267,
#          'cabinet': 88,
#          'agrees': 59,
#          'welcome': 60,
#          'ally': 58,
#          'sterling': 2,
#          'dips': 5,
#          '31': 42,
#          'low': 147,
#          'uncertainty': 4,
#          'surge': 42,
#          'hate': 73,
#          'crimes': 318,
#          'weapons': 415,
#          'shipped': 9,
#          'jordan': 93,
#          'intended': 30,
#          'syrian': 610,
#          'rebels': 363,
#          'systematically': 15,
#          'stolen': 113,
#          'jordanian': 22,
#          'operatives': 13,
#          'sold': 127,
#          'arms': 247,
#          'merchants': 5,
#          'black': 224,
#          'american': 549,
#          'officials': 601,
#          'angela': 66,
#          'file': 69,
#          'exit': 46,
#          'papers': 96,
#          'begin': 95,
#          'hope': 78,
#          'threatened': 146,
#          'species': 115,
#          'aquarium': 3,
#          'osaka': 5,
#          'succeeded': 10,
#          'artificially': 7,
#          'rockhopper': 2,
#          'penguin': 8,
#          'sky': 44,
#          'journalist': 215,
#          'speechless': 6,
#          'mp': 135,
#          'nothere': 22,
#          'plan': 347,
#          'giant': 170,
#          'panda': 11,
#          'macau': 1,
#          'gives': 140,
#          'twins': 9,
#          'get': 467,
#          'britain': 490,
#          'invoke': 3,
#          'article': 98,
#          'sea': 391,
#          'turtle': 17,
#          'beaten': 128,
#          'dead': 737,
#          'taking': 215,
#          'selfies': 2,
#          'loggerhead': 2,
#          'receiving': 29,
#          'sticks': 15,
#          'stepped': 18,
#          'german': 701,
#          'lawyers': 75,
#          'probe': 143,
#          'erdogan': 129,
#          'alleged': 197,
#          'intensify': 11,
#          'cooperation': 42,
#          'fellow': 27,
#          'supporters': 86,
#          '52': 36,
#          'win': 132,
#          'entirely': 28,
#          'overwhelming': 19,
#          'calling': 181,
#          'government': 2076,
#          'hold': 143,
#          'prevent': 142,
#          'irreversible': 16,
#          'damage': 108,
#          'turkey': 544,
#          'isorry': 2,
#          'downing': 25,
#          'russian': 1222,
#          'jet': 98,
#          'edward': 182,
#          'snowden': 445,
#          'lawyer': 121,
#          'push': 101,
#          'pardon': 13,
#          'obama': 533,
#          'opinion': 52,
#          'poll': 132,
#          'majority': 108,
#          'half': 277,
#          'adults': 33,
#          'say': 852,
#          'happy': 41,
#          'result': 114,
#          'five': 400,
#          '43': 61,
#          'saying': 243,
#          'unhappy': 13,
#          'outcome': 13,
#          'conservative': 101,
#          'campaigner': 13,
#          'post': 207,
#          'economists': 20,
#          'predict': 19,
#          'recession': 77,
#          'weakening': 9,
#          'isuperstate': 1,
#          'france': 659,
#          'creating': 71,
#          'superstate': 2,
#          'limiting': 12,
#          'powers': 116,
#          'individual': 25,
#          'britains': 24,
#          'decision': 124,
#          'pakistani': 238,
#          'clerics': 39,
#          'declare': 55,
#          'transgender': 17,
#          'marriages': 29,
#          'legal': 285,
#          'david': 217,
#          'cameron': 181,
#          'pm': 356,
#          'forecasts': 8,
#          'votes': 114,
#          'nicola': 4,
#          'sturgeon': 5,
#          'highly': 72,
#          'likely': 217,
#          'largest': 394,
#          'tibetan': 47,
#          'buddhist': 32,
#          'institute': 35,
#          'ordered': 209,
#          'demolished': 10,
#          'chinese': 967,
#          'single': 132,
#          'place': 183,
#          'rich': 164,
#          'richer': 17,
#          'expense': 15,
#          'poor': 195,
#          'oxfam': 18,
#          'warns': 362,
#          'spanish': 165,
#          'returned': 48,
#          'spain': 267,
#          'back': 554,
#          'drops': 66,
#          'nearly': 296,
#          'strong': 83,
#          'results': 81,
#          'newcastle': 3,
#          'jk': 2,
#          'rowling': 2,
#          'leads': 61,
#          'charge': 131,
#          'buenos': 12,
#          'aires': 12,
#          'close': 200,
#          '140': 24,
#          'captivity': 5,
#          'degrading': 5,
#          'horacio': 1,
#          'rodrguez': 1,
#          'larreta': 1,
#          'zoos': 5,
#          'animals': 117,
#          'gradually': 4,
#          'moved': 45,
#          'nature': 63,
#          'reserves': 57,
#          'argentina': 137,
#          'provide': 84,
#          'suitable': 5,
#          'northern': 251,
#          'deputy': 64,
#          'polls': 30,
#          'polling': 10,
#          'happened': 62,
#          'petition': 59,
#          'popular': 87,
#          'crashing': 7,
#          'north': 1271,
#          'korea': 1214,
#          'printing': 16,
#          'massive': 237,
#          'amounts': 37,
#          'fake': 134,
#          'currency': 121,
#          'defectors': 27,
#          'sinn': 5,
#          'fein': 6,
#          'irish': 192,
#          'reunification': 16,
#          '70': 133,
#          'sharemarket': 1,
#          'disowns': 2,
#          '350m': 1,
#          'nhs': 41,
#          'hours': 266,
#          'soon': 138,
#          'possible': 184,
#          '350': 21,
#          'fund': 135,
#          'big': 269,
#          'mistake': 47,
#          'captions': 1,
#          'takes': 177,
#          'every': 299,
#          'send': 155,
#          'stamped': 2,
#          'material': 64,
#          'london': 425,
#          'banking': 95,
#          'job': 134,
#          'start': 161,
#          'large': 186,
#          'spike': 13,
#          'searches': 22,
#          'passport': 43,
#          'applications': 12,
#          'broke': 74,
#          'backs': 67,
#          'remain': 85,
#          '94': 17,
#          'night': 149,
#          'residents': 142,
#          'guilty': 193,
#          'insulting': 81,
#          'recep': 24,
#          'tayyip': 28,
#          'depicting': 14,
#          'gollum': 2,
#          'character': 15,
#          'lord': 57,
#          'rings': 12,
#          'antalya': 1,
#          'province': 77,
#          'rifat': 1,
#          'cetin': 1,
#          'jail': 322,
#          'sentence': 122,
#          'stripped': 42,
#          'parental': 7,
#          'custody': 54,
#          'today': 363,
#          'decides': 31,
#          'whether': 128,
#          'e': 87,
#          'cigarettes': 32,
#          'public': 567,
#          'warn': 93,
#          'ban': 637,
#          'using': 345,
#          'places': 57,
#          'damaging': 29,
#          'may': 863,
#          'put': 216,
#          ...})

# %% [markdown]
# # A note on Word Embeddings

# %% [markdown]
# ![word_embed](https://github.com/dasarpai/DAI-Projects/blob/main/BFSI/DoeJones-Prediction-with-News/resources/wordvectors.png?raw=1)

# %% [markdown]
# **Reference**: https://nlp.stanford.edu/projects/glove/

# %% [markdown]
# ## We are going to use Glove embeddings to initialize our weights while designing our neural network. Let's load the same so that we can ensure our headline corpus' vocabulary matches where possible with Glove Embedding vocabulary.

# %%
# Load GloVe's embeddings
embeddings_index = {}
with open('glove.840B.300d.txt', encoding='utf-8') as f:
    for line in f:
        values = line.split(' ')
        word = values[0]
        embedding = np.asarray(values[1:], dtype='float32')
        embeddings_index[word] = embedding

print('Word embeddings:', len(embeddings_index))
# Out:
# Word embeddings: 2196016

# %% [markdown]
# ## It is not necessary that we will have embeddings for all the words in Glove. So to limit such cases by limiting vocabulary by applying simple logic:  Remove the words that are "rare" and are not available in Glove

# %%
# Limit the vocab that we will use to words that appear ≥ threshold or are in GloVe

# Define threshold
threshold = 10

#dictionary to convert words to integers
vocab_to_int = {}

value = 0
for word, count in unique_word_counts.items():
    if count >= threshold or word in embeddings_index:
        vocab_to_int[word] = value
        value += 1

# %%
vocab_to_int
# Out:
# {'jamaica': 0,
#  'proposes': 1,
#  'marijuana': 2,
#  'dispensers': 3,
#  'tourists': 4,
#  'airports': 5,
#  'following': 6,
#  'legalisation': 7,
#  'kiosks': 8,
#  'desks': 9,
#  'would': 10,
#  'give': 11,
#  'people': 12,
#  'license': 13,
#  'purchase': 14,
#  '2': 15,
#  'ounces': 16,
#  'drug': 17,
#  'use': 18,
#  'stay': 19,
#  'stephen': 20,
#  'hawking': 21,
#  'says': 22,
#  'pollution': 23,
#  'still': 24,
#  'biggest': 25,
#  'threats': 26,
#  'mankind': 27,
#  'certainly': 28,
#  'become': 29,
#  'less': 30,
#  'greedy': 31,
#  'stupid': 32,
#  'treatment': 33,
#  'environment': 34,
#  'past': 35,
#  'decade': 36,
#  'boris': 37,
#  'johnson': 38,
#  'run': 39,
#  'tory': 40,
#  'party': 41,
#  'leadership': 42,
#  'six': 43,
#  'gay': 44,
#  'men': 45,
#  'ivory': 46,
#  'coast': 47,
#  'abused': 48,
#  'forced': 49,
#  'flee': 50,
#  'homes': 51,
#  'pictured': 52,
#  'signing': 53,
#  'condolence': 54,
#  'book': 55,
#  'victims': 56,
#  'recent': 57,
#  'attack': 58,
#  'nightclub': 59,
#  'florida': 60,
#  'switzerland': 61,
#  'denies': 62,
#  'citizenship': 63,
#  'muslim': 64,
#  'immigrant': 65,
#  'girls': 66,
#  'refused': 67,
#  'swim': 68,
#  'boys': 69,
#  'report': 70,
#  'palestinian': 71,
#  'terrorist': 72,
#  'stabs': 73,
#  'israeli': 74,
#  'teen': 75,
#  'girl': 76,
#  'death': 77,
#  'bedroom': 78,
#  'puerto': 79,
#  'rico': 80,
#  'default': 81,
#  '$': 82,
#  '1': 83,
#  'billion': 84,
#  'debt': 85,
#  'friday': 86,
#  'republic': 87,
#  'ireland': 88,
#  'fans': 89,
#  'awarded': 90,
#  'medal': 91,
#  'sportsmanship': 92,
#  'paris': 93,
#  'mayor': 94,
#  'afghan': 95,
#  'suicide': 96,
#  'bomber': 97,
#  'kills': 98,
#  '40': 99,
#  'bbc': 100,
#  'news': 101,
#  'us': 102,
#  'airstrikes': 103,
#  'kill': 104,
#  'least': 105,
#  '250': 106,
#  'isis': 107,
#  'fighters': 108,
#  'convoy': 109,
#  'outside': 110,
#  'fallujah': 111,
#  'official': 112,
#  'turkish': 113,
#  'cop': 114,
#  'took': 115,
#  'istanbul': 116,
#  'gunman': 117,
#  'hailed': 118,
#  'hero': 119,
#  'cannabis': 120,
#  'compounds': 121,
#  'could': 122,
#  'treat': 123,
#  'alzheimer': 124,
#  'removing': 125,
#  'plaque': 126,
#  'forming': 127,
#  'proteins': 128,
#  'brain': 129,
#  'cells': 130,
#  'research': 131,
#  'suggests': 132,
#  'japan': 133,
#  'top': 134,
#  'court': 135,
#  'approved': 136,
#  'blanket': 137,
#  'surveillance': 138,
#  'country': 139,
#  'muslims': 140,
#  'nothey': 141,
#  'made': 142,
#  'suspects': 143,
#  'never': 144,
#  'anything': 145,
#  'wrong': 146,
#  'japanese': 147,
#  'mohammed': 148,
#  'fujita': 149,
#  'cia': 150,
#  'gave': 151,
#  'romania': 152,
#  'millions': 153,
#  'host': 154,
#  'secret': 155,
#  'prisons': 156,
#  'groups': 157,
#  'urge': 158,
#  'united': 159,
#  'nations': 160,
#  'suspend': 161,
#  'saudi': 162,
#  'arabia': 163,
#  'rights': 164,
#  'council': 165,
#  'googles': 166,
#  'free': 167,
#  'wifi': 168,
#  'indian': 169,
#  'railway': 170,
#  'stations': 171,
#  'better': 172,
#  'countrys': 173,
#  'paid': 174,
#  'services': 175,
#  'mounting': 176,
#  'evidence': 177,
#  'hobbits': 178,
#  'wiped': 179,
#  'modern': 180,
#  'humans': 181,
#  'ancestors': 182,
#  '50000': 183,
#  'years': 184,
#  'ago': 185,
#  'carried': 186,
#  'tuesday': 187,
#  'terror': 188,
#  'ataturk': 189,
#  'airport': 190,
#  'russia': 191,
#  'uzbekistan': 192,
#  'kyrgyzstan': 193,
#  'offical': 194,
#  'said': 195,
#  'calls': 196,
#  'un': 197,
#  'human': 198,
#  'military': 199,
#  'aggresion': 200,
#  'yemen': 201,
#  '100': 202,
#  'nobel': 203,
#  'laureates': 204,
#  'call': 205,
#  'greenpeace': 206,
#  'anti': 207,
#  'gmo': 208,
#  'obstruction': 209,
#  'developing': 210,
#  'world': 211,
#  'british': 212,
#  'pedophile': 213,
#  'sentenced': 214,
#  '85': 215,
#  'trafficking': 216,
#  'child': 217,
#  'abuse': 218,
#  'images': 219,
#  'shaw': 220,
#  'kingpin': 221,
#  'sexual': 222,
#  'violence': 223,
#  'children': 224,
#  'sent': 225,
#  'dozens': 226,
#  'online': 227,
#  'discussed': 228,
#  'plans': 229,
#  'assault': 230,
#  'probation': 231,
#  'permitted': 232,
#  '200': 233,
#  'offshore': 234,
#  'fracks': 235,
#  'gulf': 236,
#  'mexico': 237,
#  '2010': 238,
#  '2014': 239,
#  'allowed': 240,
#  '72': 241,
#  'gallons': 242,
#  'chemical': 243,
#  'discharge': 244,
#  'swimming': 245,
#  'ridicule': 246,
#  'french': 247,
#  'beach': 248,
#  'police': 249,
#  'carry': 250,
#  'guns': 251,
#  'trunks': 252,
#  'lifeguards': 253,
#  'frances': 254,
#  'busiest': 255,
#  'beaches': 256,
#  'bullet': 257,
#  'proof': 258,
#  'vests': 259,
#  'first': 260,
#  'time': 261,
#  'summer': 262,
#  'amid': 263,
#  'fears': 264,
#  'terrorists': 265,
#  'target': 266,
#  'holidaymakers': 267,
#  'uefa': 268,
#  'minutes': 269,
#  'silence': 270,
#  'euro': 271,
#  '2016': 272,
#  'noturkey': 273,
#  'already': 274,
#  'eliminated': 275,
#  'law': 276,
#  'enforcement': 277,
#  'sources': 278,
#  'gun': 279,
#  'used': 280,
#  'attacks': 281,
#  'came': 282,
#  'phoenix': 283,
#  'explosion': 284,
#  'yemeni': 285,
#  'former': 286,
#  'president': 287,
#  'terrorism': 288,
#  'offspring': 289,
#  'wahhabism': 290,
#  'al': 291,
#  'saud': 292,
#  'regime': 293,
#  'uk': 294,
#  'must': 295,
#  'accept': 296,
#  'freedom': 297,
#  'movement': 298,
#  'access': 299,
#  'eu': 300,
#  'market': 301,
#  'devastated': 302,
#  'scientists': 303,
#  'late': 304,
#  'captive': 305,
#  'breed': 306,
#  'mammal': 307,
#  'lost': 308,
#  'climate': 309,
#  'change': 310,
#  'australian': 311,
#  'conservationists': 312,
#  'spent': 313,
#  '5': 314,
#  'months': 315,
#  'obtaining': 316,
#  'permissions': 317,
#  'planning': 318,
#  'breeding': 319,
#  'program': 320,
#  'arrived': 321,
#  'rodents': 322,
#  'tiny': 323,
#  'island': 324,
#  'labor': 325,
#  'leader': 326,
#  'jeremy': 327,
#  'corbyn': 328,
#  'loses': 329,
#  'confidence': 330,
#  'vote': 331,
#  'refuses': 332,
#  'resign': 333,
#  'shop': 334,
#  'firebombed': 335,
#  'inside': 336,
#  'mexican': 337,
#  'authorities': 338,
#  'sexually': 339,
#  'torture': 340,
#  'women': 341,
#  'prison': 342,
#  'shares': 343,
#  'pound': 344,
#  'continue': 345,
#  'recover': 346,
#  'iceland': 347,
#  'historian': 348,
#  'wins': 349,
#  'presidential': 350,
#  'election': 351,
#  '99': 352,
#  'million': 353,
#  'year': 354,
#  'old': 355,
#  'bird': 356,
#  'wings': 357,
#  'found': 358,
#  'encased': 359,
#  'amber': 360,
#  'finding': 361,
#  'things': 362,
#  'trapped': 363,
#  'far': 364,
#  'rare': 365,
#  'researchers': 366,
#  'burma': 367,
#  'pair': 368,
#  'like': 369,
#  'frozen': 370,
#  'knew': 371,
#  'something': 372,
#  'special': 373,
#  'chatbot': 374,
#  'programmed': 375,
#  'teenager': 376,
#  'successfully': 377,
#  'challenged': 378,
#  '160000': 379,
#  'parking': 380,
#  'tickets': 381,
#  'since': 382,
#  'launch': 383,
#  'last': 384,
#  'philippine': 385,
#  'elect': 386,
#  'monday': 387,
#  'aggressively': 388,
#  'promote': 389,
#  'artificial': 390,
#  'birth': 391,
#  'control': 392,
#  'even': 393,
#  'risk': 394,
#  'getting': 395,
#  'fight': 396,
#  'dominant': 397,
#  'catholic': 398,
#  'church': 399,
#  'staunchly': 400,
#  'opposes': 401,
#  'contraceptives': 402,
#  'belgian': 403,
#  'prime': 404,
#  'minister': 405,
#  'ridicules': 406,
#  'nigel': 407,
#  'farage': 408,
#  'accuses': 409,
#  'ukip': 410,
#  'lying': 411,
#  'referendum': 412,
#  'campaign': 413,
#  'laughing': 414,
#  'islamic': 415,
#  'state': 416,
#  'bombings': 417,
#  'southern': 418,
#  '38': 419,
#  'escape': 420,
#  'tunnel': 421,
#  'dug': 422,
#  'hand': 423,
#  'holocaust': 424,
#  'massacre': 425,
#  'site': 426,
#  'land': 427,
#  'beijing': 428,
#  'sinking': 429,
#  'much': 430,
#  'four': 431,
#  'inches': 432,
#  'per': 433,
#  'overconsumption': 434,
#  'groundwater': 435,
#  'according': 436,
#  'new': 437,
#  'car': 438,
#  'bomb': 439,
#  'mosque': 440,
#  'perth': 441,
#  'australia': 442,
#  'emaciated': 443,
#  'lions': 444,
#  'zoo': 445,
#  'blood': 446,
#  'soaked': 447,
#  'cages': 448,
#  'left': 449,
#  'starve': 450,
#  'due': 451,
#  'civil': 452,
#  'war': 453,
#  'rupert': 454,
#  'murdoch': 455,
#  'describes': 456,
#  'brexit': 457,
#  'wonderful': 458,
#  'media': 459,
#  'mogul': 460,
#  'likened': 461,
#  'leaving': 462,
#  'break': 463,
#  'shared': 464,
#  'view': 465,
#  'donald': 466,
#  'trump': 467,
#  'able': 468,
#  'man': 469,
#  'killed': 470,
#  'google': 471,
#  'disastrous': 472,
#  'symantec': 473,
#  'norton': 474,
#  'vulnerabilities': 475,
#  'bad': 476,
#  'gets': 477,
#  'extremist': 478,
#  'rise': 479,
#  'germany': 480,
#  'domestic': 481,
#  'intelligence': 482,
#  'agency': 483,
#  'right': 484,
#  'islamist': 485,
#  'radical': 486,
#  'gaining': 487,
#  'membership': 488,
#  'labour': 489,
#  'mps': 490,
#  'pass': 491,
#  'motion': 492,
#  'zealand': 493,
#  'town': 494,
#  'notoo': 495,
#  'many': 496,
#  'jobs': 497,
#  'launches': 498,
#  'drive': 499,
#  'recruit': 500,
#  'outsiders': 501,
#  '500': 502,
#  'want': 503,
#  'save': 504,
#  'great': 505,
#  'barrier': 506,
#  'reef': 507,
#  'stop': 508,
#  'supporting': 509,
#  'coal': 510,
#  'personal': 511,
#  'details': 512,
#  '112': 513,
#  '000': 514,
#  'officers': 515,
#  'uploaded': 516,
#  'security': 517,
#  'breach': 518,
#  'fortnight': 519,
#  'two': 520,
#  'murdered': 521,
#  'home': 522,
#  'jihadist': 523,
#  'sp': 524,
#  'cuts': 525,
#  'kingdom': 526,
#  'sovereign': 527,
#  'credit': 528,
#  'rating': 529,
#  'aa': 530,
#  'aaa': 531,
#  'huge': 532,
#  'helium': 533,
#  'deposit': 534,
#  'africa': 535,
#  'ceo': 536,
#  'south': 537,
#  'african': 538,
#  'broadcaster': 539,
#  'quits': 540,
#  'shortly': 541,
#  'negative': 542,
#  'banned': 543,
#  'cost': 544,
#  'investors': 545,
#  'trillion': 546,
#  'worst': 547,
#  'one': 548,
#  'day': 549,
#  'drop': 550,
#  'ever': 551,
#  'hong': 552,
#  'kong': 553,
#  'democracy': 554,
#  'activists': 555,
#  'return': 556,
#  'rule': 557,
#  'step': 558,
#  'independence': 559,
#  'join': 560,
#  'non': 561,
#  'countries': 562,
#  'osborne': 563,
#  'absolutely': 564,
#  'going': 565,
#  'cut': 566,
#  'spending': 567,
#  'raise': 568,
#  'taxes': 569,
#  'wouldo': 570,
#  'let': 571,
#  'scotland': 572,
#  'scottish': 573,
#  'mep': 574,
#  'alyn': 575,
#  'smith': 576,
#  'urged': 577,
#  'members': 578,
#  'european': 579,
#  'parliament': 580,
#  'stand': 581,
#  'hit': 582,
#  'history': 583,
#  'making': 584,
#  'dollar': 585,
#  'parity': 586,
#  'end': 587,
#  'merkel': 588,
#  'vows': 589,
#  'strengthen': 590,
#  'tells': 591,
#  'cherry': 592,
#  'picking': 593,
#  'ryanair': 594,
#  'deploy': 595,
#  'aircraft': 596,
#  'routes': 597,
#  'next': 598,
#  '2017': 599,
#  'instead': 600,
#  'focus': 601,
#  'union': 602,
#  'destroy': 603,
#  'larry': 604,
#  'king': 605,
#  'siemens': 606,
#  'freezes': 607,
#  'wind': 608,
#  'power': 609,
#  'investment': 610,
#  'canada': 611,
#  'pledge': 612,
#  '50': 613,
#  'clean': 614,
#  'energy': 615,
#  '2025': 616,
#  'increasing': 617,
#  'torturing': 618,
#  'refugees': 619,
#  'medical': 620,
#  'experts': 621,
#  'claim': 622,
#  'richard': 623,
#  'branson': 624,
#  'founder': 625,
#  'virgin': 626,
#  'group': 627,
#  'company': 628,
#  'third': 629,
#  'value': 630,
#  'voted': 631,
#  'leave': 632,
#  'week': 633,
#  '37': 634,
#  'skull': 635,
#  'borneo': 636,
#  'reveals': 637,
#  'surprise': 638,
#  'study': 639,
#  'deep': 640,
#  'oldest': 641,
#  'discovered': 642,
#  'se': 643,
#  'asia': 644,
#  'ancient': 645,
#  'person': 646,
#  'related': 647,
#  'indigenous': 648,
#  'australians': 649,
#  'originally': 650,
#  'thought': 651,
#  'discovery': 652,
#  'game': 653,
#  'changer': 654,
#  'palestinians': 655,
#  'stone': 656,
#  'western': 657,
#  'wall': 658,
#  'worshipers': 659,
#  'shut': 660,
#  'temple': 661,
#  'mount': 662,
#  'jean': 663,
#  'claude': 664,
#  'asks': 665,
#  'romanians': 666,
#  'offering': 667,
#  '48': 668,
#  'britons': 669,
#  'bucharest': 670,
#  'newspaper': 671,
#  'app': 672,
#  'connects': 673,
#  'loving': 674,
#  'romanian': 675,
#  'families': 676,
#  'needy': 677,
#  'brits': 678,
#  'allowing': 679,
#  'offer': 680,
#  'help': 681,
#  'immigrants': 682,
#  'apply': 683,
#  'id': 684,
#  'gibraltar': 685,
#  'talks': 686,
#  '8': 687,
#  'bombers': 688,
#  'strike': 689,
#  'lebanon': 690,
#  'forces': 691,
#  'routinely': 692,
#  'amnesty': 693,
#  'international': 694,
#  'compiled': 695,
#  'testimonies': 696,
#  'despite': 697,
#  'thousands': 698,
#  'complaints': 699,
#  '15': 700,
#  'probes': 701,
#  'led': 702,
#  'criminal': 703,
#  'convictions': 704,
#  '1991': 705,
#  'barclays': 706,
#  'rbs': 707,
#  'suspended': 708,
#  'trading': 709,
#  'tanking': 710,
#  'pope': 711,
#  'ask': 712,
#  'forgiveness': 713,
#  'gays': 714,
#  'poland': 715,
#  'xenophobic': 716,
#  'poles': 717,
#  'second': 718,
#  'cabinet': 719,
#  'agrees': 720,
#  'welcome': 721,
#  'ally': 722,
#  'sterling': 723,
#  'dips': 724,
#  '31': 725,
#  'low': 726,
#  'uncertainty': 727,
#  'surge': 728,
#  'hate': 729,
#  'crimes': 730,
#  'weapons': 731,
#  'shipped': 732,
#  'jordan': 733,
#  'intended': 734,
#  'syrian': 735,
#  'rebels': 736,
#  'systematically': 737,
#  'stolen': 738,
#  'jordanian': 739,
#  'operatives': 740,
#  'sold': 741,
#  'arms': 742,
#  'merchants': 743,
#  'black': 744,
#  'american': 745,
#  'officials': 746,
#  'angela': 747,
#  'file': 748,
#  'exit': 749,
#  'papers': 750,
#  'begin': 751,
#  'hope': 752,
#  'threatened': 753,
#  'species': 754,
#  'aquarium': 755,
#  'osaka': 756,
#  'succeeded': 757,
#  'artificially': 758,
#  'rockhopper': 759,
#  'penguin': 760,
#  'sky': 761,
#  'journalist': 762,
#  'speechless': 763,
#  'mp': 764,
#  'nothere': 765,
#  'plan': 766,
#  'giant': 767,
#  'panda': 768,
#  'macau': 769,
#  'gives': 770,
#  'twins': 771,
#  'get': 772,
#  'britain': 773,
#  'invoke': 774,
#  'article': 775,
#  'sea': 776,
#  'turtle': 777,
#  'beaten': 778,
#  'dead': 779,
#  'taking': 780,
#  'selfies': 781,
#  'loggerhead': 782,
#  'receiving': 783,
#  'sticks': 784,
#  'stepped': 785,
#  'german': 786,
#  'lawyers': 787,
#  'probe': 788,
#  'erdogan': 789,
#  'alleged': 790,
#  'intensify': 791,
#  'cooperation': 792,
#  'fellow': 793,
#  'supporters': 794,
#  '52': 795,
#  'win': 796,
#  'entirely': 797,
#  'overwhelming': 798,
#  'calling': 799,
#  'government': 800,
#  'hold': 801,
#  'prevent': 802,
#  'irreversible': 803,
#  'damage': 804,
#  'turkey': 805,
#  'downing': 806,
#  'russian': 807,
#  'jet': 808,
#  'edward': 809,
#  'snowden': 810,
#  'lawyer': 811,
#  'push': 812,
#  'pardon': 813,
#  'obama': 814,
#  'opinion': 815,
#  'poll': 816,
#  'majority': 817,
#  'half': 818,
#  'adults': 819,
#  'say': 820,
#  'happy': 821,
#  'result': 822,
#  'five': 823,
#  '43': 824,
#  'saying': 825,
#  'unhappy': 826,
#  'outcome': 827,
#  'conservative': 828,
#  'campaigner': 829,
#  'post': 830,
#  'economists': 831,
#  'predict': 832,
#  'recession': 833,
#  'weakening': 834,
#  'france': 835,
#  'creating': 836,
#  'superstate': 837,
#  'limiting': 838,
#  'powers': 839,
#  'individual': 840,
#  'britains': 841,
#  'decision': 842,
#  'pakistani': 843,
#  'clerics': 844,
#  'declare': 845,
#  'transgender': 846,
#  'marriages': 847,
#  'legal': 848,
#  'david': 849,
#  'cameron': 850,
#  'pm': 851,
#  'forecasts': 852,
#  'votes': 853,
#  'nicola': 854,
#  'sturgeon': 855,
#  'highly': 856,
#  'likely': 857,
#  'largest': 858,
#  'tibetan': 859,
#  'buddhist': 860,
#  'institute': 861,
#  'ordered': 862,
#  'demolished': 863,
#  'chinese': 864,
#  'single': 865,
#  'place': 866,
#  'rich': 867,
#  'richer': 868,
#  'expense': 869,
#  'poor': 870,
#  'oxfam': 871,
#  'warns': 872,
#  'spanish': 873,
#  'returned': 874,
#  'spain': 875,
#  'back': 876,
#  'drops': 877,
#  'nearly': 878,
#  'strong': 879,
#  'results': 880,
#  'newcastle': 881,
#  'jk': 882,
#  'rowling': 883,
#  'leads': 884,
#  'charge': 885,
#  'buenos': 886,
#  'aires': 887,
#  'close': 888,
#  '140': 889,
#  'captivity': 890,
#  'degrading': 891,
#  'horacio': 892,
#  'zoos': 893,
#  'animals': 894,
#  'gradually': 895,
#  'moved': 896,
#  'nature': 897,
#  'reserves': 898,
#  'argentina': 899,
#  'provide': 900,
#  'suitable': 901,
#  'northern': 902,
#  'deputy': 903,
#  'polls': 904,
#  'polling': 905,
#  'happened': 906,
#  'petition': 907,
#  'popular': 908,
#  'crashing': 909,
#  'north': 910,
#  'korea': 911,
#  'printing': 912,
#  'massive': 913,
#  'amounts': 914,
#  'fake': 915,
#  'currency': 916,
#  'defectors': 917,
#  'sinn': 918,
#  'fein': 919,
#  'irish': 920,
#  'reunification': 921,
#  '70': 922,
#  'sharemarket': 923,
#  'disowns': 924,
#  '350m': 925,
#  'nhs': 926,
#  'hours': 927,
#  'soon': 928,
#  'possible': 929,
#  '350': 930,
#  'fund': 931,
#  'big': 932,
#  'mistake': 933,
#  'captions': 934,
#  'takes': 935,
#  'every': 936,
#  'send': 937,
#  'stamped': 938,
#  'material': 939,
#  'london': 940,
#  'banking': 941,
#  'job': 942,
#  'start': 943,
#  'large': 944,
#  'spike': 945,
#  'searches': 946,
#  'passport': 947,
#  'applications': 948,
#  'broke': 949,
#  'backs': 950,
#  'remain': 951,
#  '94': 952,
#  'night': 953,
#  'residents': 954,
#  'guilty': 955,
#  'insulting': 956,
#  'recep': 957,
#  'tayyip': 958,
#  'depicting': 959,
#  'gollum': 960,
#  'character': 961,
#  'lord': 962,
#  'rings': 963,
#  'antalya': 964,
#  'province': 965,
#  'rifat': 966,
#  'jail': 967,
#  'sentence': 968,
#  'stripped': 969,
#  'parental': 970,
#  'custody': 971,
#  'today': 972,
#  'decides': 973,
#  'whether': 974,
#  'e': 975,
#  'cigarettes': 976,
#  'public': 977,
#  'warn': 978,
#  'ban': 979,
#  'using': 980,
#  'places': 981,
#  'damaging': 982,
#  'may': 983,
#  'put': 984,
#  'smokers': 985,
#  'quit': 986,
#  'rosanna': 987,
#  'connor': 988,
#  'health': 989,
#  'england': 990,
#  'china': 991,
#  'harvesting': 992,
#  'organs': 993,
#  'prisoners': 994,
#  'opens': 995,
#  'fire': 996,
#  'cinema': 997,
#  'complex': 998,
#  'several': 999,
#  ...}

# %%
len(vocab_to_int)
# Out:
# 31295

# %%
# Special tokens that will be added to our vocab
codes = ["<UNK>","<PAD>"]

# Add codes to vocab
for code in codes:
    vocab_to_int[code] = len(vocab_to_int)

# Dictionary to convert integers to words
int_to_vocab = {}
for word, value in vocab_to_int.items():
    int_to_vocab[value] = word

usage_ratio = round(len(vocab_to_int) / len(unique_word_counts),4)*100

print("Total Number of Unique Words:", len(unique_word_counts))
print("Number of Words we will use:", len(vocab_to_int))
print("Percent of Words we will use: {}%".format(usage_ratio))
# Out:
# Total Number of Unique Words: 36311
# Number of Words we will use: 31297
# Percent of Words we will use: 86.19%

# %% [markdown]
# ## For the words which are common within headlines but are absent in Glove corpus, we will have to randomly initialize them. Over the training, those values will be finetuned along with those of Glove vectors.

# %%
# Need to use 300 for embedding dimensions to match GloVe's vectors.
embedding_dim = 300

nb_words = len(vocab_to_int)
# Create matrix with default values of zero
word_embedding_matrix = np.zeros((nb_words, embedding_dim))
for word, i in vocab_to_int.items():
    if word in embeddings_index:
        word_embedding_matrix[i] = embeddings_index[word]
    else:
        # If word not in GloVe, create a random embedding for it
        new_embedding = np.array(np.random.uniform(-1.0, 1.0, embedding_dim))
        embeddings_index[word] = new_embedding
        word_embedding_matrix[i] = new_embedding

# Check if value matches len(vocab_to_int)
print(len(word_embedding_matrix))
# Out:
# 31297

# %% [markdown]
# ## Convert the word sequences to equivalent integer sequences so that it can be used as input to the model

# %%
# Change the text from words to integers
# If word is not in vocab, replace it with <UNK> (unknown)
word_count = 0
unk_count = 0

headlines_sequence = []

for daily_headline in clean_headlines:
    daily_headlines_seq = []
    for headline in daily_headline:
        headline_seq = []
        for word in headline.split():
            word_count += 1
            if word in vocab_to_int:
                headline_seq.append(vocab_to_int[word])
            else:
                headline_seq.append(vocab_to_int["<UNK>"])
                unk_count += 1
        daily_headlines_seq.append(headline_seq)
    headlines_sequence.append(daily_headlines_seq)

unk_percent = round(unk_count/word_count,4)*100

print("Total number of words in headlines:", word_count)
print("Total number of UNKs in headlines:", unk_count)
print("Percent of words that are UNK: {}%".format(unk_percent))
# Out:
# Total number of words in headlines: 616686
# Total number of UNKs in headlines: 7139
# Percent of words that are UNK: 1.16%

# %%
len(headlines_sequence)
type(headlines_sequence[0][0][0])
# Out:
# int

# %%
len(headlines_sequence[0:1][0][2])
# Out:
# 7

# %%
a=headlines_sequence[:1]
for k in range(len(headlines_sequence)):
    for i in range(len(headlines_sequence[k])) :
        print(headlines_sequence[k][i], end="\n")
        #for j in range(len(headlines_sequence[k][i])) :
        #    print(headlines_sequence[k][i], end="\n")
    print("================")
# Out:
# Streaming output truncated to the last 5000 lines.
# [5967, 212, 1011, 18152, 25281, 3202, 44, 29739, 27939, 31295, 31295]
# [5967, 7349, 9455, 1037, 7921, 7737, 1798]
# [5967, 5535, 801, 5405, 30236, 4658, 13977, 211, 101]
# [5967, 25272, 2370, 341, 6864, 876, 2729, 514, 184]
# [5967, 367, 476, 2584, 2165, 199, 11155, 503, 967, 5289, 5290, 22310, 823, 184, 11411, 102, 7628]
# [5967, 162, 3013, 3213, 6099, 825, 21310, 45, 3645, 3455]
# [5967, 29162, 7770, 8040, 31295, 2709, 4422, 562]
# ================
# [5967, 28146, 2056, 14665, 2022, 2205, 2712, 29710]
# [5967, 16118, 876, 18214, 4103, 11917, 31295, 18762, 437, 4037, 4431]
# [5967, 294, 14146, 5948, 3153, 2545, 5185, 4405]
# [5967, 711, 5254, 1823, 71, 416, 4872, 5909, 3895, 484, 12, 527, 71, 5314, 427, 30237]
# [5967, 823, 45, 2262, 162, 163, 22996, 4060, 10784, 730, 23403, 1551, 2474]
# [5967, 4719, 5549, 142, 638, 3922, 972, 786, 15183, 551, 3395, 3512, 9807]
# [5967, 4760, 4761, 2044, 698, 1482, 18035, 804, 453, 21828, 496, 83, 514, 3029, 1530, 105, 613, 3029, 972, 4487, 5674, 1900, 139, 902, 453, 2991]
# [5967, 11422, 287, 2066, 1754, 4431, 449, 4473]
# [5967, 1898, 95, 8601, 3705, 24662, 1185, 58, 629, 58, 66, 2277, 1070, 1726, 4620, 264, 3466, 15884, 7032, 21312, 66]
# [5967, 31295, 914, 4334, 358, 1148, 3427, 5525]
# [5967, 4719, 2529, 96, 7921, 9963, 2742, 3683, 3684, 291, 4319, 13084, 198, 164, 1236, 787, 134, 188, 2349]
# [5967, 100, 2648, 1784, 419, 30238, 10679, 2949, 392]
# [5967, 17939, 4760, 4761, 4839, 430, 1073, 211, 1089]
# [5967, 711, 2303, 655, 658, 30239, 3937, 11736, 7951, 16159, 31295, 4153]
# [5967, 27957, 3126, 1425, 159, 6202, 159, 1555, 13448, 3791, 936, 139, 393, 6422, 825, 27940, 2694, 310, 1620, 1737, 4147, 775, 2457, 3709, 211]
# [5967, 424, 5798, 4532, 167]
# [5967, 191, 2304, 159, 1555, 134, 517, 1760, 4049]
# [5967, 920, 15200, 7069, 3489, 1820, 10649, 517, 1750, 2177, 2093, 12230, 15200, 28066, 7069, 21181]
# [5967, 30184, 31295, 762, 3167, 2347, 3097, 342, 2272, 7362, 4302, 8810, 70, 102, 453, 1831, 3735, 1554, 1492, 4979, 131]
# [5967, 711, 591, 655, 658, 30239, 3937, 11736, 7951, 16159, 676, 4153]
# [5967, 2778, 12543, 615, 983, 1935, 8159, 694, 3762, 1208, 39, 12808, 395, 801, 615, 278, 1028, 1434, 1358, 31295, 776, 13516, 2038, 1008, 10810, 2532, 644]
# [5967, 31295, 1474, 1633, 30240, 30241, 5138, 340, 7042, 1719]
# [5967, 31295, 485, 108, 8181, 3830, 4132, 800, 800, 691, 6137]
# [5967, 31295, 1561, 13398, 7769, 7770, 1286, 1534]
# [5967, 303, 10713, 820, 548, 139, 2793, 6857, 1425, 4615, 822, 309, 310]
# ================
# [5967, 4719, 13465, 498, 82, 58, 458, 571, 102, 560, 937, 30242]
# [5967, 74, 1033, 1410, 5339, 18201, 5339, 2425, 31295, 1494, 5081, 1935, 3691, 456, 7431, 16769, 1767, 3689, 2192, 2841, 6971, 11886]
# [5967, 310, 991, 8892, 102, 1385, 858, 709, 5977]
# [5967, 5423, 1858, 2971, 4070]
# [5967, 4431, 11422, 811, 9799, 549, 7311, 516, 6280, 409, 11422, 287, 27433, 30208, 1788]
# [5967, 4719, 211, 989, 3396, 5490, 311, 366, 622, 7769, 7770, 4156, 4203, 6679, 983, 6027, 822, 198, 5795]
# [5967, 4334, 13729, 3295]
# [5967, 7486, 6280, 4431, 1170, 77, 2480, 4751, 287, 30243, 18031, 6694]
# [5967, 807, 482, 278, 18016, 1637, 12519, 2841, 77, 2742, 5849, 31295, 6775, 642, 30244, 14545, 30245, 613, 84, 2448, 6982, 74, 4166, 4150, 29, 1531]
# [5967, 16513, 3755, 10161, 1879, 6560, 772, 22207, 28054]
# [5967, 13587, 224, 25150, 2263, 17822, 3755]
# [5967, 30246, 2440, 16972, 4273, 14376, 340, 17352, 3871, 17601]
# [5967, 24662, 1582, 10677, 95, 66, 12401, 6, 629, 2277, 3666]
# [5967, 31295, 6427, 3974, 4431, 7311, 11422, 811, 5440, 287, 7486, 77, 873]
# [5967, 1186, 1534, 3199, 12543, 415, 6037, 157, 691, 2620, 22669, 8101, 800, 12318, 5130]
# [5967, 3774, 4298, 865, 5116]
# [5967, 31295, 4663, 6137, 4760, 4761, 1234, 972, 437, 2648, 437, 2352, 2991]
# [5967, 8293, 70, 211, 6900, 981, 2276, 7349, 5501, 22033, 12478]
# [5967, 29650, 17757, 800, 691, 4487, 1900, 105, 1638, 779]
# [5967, 469, 3764, 229, 2558, 1767, 437, 3185, 102, 6812, 1767, 6685, 5178, 2055, 2056, 3093, 8941]
# [5967, 31295, 22, 9834, 470, 4760, 4761, 1900, 58]
# [5967, 9834, 470, 4760, 4761, 1900, 58]
# [5967, 940, 1300, 8101, 5115, 155, 482, 1494]
# [5967, 191, 2315, 1691, 549, 16282, 13346, 4517, 5394, 1759, 4807, 2246, 858, 5636, 199, 11128, 382, 3570, 3825]
# [5967, 16513, 144, 9922, 11289]
# ================
# [5967, 1798, 1646, 276, 584, 1269, 8907, 64, 1585, 5948, 1017, 8284, 632, 4103, 1450, 6776, 971, 224, 5619, 611, 25642, 974, 12228, 5129, 5316, 2802]
# [5967, 1767, 3123, 5883, 745, 1635, 1539, 2684, 4082, 1105, 8752, 565, 476, 26502, 18670]
# [5967, 843, 287, 7367, 7368, 7369, 779]
# [5967, 31295, 313, 4779, 12119, 16418, 583, 4031, 4760, 4761, 4528, 11128, 468, 9030, 102, 752, 6176, 4509]
# [5967, 249, 6994, 9041, 4170, 4333, 260, 866, 30247, 840, 8343, 5978, 18874]
# [5967, 30184, 31295, 167, 1342, 708, 3097, 8285, 3097, 800, 6071, 167, 1310]
# [5967, 31295, 2484, 4135, 14012, 2197, 7133]
# [5967, 5594, 3386, 4999, 11081, 6666, 4431, 24836, 7501, 3049, 1458, 269, 4382, 4999, 2066, 3666, 4219, 3563, 1458, 8846, 1594, 353, 7304, 4999, 6280, 4431, 15, 514]
# [5967, 10413, 74, 1482, 9865, 703, 3919, 711, 30248, 738, 2801, 3320, 661, 4745, 31295]
# [5967, 5535, 22996, 8862, 1284, 1286, 878, 613, 1459, 30, 6404, 4298, 25763, 20590, 694, 2719, 1411, 1162, 5924, 1893]
# [5967, 843, 287, 30249, 9671, 24894, 1106, 28105, 6933, 1043, 6027, 102, 1105, 1007, 211, 2694, 1553, 6027, 1043, 396, 1783, 1838, 5444, 1862, 1838, 5444, 1450, 361, 2154]
# [5967, 197, 10067, 4760, 4761, 23843, 12480, 224, 2150]
# [5967, 3178, 15130, 5909, 613, 12, 1108, 804, 3753, 5706, 5900, 8573, 5909, 626, 5222]
# [5967, 9777, 2317, 3197, 2083, 2077, 711, 711, 28021, 3118, 3707, 2077, 11551, 10615, 31295, 423]
# [5967, 6960, 3658, 1211, 939, 2117, 888, 671, 660, 1075, 1425, 145, 16118, 139]
# [5967, 739, 605, 437, 1434, 1358, 2610, 3084, 6463]
# [5967, 105, 10118, 24021, 30250, 225, 522, 1798, 1831, 395, 3254]
# [5967, 1554, 4395, 3452, 102, 762]
# [5967, 1838, 2277, 9739, 83, 2094, 16116, 972, 14506, 649, 8862]
# [5967, 28042, 5115, 172, 8611, 1231, 800, 6499, 5335, 6769]
# [5967, 6560, 5236, 11890]
# [5967, 436, 287, 1105, 150, 4679, 1553, 6027, 1106]
# [5967, 442, 2233, 691, 991, 3186]
# [5967, 294, 5402, 598, 5171, 1576, 9336]
# [5967, 308, 69, 22843, 50, 5316, 2414, 10231]
# ================
# [5967, 13284, 10838, 3677, 20200, 4279, 19012, 295, 9795, 651, 249, 11834, 773]
# [5967, 212, 64, 682, 2613, 7811, 212, 5315, 2192]
# [5967, 920, 1280, 915, 12740, 5339, 280, 671, 30251, 1176, 211]
# [5967, 300, 1834, 2545, 30252, 11019, 20804, 430, 1091, 167, 2732, 3835, 2165, 1023, 15612]
# [5967, 1108, 351, 554, 983, 2083, 8412, 1298, 18883]
# [5967, 31295, 30253, 31295, 4186, 2189, 198, 164, 1474, 11145, 1594, 354, 968, 1125, 4060, 4500]
# [5967, 503, 632, 1366, 2111, 1590, 2414, 470, 224, 470, 341, 470, 1106, 420]
# [5967, 1798, 1134, 3575, 614, 3259, 21843]
# [5967, 28064, 911, 6877, 1259, 2930, 981, 647, 15078, 298]
# [5967, 24470, 212, 276, 15961, 936, 30254, 8595, 2310, 4520, 12557, 936, 1189, 927, 30255, 217, 13375, 6812]
# [5967, 1590, 876, 2150, 3691]
# [5967, 4299, 687, 514, 12, 3509, 1048, 1395, 3029, 944, 2418, 7571, 12002, 18590, 1971, 9909, 1231, 2460, 496, 3796, 2694, 12187]
# [5967, 1596, 698, 9877, 50, 2414]
# [5967, 11352, 2028, 2906, 5081, 20393, 2775, 11793, 4689, 4431]
# [5967, 910, 911, 589, 11465, 1164, 2911]
# [5967, 2323, 11344, 30256, 3743, 232, 12705, 12275, 140, 2916, 22711, 12275, 2569, 30257]
# [5967, 31295, 469, 1219, 3719, 1754, 3438, 1017]
# [5967, 655, 2082, 10905, 74, 11933, 3691, 2625, 453, 4344, 9331, 30258, 3788, 2074, 11698, 2061, 5904]
# [5967, 83, 353, 12, 7857, 2414, 1105, 4850]
# [5967, 31295, 249, 773, 812, 18979, 20238]
# [5967, 1099, 104, 11344, 7399, 30259]
# [5967, 22848, 9746, 4573, 5744, 2360, 23311, 11382]
# [5967, 31295, 5784, 217, 2533, 9165, 4031]
# [5967, 30260, 9673, 549, 7182, 568, 224, 104, 3230, 31295, 217]
# [5967, 117, 15937, 1070, 249, 1731, 4103, 35, 1189, 927, 4900, 251, 944, 5961, 7999, 2912, 249, 3911, 4039, 30261]
# ================
# [5967, 4719, 10886, 1234, 211, 26421, 15937, 1933, 18733, 1637, 9211, 3510, 24, 820, 4931, 6920, 266, 2229]
# [5967, 5344, 18851, 401, 31295, 2076, 3284, 276, 329, 942]
# [5967, 31295, 1735, 2645, 4267, 30262, 30263, 7747, 25, 5259, 382, 8091]
# [5967, 300, 1550, 331, 1476, 7552, 10279]
# [5967, 31295, 1171, 4958, 142, 2975, 7926, 229, 18, 3420, 3867, 1362, 389, 2975, 4198]
# [5967, 480, 2190, 19754, 30264, 1362]
# [5967, 29155, 7309, 5547, 6133, 1594, 184, 697, 579, 2165, 294]
# [5967, 300, 98, 2076, 3284, 2545, 557, 19399, 2545, 3629, 484]
# [5967, 5975, 30265, 454, 455, 3141, 11608, 603, 2545, 5850, 1534, 2545, 928]
# [5967, 31295, 24021, 5129, 1749, 1921]
# [5967, 31295, 736, 6724, 12568]
# [5967, 1141, 2662, 1332, 8980, 12388, 15399, 1313, 2991, 657, 991, 2767, 1533]
# [5967, 31295, 851, 22, 862, 1234, 6587, 2227, 265, 4398, 9420, 3543, 28651]
# [5967, 2338, 1164, 5161, 74, 3687]
# [5967, 4719, 3195, 2925, 3690, 233, 1331, 11779, 2039, 324, 5472, 6446, 437, 1288, 4283]
# [5967, 611, 29627, 7769, 7770, 211, 260, 1319, 30266, 31295, 9067, 30267, 22, 1261, 989, 405, 2855, 611]
# [5967, 31295, 31295, 10377, 1299, 1659, 3973, 3064, 39, 3347, 30268, 2527, 3722, 14014, 5444]
# [5967, 144, 2125, 496, 4915, 12, 211, 872, 159, 160, 2222]
# [5967, 10631, 10, 1170, 3188, 1148, 3284, 470, 202, 2229]
# [5967, 1134, 453, 5447, 751, 5729, 263, 13837, 3551, 1265, 3413]
# [5967, 454, 455, 13375, 4263, 101, 2950, 9098, 174, 30269]
# [5967, 1320, 403, 6030, 491, 3430, 2020, 9321, 1111]
# [5967, 2937, 1231, 249, 2222, 30270, 12943, 14015, 2578, 1709, 550, 1483, 1850, 16116, 2277, 396, 249, 3381, 9547, 885]
# [5967, 2040, 477, 2381, 5444, 30271, 2, 30272]
# [5967, 1675, 2848, 548, 2745, 2793, 256]
# ================
# [5967, 4719, 2205, 41, 1987, 629, 25, 41, 2130, 488, 5464]
# [5967, 437, 2811, 4782, 15324, 352, 433, 4272, 8277]
# [5967, 1513, 5948, 1073, 1157, 1592, 7394, 11409, 10784, 294]
# [5967, 74, 198, 164, 1474, 30273, 31295, 857, 225, 967, 694, 4082, 681]
# [5967, 807, 4248, 1028, 2222, 34, 14073, 470, 6912, 2973, 12229, 6493, 5543, 12229, 1082]
# [5967, 1192, 45, 1879, 31295, 1683, 5108, 12, 113, 1348, 578, 416, 1519, 1845, 1750, 7966, 1146, 681, 3904, 1892, 10621, 31295, 5105]
# [5967, 31295, 3013, 2066, 6690, 3230, 1342]
# [5967, 1234, 1622, 266, 2229, 4931, 31295, 10871, 1224, 1683, 2229, 22977, 2242, 1611, 2474, 286, 4931, 5129, 1571, 6388, 1767, 22, 1767, 8304, 5129]
# [5967, 152, 2074, 395, 4190, 353, 271, 1252, 300]
# [5967, 122, 1352, 9954, 469, 13721, 77, 1554, 7193]
# [5967, 12, 3274, 20206]
# [5967, 767, 6424, 11164, 311, 8864, 494]
# [5967, 1798, 7021, 11244, 7770, 3203]
# [5967, 197, 5254, 299, 155, 74, 340, 967, 197, 788, 1123, 1767, 955, 453, 730]
# [5967, 202, 779, 95, 1262, 858, 2338, 3689, 1769, 865, 1220, 382, 102, 702, 691, 13901, 1798, 3759]
# [5967, 19272, 12242, 555, 2347, 5018, 3379, 188, 1483]
# [5967, 30274, 154, 22, 4435, 55, 729, 294, 1852, 2296, 2153]
# [5967, 31295, 2325, 1217, 543, 294]
# [5967, 790, 453, 730, 1829, 3691, 453, 1097, 197, 1268, 70]
# [5967, 5115, 4333, 786, 4312, 1643]
# [5967, 336, 1145, 9359, 198, 1923, 15628, 27554, 30275, 30276, 30277, 30037, 226, 393, 1596, 3078, 548, 12956, 17568, 1221, 17568, 30278]
# [5967, 504, 11344, 1248, 998]
# [5967, 191, 4775, 18, 5153, 3511, 2973, 12229]
# [5967, 9028, 3895, 8468, 2097, 413, 198, 216]
# [5967, 31295, 2233, 4967, 3551]
# ================
# [5967, 1365, 12446, 29765, 628, 1834, 6776, 21322, 800, 603, 3563, 31295, 31295, 3349, 2464, 548, 384, 3228, 3226, 211]
# [5967, 119, 3002, 700, 11616, 43, 996]
# [5967, 4405, 2331, 102, 484, 943, 5237, 28339, 1382, 27957, 2694, 28599, 4147, 1541, 364, 27940, 7285, 27940, 565, 967]
# [5967, 31295, 453, 2199, 11327, 11328, 30279, 16635, 6724, 578, 31295, 3224, 31295, 10952, 1311, 83, 4678]
# [5967, 197, 70, 409, 74, 199, 20587, 3691, 453]
# [5967, 1085, 1485, 297, 4995, 936, 1418, 260, 261, 639, 1784]
# [5967, 12573, 5806, 26849, 31295, 1179, 1134, 453, 1362]
# [5967, 300, 409, 212, 6062, 11517, 5344, 6258]
# [5967, 818, 353, 9877, 3310, 22843, 6862, 122, 49, 50, 263, 3199, 2414, 1106, 108, 199]
# [5967, 4719, 1659, 25, 9014, 7499, 3593, 779, 927, 2332, 1377, 1345]
# [5967, 13161, 3525, 1328, 611, 1176, 5000, 13161, 2464, 5804, 87, 1410, 4649, 2465, 5192, 1279, 6641, 15362, 281, 364, 484, 1946]
# [5967, 864, 746, 158, 8128, 9826, 5259, 2460]
# [5967, 74, 1148, 1150, 4162, 5215, 1554]
# [5967, 13009, 2066, 16804, 7098]
# [5967, 835, 2047, 159, 1555, 3021, 8058]
# [5967, 28441, 3142, 4051, 817, 1582, 3904, 2991, 7098, 1552]
# [5967, 4719, 197, 2222, 2066, 1767, 972, 411, 281, 159, 160, 1274, 8085, 3691, 199, 413, 1028, 548, 2529, 470, 99, 12, 3941, 5631, 3521]
# [5967, 2522, 9464, 622, 15323, 17737, 14006, 566, 20603]
# [5967, 1558, 2870, 2310, 22, 3327, 9840]
# [5967, 773, 5072, 2415, 240, 1129, 139, 1028, 8669, 2325]
# [5967, 3764, 22, 1602, 2610, 686, 484, 5444]
# [5967, 1767, 2996, 15643, 197, 70, 3691, 453]
# [5967, 786, 1507, 30280, 979, 2315]
# [5967, 4356, 2016, 851, 8949, 15024, 10391]
# [5967, 30281, 977, 205, 12072, 5607, 1534, 9844, 2575, 31295, 16107, 30282, 1199, 39, 27737, 1617, 1142, 5863, 4304, 579, 580, 2066, 30283, 10347, 1286, 30284, 30285]
# ================
# [5967, 22848, 163, 2472, 2015, 4141, 66, 1286]
# [5967, 3254, 1585, 19054, 5338, 5263, 31295, 15384, 31295, 5338, 135, 862, 25797, 2747, 2684, 102, 82, 314, 12165, 446, 1539, 2289, 30286, 2344]
# [5967, 431, 35, 30287, 23098, 12311, 3568, 5607, 12373, 3120, 6658]
# [5967, 1109, 354, 355, 3254, 1585, 2341, 3808, 77, 968, 4431, 8388, 4598]
# [5967, 1450, 10886, 12424, 581, 159, 6996, 9604, 340, 3508, 1493, 8360, 102]
# [5967, 1712, 30284, 30285, 1286, 354, 355, 29914, 2994, 3195, 851, 7631, 12072]
# [5967, 28192, 3305, 10900, 7769, 7770, 30288, 1858, 5331, 142, 532, 30289, 237]
# [5967, 31295, 405, 14269, 23778, 195, 10, 205, 873, 800, 802, 1268, 19165, 27968, 4029, 1767, 2990, 691, 10886, 1234, 211]
# [5967, 191, 2233, 8411, 2038, 1164, 171, 122, 3662, 1590, 146]
# [5967, 1626, 3097, 5644, 8958, 9360, 3524, 3320, 2531, 899, 470, 215, 12]
# [5967, 29650, 17757, 1234, 4487, 1900, 98, 3962, 2229]
# [5967, 2076, 45, 748, 3919, 16154, 1262]
# [5967, 16035, 816, 2398, 74, 1316, 5982, 58, 1554, 1767, 1611, 2610, 674, 12, 2584]
# [5967, 1554, 498, 103, 2355, 4749]
# [5967, 74, 1954, 1146, 996, 10193, 26165, 3472, 3691]
# [5967, 7610, 1767, 737, 3193, 3691, 1595, 3451, 500, 655, 21336]
# [5967, 548, 353, 6673, 5108, 7627, 2478, 183, 10954, 1640, 351]
# [5967, 11, 13344, 29394, 2171, 300, 1178, 262, 1863, 4147, 4635, 139, 4199, 1232]
# [5967, 5218, 3452, 8101, 2205, 326]
# [5967, 31295, 31295, 25140, 2747, 5909, 31295, 12981, 6202, 342, 112, 6426, 3283, 3053, 28376, 6448, 1917, 1138, 1116, 1838, 779]
# [5967, 31295, 30290, 281, 18589, 942]
# [5967, 31295, 1106, 17492, 50, 10679, 1418, 1108, 7285]
# [5967, 1767, 2341, 3162, 2441, 745, 579, 6996, 5190, 1554, 8835, 936, 1611, 3335, 1157, 3277, 1157, 2064, 4043, 3605, 7237, 7205, 4267, 2098, 25281, 6080, 71, 416]
# [5967, 247, 2925, 195, 6156, 2216, 5115, 1376, 4398, 17629, 247, 199, 2427, 7252, 1643, 142, 39]
# [5967, 10151, 3691, 1595, 30291, 5505, 15098, 18691, 2506, 13095, 6144, 261, 74, 4416]
# ================
# [5967, 6899, 10078, 906, 633, 387, 2034, 793, 1021, 3544, 744, 6656, 5145, 3393, 1948, 13055, 30292, 1295, 2277, 5096, 1061, 6202, 2277]
# [5967, 9739, 2164, 7061, 30293, 1549, 2991, 13368, 582, 470, 76, 2089, 342]
# [5967, 6420, 13811, 74, 8521, 2515, 10090, 6003, 1657, 5405, 71, 17174]
# [5967, 28947, 240, 49, 10559, 5270, 28005, 20460, 355, 1284, 687, 377, 17873, 613, 354, 355, 8284]
# [5967, 431, 10889, 9842, 2263, 31295, 6757, 6048, 1295, 1296, 4616, 778, 48, 431, 10889, 214, 6105, 1186, 314, 687, 314, 184, 967]
# [5967, 681, 5481, 2044, 31295, 2246, 10140, 8570, 3645, 2545, 5013]
# [5967, 7421, 646, 4532, 1735, 8265, 1020, 13122, 4127, 1594, 470, 3824, 1529, 10470, 4317, 101, 30294, 101, 8164, 6989, 5073, 7968]
# [5967, 28192, 430, 1097, 10638, 773, 1834, 772, 1978, 1526, 1127, 2054, 1831, 3904, 3355, 1867, 587, 404, 405, 25772, 11074, 195]
# [5967, 6473, 16236, 4156, 7769, 7770, 2558, 2172, 3215, 503, 3153, 8312, 15]
# [5967, 1767, 872, 300, 7566, 2710]
# [5967, 5288, 12, 418, 535, 211, 645, 6214]
# [5967, 1659, 858, 1067, 609, 5637, 3692, 8131, 875]
# [5967, 31295, 1176, 613, 13120, 3619, 1942, 340, 10506, 10283]
# [5967, 16597, 3842, 1026, 30295, 752, 4388, 2242, 4156, 10033, 1678, 2089, 3489]
# [5967, 1683, 341, 224, 14867, 1275, 7610, 1767]
# [5967, 3320, 424, 3092, 5923, 2863, 3320, 12, 211, 56, 4561, 1132, 4785, 25161, 4817, 1871, 7232, 3606]
# [5967, 219, 2180, 159, 160, 1345, 4760, 17757, 199, 13893, 996, 2991, 183, 2229, 363]
# [5967, 1127, 2802, 446, 1828, 5596, 1768, 801, 4776, 7453, 19835, 8777, 730, 3606, 340, 14951, 33, 17221, 1581, 1440, 10205]
# [5967, 10063, 31295, 7769, 7770, 459, 6147]
# [5967, 30296, 3713, 16234, 16236]
# [5967, 587, 71, 19519, 4967, 197, 591, 1767]
# [5967, 71, 3733, 1224, 3264, 10318]
# [5967, 5723, 1879, 99, 578, 983, 11916, 3880, 627, 702, 6114, 745, 1630, 15606, 30297, 1020, 800, 22, 2910, 5999, 746, 1603, 977, 17282, 3139, 3830, 800]
# [5967, 23178, 2342, 437, 2937, 3825, 1028, 1862, 23098, 16406, 30298, 30299, 12149, 27939, 495, 31295, 11744, 16306, 31295, 1119, 1393, 12]
# [5967, 31295, 96, 3524, 2774, 5119, 14098]
# ================
# [5967, 5984, 101, 58, 2268, 1988, 2169, 438, 3346, 582, 1988, 2832, 1295, 1296, 1588, 977]
# [5967, 6032, 2994, 3360, 7769, 1055]
# [5967, 4719, 1319, 56, 7769, 7770, 936, 3123, 4382, 211]
# [5967, 15057, 30300, 12, 1118, 12626, 249, 207, 188, 1117, 30301, 30, 5543, 30302, 1879, 188, 8420, 294]
# [5967, 31295, 17378, 10393, 7747, 16208, 5918]
# [5967, 1565, 800, 1834, 587, 28330, 7616, 1163, 1295, 30303, 381, 12382, 30304]
# [5967, 3320, 7022, 27813, 1767, 8734, 11731, 207, 7570]
# [5967, 910, 911, 3210, 2906, 2125, 471]
# [5967, 5820, 9113, 3451, 5999, 548, 1108, 1807, 45, 358, 779]
# [5967, 212, 691, 3941, 587, 3904, 3543, 1831, 972]
# [5967, 233, 9561, 249, 11667, 9893, 940, 276, 1447, 13243, 699, 105, 1395, 1552, 13005, 2069, 341]
# [5967, 4719, 9843, 1010, 2402, 4826, 5115, 3986, 1332, 6322, 1905, 30305]
# [5967, 28146, 2205, 41, 477, 314, 83, 2774, 300, 816]
# [5967, 88, 1, 1341, 276]
# [5967, 25728, 315, 3277, 453, 3539, 1769, 1505, 24, 15420]
# [5967, 870, 3390, 3619, 5055, 3571, 7769, 7770, 11718, 842, 5857, 1319, 933, 197, 1436, 6001]
# [5967, 31295, 7769, 7770, 3096, 2723, 30306, 5171, 369, 4831, 129, 9770]
# [5967, 1286, 7554, 15948, 3558, 2439, 7182, 5012, 562, 6279, 2529, 9210, 1552, 7769, 16234, 31295, 11534]
# [5967, 773, 5446, 3904, 3543, 1831]
# [5967, 28002, 3090, 800, 7770, 396, 872, 8312]
# [5967, 12, 3141, 5041, 6113, 23648, 11041, 6863, 4532, 876, 1579, 6933, 10078, 565, 384, 1109, 1549, 184]
# [5967, 5893, 9654, 102, 2460, 1416, 211, 2460, 238]
# [5967, 1748, 3082, 10036, 24, 2082, 7529]
# [5967, 4431, 30307, 8161, 15897, 21996, 2202, 30308, 4573, 2352]
# [5967, 835, 14379, 1070, 3284, 276, 6724, 300, 857]
# ================
# [5967, 11427, 3096, 7770, 237, 3792, 1858, 511, 18]
# [5967, 3360, 1497, 2916, 2952, 4299, 2438, 15422, 7769, 7770]
# [5967, 6668, 3117, 4071, 358, 2093, 2337, 17847]
# [5967, 1341, 3662, 29, 5949, 2924, 88, 5028, 9621, 3641, 4064, 1871, 405, 30309, 30310]
# [5967, 191, 653, 4671, 7603, 7603, 8101, 2427, 3558, 1333]
# [5967, 82, 1395, 10333, 8071, 1108, 1126, 5000, 30311, 548, 10333, 433, 217, 7865]
# [5967, 991, 571, 1650, 8595, 197, 2194, 558, 3724, 3652, 4239, 1650]
# [5967, 910, 911, 3276, 1357, 3924, 517, 165, 3920, 17190, 384, 1357, 3924]
# [5967, 31295, 162, 163, 8525, 13336, 30312, 7359, 20096, 4431]
# [5967, 120, 6929, 2060, 212, 1295, 135, 3296, 17, 276]
# [5967, 10246, 1717, 786, 22640, 2158, 150]
# [5967, 83, 1395, 2336, 10294, 11738, 1931, 23892, 383]
# [5967, 1046, 8312, 1490, 4151, 314, 825, 3606, 1760]
# [5967, 31295, 995, 1161, 9619]
# [5967, 159, 1555, 318, 566, 22820, 6569, 3631, 1539, 173, 23568, 585, 8511, 4989, 9529, 698, 1954, 22235, 10497, 627, 3543]
# [5967, 211, 2056, 1123, 3277, 1657, 3762, 3162, 21995, 1592, 671]
# [5967, 26507, 11411, 30313, 376, 30314, 28483, 28692, 6552, 5444, 10087, 18646]
# [5967, 1088, 280, 12466, 1212, 1858, 5052, 1642, 7364, 875]
# [5967, 31295, 7689, 2258, 365, 169, 3224, 12934, 9328, 30315, 2524, 754, 3471, 1845, 28171, 767, 3044, 3373, 1617, 181, 1628, 4837, 7412, 20694, 4915, 2978, 7524]
# [5967, 31295, 7769, 7770, 1552, 2529, 437, 493]
# [5967, 141, 358, 16116, 30316, 7021]
# [5967, 249, 807, 1366, 1266, 1267, 972, 3514, 365, 1591, 8433, 738, 7968, 2942, 9157, 1142, 4801, 7731, 7214, 8906, 30317]
# [5967, 31295, 621, 622, 4277, 16043, 5507]
# [5967, 71, 1703, 20045, 1432]
# [5967, 71, 199, 135, 1701, 469, 77, 4350, 6822, 1163, 427, 7128]
# ================
# [5967, 140, 1003, 5936, 7769, 7770, 1035, 7769, 7770, 74, 405, 5014, 102]
# [5967, 237, 3568, 7481, 31295, 14685, 7021, 6483]
# [5967, 611, 4405, 31295, 17467]
# [5967, 237, 4501, 136, 3641, 2843, 2286, 3793, 914, 9936, 511, 18, 1211, 167, 5193, 396, 2202, 17, 5659]
# [5967, 101, 30318, 7769, 7770, 1549, 9273, 12, 2150, 12096, 7770, 102, 354, 1426, 7092, 1387]
# [5967, 2862, 2863, 295, 225, 1767, 4183, 4267, 21588, 943, 5750, 10391, 6058, 13815, 15726, 71, 427]
# [5967, 30319, 5008, 628, 10778, 2558, 7769, 7770, 3174, 1378, 732, 2464, 356, 7770, 3174]
# [5967, 101, 5177, 3271, 30320, 101, 2032, 276, 856, 30321, 30322, 2863, 6556, 1091, 15751, 14401, 983, 30323]
# [5967, 1748, 1632, 19060, 2355, 1029, 1756, 811]
# [5967, 31295, 2460, 15368, 1594, 3728, 2460, 5265, 640, 2857, 5909, 7054, 3393, 21912, 4263, 22, 2011, 15217, 16517]
# [5967, 773, 3230, 188, 12122, 3983, 18485]
# [5967, 843, 4668, 1517, 439, 1106, 2899, 3576, 7146, 1337]
# [5967, 864, 1021, 7491, 102, 1291, 2278, 14033]
# [5967, 31295, 2842, 2842, 8549, 20301, 14299, 399, 3544, 21041, 30324]
# [5967, 3858, 1686, 3295, 3120, 5996, 2076, 315]
# [5967, 21022, 7769, 7770, 31295, 31295, 15173, 977, 2657, 7770, 23676]
# [5967, 25728, 45, 9626, 1089, 766, 8975, 940, 96, 281, 790, 7657, 1111]
# [5967, 29162, 7770, 13766, 3067, 2477, 61]
# [5967, 2192, 392, 2411, 627, 1339, 205, 311, 800, 861, 548, 217, 3762, 10252, 1479, 1390, 4732, 4048]
# [5967, 1767, 23371, 30325, 7769, 7770]
# [5967, 31295, 13287, 862, 587, 1395, 2143, 1061]
# [5967, 3290, 362, 3713, 496, 12, 2150, 7770, 936, 354, 496, 3029, 30326]
# [5967, 211, 15578, 20876, 1970, 556, 159, 1555]
# [5967, 159, 1555, 24155, 427, 682, 8702, 30327, 364, 2994, 562, 369, 442, 611, 18639, 6286]
# [5967, 28435, 7769, 7770, 1552, 3037, 1319, 261, 1593, 3575, 384, 633, 18990, 237]
# ================
# [5967, 4719, 3568, 7769, 7770, 7718, 337, 16234, 26937, 64, 3320, 30328, 8476, 195, 74, 989, 112, 387]
# [5967, 3582, 4157, 5794, 7769, 7770]
# [5967, 260, 7769, 7770, 1313, 237, 1366, 10237]
# [5967, 212, 800, 766, 6300, 2545, 18, 5775]
# [5967, 6338, 4329, 2694, 2263, 31295, 8768, 1450, 340]
# [5967, 30329, 910, 911]
# [5967, 26543, 3973, 30330, 2529, 4035, 1002, 6591, 496, 18564, 294, 437, 639, 1784]
# [5967, 28435, 4449, 4157, 7769, 4156]
# [5967, 1767, 155, 766, 2055, 2056, 2036, 1434, 1358, 211, 1823]
# [5967, 587, 2089, 4967, 4267, 11326]
# [5967, 11, 102, 876, 1343, 5316, 294, 800, 5958, 229, 6300, 936, 548, 4275, 196, 3363]
# [5967, 715, 155, 150, 342]
# [5967, 3698, 260, 1342, 7769, 7770, 2791, 875]
# [5967, 1046, 8312, 1490, 2903, 1186]
# [5967, 1933, 71, 1578, 6755, 74, 1330, 10465, 9797, 2464, 7999]
# [5967, 260, 9784, 404, 405, 349, 347, 351, 449, 1961, 2413]
# [5967, 300, 3447, 2292, 159, 1555, 237, 3447, 1867, 875, 1593, 260, 2791, 1342, 7769, 7770, 1002]
# [5967, 212, 1164, 14455, 5630, 2180, 3626, 939]
# [5967, 4719, 742, 1645, 2431, 1109, 1387, 35, 823, 184, 1434, 1358, 1004, 562, 3311, 1656, 102, 364, 858, 742, 4993, 3311, 725, 1085, 731, 5080, 629, 565, 1434, 1358]
# [5967, 1554, 742, 1643, 6226, 3691, 9168, 2773, 7017]
# [5967, 4719, 857, 598, 326, 910, 911, 9631]
# [5967, 431, 354, 355, 122, 801, 3552, 4170, 3631, 7769, 7770, 3568]
# [5967, 4719, 1659, 309, 303, 977, 1343, 5847, 10078, 5766, 1085, 2652, 181, 308]
# [5967, 294, 800, 11332, 229, 14811, 39, 2545, 4744, 10686, 229, 9251, 14146, 7559, 2582]
# [5967, 202, 779, 237, 7770, 3568, 3754, 30331]
# ================
# [5967, 5236, 12, 1863, 8220, 25393, 4431]
# [5967, 715, 979, 30332, 21930, 6419, 1165, 21932, 13811, 13950, 5273]
# [5967, 983, 1863, 4337, 603, 2464, 30333, 9056, 24384, 2569, 13949, 2847, 582, 1921]
# [5967, 1767, 1226, 280, 3259, 21843, 3691]
# [5967, 3552, 21783, 4663, 42, 9781, 4760, 4761, 2210, 1534, 3605, 2511, 354, 452, 453]
# [5967, 31295, 867, 20206, 1510, 2113, 5264, 2693, 14060, 562]
# [5967, 9893, 249, 1945, 195, 8958, 3645, 30334, 4703]
# [5967, 2205, 2712, 811, 1834, 14271]
# [5967, 14669, 14670, 77, 9345, 470, 5680, 286, 404, 405, 26781, 26782]
# [5967, 31295, 698, 2622, 1311, 1300, 9394, 30335, 7302, 2294, 1132]
# [5967, 213, 2842, 11081, 1343, 5772, 10115, 56]
# [5967, 415, 8141, 7146, 3009, 843, 1300]
# [5967, 1458, 779, 237, 7770, 3568]
# [5967, 4069, 12, 3029, 1831, 5033, 1217, 1529, 1893, 1070, 417, 548, 1617, 96, 97, 2506, 1785, 8877, 423, 1146, 2912, 1806, 627, 341, 224, 783, 1971, 1436, 1635]
# [5967, 875, 5796, 3788, 10131, 3347, 1186, 10636, 35, 1594, 315]
# [5967, 74, 8700, 22308, 211, 1502, 295, 550, 27939, 427, 31295, 27939, 10413, 416, 31295, 9378, 27438, 2856, 1767, 655, 28197, 8570]
# [5967, 2056, 1834, 9273, 5995, 9893, 76, 3347]
# [5967, 2480, 2406, 6, 1497, 4147, 7766, 7893, 7122]
# [5967, 3467, 7769, 7770, 4306, 237]
# [5967, 31295, 1742, 686, 367, 568, 2610, 3965]
# [5967, 27953, 1484, 3756, 1166, 911]
# [5967, 4405, 17830, 2370, 469, 5911, 2218, 4431]
# [5967, 2130, 6263, 150, 9836, 5148]
# [5967, 286, 15148, 326, 849, 13150, 1533, 249, 5804, 87, 4123, 5571, 424]
# [5967, 203, 13085, 409, 1767, 7124, 7125]
# ================
# [5967, 823, 45, 10265, 2930, 354, 355, 17677, 1073, 11915, 4025, 28217, 801, 29984, 230, 4431, 11760, 8510, 1223, 1798, 5364, 212, 5129]
# [5967, 28146, 2205, 41, 8062, 5646, 2712, 2345]
# [5967, 74, 5129, 1827, 745, 3753, 5279, 1185, 207, 31295, 1061, 2055, 2056, 3447, 1025, 4431]
# [5967, 13464, 3013, 214, 13465, 12592, 3395, 30336, 4150]
# [5967, 1395, 1534, 1674, 3474, 276, 1106, 2227, 4153, 392, 1651, 9707, 3123, 2831, 922, 3268, 1300, 18888, 1208, 1105]
# [5967, 2205, 2712, 3013, 2066, 6690, 196, 14271]
# [5967, 22308, 2381, 5014, 10, 657, 9436, 13648, 15723, 22638]
# [5967, 31295, 1234, 4488, 280, 3236, 3451]
# [5967, 3764, 2610, 686, 655, 814, 372, 1554]
# [5967, 570, 655, 9953, 503, 416, 17252, 1434, 1358, 4031]
# [5967, 212, 1954, 7272, 198, 164, 1117, 10243, 3140, 1572, 521, 3078, 4829]
# [5967, 25140, 26675, 2406, 2146]
# [5967, 14270, 15849, 14269, 23778, 1219, 453, 730, 627, 2874, 787, 437, 276, 1925, 3642, 1675, 2360, 1483, 453, 730, 1132, 730, 3606]
# [5967, 4404, 96, 97, 470, 105, 2005, 12, 25971, 7447, 2912, 249, 20823, 1635, 1215, 7091, 676]
# [5967, 5804, 5129, 1798, 27957, 565, 396, 28197, 2306]
# [5967, 4719, 6077, 5344, 401, 227, 7362]
# [5967, 5171, 4147, 972, 4431, 581, 7792, 1612, 20244, 1394, 211, 31295, 1553, 10858]
# [5967, 19341, 287, 20677, 10714, 2118, 2066, 211, 2056, 1332, 8387, 139, 999, 184, 185, 4734, 167, 301, 3572, 1090, 1635, 5653]
# [5967, 1767, 9572, 102, 1843, 71, 522]
# [5967, 24662, 4333, 2419, 1105, 3697, 3009, 1300]
# [5967, 147, 800, 667, 2684, 1148, 2685, 1596, 698, 8468, 14413, 1398, 745, 682, 676, 2042, 1288, 5602, 144, 2064, 133]
# [5967, 991, 5958, 437, 3505, 1164, 1744]
# [5967, 4147, 101, 5130, 1052, 485, 876, 26444, 139, 476, 101, 5130, 1052, 485, 876, 26444, 139]
# [5967, 703, 22081, 2694, 9459, 31295, 10993, 340, 9739, 30337, 30338, 7385, 2299, 2059, 772, 4986, 8883]
# [5967, 1823, 762, 2289, 780, 4431, 14436, 10998, 1945]
# ================
# [5967, 74, 8700, 1942, 1007, 8451, 4813, 814, 17289, 984, 25707, 437, 2610, 13328, 1767, 1834]
# [5967, 4431, 1784, 5111, 1988, 1223, 469, 14659, 996, 2478, 26804, 721, 3858, 30339, 19]
# [5967, 991, 1834, 1482, 2385, 4202, 310, 437, 684, 1298]
# [5967, 102, 30244, 14545, 2222, 358, 779]
# [5967, 1097, 6501, 287, 13451, 1627, 159, 160, 2719, 3743]
# [5967, 4719, 880, 7991, 7071, 655, 9905, 7128, 6676, 296, 520, 416, 2856, 15767, 1356, 25196, 4493, 3100, 655, 2398, 7128, 2534, 865, 14321, 1592, 416, 2410]
# [5967, 579, 1441, 857, 2483, 150, 3757, 6442, 746, 4123, 4957, 694, 979, 340, 2506, 12276, 7453, 522, 436, 159, 160, 746, 198, 164, 787]
# [5967, 922, 271, 7935, 885, 8237, 1436, 1975, 1017, 1395, 1186, 15215]
# [5967, 1594, 45, 1879, 1582, 439, 3139, 294, 520, 1726, 185, 2347, 1450, 885]
# [5967, 16513, 3755, 18334, 5111, 1988, 15981, 4473, 22778, 778, 21812, 39, 26804, 29358, 19973, 8726]
# [5967, 24470, 835, 1332, 491, 1439, 437, 276, 10, 566, 2545, 299, 12, 16759, 6122, 3154, 4463, 8960, 483, 1035, 20871, 249, 30340, 6197, 5185, 1240]
# [5967, 211, 8736, 71, 16708, 14469, 3012, 12789, 9602, 655, 27448, 2168, 56, 3320, 416]
# [5967, 31295, 2222, 30341, 30342, 22, 4381, 4386, 282, 611]
# [5967, 26301, 5958, 229, 613, 2113, 30343]
# [5967, 807, 22843, 2293, 12682, 2056, 20444, 8643, 4431, 191, 4431]
# [5967, 3764, 6024, 3334, 102, 1141, 3762]
# [5967, 8844, 11457, 770, 2035, 814, 324, 10113, 1390, 2936]
# [5967, 2855, 1007]
# [5967, 504, 13354, 31295, 866, 311, 2949, 679, 29855, 8114, 1846, 598, 8489, 2042, 907, 30344, 772, 26509]
# [5967, 12155, 337, 17, 7148, 31295]
# [5967, 1236, 11666, 358, 7279, 47]
# [5967, 30345, 2141, 31295, 30346, 975, 642, 10476, 1119, 83, 2245, 2474, 9664]
# [5967, 30347, 14592, 3252, 4202, 3968]
# [5967, 355, 1002, 4775, 974, 14226, 3757, 746, 340]
# [5967, 19408, 4760, 4761, 1587]
# ================
# [5967, 31295, 90, 11325, 15534]
# [5967, 4719, 2205, 2712, 30348]
# [5967, 579, 2545, 3985, 17965, 31295, 6789, 631, 579, 2545, 2727]
# [5967, 1702, 7186, 4449, 6824, 212, 249, 9764, 9893, 1281, 10057, 17654]
# [5967, 212, 249, 2424, 31295, 459]
# [5967, 74, 287, 503, 211, 614, 1164, 1382, 5303, 4378, 1382, 1350, 30098, 1946, 30349, 7032, 1683]
# [5967, 31295, 1325, 2205, 41]
# [5967, 1618, 416, 1802, 1626, 6135, 2165, 2169]
# [5967, 437, 4431, 1784, 249, 9519, 1109, 1061, 2069, 12, 20994, 8959, 4431]
# [5967, 991, 229, 2233, 1421, 514, 9763, 3502, 4074, 596, 5196]
# [5967, 2355, 5138, 618, 44, 45, 30350, 16396]
# [5967, 31295, 4329, 6024, 10830, 6926, 520, 27331, 5675, 30351, 3395, 2606, 5602, 17549, 482, 5983]
# [5967, 13570, 1971, 11326, 2745]
# [5967, 1691, 22843, 6862, 1106, 6048, 598, 1418, 202, 1427, 1337, 1208, 102, 1954, 595, 1105]
# [5967, 2545, 11291, 1602, 579, 580]
# [5967, 75, 2205, 282, 3561, 6687, 280, 3561, 30352]
# [5967, 1458, 184, 185, 6982, 4381, 3744, 627, 3320, 265, 2910, 550, 8127, 1382, 940, 3120, 249, 1794]
# [5967, 991, 5636, 1164, 1744, 260, 261, 583]
# [5967, 29650, 4761, 1234, 2066, 7429]
# [5967, 4142, 514, 22291, 619, 50, 21828, 6528, 4760, 4761]
# [5967, 4382, 687, 354, 355, 5869, 17040, 2161, 22, 74, 800, 10429, 3724, 655]
# [5967, 8673, 8845, 3336, 1760, 159, 1555, 8961, 3162, 5909, 23577, 207, 745, 14395, 145, 10374, 2522]
# [5967, 13451, 3593, 5880, 11149, 424, 30353, 18968, 3735, 2732]
# [5967, 31295, 1585, 22, 13768, 287, 21733, 16116, 2273, 4226, 398, 10801]
# [5967, 13451, 2732, 197, 2719, 3743, 1097, 6501]
# ================
# [5967, 1767, 973, 2233, 3092, 1865, 12195, 64, 11699]
# [5967, 74, 20896, 16197, 6437, 28123, 28124, 9417, 3335, 2620, 3320, 12, 1767, 1007]
# [5967, 4719, 977, 3027, 6566, 9350, 19832, 5888]
# [5967, 3961, 1457, 5185, 12724, 1176, 211, 358, 159, 526, 547, 26511, 3139, 3835, 1269, 9247, 12285, 28021, 1031, 3219, 6398, 5090, 5185, 800, 1128]
# [5967, 13451, 22, 1767, 39, 2305, 800, 657, 6401, 6078, 22638, 197, 2719]
# [5967, 4931, 15928, 2069, 341, 3024, 6095, 5142, 8670, 12231, 30354, 9609, 3451, 463]
# [5967, 9769, 8687, 30355, 30356, 779, 9905]
# [5967, 4807, 2063, 5565, 4760, 4761, 15553, 3515, 2803]
# [5967, 1508, 2066, 9964, 6476, 1055, 655, 3691]
# [5967, 694, 3651, 495, 932, 169, 45]
# [5967, 805, 30357, 30358, 1784, 8431, 579, 602, 17713, 24822]
# [5967, 28678, 287, 17958, 1767, 5595, 14245, 1712, 3097, 11888, 3345, 207, 3743, 14013, 5124, 2719, 2506, 6955]
# [5967, 773, 10908, 2719, 13451, 196, 1767, 2305]
# [5967, 6049, 62, 30359, 217, 3297, 12028, 31295, 680, 18609, 30360]
# [5967, 991, 304, 384, 354, 800, 566, 83, 1459, 2113, 2169, 2443, 2391, 30361, 12836, 4814, 83, 3728, 10866, 4620, 7993, 430, 99, 1459, 3239, 30362, 6620, 7782, 2443, 4814, 12836]
# [5967, 436, 1593, 579, 4167, 928, 751, 1268, 212, 800, 18, 2545, 138]
# [5967, 31295, 11406, 1948, 2205, 2712]
# [5967, 1508, 3358, 1099, 6587, 2189, 1692, 1582, 21336, 1301, 1767, 199, 1353, 3691]
# [5967, 7018, 772, 8101, 5115, 4912, 3023, 10, 504, 1539, 29565]
# [5967, 340, 4473, 3884, 10543, 4283, 3743, 2719]
# [5967, 693, 694, 10681, 16077, 5209, 3203, 199, 557]
# [5967, 5130, 30363, 5335, 867, 5115]
# [5967, 3259, 10577, 1125, 2301, 3912, 31295, 2545, 3985, 2945]
# [5967, 1985, 5733, 2331, 13631, 318, 4813, 2177, 23749, 14033, 1985, 4557, 3384, 31295, 318, 4813]
# [5967, 9777, 2317, 30364, 15497, 6596, 2610, 2719, 4532, 1142, 1970, 1316, 10007, 5975, 12080, 6982, 449, 2360, 2474]
# ================
# [5967, 816, 3598, 15489, 2119, 6825, 433, 4272, 1724, 2205, 2712, 12592, 9327]
# [5967, 2205, 2712, 16567, 20211, 565, 30365]
# [5967, 14981, 5237, 1186, 20716, 11786, 3076, 11523, 8326, 1827, 1263, 30366]
# [5967, 9893, 6050, 23462, 77, 2097, 58, 718, 830, 27550, 132]
# [5967, 2205, 2712, 358, 955]
# [5967, 552, 553, 1021, 331, 2614, 3082, 2246, 223]
# [5967, 5549, 18190, 403, 17190, 112, 1559, 31295, 1137, 18, 3651]
# [5967, 159, 1555, 621, 1105, 1178, 29, 415, 416, 28197, 2706, 584, 2336, 3097, 1057, 159, 1555, 482, 112, 22]
# [5967, 83, 502, 169, 5055, 10715, 1119, 96]
# [5967, 4719, 340, 2373, 3471, 1157, 3485, 5975, 786, 18350, 1846, 16006, 3550, 578, 3115, 23412, 293, 1016, 30367, 20413]
# [5967, 940, 9893, 18733, 3029, 30368, 30369, 3557, 3213, 369, 30370, 3176]
# [5967, 31295, 9068, 5055, 1108, 10715, 96, 4989, 2669]
# [5967, 6668, 538, 4749, 1195, 1617, 3362]
# [5967, 3858, 249, 2588, 766, 4135, 2545, 31295]
# [5967, 191, 1953, 1930, 1642, 744, 776, 3505, 3230, 453, 5729, 4710, 5199]
# [5967, 10867, 1395, 167, 2389, 227, 2824, 4665, 2205, 2712, 2345]
# [5967, 26056, 135, 22, 340, 1483, 3757, 746, 345, 697, 21719, 3880]
# [5967, 4719, 13465, 12592, 358, 955, 548, 354, 967, 1549, 353, 30371, 1252]
# [5967, 2161, 470, 9893, 3029, 2755, 15141, 437, 15585, 637]
# [5967, 249, 27939, 12733, 3451, 31295, 1485, 25714, 30243, 3451]
# [5967, 3868, 191, 1970, 31295, 15546, 879, 469, 416]
# [5967, 807, 691, 4472, 929, 2293, 5729]
# [5967, 645, 370, 8094, 6800, 446, 4807, 2337, 7167]
# [5967, 8165, 535, 286, 217, 5129, 1017, 1795, 346, 31295, 453]
# [5967, 14088, 5625, 3791, 1602, 3801, 6297, 4822, 159, 1555]
# ================
# [5967, 940, 249, 3378, 31295, 3541, 11760, 145, 2195, 9405, 1872]
# [5967, 13045, 477, 23897, 600, 681, 799, 311, 4269, 1633, 822]
# [5967, 169, 351, 8869, 3245, 2005, 1534, 5000, 249, 211, 25, 5462, 816, 6707]
# [5967, 95, 341, 13721, 1061, 1029, 276, 2558, 6494, 45]
# [5967, 249, 11667, 3510, 22473, 7918]
# [5967, 2260, 23169, 4566, 24068, 100]
# [5967, 2205, 2712, 4500, 6198, 2345, 1867, 86]
# [5967, 191, 5446, 453, 3868]
# [5967, 1596, 1574, 2118, 6202, 579, 602, 10652, 3364, 4660, 1061, 10652, 3924, 2836, 2952, 7768, 3835, 7107, 1399, 11348, 1218, 995, 8489, 7252, 3248, 4975, 13077, 20759, 5055]
# [5967, 4431, 249, 2570, 23960, 9893, 1061, 1581]
# [5967, 2161, 477, 2832, 10681, 5219]
# [5967, 548, 7505, 9204, 2288, 5116, 13389, 3772, 864, 3969, 4540, 1510, 2569, 6987, 1856, 4701, 1595, 9204, 83, 1900, 544, 864, 989, 746, 660, 2143, 1595, 2291, 632, 428, 5883, 4267]
# [5967, 287, 8145, 191, 3335, 2189, 1766, 3652, 297, 1061]
# [5967, 773, 249, 2558, 1119, 16652, 1581, 2484, 14228]
# [5967, 437, 198, 164, 6085, 70, 8349, 1049, 767, 342, 548, 6567, 12611, 1555, 211]
# [5967, 1426, 95, 341, 3188, 31295, 437, 1029, 12978, 1117, 21906, 157, 13389, 4814, 20038, 1680, 45, 341, 753, 77, 1035, 30372, 2767]
# [5967, 3097, 303, 4277, 8055, 2899, 1157, 1554, 8182, 29, 326, 2469, 4122]
# [5967, 10525, 249, 561, 6500, 2994, 222, 6787]
# [5967, 26056, 4013, 550, 1342, 3757, 746]
# [5967, 31295, 13082, 6783, 2977, 894]
# [5967, 8349, 369, 767, 342, 1622, 198, 164, 627]
# [5967, 7421, 1140, 3858, 180, 549, 2932]
# [5967, 31295, 294, 249, 21663, 395, 8961, 294, 249, 1150, 4790, 4, 10004, 2832, 3541]
# [5967, 2852, 197, 702, 1268, 1898, 12, 548, 967, 358, 177, 1420, 2155, 14951, 5435, 7477, 31295, 31295, 7075, 354, 355, 3376, 874, 3005, 2502, 8083, 338, 820, 3705]
# [5967, 191, 5446, 1494, 3868]
# ================
# [5967, 31295, 23985, 480, 1852, 7934, 4176, 3815]
# [5967, 8165, 535, 7258, 4749, 820, 1617, 6746, 6747]
# [5967, 31295, 163, 1544, 17159, 2795, 13391, 217, 10538]
# [5967, 4431, 1585, 26367, 778, 114, 9893, 1281]
# [5967, 1590, 247, 247, 4671, 7603, 5115, 5115, 8958, 104, 5679, 603, 384, 102, 1643, 2767]
# [5967, 264, 773, 17883, 138, 2123, 13837, 1489, 19127, 848, 2293]
# [5967, 28042, 5115, 6322, 1186, 1642]
# [5967, 1767, 766, 6242, 159, 160, 483, 1268, 790, 453, 730, 74, 1954, 1508, 2227, 2414, 3691]
# [5967, 10238, 1232, 4344, 13290]
# [5967, 4719, 31295, 3320, 1331, 6996, 562, 24, 3111, 4151, 20065, 15362, 7940, 437, 1767, 5211, 3664, 1846, 3320, 416, 24230, 1002, 7831, 1146, 579, 12008]
# [5967, 773, 2669, 1031, 1482, 155, 138, 2545, 2704, 579, 4167]
# [5967, 167, 2732, 6448, 7693]
# [5967, 95, 21142, 778, 2830, 972]
# [5967, 19341, 287, 20677, 10714, 5446, 1609, 689, 13948, 5541, 58, 8934, 942, 8934, 1560, 12]
# [5967, 9893, 1061, 7186, 1233, 19734, 177, 249]
# [5967, 1132, 730, 3606, 29, 25830, 26470, 587, 11348, 974, 2963, 8360, 2310, 1132, 974, 906, 15768]
# [5967, 249, 1073, 5608, 4433, 6041, 5775]
# [5967, 341, 582, 2961, 5096, 276, 3202, 820, 9105, 19120, 1029]
# [5967, 31295, 22, 571, 102, 11493, 5115]
# [5967, 505, 4262, 14085, 211, 10632, 1643, 1264, 21869, 5900, 31295, 2767]
# [5967, 940, 249, 1945, 708, 4431, 8518, 11667, 25067, 4431]
# [5967, 4459, 2745, 1587]
# [5967, 5549, 31295, 102, 6072, 4202]
# [5967, 28002, 6707, 7140, 4509, 4140, 2]
# [5967, 24662, 3283, 11528, 1785, 11286, 1798]
# ================
# [5967, 3099, 6830, 5614, 5092, 11196]
# [5967, 384, 1726, 2511, 69, 45, 2529, 470, 4404, 2168, 44]
# [5967, 910, 911, 8912, 197, 517, 165, 17190, 1931, 383, 17156, 30373, 19911, 1666, 1164, 731]
# [5967, 910, 911, 1497, 197, 13455]
# [5967, 15963, 15964, 6338, 4461]
# [5967, 294, 249, 1262, 226, 51, 309, 310, 555, 1879]
# [5967, 3360, 409, 4081, 3171, 281, 3172, 17391, 627, 72, 3396, 260, 261]
# [5967, 4719, 5380, 27968, 2170, 17848, 30374, 9603, 7237, 1987, 3466, 3899, 1211, 8494, 9029, 2192, 3466, 25823]
# [5967, 18754, 10632, 2680, 551, 1162, 9545, 8090, 1642, 2728, 2836, 30375, 7427, 11492, 30376, 5115]
# [5967, 991, 3210, 2906, 5974]
# [5967, 6071, 104, 159, 1555, 247, 2926, 10987, 1806, 4263, 2163]
# [5967, 7610, 1767, 31295, 2109, 1845]
# [5967, 4416, 799, 413, 1031, 31295, 1032, 989, 11149, 5209, 3203, 459, 1781, 2391, 6608, 17916]
# [5967, 8098, 10296, 469, 477, 5012, 184]
# [5967, 31295, 2222, 1767, 10, 12963, 7421, 58, 1554, 439, 2083, 1418, 13210, 996, 984, 1554, 3844, 1178, 1164, 731, 1948, 2572, 64, 211]
# [5967, 31295, 3448, 470, 8101, 5115, 10868, 468, 2558, 1170, 953, 11161, 2039]
# [5967, 212, 800, 5171, 1863, 801, 25221, 229, 10461, 30377, 4402, 1127, 2054, 1982, 1181]
# [5967, 1319, 4374, 250, 281, 1840, 773]
# [5967, 1166, 911, 589, 8859, 1164, 1306, 587, 686]
# [5967, 4760, 4761, 21783, 3076, 736, 820, 1602, 8280, 5873, 1098, 800, 691]
# [5967, 28045, 3677, 1622, 31295, 3764, 2233, 71, 1611, 520, 655, 6404]
# [5967, 31295, 15938, 287, 10681, 276, 2123, 3197, 967, 3113]
# [5967, 23038, 1140, 5130, 5115, 579, 1642, 9978, 1164, 5678, 5130, 1653]
# [5967, 5115, 4333, 520, 1642, 5130]
# [5967, 2055, 12837, 6996, 229, 1014]
# ================
# [5967, 4719, 1019, 9056, 2541, 849, 11214, 1987, 26218, 627, 3525, 566, 1818, 198, 2192]
# [5967, 745, 5516, 4894, 5115, 470]
# [5967, 31295, 24795, 1657, 7106, 1597, 13834, 20998, 1116, 24630]
# [5967, 31295, 3691, 1353, 1632, 14968, 16317, 11409, 3691, 8772, 7095, 1539, 1767]
# [5967, 24470, 6158, 8278, 5608, 14060, 1613, 2777, 31295, 47, 4378, 1286, 1141, 1642, 1028, 823, 4153, 633, 106, 2163]
# [5967, 5237, 731, 6001, 7496, 849, 7282, 521, 764, 313, 354, 5490, 77]
# [5967, 437, 493, 9076, 602, 6256, 396, 876, 8988]
# [5967, 814, 4456, 2292, 1539, 7249, 3791]
# [5967, 5115, 6155, 104, 4263, 102, 247, 2163]
# [5967, 1342, 5237, 10681, 565, 30378]
# [5967, 1227, 5115]
# [5967, 5549, 6795, 13639, 18542, 6774, 102, 3185, 1948, 1201, 5237]
# [5967, 3447, 1105, 1525, 3596, 2210, 315]
# [5967, 212, 1840, 3963, 1299, 354, 437, 13736, 30379, 991, 30380, 16328]
# [5967, 579, 3432, 7867, 944, 2336, 4712, 2465, 1806, 5055, 535, 644, 1398, 1007]
# [5967, 3737, 1505, 24, 1450, 7105, 1657]
# [5967, 30381, 9567, 5245, 605, 8934, 1659, 384, 9569, 526]
# [5967, 814, 22, 102, 1768, 3576, 9117, 1295, 3023]
# [5967, 159, 1555, 199, 2071, 281, 8101, 5115, 427, 1580]
# [5967, 294, 249, 2483, 8111, 4431, 3347, 17020, 5129, 30382, 15334, 76]
# [5967, 4719, 520, 30383, 5130]
# [5967, 1727, 1368, 4153, 8963, 786, 9025]
# [5967, 1554, 4078, 2477, 95, 249]
# [5967, 5729, 2484, 3443, 16821, 287]
# [5967, 548, 25030, 70, 5263, 3726, 1052, 8348, 991, 9262, 8255, 510, 8539]
# ================
# [5967, 207, 800, 2484, 7236, 214, 77]
# [5967, 5984, 1392, 1736, 1841, 1606, 1166, 911, 326]
# [5967, 150, 3090, 155, 156]
# [5967, 1386, 1127, 867, 162, 2192, 2465, 1116, 1127, 1539, 4532, 2165, 3340]
# [5967, 4719, 294, 249, 1945, 3280, 6050, 23462, 3575, 4454, 8614, 4041, 972]
# [5967, 5374, 184, 102, 7959, 13711, 9877, 24076, 30384, 548, 551, 2381, 2172, 1539]
# [5967, 579, 1004, 562, 225, 7252, 25641, 3019, 8101, 2039, 579, 562, 225, 22644, 1164, 5678, 3892, 776, 5619, 6322, 3449]
# [5967, 1138, 139, 5909, 159, 1555, 199, 9581, 18714, 2648]
# [5967, 23040, 3756, 50, 24080, 9247, 19423, 30385, 31295]
# [5967, 74, 691, 10142, 4172, 14789, 7256, 4333, 3449]
# [5967, 633, 8250, 484, 1961, 74, 800, 115, 609, 7719, 3538, 6569, 722, 3894, 1434, 1358, 2610, 1966, 122, 6312, 2781]
# [5967, 4839, 74, 800, 369, 23652, 4433, 1453, 23667, 8258]
# [5967, 584, 207, 7570, 4967, 830, 1226, 22359, 30386, 70, 207, 7570]
# [5967, 619, 470, 3430, 8036, 4760, 4761, 1234, 21783, 4663, 159, 160, 2222, 22, 7723, 983, 955, 453, 730]
# [5967, 294, 249, 19501, 3989, 392]
# [5967, 4110, 517, 12968, 314, 4098, 773, 134, 3049, 288, 1945, 7262, 8676, 2667, 10593, 3983, 155, 4049, 23960]
# [5967, 28319, 30387, 10216, 30388, 153, 2448]
# [5967, 601, 2169, 217, 23182, 5737, 3719, 1029]
# [5967, 4719, 1342, 4776, 1690, 198, 164, 4500, 2439, 3558, 7182, 31295, 11738, 4776, 3355, 1066, 31295, 12, 8777, 31295, 5012]
# [5967, 105, 1109, 12, 470, 878, 1426, 1529, 7968, 1900, 384, 3697, 4760, 4761, 2506, 21783, 4663, 13893, 548, 2847, 1963, 547, 549, 1887, 382, 943, 199, 413, 6271, 5936]
# [5967, 6338, 8949, 2899, 2259, 2770, 5115]
# [5967, 247, 1550, 3246, 2545, 9117, 3641]
# [5967, 31295, 5559, 3237, 1735, 1356]
# [5967, 431, 12571, 214, 77, 4857, 3446, 9355, 21139]
# [5967, 183, 801, 1061, 287, 5729, 139]
# ================
# [5967, 23622, 287, 23027, 4392, 491, 4022, 1858, 102, 1450, 8400, 745, 338]
# [5967, 4070, 17, 1557, 3762, 1784, 7054, 880, 823, 184, 1597, 1612, 31295, 1756, 17188, 550, 3788, 2396, 1552, 4128]
# [5967, 10151, 8136, 17, 1557, 4070]
# [5967, 24887, 7450, 24112, 1590, 24887]
# [5967, 1127, 9592, 17134, 212, 47, 8295, 1127, 3295, 479]
# [5967, 247, 4405, 8099, 2830, 2484, 1134, 4731, 8768, 249, 9715]
# [5967, 1007, 9884, 26480]
# [5967, 12319, 463, 1183, 24, 3793, 6448, 551, 29, 932, 3386, 8687, 744, 22969]
# [5967, 286, 5212, 287, 4012, 29476, 214, 2511, 184]
# [5967, 9893, 77, 1784, 5719, 1410, 249]
# [5967, 249, 49, 383, 913, 188, 1259, 294, 31295, 1183, 1461, 1378, 1784, 23960, 134, 155, 30389, 4049, 138, 1494]
# [5967, 864, 31295, 1021, 1590]
# [5967, 480, 6608, 1211, 10537, 480, 4732, 2031, 5209]
# [5967, 26703, 133, 8854, 202, 8403, 1236, 1934, 1157, 8854, 8934, 3774, 18974, 5842, 1483, 676, 27939, 31295, 27939]
# [5967, 28045, 3677, 4226, 398, 8939, 27425, 13091, 711, 1558, 16675, 261, 6848, 2304]
# [5967, 191, 2927, 77]
# [5967, 25728, 2066, 1119, 31295, 4261, 796, 11184, 1460, 3118, 167]
# [5967, 19677, 1879, 3049, 288, 1945, 637, 8810, 4049]
# [5967, 384, 4783, 2978, 4393, 4404, 438, 3524, 1475, 2747, 12261]
# [5967, 1833, 30390, 11391, 5932]
# [5967, 31295, 10046, 159, 1555, 6316, 3293]
# [5967, 3320, 8521, 8265, 2055, 2056, 1845]
# [5967, 22268, 5559, 3237, 5592, 1356, 4287, 8071, 517, 7068, 17082]
# [5967, 3320, 8521, 8265, 2055, 2056, 1845, 16353, 438, 14616, 982, 51]
# [5967, 3858, 7300, 325, 6909, 4067, 762, 10063, 22211]
# ================
# [5967, 4719, 7106, 8278, 3858]
# [5967, 1596, 23960, 15723, 1061, 110, 572, 10184, 437, 276, 820, 122, 508, 780, 8564, 249]
# [5967, 74, 15515, 198, 164, 1767, 6027, 188, 1450, 7232, 3691]
# [5967, 25393, 453, 2060, 147, 6049, 453, 2060, 8291]
# [5967, 2355, 3671, 25632, 968, 566, 548, 354]
# [5967, 114, 1588, 469, 9893, 469, 1597, 1633, 3557, 3213, 26004]
# [5967, 22421, 24470, 146, 12, 4431, 22740, 2423, 2736, 30391]
# [5967, 1021, 6544, 2767, 139, 580, 1061, 1691, 7930, 6149, 41, 1376, 2406, 351]
# [5967, 814, 31295, 1948, 30392, 1288, 74, 405, 8912, 1767, 1073, 1497, 814]
# [5967, 31295, 18, 2021, 4240, 5644, 6544]
# [5967, 347, 195, 548, 823, 2306, 562, 211]
# [5967, 12067, 2684, 82, 28453, 1756, 3425, 224, 17, 4500, 3114]
# [5967, 71, 4460, 3313, 98, 1070, 7128, 11641, 249, 1945, 15937, 779, 9030, 11657, 5279, 4103, 3789, 2169, 4820, 1827, 779, 3230, 71, 3592]
# [5967, 2511, 184, 342, 1748, 287, 2623, 4012, 29476, 955, 1754, 5681, 77, 9345, 2734, 496, 14670, 3757]
# [5967, 31295, 211, 2936, 916, 1298, 1835, 587, 4280]
# [5967, 384, 3917, 4271, 354, 355, 3594, 1020, 1630, 2101, 778, 11699, 1157, 164, 157, 825, 26119, 2899, 864, 800, 1717, 1966, 30393, 1756, 1596, 3082, 2246, 12668]
# [5967, 169, 762, 8116, 3671, 134, 405, 3671, 1061, 7523, 4364]
# [5967, 2202, 1281, 6296, 6544]
# [5967, 1108, 1852, 1561, 15550, 4621, 6302, 611, 22825, 6302, 15550, 3642, 1561, 4282, 4769, 18402, 611, 2441, 15550]
# [5967, 291, 5299, 1073, 814, 1246, 113, 580]
# [5967, 169, 3671, 25632, 2347]
# [5967, 31295, 5142, 11468, 31295, 8923]
# [5967, 2726, 2744, 1921, 3884, 442]
# [5967, 31295, 1021, 1262, 580]
# [5967, 2700, 8976, 23259, 6325, 598, 8107, 1085, 1587, 6085, 61, 6748, 5125, 23259, 260, 657, 139, 30394, 133, 1048]
# ================
# [5967, 28532, 2233, 1366]
# [5967, 31295, 1442, 198, 216, 12213, 4301]
# [5967, 3433, 21814, 3861, 29699, 5544]
# [5967, 286, 102, 4383, 6910, 74, 16689, 102, 746]
# [5967, 31295, 8278, 3858, 1684]
# [5967, 3571, 4405, 470, 671, 7536, 9893, 5552, 9158, 820, 469, 2767, 459, 10002, 2529, 77, 8251]
# [5967, 74, 249, 885, 8700, 22308, 1539, 6166, 3507, 7098, 518, 4566]
# [5967, 31295, 6032, 2294, 1132, 17713, 24822]
# [5967, 74, 71, 198, 164, 157, 195, 387, 9610, 177, 74, 1954, 2767, 71, 620, 1236, 6094, 8458, 1000, 12, 57, 1353, 3691]
# [5967, 105, 1898, 779, 5095, 12, 308, 51, 1313, 3433]
# [5967, 31295, 3728, 2076, 1313, 2830, 2532, 3433]
# [5967, 703, 1483, 18122, 6357, 469, 1425, 3359, 29, 537, 10426, 287, 12982, 1441, 972, 1596, 1166, 5032, 578, 2466, 2220, 14012, 9983, 16501, 13470, 2417, 31295, 15192, 11674, 4241, 9624, 279]
# [5967, 2718, 1712, 1833, 983, 7182]
# [5967, 3277, 2305, 5765, 1141, 405, 1319, 609, 800, 11591, 31295]
# [5967, 10867, 4151, 800, 1551, 8623, 991, 287, 12442, 12443, 404, 405, 8600, 19415, 1978, 6149, 41, 991, 8334]
# [5967, 9893, 1502, 29891, 2387, 7149, 167, 1645, 1844]
# [5967, 71, 2847, 308, 1070, 2833, 3691, 6987, 6850, 203, 4130]
# [5967, 105, 1109, 779, 3433, 1313, 3728, 2076, 4143, 3251, 3596, 698, 449, 7091]
# [5967, 21222, 779, 5544, 1588, 3433]
# [5967, 224, 1395, 2216, 8614, 15884, 4654, 58, 520, 69, 294]
# [5967, 24662, 4903, 440, 5672]
# [5967, 851, 11074, 14718, 9336, 4047]
# [5967, 19570, 2694, 19181, 15553, 816, 822, 3269, 2351, 876, 199, 5190, 1166, 911]
# [5967, 31295, 469, 3346, 5999, 287, 814, 4654, 3662, 144, 1162, 155, 1257]
# [5967, 551, 8958, 14082, 10596, 5405, 2055, 2056, 15045, 658, 20500]
# ================
# [5967, 671, 30395, 1611, 30396, 341, 12397, 800, 719]
# [5967, 12, 7219, 25791, 1578, 4263, 983, 10265, 974, 503, 4793, 9076, 1192, 927, 1450, 1436, 1657, 462, 9981, 3556]
# [5967, 14981, 3706, 9893, 1281, 1571, 4263, 5888]
# [5967, 437, 1141, 405, 1767, 31295, 22308, 26, 6830, 2648, 3360, 5923]
# [5967, 4431, 260, 1299, 977, 14576, 1585, 22843, 5741, 9877, 1175, 4539, 2454, 842, 1544, 2610, 1547, 6816, 4793, 29692, 22843, 1106, 240, 6845, 415, 276]
# [5967, 22672, 462, 393, 2150]
# [5967, 1767, 15611, 1576, 12866]
# [5967, 260, 3924, 3764, 2766, 814, 6442, 102, 11, 1998, 14439, 5779, 2350, 6338, 7544, 102]
# [5967, 7842, 3655, 30396, 341, 74, 719]
# [5967, 249, 862, 4395, 6824, 3242, 1082, 688, 1070, 354, 297, 1091, 2004]
# [5967, 3979, 437, 211, 4732, 1211]
# [5967, 197, 3051, 3320, 3013, 1717, 3691, 453, 730, 3555]
# [5967, 2323, 1852, 14965]
# [5967, 18182, 17568, 17823, 122, 3778, 1507, 2097, 9966]
# [5967, 28064, 31295, 2165, 25465, 41, 3383, 6761, 17844, 31295, 2710, 4327, 11149, 30397]
# [5967, 4719, 5907, 5923, 775, 15376]
# [5967, 3202, 30398, 95, 276, 9105, 1029]
# [5967, 10413, 12, 470, 1192, 1000, 304, 86, 439, 7051, 110, 3725, 7172, 418, 1647, 249, 195]
# ...
# [5967, 31295, 13063, 31247, 3237, 1508, 326, 1987, 2109]
# [5967, 56, 3425, 24253, 2105, 1828, 476, 4986, 1622, 3425, 112]
# [5967, 191, 2066, 4957, 1098, 1547]
# [5967, 431, 470, 13954, 1281]
# [5967, 415, 72, 3396, 1895]
# [5967, 294, 217, 4549, 4744, 280, 6014, 1785, 12]
# ================
# [5967, 11252, 22, 1602, 984, 807, 1357, 1298, 3172, 13603, 159, 1555, 229, 595, 1357, 9086, 715, 5804, 87]
# [5967, 31248, 437, 55, 35, 999, 1579, 1085, 6088, 3542, 3550, 5553, 29, 5039, 2901, 522, 160, 2454]
# [5967, 5729, 1942, 191, 10, 2424, 1353, 537, 14390, 3722, 19067, 3049, 58, 903, 2611, 405, 1304]
# [5967, 31295, 326, 1226, 7680, 7124, 7125]
# [5967, 27953, 812, 1831, 453, 30523, 482, 7127]
# [5967, 191, 31249, 3757, 437, 211, 9478]
# [5967, 2351, 1028, 9583, 31295, 1879, 1774, 991, 18764, 9743, 1198, 859, 157]
# [5967, 5713, 981, 11243, 5368, 67, 294, 2147, 1871, 3408, 544, 4357, 261]
# [5967, 12936, 1657, 2059, 2055, 2056, 29, 1420, 676, 870, 1540, 1657]
# [5967, 311, 6258, 8829, 633]
# [5967, 212, 800, 1375, 3085, 324, 151, 159, 1555]
# [5967, 28608, 2177, 2355, 7694, 2998, 1219, 8301, 439, 4103, 13306, 7519, 2169]
# [5967, 21052, 864, 1279, 2421]
# [5967, 10984, 1954, 16705, 3239, 5153, 10, 951, 336, 5729, 8352, 4263]
# [5967, 372, 2276, 13500, 211, 6900, 12]
# [5967, 4719, 864, 341, 31250, 983, 4110, 2537, 6618]
# [5967, 159, 1555, 702, 2413, 98, 7833, 95, 2229]
# [5967, 991, 6728, 294, 2429, 615, 1666]
# [5967, 1105, 2165, 41, 20306, 1475, 21205, 8284, 287]
# [5967, 25728, 45, 2506, 188, 788, 2742, 26, 104, 25772, 11074]
# [5967, 159, 1555, 2580, 199, 3151, 1265]
# [5967, 996, 17983, 9565, 1585, 12987]
# [5967, 294, 2460, 1867, 12621]
# [5967, 2302, 354, 355, 3002, 642, 7082, 1769]
# [5967, 1774, 91, 261, 1116, 31251, 4678]
# ================
# [5967, 212, 8772, 2506, 2348, 2712, 349, 848, 2004, 1150, 1141, 3364, 1571, 16513, 177]
# [5967, 864, 983, 470, 889, 12571, 633, 1914, 1915]
# [5967, 159, 1555, 2925, 1642, 1717, 5729]
# [5967, 4090, 8239, 864, 1171, 7098]
# [5967, 551, 23766, 1841, 1842, 19242, 369, 6684, 2277, 1590, 4507, 2025, 31252, 1628, 862, 286, 1054, 2572, 2169, 470]
# [5967, 191, 1164, 1760, 2250]
# [5967, 5804, 287, 295, 1061, 30042, 8424, 5643, 8752, 12758]
# [5967, 613, 1436, 1448, 2446, 477, 280]
# [5967, 991, 2908, 2929, 4404, 3614, 31253, 9583, 31295, 1186, 7628, 2662, 1395, 1534, 967, 3377, 7236, 1281, 1774]
# [5967, 1590, 1179, 571, 5729, 845, 453, 1134, 191, 818, 31254, 3793, 139, 326, 477, 31255, 3355, 31256, 31257]
# [5967, 31258, 5729, 2200, 453, 191, 26004]
# [5967, 9437, 1707, 19941, 1127, 5080, 5444, 31259, 7050, 3267, 5729, 980, 191, 600, 9602]
# [5967, 191, 3276, 3297, 1353, 731, 1767, 9390]
# [5967, 6952, 249, 9254, 31260, 72, 1058]
# [5967, 211, 641, 469, 1633, 1284, 6789]
# [5967, 191, 1701, 102, 1357, 1547]
# [5967, 31295, 842, 14665, 2709, 1265, 19766, 21183, 3706, 1105, 4979, 1141, 3762, 3041]
# [5967, 31295, 3776, 2938, 10330, 5479, 16498, 15334, 25738, 1015]
# [5967, 1708, 15611, 31261, 7497, 430, 4241, 22172, 3576, 6933, 9021, 2031]
# [5967, 864, 31250, 1702, 112, 4049, 1784]
# [5967, 5692, 58, 98, 105, 613, 1105, 742, 3599]
# [5967, 4719, 31295, 580, 136, 112, 1460, 191, 2915, 559]
# [5967, 5729, 4853, 718, 7064, 453, 31295, 31262, 4370, 579, 815]
# [5967, 72, 637, 10679, 23022, 22712, 1108]
# [5967, 694, 1171, 5983, 498, 788, 31263, 1284]
# ================
# [5967, 10413, 1805, 864, 341, 214, 354, 1279, 325, 2224, 9732, 11406, 112, 1171, 1061, 3697]
# [5967, 4719, 609, 1873, 198, 164, 165, 159, 160, 543, 2710, 13448, 3474, 276, 198, 164, 415, 211]
# [5967, 2394, 3825, 199, 5129, 260, 236, 453, 13355, 5850, 1831, 453, 17872, 83, 83]
# [5967, 2464, 30, 585, 2143, 31295, 6041, 2736, 29361, 494]
# [5967, 191, 4021, 596, 5196, 1125]
# [5967, 4719, 745, 12, 13457, 13250, 355, 1002, 5107, 3757, 14351, 766, 4241, 5729, 1134]
# [5967, 18078, 6279, 3789, 191, 559]
# [5967, 191, 872, 5190, 2524, 11993, 102, 1357, 9086]
# [5967, 1108, 3733, 11236, 99, 1231, 11356, 31264, 31102, 1666]
# [5967, 1805, 864, 341, 214, 325, 1279, 17014, 6776, 1061, 1774]
# [5967, 1068, 24517, 15354, 3427]
# [5967, 24662, 662, 8559, 6787, 12370, 7318]
# [5967, 5049, 5127, 779, 31295, 1068, 3844, 3427]
# [5967, 657, 482, 1978, 72, 281, 1108, 6500, 1254, 2545, 2959, 280, 937, 188, 975, 3656, 269, 11569, 2996]
# [5967, 26056, 297, 2732, 1633, 31265, 77, 873, 20367, 3802]
# [5967, 31266, 31267, 19960]
# [5967, 191, 15587, 1925, 229, 566, 199, 2901, 1134]
# [5967, 1928, 453, 247, 3880, 5254, 6848, 1798, 1111]
# [5967, 3757, 2502, 21306, 2901, 291, 4319]
# [5967, 31295, 3535, 191, 144, 8958, 453]
# [5967, 2600, 158, 6341, 1117, 437, 6258, 3508]
# [5967, 4719, 261, 18574, 10769, 191, 1199]
# [5967, 6223, 1357, 3284, 7368, 7369, 983, 23699]
# [5967, 10914, 571, 8630, 4822, 3215, 2684, 27270, 27263, 15534]
# [5967, 4719, 260, 1067, 8226, 1075, 899]
# ================
# [5967, 469, 1879, 9076, 823, 927, 780, 8326, 249, 15323, 3122, 2425, 2042]
# [5967, 4719, 102, 1357, 2611, 1298, 3638, 31268, 144, 39]
# [5967, 31295, 12995, 5440, 807, 4031, 5729]
# [5967, 746, 1395, 247, 5129, 470, 2773, 1705]
# [5967, 31295, 4172, 1117, 2558, 991, 13950, 11356]
# [5967, 191, 4309, 102, 2443]
# [5967, 140, 1186, 2276, 314, 1186, 353, 12, 2558, 817, 139, 2272, 14646, 9839, 1617, 56, 561, 64]
# [5967, 24662, 691, 104, 1395, 247, 5129, 1262, 159, 1555, 2772]
# [5967, 6787, 19851, 1055, 4950, 1635, 1236, 6452, 35, 823, 184]
# [5967, 537, 14390, 9303]
# [5967, 2855, 1171, 6419, 1073, 5954, 8669, 31269, 19960]
# [5967, 437, 2937, 2253, 10596, 8723, 1533, 1152, 428, 7236, 1061, 2522]
# [5967, 102, 449, 10253, 1134, 229, 8494, 2709, 191]
# [5967, 4119, 31270, 31271, 6246, 766, 984, 1303, 3239, 4666]
# [5967, 1134, 607, 807, 2901, 5729]
# [5967, 1385, 3153, 199, 453, 653, 5717, 3167, 642, 234, 1127]
# [5967, 1457, 514, 1252, 212, 1585, 3509, 6604, 653, 227]
# [5967, 11603, 354, 355, 31272, 641, 646, 4703]
# [5967, 16750, 314, 184, 185, 2479, 2794, 8091, 3524, 197, 5914, 1831]
# [5967, 102, 1592, 9375, 31273, 3550, 1254, 358, 937, 1760, 3363, 2909, 439, 2996, 1108, 12843, 139]
# [5967, 1106, 104, 1395, 247, 1954, 2773, 95, 1300]
# [5967, 11427, 14074, 234, 608, 609, 875]
# [5967, 24662, 691, 104, 1395, 247, 5129, 1262, 159, 1555, 2772]
# [5967, 1105, 5462, 1007]
# [5967, 8427, 13073, 3390, 580]
# ================
# [5967, 95, 342, 817, 1617, 994, 11145, 1109, 354, 2908, 56, 1029]
# [5967, 4433, 76, 9399]
# [5967, 1105, 21306, 333, 632, 139]
# [5967, 31295, 8116, 2832, 715, 5128, 548, 4036]
# [5967, 773, 188, 1117, 449, 2169, 25136]
# [5967, 1554, 3446, 5248, 1221]
# [5967, 164, 561, 140, 5015, 437, 10108, 3946]
# [5967, 31295, 31295, 18807, 807, 3481, 2414]
# [5967, 4719, 505, 3307, 453, 274, 1776, 1878, 1434, 1358, 1628, 9933, 1641, 17068, 9989, 1176, 211, 5773, 496, 1085, 453, 188]
# [5967, 18114, 102, 13355, 2564, 1831]
# [5967, 191, 2557, 11132, 4680, 5394, 5729, 102, 2990, 112]
# [5967, 287, 22, 17044, 4665, 4505, 2004, 10, 1981, 31295, 4166]
# [5967, 5462, 5729, 3090, 3880, 1142, 5177, 4478, 2730]
# [5967, 437, 2861, 453, 15767, 807, 5182]
# [5967, 12573, 8752, 4364, 8182, 4130, 1127, 1539, 609]
# [5967, 31295, 1768, 44, 5675]
# [5967, 437, 1009, 5177, 7018, 1920, 31274, 17467]
# [5967, 4719, 2306, 12702, 1706, 1516, 935, 20446, 2055]
# [5967, 1767, 815, 4249, 2730, 24810]
# [5967, 1134, 1687]
# [5967, 12573, 287, 22897, 7028, 1548, 2464, 1142]
# [5967, 3823, 449, 2994, 2175, 27621, 138, 12327, 1150]
# [5967, 1516, 1699, 102, 1211, 3305, 295, 632, 1170]
# [5967, 1592, 2590, 4744, 2024, 6793, 5547]
# [5967, 31295, 665, 9399, 341, 1129, 494]
# ================
# [5967, 7479, 1591, 44, 469, 476, 4680, 354, 355, 28912, 10, 24, 5706]
# [5967, 191, 159, 1555, 715, 1357, 1547, 1590, 19984]
# [5967, 800, 2066, 836, 1117, 1917, 4182, 297, 6406, 294, 7598, 70, 197, 5983, 198, 164]
# [5967, 4719, 3195, 800, 7161, 4101, 398, 1991, 2091, 13811, 11128, 31275, 2210, 800]
# [5967, 3535, 5729, 2200, 4031, 14390]
# [5967, 991, 12422, 13182, 7124, 1317, 224, 1774, 1173, 915]
# [5967, 197, 2710, 297, 6406, 294, 20174]
# [5967, 807, 2406, 3276, 1164, 689, 715, 3757, 5254, 1265, 7095, 5729]
# [5967, 191, 11154, 3562, 1357, 2611, 426]
# [5967, 191, 5729, 4031, 9833, 11245, 392, 10810, 615, 5193]
# [5967, 1270, 633, 1691, 5729, 770, 191, 14456, 9536, 299, 10810, 2729, 84, 10222, 1127, 12154, 3695, 2527, 1185]
# [5967, 3570, 557, 1942, 2240, 1488, 16244, 2055, 1488, 1052, 12, 1942]
# [5967, 31295, 2066, 1293, 1592, 2590, 4744, 7790, 24604, 7309, 878, 9273, 224, 144, 2272, 2060]
# [5967, 191, 5729, 8630, 31276, 22235]
# [5967, 2730, 31295, 102, 731, 25033, 5729]
# [5967, 26597, 4177, 23306, 1708, 6826, 5729, 7598, 3902, 1831]
# [5967, 27014, 25343, 1863, 508, 6494, 1873]
# [5967, 102, 746, 195, 199, 3915, 5729, 29, 5873]
# [5967, 1767, 11387, 1954, 470, 3953, 15307]
# [5967, 22823, 1117, 10385, 4405, 17003, 9764, 6984, 18097]
# [5967, 864, 23, 9953, 5851, 369]
# [5967, 4090, 13372, 22584, 4461, 1698, 3515, 3447, 1217]
# [5967, 3757, 591, 1516, 8203, 581]
# [5967, 5729, 1127, 11338]
# [5967, 5485, 820, 766, 2412, 12573, 287]
# ================
# [5967, 621, 4173, 4180, 1858]
# [5967, 453, 537, 31295, 6825, 8564, 142, 807, 1632]
# [5967, 28146, 28595, 31277, 31295, 8116, 5444, 91, 1171, 31278, 12143]
# [5967, 191, 10556, 77, 8255, 537, 14390, 5108, 650, 470, 7889, 15, 514]
# [5967, 31295, 470, 2245, 336, 1105, 983, 3736, 150]
# [5967, 10608, 1701, 8762, 4103, 8455, 3658, 13730, 3203, 64, 11832]
# [5967, 715, 102, 6688, 21160, 2990, 1547, 9945, 5589]
# [5967, 2730, 12317, 31295, 9078, 4658, 9078]
# [5967, 191, 22373, 537, 31295, 77, 8255, 22, 198, 164, 627]
# [5967, 21306, 3075, 333, 1862, 2360, 4505]
# [5967, 31295, 142, 229, 315, 185, 11164, 5729]
# [5967, 1708, 5190, 5729, 484]
# [5967, 1828, 1467, 4881, 1127, 867, 31295, 7174, 5671]
# [5967, 4719, 102, 715, 4961, 9382, 1547, 229, 2225, 102, 2611, 9086]
# [5967, 191, 4398, 26052, 5396, 18435, 274, 9392, 12573, 199]
# [5967, 2056, 15217, 7832, 12573, 1587, 15, 1534, 1183]
# [5967, 5729, 31279, 122, 1146, 876, 191, 102, 2709, 184, 211, 101, 8693, 2569, 294]
# [5967, 453, 12758, 430, 7009, 745, 8636, 499, 1584, 5459]
# [5967, 561, 459, 3541, 537, 31295, 4031]
# [5967, 12573, 1142, 6666, 1170, 807, 11165, 2464, 13953, 4431]
# [5967, 22848, 163, 2747, 2557, 4135, 217, 4141]
# [5967, 24662, 5842, 453, 4950, 1635, 1236]
# [5967, 191, 211, 8630, 31295, 3896, 14442]
# [5967, 31295, 736, 2658, 7017, 176, 1417, 58]
# [5967, 1647, 2610, 14017, 820, 140, 1863, 18838, 3619, 2110]
# ================
# [5967, 159, 1555, 332, 1767, 731, 58, 1554, 70]
# [5967, 287, 862, 58, 31295, 1300, 537, 14390, 371, 10237, 3575, 10278]
# [5967, 1767, 11387, 1954, 470, 3953, 15307]
# [5967, 31295, 3762, 1327, 1858, 11440, 22, 286, 452, 19315, 6552, 31295, 207, 1858, 1472]
# [5967, 2194, 1702, 354, 355, 358, 21550, 2774, 5335, 174, 5681, 4473, 237, 1717, 114, 540, 25536, 1567, 4596, 6088, 9120, 1150]
# [5967, 991, 896, 1395, 353, 5544, 7571, 31280, 51]
# [5967, 3757, 3978, 1494, 772, 191, 31281, 26480, 587, 2089]
# [5967, 807, 691, 10044, 12573, 1642]
# [5967, 3595, 2925, 1148, 7657, 16106, 7012, 287, 2990, 2405, 18038, 6530, 6547, 1611, 1164, 731, 14767, 11641]
# [5967, 9388, 6668, 4706, 191, 2031, 5729, 10283]
# [5967, 1782, 937, 3505, 744, 776, 681, 5729, 937, 1954, 4950, 1635, 2860]
# [5967, 102, 872, 74, 766, 689, 1554, 1164, 8085]
# [5967, 22735, 31295, 520, 14683, 1254, 621, 7604, 5729, 1741, 139, 4363, 2478, 263, 7431, 199, 2781, 191]
# [5967, 4719, 6668, 4182, 5729, 1274, 191, 1091, 4360]
# [5967, 1708, 5190, 5729, 484]
# [5967, 4759, 2214, 1181]
# [5967, 102, 4950, 10598, 928, 5729, 191, 1588, 102, 31202]
# [5967, 5729, 9362, 282, 102, 278]
# [5967, 807, 109, 2723, 5729, 4957, 6687]
# [5967, 74, 2611, 405, 102, 689, 1554]
# [5967, 3535, 1199]
# [5967, 4632, 807, 691, 1717, 3724, 3413, 518, 1098, 1288]
# [5967, 1386, 2730, 7775, 159, 1555, 4031, 816]
# [5967, 12573, 287, 22, 102, 199, 1073, 392, 31282, 5, 1518, 62]
# [5967, 8346, 203, 13085, 26671, 31295, 409, 159, 1555, 1134, 27360, 191]
# ================
# [5967, 28081, 29239, 2245, 354, 355, 25658, 2204, 18431, 915]
# [5967, 191, 5446, 5729, 1494]
# [5967, 222, 1693, 10, 224]
# [5967, 291, 19408, 31283, 6566, 1948, 1831, 4561, 1058, 2734, 15909, 197, 415, 1028, 341, 1676, 24772]
# [5967, 1098, 5729, 1516, 31284, 2055]
# [5967, 2300, 1249, 3756, 104, 31285, 82, 202, 10333]
# [5967, 31295, 19823, 12573, 453, 3421, 609]
# [5967, 1332, 772, 6608, 2572, 5729, 191, 453, 331, 5236, 5729, 2200, 5236, 191]
# [5967, 102, 199, 14468, 5589, 31286, 807, 199, 3443, 537, 14390, 24, 1332, 3336, 906, 102, 2990, 112, 195, 387]
# [5967, 159, 1555, 2047, 453, 23206, 1554, 10489, 585]
# [5967, 3535, 12573, 199, 2767, 537, 31295, 1300, 31295, 5552, 1931, 13308, 3990, 3790, 944, 9989]
# [5967, 6668, 18, 6824, 31295, 6516, 1301, 12573, 70, 4431]
# [5967, 3979, 453, 1774, 2204, 2079, 645, 6863, 6687, 4031, 1362, 11903, 122, 2424, 780, 239, 1362, 5444, 191]
# [5967, 2394, 9902, 944, 9701, 14375, 4080, 1366, 12869, 1302, 2712]
# [5967, 4719, 2216, 134, 41, 1078, 211]
# [5967, 159, 1555, 1954, 24, 5729, 5237, 5729, 260, 866]
# [5967, 1708, 5190, 5729, 484]
# [5967, 3535, 409, 159, 1555, 584, 2030, 23506, 9815, 1453, 12758, 1418]
# [5967, 191, 5729, 1134, 2861, 453, 520]
# [5967, 28081, 29239, 14506, 354, 355, 702, 139, 453, 1291, 177, 915]
# [5967, 453, 5729, 74, 2959]
# [5967, 3393, 1637, 102, 5045, 5729, 11164, 537, 14390, 31287, 3757]
# [5967, 17713, 605, 16675, 102, 1134, 2994, 12573, 6826, 537, 14390, 31288, 807, 11491]
# [5967, 1007, 437, 237]
# [5967, 100, 101, 644, 3609, 4681, 469, 309]
# ================
# [5967, 4688, 1007, 1134, 681, 102, 4688, 681, 102, 681, 1831]
# [5967, 3757, 5090, 7732, 12573, 4031]
# [5967, 3320, 12573, 405, 6499, 74, 5137, 24404, 191]
# [5967, 12573, 1234, 12843, 25790, 2730, 7146, 31289, 3006, 191, 1450, 1170, 3770]
# [5967, 1171, 2204, 1173, 8929, 6410]
# [5967, 14439, 2938, 437, 493, 6334, 1831]
# [5967, 191, 5593, 74, 199, 3297, 5729]
# [5967, 745, 7628, 3310, 14390, 4751, 159, 1555, 12573, 1502, 1132, 5547, 12]
# [5967, 721, 211, 453, 19903, 1295, 4192]
# [5967, 5729, 3443, 933, 5213, 17722]
# [5967, 191, 9855, 12407, 5729, 159, 1555, 22, 293, 310, 9042]
# [5967, 31290, 31291, 349, 260, 551, 840, 1171, 2537, 91, 1108]
# [5967, 159, 1555, 1643, 2723, 2038, 6369, 6528]
# [5967, 31295, 4967, 9432, 1075, 2570, 986, 1862, 2064, 437, 1461, 6996]
# [5967, 4719, 247, 3555, 3111, 31269, 31292, 21868, 3555]
# [5967, 1767, 102, 2994, 12573, 8203]
# [5967, 1942, 1142, 9004, 807, 12573, 430, 56]
# [5967, 12761, 24, 565, 5886, 611, 249, 521, 3002, 3917]
# [5967, 991, 6728, 102, 858, 7551]
# [5967, 453, 537, 14390, 17082]
# [5967, 74, 15515, 627, 1701, 416, 340]
# [5967, 191, 778, 159, 1555, 1717, 7778, 1127]
# [5967, 9823, 3193, 5729, 191, 4031]
# [5967, 191, 430, 172, 453]
# [5967, 3575, 709, 1017, 1436]
# ================
# [5967, 5729, 31295, 520, 807, 3898, 562, 3443, 3669, 453]
# [5967, 5984, 21306, 17374]
# [5967, 191, 972, 5208, 1954, 4545, 537, 14390, 6824, 2414, 6280]
# [5967, 807, 4517, 6048, 3724, 1300, 537, 14390, 4397, 3722, 4745, 12573, 5140, 996]
# [5967, 95, 224, 1155, 12113, 159, 160, 112, 22, 1777, 1070, 354, 355, 1155, 6448]
# [5967, 5049, 807, 4517, 6213, 537, 14390, 19023, 5729, 15937, 520, 807, 1517]
# [5967, 5984, 5729, 12101, 537, 14390, 191, 1022, 10, 4292, 8278]
# [5967, 6277, 31295, 10784, 6448, 18380, 30229, 31293, 214, 314, 9720, 184, 6133, 2402, 8883, 5171, 369]
# [5967, 12573, 1954, 12160, 31295, 1300, 19365, 462, 999, 3339, 12, 470, 4431]
# [5967, 14981, 159, 1555, 4554, 5729, 453, 191]
# [5967, 1959, 770, 2699, 3014, 1767, 58, 1554, 22, 159, 1555, 4197, 74, 199, 10484]
# [5967, 9668, 4270, 2293, 3015, 6197, 745, 977, 6338]
# [5967, 191, 5729, 453, 17458, 134, 4382, 2204, 18431, 1774, 11886, 17654, 7746, 258, 5380, 11905]
# [5967, 991, 591, 3757, 19, 562, 5568]
# [5967, 14981, 211, 453, 8151, 943, 972]
# [5967, 5729, 12101, 537, 14390, 191, 477, 1978, 1134, 8855, 5729, 16053, 1097, 2336, 453]
# [5967, 291, 4319, 2341, 485, 2657]
# [5967, 25489, 1959, 102, 10, 2310, 802, 74, 689, 1554, 74, 2990, 405, 14269, 23778, 1767, 3735, 29733, 1691, 1342, 199, 16310]
# [5967, 4839, 6995, 549, 579, 602, 136, 437, 4183, 1554, 1061, 1164, 10251]
# [5967, 5729, 5178, 83, 514, 5129, 1831, 681, 396, 807, 691, 5729, 10085, 1418, 537, 14390]
# [5967, 1518, 13375, 2571, 1554, 476, 8673, 102, 101, 211, 70]
# [5967, 12758, 1587, 5729, 12101, 537, 14390]
# [5967, 169, 3671, 31294, 2185, 369, 2064]
# [5967, 8520, 2642, 1032, 5401, 543, 1774]
# [5967, 681, 237, 5681, 728]
# ================

# %% [markdown]
# ## Ensure that the variations in the number of news headlines each day and length of each headlines are handled by taking an average number of headlines each day and average length per headline

# %%
# Find the length of headlines
lengths = []
for headlines in headlines_sequence:
    for headline in headlines:
        lengths.append(len(headline))

# Create a dataframe so that the values can be inspected
lengths = pd.DataFrame(lengths, columns=['counts'])

# %%
lengths.describe()
# Out:
#              counts
# count  49693.000000
# mean      12.409917
# std        6.789827
# min        1.000000
# 25%        7.000000
# 50%       10.000000
# 75%       16.000000
# max       41.000000

# %% [markdown]
# ## Limit the length of a day's news to 200 words, and the length of any headline to 16 words. These values are chosen to not have an excessively long training time and balance the number of headlines used and the number of words from each headline.

# %%
max_headline_length = 16
max_daily_length = 200
pad_headlines = []

# For each date in all the dates available
for headlines in headlines_sequence:
    pad_daily_headlines = []
    # for each headline for each date
    for headline in headlines:
        # Add headline if it is less than max length
        if len(headline) <= max_headline_length:
            for word in headline:
                pad_daily_headlines.append(word)
        # Limit headline if it is more than max length
        else:
            headline = headline[:max_headline_length]
            for word in headline:
                pad_daily_headlines.append(word)

    # Pad daily_headlines if they are less than max length
    if len(pad_daily_headlines) < max_daily_length:
        for i in range(max_daily_length-len(pad_daily_headlines)):
            pad = vocab_to_int["<PAD>"]
            pad_daily_headlines.append(pad)
    # Limit daily_headlines if they are more than max length
    else:
        pad_daily_headlines = pad_daily_headlines[:max_daily_length]
    pad_headlines.append(pad_daily_headlines)

# %% [markdown]
# ## Split data into training and testing sets.
# ## Validating data will be created during training.

# %%
x_train, x_test, y_train, y_test = train_test_split(pad_headlines, norm_price, test_size = 0.15, random_state = 2)

x_train = np.array(x_train)
x_test = np.array(x_test)
y_train = np.array(y_train)
y_test = np.array(y_test)

# %%
# Check the lengths
print(len(x_train))
print(len(x_test))
# Out:
# 1689
# 299

# %% [markdown]
# # Model Building

# %% [markdown]
# ## 1. Define the hyperparameters

# %%
filter_length = 5
dropout = 0.5
learning_rate = 0.001
weights = initializers.TruncatedNormal(mean=0.0, stddev=0.1, seed=2)
nb_filter = 16
rnn_output_size = 128
hidden_dims = 128

# %% [markdown]
# ## 2. Create the model

# %%
def build_model():

    model = Sequential()

    # Layer 1 - Embedding
    model.add(Embedding(nb_words,
                         embedding_dim,
                         weights=[word_embedding_matrix],
                         input_length=max_daily_length))
    model.add(Dropout(dropout))

    # Layer 2 - Convolution 1 with dropout
    model.add(Convolution1D(filters = nb_filter,
                             kernel_size = filter_length,
                             padding = 'same',
                             activation = 'relu'))
    model.add(Dropout(dropout))

    # Layer 3 - Convolution 2 with Dropout
    model.add(Convolution1D(filters = nb_filter,
                                 kernel_size = filter_length,
                                 padding = 'same',
                                 activation = 'relu'))
    model.add(Dropout(dropout))

    # Layer 4 - RNN with dropout
    model.add(LSTM(rnn_output_size,
                    activation=None,
                    kernel_initializer=weights,
                    dropout = dropout))

    # Layer 5 - Dense FFN with Dropout
    model.add(Dense(hidden_dims, kernel_initializer=weights))
    model.add(Dropout(dropout))

    model.add(Dense(1,
                    kernel_initializer = weights,
                    name='output'))

    model.compile(loss='mean_squared_error',
                  optimizer=Adam(lr=learning_rate,clipvalue=1.0))
    return model

# %% [markdown]
# ## 3. Fit the model

# %%
def build_model():
    model = Sequential()

    # Layer 1 - Embedding
    model.add(Embedding(nb_words,
                        embedding_dim,
                        weights=[word_embedding_matrix],
                        input_length=max_daily_length))  # Remove `input_length` if still causing issues
    model.add(Dropout(dropout))

    # Layer 2 - Convolution 1 with dropout
    model.add(Convolution1D(filters=nb_filter,
                            kernel_size=filter_length,
                            padding='same',
                            activation='relu'))
    model.add(Dropout(dropout))

    # Layer 3 - Convolution 2 with Dropout
    model.add(Convolution1D(filters=nb_filter,
                            kernel_size=filter_length,
                            padding='same',
                            activation='relu'))
    model.add(Dropout(dropout))

    # Layer 4 - RNN with dropout
    model.add(LSTM(rnn_output_size,
                   activation=None,
                   kernel_initializer=weights,
                   dropout=dropout))

    # Layer 5 - Dense FFN with Dropout
    model.add(Dense(hidden_dims, kernel_initializer=weights))
    model.add(Dropout(dropout))

    # Output layer
    model.add(Dense(1, kernel_initializer=weights, name='output'))

    # Compile model
    model.compile(loss='mean_squared_error',
                  optimizer=Adam(learning_rate=learning_rate, clipvalue=1.0))  # Corrected `learning_rate` keyword
    return model

# %%
gpus = tf.config.list_physical_devices('GPU')
if gpus:
    try:
        # Restrict TensorFlow to only allocate memory as needed
        for gpu in gpus:
            tf.config.experimental.set_memory_growth(gpu, True)
    except RuntimeError as e:
        print(e)

# %%
model = build_model()
print()
# save_best_weights = 'best_weights.h5'

# callbacks = [ModelCheckpoint(save_best_weights, monitor='val_loss', save_best_only=True),
#             EarlyStopping(monitor='val_loss', patience=5, verbose=1, mode='auto'),
#             ReduceLROnPlateau(monitor='val_loss', factor=0.2, verbose=1, patience=3)]

save_best_weights = 'best_weights.keras'

callbacks = [
    ModelCheckpoint(save_best_weights, monitor='val_loss', save_best_only=True),
    EarlyStopping(monitor='val_loss', patience=5, verbose=1, mode='auto'),
    ReduceLROnPlateau(monitor='val_loss', factor=0.2, verbose=1, patience=3)
]

# history = model.fit([x_train],
#                     y_train,
#                     batch_size=128,
#                     epochs=100,
#                     validation_split=0.15,
#                     verbose=True,
#                     shuffle=True,
#                     callbacks = callbacks)

history = model.fit(
    x_train,   # Remove the brackets here
    y_train,
    batch_size=128,
    epochs=100,
    validation_split=0.15,
    verbose=True,
    shuffle=True,
    callbacks=callbacks
)

print(model.summary())
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/embedding.py:90: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(
# Epoch 1/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 27s 620ms/step - loss: 0.1116 - val_loss: 0.0462 - learning_rate: 0.0010
# Epoch 2/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 217ms/step - loss: 0.0383 - val_loss: 0.0384 - learning_rate: 0.0010
# Epoch 3/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 147ms/step - loss: 0.0190 - val_loss: 0.0226 - learning_rate: 0.0010
# Epoch 4/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 134ms/step - loss: 0.0154 - val_loss: 0.0124 - learning_rate: 0.0010
# Epoch 5/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 3s 234ms/step - loss: 0.0129 - val_loss: 0.0092 - learning_rate: 0.0010
# Epoch 6/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 143ms/step - loss: 0.0116 - val_loss: 0.0087 - learning_rate: 0.0010
# Epoch 7/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 3s 163ms/step - loss: 0.0108 - val_loss: 0.0079 - learning_rate: 0.0010
# Epoch 8/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - loss: 0.0105 - val_loss: 0.0082 - learning_rate: 0.0010
# Epoch 9/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 138ms/step - loss: 0.0110 - val_loss: 0.0076 - learning_rate: 0.0010
# Epoch 10/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 3s 246ms/step - loss: 0.0113 - val_loss: 0.0072 - learning_rate: 0.0010
# Epoch 11/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - loss: 0.0102 - val_loss: 0.0075 - learning_rate: 0.0010
# Epoch 12/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.0101 - val_loss: 0.0074 - learning_rate: 0.0010
# Epoch 13/100
# 11/12 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.0095
# Epoch 13: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.0095 - val_loss: 0.0072 - learning_rate: 0.0010
# Epoch 14/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 0.0095 - val_loss: 0.0073 - learning_rate: 2.0000e-04
# Epoch 15/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 0.0093 - val_loss: 0.0076 - learning_rate: 2.0000e-04
# Epoch 15: early stopping
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ embedding (Embedding)                │ (None, 200, 300)            │       9,389,100 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 200, 300)            │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv1d (Conv1D)                      │ (None, 200, 16)             │          24,016 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_1 (Dropout)                  │ (None, 200, 16)             │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv1d_1 (Conv1D)                    │ (None, 200, 16)             │           1,296 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_2 (Dropout)                  │ (None, 200, 16)             │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ lstm (LSTM)                          │ (None, 128)                 │          74,240 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 128)                 │          16,512 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_3 (Dropout)                  │ (None, 128)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ output (Dense)                       │ (None, 1)                   │             129 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 28,515,881 (108.78 MB)
#  Trainable params: 9,505,293 (36.26 MB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 19,010,588 (72.52 MB)
# None

# %%
save_best_weights = 'best_weights.keras' # Change the file extension to .keras

callbacks = [ModelCheckpoint(save_best_weights, monitor='val_loss', save_best_only=True),
            EarlyStopping(monitor='val_loss', patience=5, verbose=1, mode='auto'),
            ReduceLROnPlateau(monitor='val_loss', factor=0.2, verbose=1, patience=3)]

# %% [markdown]
# ## 4. Predict using the model

# %%
predictions = model.predict([x_test], verbose = True)
# Out:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 124ms/step

# %%
predictions = model.predict(x_test, verbose=True) # Remove the square brackets around x_test
# Out:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 84ms/step

# %%
import numpy as np

# Convert x_test to the expected data type if necessary
x_test = x_test.astype(np.float32)

# Reshape x_test to match the input shape expected by the model
# Assuming the input shape is (200, 1) for example:
x_test = x_test.reshape(-1, 200, 1)

predictions = model.predict(x_test, verbose=True) # Remove the square brackets around x_test
# Out:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 99ms/step

# %%
import numpy as np

# Convert x_test to the expected data type if necessary
x_test = x_test.astype(np.float32)

# Reshape x_test to match the input shape expected by the model
# Assuming the input shape is (200, 1) for example:
x_test = x_test.reshape(-1, 200, 1)

# Check for None values in x_test
if np.any(np.isnan(x_test)): # Check for NaN which represents missing data or None
    print("x_test contains None or NaN values!")
    # Handle the None values (e.g., impute with mean/median or remove)
    x_test = np.nan_

# %%
predictions = model.predict(x_test, verbose=True) # Remove the square brackets around x_test
# Out:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step

# %%
import numpy as np

# Convert x_test to the expected data type if necessary
x_test = x_test.astype(np.float32)

# Reshape x_test to match the input shape expected by the model
# Assuming the input shape is (200, 1) for example:
x_test = x_test.reshape(-1, 200, 1)

# Check for None or NaN (Not a Number) values in x_test
if np.any(np.isnan(x_test)) or np.any(x_test == None): # Check for both NaN and None
    print("x_test contains None or NaN values!")
    # Handle the None/NaN values: Replace them with a suitable value (e.g., 0, mean, median)
    # Example: Replacing with 0
    x_test = np.nan_to_num(x_test, nan=0.0, posinf=0.0, neginf=0.0) # Replaces NaN with 0. Handles +/- infinity as well.
    # If you want to remove rows with None/NaN values instead:
    # rows_with_none = np.any(np.isnan(x_test), axis=1) # Find rows with None/NaN
    # x_test = x_test[~rows_with_none]  # Select rows without None/NaN


predictions = model.predict(x_test, verbose=True) # Remove the square brackets around x_test
# Out:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step

# %%
# Compare testing loss to training and validating loss
mse(y_test, predictions)
# Out:
# 0.007533114229954784

# %%
# Revert prediction back to actual scale
def unnormalize(price):
    '''Revert values to their unnormalized amounts'''
    price = price*(max_price-min_price)+min_price
    return(price)

# %%
# Store back-scaled predictions
unnorm_predictions = []
for pred in predictions:
    unnorm_predictions.append(unnormalize(pred))

# Store back-scaled actuals
unnorm_y_test = []
for y in y_test:
    unnorm_y_test.append(unnormalize(y))

# %%
# Calculate the median absolute error for the predictions
mae(unnorm_y_test, unnorm_predictions)
# Out:
# 84.98162773046897

# %%
pd.Series(unnorm_y_test).describe()
# Out:
# count    299.000000
# mean       7.094101
# std      139.532324
# min     -673.139648
# 25%      -54.689941
# 50%       10.759766
# 75%       87.465332
# max      541.050782
# dtype: float64

# %% [markdown]
# ## Make Your Own Predictions

# %% [markdown]
# Below is the code necessary to make your own predictions. I found that the predictions are most accurate when there is no padding included in the input data. In the create_news variable, I have some default news that you can use, which is from April 30th, 2017. Just change the text to whatever you want, then see the impact your new headline will have.

# %%
def news_to_int(news):
    '''Convert your created news into integers'''
    ints = []
    for word in news.split():
        if word in vocab_to_int:
            ints.append(vocab_to_int[word])
        else:
            ints.append(vocab_to_int['<UNK>'])
    return ints

# %%
def padding_news(news):
    '''Adjusts the length of your created news to fit the model's input values.'''
    padded_news = news
    if len(padded_news) < max_daily_length:
        for i in range(max_daily_length-len(padded_news)):
            padded_news.append(vocab_to_int["<PAD>"])
    elif len(padded_news) > max_daily_length:
        padded_news = padded_news[:max_daily_length]
    return padded_news

# %%
# Default news that you can use

create_news =  "Woman says note from Chinese 'prisoner' was hidden in new purse. \
               21,000 AT&T workers poised for Monday strike \
               housands march against Trump climate policies in D.C., across USA \
               Kentucky judge won't hear gay adoptions because it's not in the child's \"best interest\" \
               Multiple victims shot in UTC area apartment complex \
               Drones Lead Police to Illegal Dumping in Riverside County | NBC Southern California \
               An 86-year-old Californian woman has died trying to fight a man who was allegedly sexually assaulting her 61-year-old friend. \
               Fyre Festival Named in $5Million+ Lawsuit after Stranding Festival-Goers on Island with Little Food, No Security. \
               The \"Greatest Show on Earth\" folds its tent for good \
               U.S.-led fight on ISIS have killed 352 civilians: Pentagon \
               Woman offers undercover officer sex for $25 and some Chicken McNuggets \
               Ohio bridge refuses to fall down after three implosion attempts \
               Jersey Shore MIT grad dies in prank falling from library dome \
               New York graffiti artists claim McDonald's stole work for latest burger campaign \
               SpaceX to launch secretive satellite for U.S. intelligence agency \
               Severe Storms Leave a Trail of Death and Destruction Through the U.S. \
               Hamas thanks N. Korea for its support against ‘Israeli occupation’ \
               Baker Police officer arrested for allegedly covering up details in shots fired investigation \
               Miami doctor’s call to broker during baby’s delivery leads to $33.8 million judgment \
               Minnesota man gets 15 years for shooting 5 Black Lives Matter protesters \
               South Australian woman facing possible 25 years in Colombian prison for drug trafficking \
               The Latest: Deal reached on funding government through Sept. \
               Russia flaunts Arctic expansion with new military bases"

clean_news = clean_text(create_news)

int_news = news_to_int(clean_news)

pad_news = padding_news(int_news)

pad_news = np.array(pad_news).reshape((1,-1))

pred = model.predict([pad_news])

price_change = unnormalize(pred)

print("The Dow should open: {} from the previous open.".format(np.round(price_change[0][0],2)))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# The Dow should open: -38.849998474121094 from the previous open.
