# %%
# from google.colab import drive
# drive.mount('/content/drive')

# %%
# @title Load Configuraiton 
import hbqaconfig
conf = hbqaconfig.setEnv('local')
# for k,v in conf.items(): print (k,":",v)
# Out:
# DATA_FOLDER : H:\My Drive\HBQA\Data\
# PE_FOLDER : H:\My Drive\HBQA\Data\1-PE\
# QAGS_FOLDER : H:\My Drive\HBQA\Data\2-QAGS\
# DRS_FOLDER : H:\My Drive\HBQA\Data\3-DRS
# AGS_FOLDER : H:\My Drive\HBQA\Data\4-AGS\
# REPORT_FOLDER : H:\My Drive\HBQA\Data\5-REPORT\
# CORPUS_SECTIONS_FOLDER : H:\My Drive\HBQA\CorpusBooks\MBBook-from-HTML\
# CORPUS_CHAPTER_FOLDER : H:\My Drive\HBQA\CorpusBooks\MBBook-from-HTML-Chapters\
# OPENAI_KEY : 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
# PINECONE_API_KEY : ddf2ef12-9108-4e80-b438-8f86a0b617c0
# PINECONE_ENV : asia-southeast1-gcp-free
# CHATPDF_KEY : sec_LuLvKVr3UFLFF1AQndloCsZURxM7Lsi4

# %%
import pandas as pd 
df = pd.read_csv(conf['DATA_FOLDER']+'01.1-Mahabharat_Metadata.csv')
df.head(3)
# Out:
#    Book_Id          Book_Name  Section_Id              File_Name  \
# 0        1  Book 1: Adi Parva  Book01_002  mahabharata_01002.txt
# 1        2  Book 1: Adi Parva  Book01_003  mahabharata_01003.txt
# 2        3  Book 1: Adi Parva  Book01_004  mahabharata_01004.txt
#
#                                                  URL Section_Roman  \
# 0  https://www.mahabharataonline.com/translation/...     Section I
# 1  https://www.mahabharataonline.com/translation/...    Section II
# 2  https://www.mahabharataonline.com/translation/...   Section III
#
#    Section_Word_Count  Section_Letter_Count  Section_Para_Count  Avg_Word_Len
# 0                7464                 44206                  45          5.92
# 1                8608                 52123                  33          6.06
# 2                6089                 35041                  48          5.75

# %%
df.describe([.25,.50,.75,.90,.95, .99])
# Out:
#            Book_Id  Section_Word_Count  Section_Letter_Count  \
# count  2100.000000         2100.000000           2100.000000
# mean   1052.930476         1138.362381           6665.994762
# std     608.453845          924.710517           5342.183066
# min       1.000000           90.000000            514.000000
# 25%     525.750000          629.750000           3675.750000
# 50%    1052.500000          901.000000           5254.000000
# 75%    1580.250000         1343.000000           7919.000000
# 90%    1895.100000         1976.200000          11565.100000
# 95%    2001.050000         2574.400000          15047.200000
# 99%    2085.010000         4320.170000          25093.710000
# max    2106.000000        14850.000000          84950.000000
#
#        Section_Para_Count  Avg_Word_Len
# count         2100.000000   2100.000000
# mean             5.341429      5.871605
# std              4.669557      0.198274
# min              2.000000      5.260000
# 25%              3.000000      5.740000
# 50%              4.000000      5.870000
# 75%              6.000000      5.990000
# 90%              9.000000      6.100000
# 95%             12.000000      6.170000
# 99%             21.010000      6.390100
# max             86.000000      8.180000

# %%
import openai 
from langchain.text_splitter import CharacterTextSplitter

# %% [markdown]
# # Create Chunk for Prompt Creation
# - If we do not split and create chunk then ChatGPT cannot handle it. Secondly it will be more costly.
# - These chunk should be used to to creating ChatGPT QA prompt.

# %%
def Create_Chunks(df1, df_chunks, idx_of_files, chunk_id, verbose):
    # split into chunks
    text_splitter = CharacterTextSplitter(
        separator="\n",
        chunk_size=8000,
        chunk_overlap=300,
        length_function=len
    )
    
    for i in idx_of_files:
        section_file_name = df1.loc[i,"File_Name"]
        section_id = df1.loc[i, "Section_Id"]
        Section_Word_Count = df1.loc[i, "Section_Word_Count"] 
        Section_Letter_Count = df1.loc[i,"Section_Letter_Count"]
        #question_to_generate = df1.loc[i,"Questions"]

        if verbose:
            print ("File:",section_file_name,
                    '| Sectionid:', section_id,
                    "| Section Words Count:", Section_Word_Count, 
                    "| Section Letter Count:",Section_Letter_Count,
                    #'| Questions:',question_to_generate
                    )
                 
        section_file_path = conf['CORPUS_SECTIONS_FOLDER']+ section_file_name
        with open(section_file_path, "r") as file_section:
            text = file_section.readlines()
            text = "\n".join(text)
            # text = text.replace('\n\n \n\n', '\n')

        #print(section_file_name)  
        chunks = text_splitter.split_text(text)
        
        for chunk in chunks: 
            new_row = section_id, chunk_id, chunk 
            df_chunks.loc[chunk_id] = new_row
            chunk_id = chunk_id +1

    return chunk_id, df_chunks

# %%
# Initialize dataset for prompt 
df_chunks = pd.DataFrame(columns=['Section_Id','Chunk_Id','Chunk'])
# Initialize context_id
chunk_id = 1 

# Generate Questions & Answers for Sections.
idx_of_files = df.index
chunk_id, df_chunks = Create_Chunks(df, df_chunks, idx_of_files, chunk_id, verbose=False)
#print(f"{chunk_id} Chunks Generated")
# Out:
# Created a chunk of size 10832, which is longer than the specified 8000
# Created a chunk of size 10810, which is longer than the specified 8000
# Created a chunk of size 16668, which is longer than the specified 8000
# Created a chunk of size 9381, which is longer than the specified 8000
# Created a chunk of size 9897, which is longer than the specified 8000
# Created a chunk of size 10162, which is longer than the specified 8000
# Created a chunk of size 8639, which is longer than the specified 8000
# Created a chunk of size 18774, which is longer than the specified 8000
# Created a chunk of size 11551, which is longer than the specified 8000
# Created a chunk of size 10646, which is longer than the specified 8000
# Created a chunk of size 8495, which is longer than the specified 8000
# Created a chunk of size 8097, which is longer than the specified 8000
# Created a chunk of size 8213, which is longer than the specified 8000
# Created a chunk of size 8013, which is longer than the specified 8000
# Created a chunk of size 11989, which is longer than the specified 8000
# Created a chunk of size 9097, which is longer than the specified 8000
# Created a chunk of size 9146, which is longer than the specified 8000
# Created a chunk of size 10310, which is longer than the specified 8000
# Created a chunk of size 8069, which is longer than the specified 8000
# Created a chunk of size 8609, which is longer than the specified 8000
# Created a chunk of size 21415, which is longer than the specified 8000
# Created a chunk of size 8061, which is longer than the specified 8000
# Created a chunk of size 8355, which is longer than the specified 8000
# Created a chunk of size 8132, which is longer than the specified 8000
# Created a chunk of size 10695, which is longer than the specified 8000
# Created a chunk of size 9761, which is longer than the specified 8000
# Created a chunk of size 9843, which is longer than the specified 8000
# Created a chunk of size 8637, which is longer than the specified 8000
# Created a chunk of size 14883, which is longer than the specified 8000
# Created a chunk of size 9650, which is longer than the specified 8000
# Created a chunk of size 8889, which is longer than the specified 8000
# Created a chunk of size 10651, which is longer than the specified 8000
# Created a chunk of size 13014, which is longer than the specified 8000
# Created a chunk of size 9041, which is longer than the specified 8000
# Created a chunk of size 15856, which is longer than the specified 8000
# Created a chunk of size 12777, which is longer than the specified 8000
# Created a chunk of size 8691, which is longer than the specified 8000
# Created a chunk of size 9926, which is longer than the specified 8000
# Created a chunk of size 9355, which is longer than the specified 8000
# Created a chunk of size 9776, which is longer than the specified 8000
# Created a chunk of size 10271, which is longer than the specified 8000
# Created a chunk of size 12113, which is longer than the specified 8000
# Created a chunk of size 8588, which is longer than the specified 8000
# Created a chunk of size 8304, which is longer than the specified 8000
# Created a chunk of size 10521, which is longer than the specified 8000
# Created a chunk of size 10366, which is longer than the specified 8000
# Created a chunk of size 25194, which is longer than the specified 8000
# Created a chunk of size 13100, which is longer than the specified 8000
# Created a chunk of size 12729, which is longer than the specified 8000

# %%
df_chunks['Chunk_Letters'] = df_chunks['Chunk'].str.len()
df_chunks['Chunk_Words'] = df_chunks['Chunk'].str.split(' ').apply(len)
df_chunks.loc[:,'Chunk_Approx_Tokens'] = (df_chunks['Chunk_Words']*1.33).round()

# %%
df_chunks.shape
# Out:
# (2832, 6)

# %%
df_chunks[:3]
# Out:
#    Section_Id  Chunk_Id                                              Chunk  \
# 1  Book01_002         1  THE MAHABHARATA ADI PARVA Section I\nOm! Havin...
# 2  Book01_002         2  The Rishi Vyasa published this mass of knowled...
# 3  Book01_002         3  Vyasa executed the compilation of the Bharata,...
#
#    Chunk_Letters  Chunk_Words  Chunk_Approx_Tokens
# 1           7511         1214               1615.0
# 2           7551         1261               1677.0
# 3           6986         1162               1545.0

# %%
df_chunks.describe([.25,.5,.8,.9,.95,.99])
# Out:
#           Chunk_Id  Chunk_Letters  Chunk_Words  Chunk_Approx_Tokens
# count  2832.000000    2832.000000  2832.000000          2832.000000
# mean   1416.500000    4943.457980   845.020127          1123.883475
# std     817.672306    2485.633082   425.385475           565.752150
# min       1.000000       1.000000     1.000000             1.000000
# 25%     708.750000    3238.750000   551.750000           733.750000
# 50%    1416.500000    4907.000000   834.000000          1109.000000
# 80%    2265.800000    6985.800000  1192.800000          1586.600000
# 90%    2548.900000    7662.800000  1311.000000          1744.000000
# 95%    2690.450000    7979.600000  1387.450000          1845.450000
# 99%    2803.690000   11932.440000  2045.140000          2720.520000
# max    2832.000000   25194.000000  4446.000000          5913.000000

# %%
df_chunks.loc[df_chunks['Chunk_Words']<=50]
# Out:
#        Section_Id  Chunk_Id  \
# 100    Book01_075       100
# 143    Book01_106       143
# 302    Book02_011       302
# 307    Book02_014       307
# 320    Book02_024       320
# ...           ...       ...
# 1774   Book09_048      1774
# 1787   Book09_057      1787
# 1790   Book09_058      1790
# 1838   Book11_015      1838
# 2473  Book13_b018      2473
#
#                                                   Chunk  Chunk_Letters  \
# 100           Section LXXIV\n(Sambhava Parva continued)             40
# 143   "Satyavati having succeeded with great difficu...            244
# 302                                          Section XI             10
# 307                 Section XIV\n(Rajasuyarambha Parva)             34
# 320                                        Section XXIV             12
# ...                                                 ...            ...
# 1774                                                 48              2
# 1787                                                 57              2
# 1790  58\n"Sanjaya said, 'Beholding that fight thus ...            244
# 1838                            16\n(Stri-vilapa-parva)             22
# 2473  Section LIII\n"Yudhishthira said, 'After the R...            159
#
#       Chunk_Words  Chunk_Approx_Tokens
# 100             4                  5.0
# 143            36                 48.0
# 302             2                  3.0
# 307             3                  4.0
# 320             2                  3.0
# ...           ...                  ...
# 1774            1                  1.0
# 1787            1                  1.0
# 1790           39                 52.0
# 1838            1                  1.0
# 2473           25                 33.0
#
# [86 rows x 6 columns]

# %%
# Remove those chunk which has chapter name or page number or junk information.
df_chunks = df_chunks.loc[df_chunks['Chunk_Words']>50]

# %%
df_chunks.shape
# Out:
# (2746, 6)

# %%
df_chunks.to_csv(conf['PE_FOLDER'] + '03-Chunked_Book-All.csv')

# %%
# Save those chunks which are not being used for this project
# which are lessor than 25 percentile (too short) and more than 99 percentile (too big)
df_chunks[ (df_chunks['Chunk_Words']<=100) | (df_chunks['Chunk_Words']>1000)].\
    to_csv(conf['PE_FOLDER']+'03-Chunked_Book-Excluded.csv',index=None)

# %%
import numpy as np
excluded_chunks = np.array(df_chunks[ (df_chunks['Chunk_Words']<=100) | \
                                      (df_chunks['Chunk_Words']>1000)].Chunk_Id.to_list())
print(excluded_chunks.shape) 
print(excluded_chunks)
# Out:
# (1049,)
# [   1    2    3 ... 2828 2830 2831]

# %%
#drop chunks which are lessor than 25 percentile (too short) and more than 99 percentile (too big)
# Filter only those chunks which has token>800 and less then 2750
df_chunks = df_chunks[ (df_chunks['Chunk_Words']>100) & (df_chunks['Chunk_Words']<=1000)]

# %%
df_chunks.to_csv(conf['PE_FOLDER'] + '03-Chunked_Book.csv')

# %%
df_chunks.shape
# Out:
# (1697, 6)

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(15,3))
plt.hist(df_chunks['Chunk_Words'], bins=40, edgecolor='k') 
plt.xlabel('Word Count')
plt.ylabel('Frequency')
plt.title('Histogram of Chunk Word Count')
plt.show()

# %%
df_chunks['Approx_Ques'] = (df_chunks['Chunk_Words']/150).apply(round)

# %%
df_chunks.tail(33)
# Out:
#       Section_Id  Chunk_Id                                              Chunk  \
# 2783  Book15_014      2783  Section XIV\n"Vaisampayana said,--'Thus addres...
# 2784  Book15_015      2784  Section XV\n"Vaisampayana said,--'The royal so...
# 2785  Book15_016      2785  Section XVI\n"Vaisampayana said, 'Great was th...
# 2786  Book15_017      2786  Section XVII\n"Kunti said, 'It is even so, O m...
# 2787  Book15_018      2787  Section XVIII\n"Vaisampayana said, 'Hearing th...
# 2788  Book15_019      2788  Section XIX\n"Vaisampayana said. 'Following th...
# 2791  Book15_022      2791  Section XXII\n"Vaisampayana said, 'Those forem...
# 2792  Book15_023      2792  Section XXIII\n"Vaisampayana said. 'That forem...
# 2793  Book15_024      2793  Section XXIV\n"Vaisampayana said, 'The Pandava...
# 2794  Book15_025      2794  Section XXV\n"Vaisampayana said, 'The king, O ...
# 2796  Book15_027      2796  Section XXVII\n"Vaisampayana said, 'They passe...
# 2797  Book15_028      2797  Section XXVIII\n"Vaisampayana said, 'After the...
# 2798  Book15_029      2798  Section XXIX\n(Putradarsana Parva)\n"Janamejay...
# 2799  Book15_029      2799  "Vaisampayana continued, 'Hearing these lament...
# 2800  Book15_030      2800  Section XXX\n"Kunti said, 'O holy one, thou ar...
# 2801  Book15_031      2801  Section XXXI.\n"Vyasa said, 'Blessed be thou, ...
# 2802  Book15_032      2802  Section XXXII\n"Vaisampayana said, 'When night...
# 2803  Book15_033      2803  Section XXXIII\n"Vaisampayana said. 'Then thos...
# 2804  Book15_034      2804  Section XXXIV\n"Sauti said, 'Hearing this stor...
# 2805  Book15_035      2805  Section XXXV\n"Vaisampayana said, 'King Dhrita...
# 2809  Book15_038      2809  Section XXXVIII\n"Yudhishthira said, 'When suc...
# 2810  Book15_039      2810  Section XXXIX\n"Narada said, 'The king has not...
# 2811  Book16_001      2811  1\nOm! Having bowed down unto Narayana, and to...
# 2812  Book16_002      2812  2\nVaishampayana said: "While the Vrishnis and...
# 2815  Book16_005      2815  5\nVaishampayana said: "Meanwhile Daruka, goin...
# 2816  Book16_006      2816  6\nVaishampayana said: "The Kuru prince beheld...
# 2818  Book16_007      2818  "After all the people had set out, the ocean, ...
# 2819  Book16_008      2819  8\nVaishampayana said: "As Arjuna entered the ...
# 2821  Book17_002      2821  2\nVaishampayana said: "Those princes of restr...
# 2823  Book18_001      2823  1\nOm! Having bowed down into Narayana, and to...
# 2827  Book18_004      2827  4\nVaishampayana said, "King Yudhishthira, thu...
# 2829  Book18_005      2829  Narada recited the Mahabharata to the gods; As...
# 2832  Book18_006      2832  "I have thus indicated the ordinances, O forem...
#
#       Chunk_Letters  Chunk_Words  Chunk_Approx_Tokens  Approx_Ques
# 2783           3101          528                702.0            4
# 2784           2669          435                579.0            3
# 2785           5134          871               1158.0            6
# 2786           3609          654                870.0            4
# 2787           3901          644                857.0            4
# 2788           2861          486                646.0            3
# 2791           4114          715                951.0            5
# 2792           2656          438                583.0            3
# 2793           2896          477                634.0            3
# 2794           4433          784               1043.0            5
# 2796           4168          673                895.0            4
# 2797           3937          664                883.0            4
# 2798           5238          909               1209.0            6
# 2799           2851          473                629.0            3
# 2800           3912          713                948.0            5
# 2801           3755          646                859.0            4
# 2802           3189          515                685.0            3
# 2803           5172          846               1125.0            6
# 2804           3891          661                879.0            4
# 2805           3309          556                739.0            4
# 2809           3473          600                798.0            4
# 2810           4656          795               1057.0            5
# 2811           5104          855               1137.0            6
# 2812           3873          657                874.0            4
# 2815           2603          451                600.0            3
# 2816           4104          727                967.0            5
# 2818           5305          872               1160.0            6
# 2819           4058          708                942.0            5
# 2821           3989          654                870.0            4
# 2823           3998          669                890.0            4
# 2827           3523          608                809.0            4
# 2829           2425          411                547.0            3
# 2832           3003          532                708.0            4

# %%
df_chunks.shape
# Out:
# (1433, 7)

# %%
df_chunks.describe()
# Out:
#           Chunk_Id  Chunk_Letters  Chunk_Words  Chunk_Approx_Tokens  \
# count  1433.000000    1433.000000  1433.000000          1433.000000
# mean   1355.055129    4123.519191   703.622470           935.833217
# std     845.296182     987.518846   167.325004           222.528611
# min       4.000000    2197.000000   400.000000           532.000000
# 25%     602.000000    3291.000000   559.000000           743.000000
# 50%    1251.000000    4087.000000   698.000000           928.000000
# 75%    2101.000000    4971.000000   849.000000          1129.000000
# max    2832.000000    6353.000000  1000.000000          1330.000000
#
#        Approx_Ques
# count  1433.000000
# mean      4.691556
# std       1.149346
# min       3.000000
# 25%       4.000000
# 50%       5.000000
# 75%       6.000000
# max       7.000000

# %%
df_chunks.Approx_Ques.sum()
# Out:
# 6723

# %%
df_chunks.to_csv(conf['PE_FOLDER']R+'03-Chunked_Book.csv',index=None)

# %%
df_chunks = pd.read_csv(conf['PE_FOLDER']+'03-Chunked_Book.csv')
df_chunks.head(3)
# Out:
#    Section_Id  Chunk_Id                                              Chunk  \
# 0  Book01_002         4  'Hear, O Sanjaya, all that happened thereupon ...
# 1  Book01_003         8  Section II\n"The Rishis said, 'O son of Suta, ...
# 2  Book01_003         9  'Listen, O ye ascetics, to the outlines of the...
#
#    Chunk_Letters  Chunk_Words  Chunk_Approx_Tokens  Approx_Ques
# 0           2742          505                672.0            3
# 1           5714          974               1295.0            6
# 2           6353          974               1295.0            6

# %%
df_chunks['Book'] = df_chunks['Section_Id'].str.split("_").str[0]

# %%
df_chunks
# Out:
#       Section_Id  Chunk_Id                                              Chunk  \
# 0     Book01_002         4  'Hear, O Sanjaya, all that happened thereupon ...
# 1     Book01_003         8  Section II\n"The Rishis said, 'O son of Suta, ...
# 2     Book01_003         9  'Listen, O ye ascetics, to the outlines of the...
# 3     Book01_003        15  "The above are the contents of the Eighteen Pa...
# 4     Book01_004        16  Section III\n(Paushya Parva)\nSauti said, "Jan...
# ...          ...       ...                                                ...
# 1428  Book17_002      2821  2\nVaishampayana said: "Those princes of restr...
# 1429  Book18_001      2823  1\nOm! Having bowed down into Narayana, and to...
# 1430  Book18_004      2827  4\nVaishampayana said, "King Yudhishthira, thu...
# 1431  Book18_005      2829  Narada recited the Mahabharata to the gods; As...
# 1432  Book18_006      2832  "I have thus indicated the ordinances, O forem...
#
#       Chunk_Letters  Chunk_Words  Chunk_Approx_Tokens  Approx_Ques    Book
# 0              2742          505                672.0            3  Book01
# 1              5714          974               1295.0            6  Book01
# 2              6353          974               1295.0            6  Book01
# 3              2997          517                688.0            3  Book01
# 4              5149          879               1169.0            6  Book01
# ...             ...          ...                  ...          ...     ...
# 1428           3989          654                870.0            4  Book17
# 1429           3998          669                890.0            4  Book18
# 1430           3523          608                809.0            4  Book18
# 1431           2425          411                547.0            3  Book18
# 1432           3003          532                708.0            4  Book18
#
# [1433 rows x 8 columns]

# %%
df_chunks.groupby(['Book'])['Approx_Ques'].sum()
# Out:
# Book
# Book01     771
# Book02     253
# Book03    1056
# Book04     216
# Book05     641
# Book06     383
# Book07     619
# Book08     227
# Book09     130
# Book10      68
# Book11      64
# Book12    1191
# Book13     595
# Book14     330
# Book15     131
# Book16      29
# Book17       4
# Book18      15
# Name: Approx_Ques, dtype: int64

# %%
df_chunks.groupby(['Section_Id'])['Approx_Ques'].sum()
# Out:
# Section_Id
# Book01_002     3
# Book01_003    15
# Book01_004     6
# Book01_006     6
# Book01_007     3
#               ..
# Book17_002     4
# Book18_001     4
# Book18_004     4
# Book18_005     3
# Book18_006     4
# Name: Approx_Ques, Length: 1342, dtype: int64

# %% [markdown]
# # Add Small Chunk Questions Towards the End of 03-Chunked_Book.csv

# %%
df_chunks = pd.read_csv(conf['PE_FOLDER'] + '03-Chunked_Book.csv')
df_chunks
# Out:
#       Section_Id  Chunk_Id                                              Chunk  \
# 0     Book01_002         4  'Hear, O Sanjaya, all that happened thereupon ...
# 1     Book01_003         8  Section II\n"The Rishis said, 'O son of Suta, ...
# 2     Book01_003         9  'Listen, O ye ascetics, to the outlines of the...
# 3     Book01_003        15  "The above are the contents of the Eighteen Pa...
# 4     Book01_004        16  Section III\n(Paushya Parva)\nSauti said, "Jan...
# ...          ...       ...                                                ...
# 1428  Book17_002      2821  2\nVaishampayana said: "Those princes of restr...
# 1429  Book18_001      2823  1\nOm! Having bowed down into Narayana, and to...
# 1430  Book18_004      2827  4\nVaishampayana said, "King Yudhishthira, thu...
# 1431  Book18_005      2829  Narada recited the Mahabharata to the gods; As...
# 1432  Book18_006      2832  "I have thus indicated the ordinances, O forem...
#
#       Chunk_Letters  Chunk_Words  Chunk_Approx_Tokens  Approx_Ques
# 0              2742          505                672.0            3
# 1              5714          974               1295.0            6
# 2              6353          974               1295.0            6
# 3              2997          517                688.0            3
# 4              5149          879               1169.0            6
# ...             ...          ...                  ...          ...
# 1428           3989          654                870.0            4
# 1429           3998          669                890.0            4
# 1430           3523          608                809.0            4
# 1431           2425          411                547.0            3
# 1432           3003          532                708.0            4
#
# [1433 rows x 7 columns]

# %%
df_chunks1 = pd.read_csv(conf['PE_FOLDER'] + '03-Chunked_Book-Excluded.csv')

# %%
df_chunks1= df_chunks1[(df_chunks1['Chunk_Words']<400) & (df_chunks1['Chunk_Words']>100)]

# %%
df_chunks1
# Out:
#       Section_Id  Chunk_Id                                              Chunk  \
# 5     Book01_002         7  "In former days, having placed the four Vedas ...
# 15    Book01_005        21  Section IV\n(Pauloma Parva)\n'UGRASRAVA SAUTI,...
# 16    Book01_011        27  Section X\n(Pauloma Parva continued)\nSauti sa...
# 17    Book01_013        29  Section XII\n(Pauloma Parva continued)\n"Sauti...
# 18    Book01_015        31  Section XIV\n(Astika Parva continued)\n"Sauti ...
# ...          ...       ...                                                ...
# 1273  Book14_052      2722  When king Yudhishthira the just of Kuru's race...
# 1289  Book14_092      2767  would do when seeing some injury done to him. ...
# 1295  Book15_012      2781  Section XII\n"Arjuna said, 'O Bhima, thou art ...
# 1297  Book15_021      2790  Section XXI\n" Vaisampayana said, 'Upon the re...
# 1308  Book18_002      2825  "Overwhelmed by sorrow and grief, and with his...
#
#       Chunk_Letters  Chunk_Words  Chunk_Approx_Tokens
# 5               779          133                177.0
# 15             1988          341                454.0
# 16             1358          242                322.0
# 17              858          145                193.0
# 18             1074          184                245.0
# ...             ...          ...                  ...
# 1273           1666          271                360.0
# 1289           1948          339                451.0
# 1295           2146          369                491.0
# 1297           2319          388                516.0
# 1308            877          147                196.0
#
# [264 rows x 6 columns]

# %%
df_chunks1.loc[:,'Approx_Ques']=1

# %%
df_chunks1
# Out:
#       Section_Id  Chunk_Id                                              Chunk  \
# 5     Book01_002         7  "In former days, having placed the four Vedas ...
# 15    Book01_005        21  Section IV\n(Pauloma Parva)\n'UGRASRAVA SAUTI,...
# 16    Book01_011        27  Section X\n(Pauloma Parva continued)\nSauti sa...
# 17    Book01_013        29  Section XII\n(Pauloma Parva continued)\n"Sauti...
# 18    Book01_015        31  Section XIV\n(Astika Parva continued)\n"Sauti ...
# ...          ...       ...                                                ...
# 1273  Book14_052      2722  When king Yudhishthira the just of Kuru's race...
# 1289  Book14_092      2767  would do when seeing some injury done to him. ...
# 1295  Book15_012      2781  Section XII\n"Arjuna said, 'O Bhima, thou art ...
# 1297  Book15_021      2790  Section XXI\n" Vaisampayana said, 'Upon the re...
# 1308  Book18_002      2825  "Overwhelmed by sorrow and grief, and with his...
#
#       Chunk_Letters  Chunk_Words  Chunk_Approx_Tokens  Approx_Ques
# 5               779          133                177.0            1
# 15             1988          341                454.0            1
# 16             1358          242                322.0            1
# 17              858          145                193.0            1
# 18             1074          184                245.0            1
# ...             ...          ...                  ...          ...
# 1273           1666          271                360.0            1
# 1289           1948          339                451.0            1
# 1295           2146          369                491.0            1
# 1297           2319          388                516.0            1
# 1308            877          147                196.0            1
#
# [264 rows x 7 columns]

# %%
pd.concat([df_chunks,df_chunks1]).to_csv(conf['PE_FOLDER'] + '03-Chunked_Book_Incl_Small_Chunk.csv',index=None)
