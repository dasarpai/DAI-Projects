# %%
https://huggingface.co/surajp/gpt2-hindi

# %%
from transformers import AutoTokenizer, AutoModelWithLMHead

tokenizer = AutoTokenizer.from_pretrained("surajp/gpt2-hindi",)

model = AutoModelWithLMHead.from_pretrained("surajp/gpt2-hindi" )
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# D:\Users\admin\anaconda3\lib\site-packages\transformers\modeling_utils.py in from_pretrained(cls, pretrained_model_name_or_path, *model_args, **kwargs)
#     855             try:
# --> 856                 state_dict = torch.load(resolved_archive_file, map_location="cpu")
#     857             except Exception:
#
# D:\Users\admin\anaconda3\lib\site-packages\torch\serialization.py in load(f, map_location, pickle_module, **pickle_load_args)
#     526             :func:`pickle_module.load` and :func:`pickle_module.Unpickler`, e.g.,
# --> 527             :attr:`errors=...`.
#     528
#
# D:\Users\admin\anaconda3\lib\site-packages\torch\serialization.py in __init__(self, name_or_buffer)
#     223     def __exit__(self, *args):
# --> 224         self.file_like.flush()
#     225
#
# ...

# %%
# !pip list
# Out:
# Package                            Version
# ---------------------------------- -------------------
# -n-core-web-sm                     2.3.1
# absl-py                            0.10.0
# aiohttp                            3.6.2
# aksharamukha                       1.8.1
# alabaster                          0.7.12
# anaconda-client                    1.7.2
# anaconda-navigator                 1.9.12
# anaconda-project                   0.8.3
# argh                               0.26.2
# asn1crypto                         1.3.0
# astroid                            2.4.2
# astropy                            4.0.1.post1
# astunparse                         1.6.3
# async-timeout                      3.0.1
# atomicwrites                       1.4.0
# attrs                              19.3.0
# autopep8                           1.5.3
# Babel                              2.8.0
# backcall                           0.2.0
# backports.functools-lru-cache      1.6.1
# ...

# %%
import tensorflow

# %%
tensorflow.__version__
# Out:
# '2.3.0'
