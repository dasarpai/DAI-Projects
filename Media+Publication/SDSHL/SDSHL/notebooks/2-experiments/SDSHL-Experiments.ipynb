# %%
import pandas as pd
import fasttext.util
import fasttext

# %% [markdown]
# # Fasttext - Facebook

# %%
help(fasttext.FastText)

# %%
#https://fasttext.cc/docs/en/supervised-tutorial.html
    
model = fasttext.train_supervised(input="cooking.train")

# %%
#https://fasttext.cc/docs/en/crawl-vectors.html
    
ft = fasttext.load_model('cc.en.300.bin')

# %%
url = 'https://dl.fbaipublicfiles.com/fasttext/data/cooking.stackexchange.tar.gz'
filename = '/cooking/cooking.tar'
#!wget url && 
#!tar xvzf cooking.stackexchange.tar.gz

import urllib.request
urllib.request.urlretrieve(url, filename)

# !tar xvzf cooking.tar

# %%
model = fasttext.load_model(r"D:\18-DS\Datasets-Large\wiki.hi\wiki.hi.bin")

#model = fasttext.train_unsupervised('data/fil9', "cbow")
#model = fasttext.train_unsupervised('data/fil9', minn=2, maxn=5, dim=300)
#model = fasttext.train_unsupervised('data/fil9', thread=4)

# %%
model = fasttext.train_unsupervised('cooking/cooking.stackexchange.txt', model='skipgram')
#model = fasttext.train_unsupervised('data.txt', model='cbow')

# %%
[model.get_word_vector(x) for x in ["हरी", "pidgey", "yellow"]]

# %%
print(model['king'])

# %%
model.get_word_vector("enviroment")
model.get_word_vector("नरेन्द्र")
model.get_nearest_neighbors('asparagus')
model.get_analogies("berlin", "germany", "france")


model_without_subwords = fasttext.train_unsupervised('data/fil9', maxn=0)
model_without_subwords.get_nearest_neighbors('accomodation')

# %%
print(model.words)

# %%
print(model.labels)

# %%
model = fasttext.train_supervised('cooking/cooking.stackexchange.txt')


def print_results(N, p, r):
    print("N\t" + str(N))
    print("P@{}\t{:.3f}".format(1, p))
    print("R@{}\t{:.3f}".format(1, r))

print_results(*model.test('cooking/cooking.stackexchange.txt'))

# %%
model.predict("Which baking dish is best to bake a banana bread ?")

# %%
model.predict("Which baking dish is best to bake a banana bread ?", k=3)

# %%
model.predict(["Which baking dish is best to bake a banana bread ?", "Why not put knives in the dishwasher?"], k=3)

# %% [markdown]
# # NLTK

# %%
import nltk
from gensim.models import word2vec
from gensim.models.word2vec import Word2Vec
import pandas as pd
import numpy as np

# %%
df= pd.read_csv("Hinglish_Sarcasm.csv")
sentences = list(df.Sentence)
text_tokens = [sent.split() for sent in sentences]

# %%
text_tokens
# Out:
# [['#News', 'तीन', 'साल', 'बाथरूम', 'में', 'बंद', 'रही', 'विवाहिता'],
#  ['#BJP',
#   'की',
#   'संवैधानिक',
#   'तिकड़म-संविधान',
#   'की',
#   'धारा',
#   'का',
#   'गलत',
#   'हवाला',
#   'देकर',
#   'सीक्रेट',
#   'बैलट',
#   '(जो',
#   'होता',
#   'ही',
#   'नहीं)',
#   'से',
#   'दिल्ली',
#   'में',
#   'सरकार',
#   'बनाने',
#   'की',
#   'अलोकतांत्रिक',
#   'साजिश।'],
#  ['हुर्रियत',
#   'जेहादी',
#   'यासिन',
#   'मलिक',
#   'और',
#   'आजाद',
#   'कश्मीर',
#   'चिलाने',
#   'वाले',
#   'कश्मीर',
#   'को',
#   'बचाने',
#   'आगे',
#   'नहीं',
#   'आएंगे',
#   '#JammuKashmirFloods.',
#   '#KashmirFloods'],
#  ['J&K:',
#   'भूस्खलन',
#   'में',
#   '7',
#   'की',
#   'मौत',
#   '20',
#   'लापता:',
#   'जम्मू-कश्मीर',
#   'के',
#   'उधमपुर',
#   'जिले',
#   'के',
#   'एक',
#   'सुदूर',
#   'पर्वतीय',
#   'गांव',
#   'में',
#   'भारी',
#   'बारिश',
#   'के',
#   'बा'],
#  ['NCP',
#   'के',
#   'पूर्व',
#   'नेता',
#   'और',
#   'मंत्री',
#   'विजय',
#   'कुमार',
#   'गावित',
#   'पर',
#   'भ्रष्टाचार',
#   'का',
#   'आरोप',
#   'लगा',
#   'और',
#   'कहा',
#   'गया',
#   'की',
#   'गावित',
#   'ने',
#   'फर्जी',
#   'लोगो',
#   'के',
#   'नाम'],
#  ['हींग',
#   'से',
#   'न',
#   'तेल',
#   'से',
#   'बन्दूक',
#   'से',
#   'न',
#   'तलवार',
#   'से',
#   '-',
#   '#ISIS',
#   'खत्म',
#   'होगा',
#   'रासयनिक',
#   'और',
#   'जैविक',
#   'गैस',
#   'और',
#   'सूंघ',
#   'से'],
#  ['#WhyMediaIsSoAntiHindu',
#   'भारत',
#   'का',
#   'मीडिया',
#   'बिकाऊ',
#   'देशद्रोही',
#   'भ्रष्ट',
#   'और',
#   'हिन्दू',
#   'विरोधी',
#   'है',
#   '|',
#   'यह',
#   'बात',
#   'अब',
#   'गूगल',
#   'भी',
#   'जानती',
#   'है'],
#  ['औरंगजेब',
#   'ने',
#   'इस्लाम',
#   'कबूल',
#   'ना',
#   'करने',
#   'पर',
#   'उन्हे',
#   'गर्मपानी',
#   'में',
#   'उबाल',
#   'कर',
#   'जिन्दा',
#   'चमड़ी',
#   'उतरवाने',
#   'का',
#   'फरमान',
#   'जारी',
#   'किया।'],
#  ['Breaking',
#   'News',
#   'रांची',
#   'में',
#   'आतंकी',
#   'संगठन',
#   'की',
#   'धमकी-',
#   "'30",
#   'दिन',
#   'में',
#   'गांव',
#   'छोड़ें',
#   'वरना',
#   'मार',
#   'देंगे',
#   'और',
#   'लड़कियों',
#   'को',
#   'मुसलमान',
#   'बना'],
#  ['आज',
#   'अनुष्का',
#   'की',
#   'नहीं',
#   "'साक्षी'",
#   'की',
#   'बारी',
#   'है।शुरू',
#   'हो',
#   'जाओ',
#   'और',
#   'निकालो',
#   'अपनी',
#   'भड़ास।'],
#  ['1',
#   'किसान',
#   '2',
#   'महीनों',
#   'से',
#   'अपने',
#   'सूखे',
#   'खेत',
#   'में',
#   'सिंचाई',
#   'के',
#   'लिए',
#   'डैम',
#   'में',
#   'पानी',
#   'छोड़ने',
#   'की',
#   'मांग',
#   'को',
#   'लेकर',
#   'अनशन',
#   'पर',
#   'है।लेकिन',
#   'नेता',
#   'सूखे',
#   'का',
#   'भी',
#   'मज़ाक',
#   'उड़ा',
#   'रहे',
#   'हैं'],
#  ['#News',
#   'बिजली',
#   'संकट',
#   'पर',
#   'केंद्र',
#   'और',
#   'महाराष्ट्र',
#   'में',
#   'तकरार'],
#  ['Farmers',
#   'Strike',
#   ':',
#   'पुलिस',
#   'की',
#   'कड़ी',
#   'बंदोबस्त',
#   'के',
#   'बिच',
#   "'किसान",
#   'क्रांति',
#   "यात्रा'",
#   'दिल्ली',
#   'पहुंची'],
#  ['NTPC',
#   'रायबरेली',
#   'को',
#   'चलाने',
#   'की',
#   'इतनी',
#   'जल्दी',
#   'क्या',
#   'थी',
#   'क्यों',
#   'हुआ',
#   'सुरक्षा',
#   'मानकों',
#   'से',
#   'खिलवाड़.',
#   'कौन',
#   'लेगा',
#   'इतने',
#   'मौतों',
#   'की',
#   'जिम्मेदारी.',
#   'Sad'],
#  ['#Hallabol',
#   'यूपी',
#   'में',
#   '86',
#   'लाख',
#   'किसानों',
#   'का',
#   'एक',
#   'लाख',
#   'तक',
#   'का',
#   'कर्ज',
#   'माफ',
#   'किए',
#   'जाने',
#   'की',
#   'खबर'],
#  ['Anti',
#   'Romeo',
#   'Squad',
#   'युक्त',
#   'उत्तर',
#   'प्रदेश',
#   'में',
#   'भी',
#   'क्लास',
#   'रूम',
#   'के',
#   'अंदर',
#   'छेड़खानी.'],
#  ['#GujaratElections2017',
#   'गुजरात',
#   'में',
#   'चुनाव',
#   'का',
#   'ऐलान।',
#   '182',
#   'सीटों',
#   'पर',
#   'दो',
#   'चरणों',
#   'में',
#   'चुनाव।',
#   'पहले',
#   'में',
#   '89',
#   'सीट',
#   'और',
#   'दूसरे',
#   'में',
#   '93'],
#  ['Pulwama',
#   'Attack:',
#   'गुलाम',
#   'नबी',
#   'आजाद',
#   'ने',
#   'सिद्धू',
#   'को',
#   'दिखाया',
#   'आईना',
#   'बोले-',
#   'PAK',
#   'से',
#   'बातचीत',
#   'का',
#   'वक्त',
#   'नहीं'],
#  ['#KarnatakaElection2018',
#   'कर्नाटक',
#   'का',
#   'नाटक',
#   'यहीं',
#   'खत्म.इतिहास',
#   'के',
#   'पन्नों',
#   'में',
#   'दर्ज',
#   'होगा',
#   'ये',
#   'दिन.येदुरप्पा',
#   'एक',
#   'बार',
#   'फिर',
#   'बने',
#   "'tragedy",
#   "king'"],
#  ['GROUND',
#   'REPORT:',
#   'एक',
#   'चायवाले',
#   'से',
#   'सुने',
#   'कैसा',
#   'था',
#   'बुलंदशहर',
#   'का',
#   'कल',
#   'का',
#   'मंज़र',
#   '|',
#   'Crime',
#   'Tak',
#   '@nishantchat',
#   '#BulandshaharViolence',
#   '#Buland.'],
#  ['‘दंगल’',
#   'को',
#   'हर',
#   'बार',
#   'लगातार',
#   'No',
#   '1',
#   'बनाए',
#   'रखने',
#   'के',
#   'लिए',
#   'आप',
#   'सभी',
#   'का',
#   'आभार!',
#   'ये',
#   'प्यार',
#   'और',
#   'साथ',
#   'हमेशा',
#   'बना',
#   'रहे!',
#   '🙏'],
#  ['SHOCKING',
#   '-',
#   'BJP',
#   'प्रवक्ता',
#   'ने',
#   'ग़द्दार',
#   'कहा',
#   'तो',
#   'कांग्रेस',
#   'प्रवक्ता',
#   'ने',
#   'पानी',
#   'से',
#   'भरा',
#   'ग्लास',
#   'फेंक',
#   'कर',
#   'मारा.',
#   'शुक्र',
#   'है',
#   'किसी',
#   'को',
#   'चोट',
#   'नहीं',
#   'आ.'],
#  ['बौखलाने', 'के', 'बाद', 'अब', 'गिड़गिड़ाने', 'पर', 'मजबूर', 'पाकिस्तान'],
#  ['‘दंगल’',
#   'को',
#   'No',
#   '1',
#   'बनाने',
#   'के',
#   'लिए',
#   'आप',
#   'सभी',
#   'का',
#   'आभार.',
#   'अपना',
#   'प्यार',
#   'और',
#   'सहयोग',
#   'ऐसे',
#   'ही',
#   'बनाए',
#   'रखिए!'],
#  ['GST',
#   'is',
#   'victory',
#   'of',
#   'PM',
#   'अगर',
#   'ये',
#   'सहीं',
#   'है',
#   'तो',
#   'पेट्रोलियम',
#   'पदार्थों',
#   'पर',
#   'इसको',
#   'अबिलम्ब',
#   'लागु',
#   'कीजिये.',
#   'ईमानदारी',
#   'थोड़ा',
#   'और',
#   'बढ़ेगी'],
#  ['#ModiInAmerica',
#   'a',
#   'win',
#   'मेरे',
#   'देशवासी',
#   'जिन्होने',
#   'हजार',
#   'कि.मी',
#   'दूर',
#   'रह',
#   'कर',
#   'हमारे',
#   'देश',
#   'कि',
#   'ईज्जत',
#   'को',
#   'बढाया',
#   'हे।'],
#  ['अभी',
#   'शम्स',
#   '(सूरज)',
#   'नहीं',
#   'डूबा',
#   'ज़रा',
#   'सी',
#   'शाम',
#   'होने',
#   'दो"',
#   'मैं',
#   'खुद',
#   'लौट',
#   'जाउंगा',
#   'मुझे',
#   '.'],
#  ['सेंसर', 'बोर्ड', 'पर', 'ही', 'कैंची', 'चलाने', 'की', 'तैयारी', 'में'],
#  ['BBC',
#   'पाकिस्तानी',
#   'सेना',
#   'की',
#   'निगरानी',
#   'में',
#   'बीबीसी',
#   'की',
#   'टीम',
#   'पहुंची',
#   'बालाकोट',
#   'के',
#   'उस',
#   'मदरसे',
#   'के',
#   'भीतर',
#   'जहां',
#   'भारत',
#   'ने',
#   'हवाई',
#   'हमले',
#   'किया',
#   'था'],
#  ['मोदी',
#   'सरकार',
#   'के',
#   'समर्थन',
#   'के',
#   'पीछे',
#   'फीयर',
#   'फैक्टर',
#   'काम',
#   'कर',
#   'रहा',
#   'है'],
#  ['Exclusive',
#   'Interview-',
#   'सिद्धू',
#   'के',
#   'समर्थन',
#   'में',
#   'अबू',
#   'आजमी',
#   'पाकिस्तान',
#   'में',
#   'इमरान',
#   'खान',
#   'के',
#   'शपथ',
#   'ग्रहण',
#   'समरोह',
#   'में',
#   'जाने',
#   'के',
#   'बाद',
#   'चौतरफा',
#   'घिरे.'],
#  ['7.5',
#   'लाख',
#   'रुपए',
#   'तक',
#   'की',
#   'राशि',
#   'पर',
#   '10',
#   'साल',
#   'तक',
#   'के',
#   'लिए',
#   'सालाना',
#   '8',
#   'प्रतिशत',
#   'का',
#   'interest',
#   'rate',
#   'सुरक्षित',
#   'किया',
#   'जाएगा:',
#   'PM'],
#  ['विचारों',
#   'पर',
#   'आमना',
#   'सामना',
#   'करिये',
#   'कलाकार',
#   'पर',
#   'व्यक्तिगत',
#   'टिप्पणी',
#   'उचित',
#   'नहीं।'],
#  ['कैलाश', 'मानसरोवर', 'के', 'बाद', 'अब', 'दुबई', 'जाएंगे', 'राहुल', 'गांधी'],
#  ['Exclusive',
#   'break-',
#   'समाजवादी',
#   'पार्टी',
#   'से',
#   'जया',
#   'बच्चन',
#   'को',
#   'फिर',
#   'राज्यसभा',
#   'का',
#   'टिकट',
#   'नरेश',
#   'अग्रवाल',
#   'को',
#   'टिकट',
#   'नहीं'],
#  ['घर',
#   'पर',
#   'काम',
#   'करने',
#   'वाले',
#   'युवक',
#   'की',
#   'शादी',
#   'में',
#   'पहुंचे',
#   'राहुल',
#   'गांधी'],
#  ['राहुल',
#   'की',
#   'कांग्रेस',
#   'में',
#   'भी',
#   'नहीं',
#   'बदली',
#   'कार्यसमिति',
#   'चयन',
#   'की',
#   'प्रक्रिया'],
#  ['गुजरात',
#   'में',
#   'बीजेपी',
#   'को',
#   'हराने',
#   'के',
#   'लिए',
#   'कांग्रेस',
#   'का',
#   "'शांति",
#   "प्लान'-"],
#  ['डेरा',
#   'के',
#   'गुंडों',
#   'के',
#   'संपर्क',
#   'में',
#   'थे',
#   'पंचकूला',
#   'के',
#   'ड्यूटी',
#   'मजिस्ट्रेट'],
#  ['BSF',
#   'ने',
#   'सरहद',
#   'पर',
#   'कोहरे',
#   'के',
#   'दौरान',
#   'बढ़ाई',
#   'चौकसी',
#   'घुसपैठ',
#   'की',
#   'आशंका'],
#  ['हनीप्रीत',
#   'का',
#   'खेल',
#   'खत्म',
#   'जसमीत',
#   'सिंह',
#   'की',
#   'ताजपोशी',
#   'की',
#   'तैयारियां',
#   'शुरू'],
#  ['लोकसभा',
#   'चुनाव',
#   'के',
#   'बाद',
#   'अपने',
#   'पहले',
#   'टीवी',
#   'इंटरव्यू',
#   'में',
#   'राहुल',
#   'गांधी',
#   'ने',
#   'कहा-',
#   'बिहार',
#   'में',
#   'डूब',
#   'रही',
#   'है',
#   'BJP.'],
#  ['खास', 'है', 'प्रियंका', 'गांधी', 'का', 'चुनावी', 'रथ', 'देखें', 'अंदर'],
#  ['मोदी',
#   'सरकार',
#   'की',
#   '‘स्किल',
#   'इंडिया’',
#   'स्कीम',
#   'को',
#   'पलीता',
#   'लगा',
#   'रहे',
#   'हैं',
#   'बिचौलिए',
#   'ठग'],
#  ['#RakshaBandhan',
#   'पर',
#   'संदेश',
#   'भाई',
#   'और',
#   'बहन',
#   'दोनों',
#   'की',
#   'रक्षा',
#   'के',
#   'लिए',
#   '.',
#   'क्योंकि',
#   'हर',
#   'जिंदगी',
#   'अनमोल',
#   'है'],
#  ['Good',
#   'Read',
#   'about',
#   '#yogiadityanath',
#   'नेपाल',
#   'को',
#   'पहला',
#   'राजा',
#   'देने',
#   'वाले',
#   'मठ',
#   'ने',
#   'यूपी',
#   'को',
#   'दिया',
#   'नया',
#   'सीएम'],
#  ['गोरक्षकों',
#   'के',
#   'नाम',
#   'पर',
#   'वसूली',
#   'जा',
#   'रही',
#   'रंगदारी',
#   'कई',
#   'चेहरे',
#   'बेनकाब.',
#   'शिव',
#   'सेना',
#   'कार्यकर्ता',
#   'शामिल'],
#  ['Champions',
#   'में',
#   'भारत',
#   'ने',
#   'पाक',
#   'हॉकी',
#   'टीम',
#   'को',
#   '4-0',
#   'हराया'],
#  ['Safety',
#   'First:',
#   'मुम्बई',
#   'में',
#   'ट्रेन',
#   'में',
#   'चढ़ते',
#   'यात्रियों',
#   'के',
#   'लिए',
#   'कोच',
#   'के',
#   'गेट',
#   'पर',
#   'नीले',
#   'रंग',
#   'की',
#   'लाइट',
#   'लगाई',
#   'जा',
#   'रही',
#   'है',
#   'जो',
#   'यात्रियों',
#   'को.'],
#  ['Aam',
#   'Aadmi',
#   'Party',
#   '-',
#   'Delhi',
#   'ने',
#   'मतदाता',
#   'सूची',
#   'से',
#   'जिंदा',
#   'लोगों',
#   'के',
#   'नाम',
#   'कटने',
#   'का',
#   'आरोप',
#   'लगाया',
#   'है.',
#   'इस',
#   'मुद्दे',
#   'पर',
#   'हमारे',
#   'संवाददाता'],
#  ['दिल्ली',
#   'की',
#   'राजनीति',
#   'में',
#   'कोहराम',
#   'मचना',
#   'तय.बीजेपी',
#   'सांसद',
#   'मनोज',
#   'तिवारी',
#   'ने',
#   'तोड़ा',
#   'सीलिंग',
#   'का',
#   'ताला।'],
#  ['छोटे',
#   'भाई',
#   'ने',
#   'मिलिंद',
#   'एकबोटे',
#   'को',
#   'पूरी',
#   'तरह',
#   'से',
#   'निर्दोष',
#   'बताया'],
#  ['MP:',
#   'पीएम',
#   'मोदी',
#   'भले',
#   'ही',
#   'VIP',
#   'कल्चर',
#   'को',
#   'खत्म',
#   'करने',
#   'की',
#   'पैरवी',
#   'करते',
#   'हों',
#   'लेकिन',
#   'लगता',
#   'नही',
#   'कि',
#   'मध्यप्रदेश',
#   'बीजेपी',
#   'उनकी',
#   'बातों',
#   'को',
#   'गम्भीरता',
#   'से',
#   'ले.'],
#  ['राफेल',
#   'करार',
#   'नियमों',
#   'के',
#   'तहत',
#   'किया',
#   'गया',
#   'सीतारमण',
#   'ने',
#   'पूछा',
#   'कि',
#   'कांग्रेस',
#   'बताए',
#   'कि'],
#  ['Exclusive',
#   '-',
#   'No',
#   'Confidence',
#   'Motion',
#   'में',
#   'शिवसेना',
#   'रहेगी',
#   'Absent',
#   'शिवसेना',
#   'ने',
#   'मोदी',
#   'सरकार',
#   'को',
#   'समर्थन',
#   'नहीं',
#   'करने',
#   'का',
#   'फैसला',
#   'किया.',
#   'शिवसेना.'],
#  ['प्रवीण', 'तोगड़िया', "'मोदी'", 'से', 'दो-दो', 'हाथ', 'करने', 'को', 'तैयार'],
#  ['हालांकि',
#   'डायलाग',
#   'वह',
#   'सपाट',
#   'तरीके',
#   'से',
#   'बोलती',
#   'नजर',
#   'आती',
#   'हैं'],
#  ['हिंदी',
#   'के',
#   'प्रयोग',
#   'में',
#   'व्याकरण',
#   'और',
#   'व्यवहार',
#   'की',
#   'गलतियां',
#   'आम',
#   'होती',
#   'जा',
#   'रही',
#   'हैं'],
#  ['हालांकि',
#   'लंबे',
#   'वक़्त',
#   'तक',
#   'फ़िल्म',
#   'बांधे',
#   'रखने',
#   'में',
#   'कामयाब',
#   'नहीं',
#   'होती'],
#  ['‘मशीन’',
#   'अब्\u200dबास-मस्\u200dतान',
#   'की',
#   'सबसे',
#   'कमजोर',
#   'फिल्\u200dम',
#   'के',
#   'रूप',
#   'में',
#   'याद',
#   'की',
#   'जाएगी',
#   'जिसमें',
#   'एक',
#   'लोकेशन',
#   'के',
#   'अलावा',
#   'सब',
#   'कुछ',
#   'फिसड्डी',
#   'रहा'],
#  ['R.S.S.',
#   'की',
#   'तर्ज',
#   'पर',
#   'विश्व',
#   'सेवक',
#   'संघ',
#   'V.S.S.बनाया',
#   'जाना',
#   'चाहिए',
#   'जो',
#   'विश्व',
#   'मानव',
#   'की',
#   'सुरक्षा',
#   'और',
#   'सम्रद्धि',
#   'के',
#   'लिए',
#   'समर्पित',
#   'हो.'],
#  ['#News', 'सीमावर्ती', 'सड़कों', 'के', 'लिए', 'बनी', 'नई', 'कंपनी'],
#  ['#ओणम',
#   'की',
#   'ढेर',
#   'सारी',
#   'शुभकामनाएं',
#   'इस',
#   'पवित्र',
#   'पर्व',
#   'पर',
#   'मैं',
#   'आपके',
#   'और',
#   'आपके',
#   'परिवार',
#   'की',
#   'खुशहाली',
#   'और',
#   'समृद्धि',
#   'की',
#   'प्रार्थना',
#   'करता',
#   'हूं'],
#  ['#BreakingNews',
#   'PM',
#   'रिलीफ',
#   'फंड',
#   'से',
#   'कश्मीर',
#   'के',
#   'विकलांगों',
#   'को',
#   'आर्थि\u200dक',
#   'मदद'],
#  ['‘बाहुबली',
#   '2’',
#   'भव्\u200dयता',
#   'और',
#   'विशालता',
#   'में',
#   'पहली',
#   'से',
#   'ज्\u200dयादा',
#   'बड़ी',
#   'और',
#   'चमकदार',
#   'हो',
#   'गई',
#   'हैं'],
#  ['‘नूर’',
#   'में',
#   'बतौर',
#   'अभिनेत्री',
#   'सोनाक्षी',
#   'सिन्\u200dहा',
#   'कुछ',
#   'नया',
#   'करती',
#   'हैं'],
#  ['हिंदी',
#   'फिल्\u200dमों',
#   'के',
#   'पारंपरिक',
#   'किरदार',
#   '‘दोस्\u200dत’',
#   'को',
#   'उन्\u200dहोंने',
#   'अच्\u200dछी',
#   'तरह',
#   'निभाया',
#   'है'],
#  ['‘द',
#   'गाजी',
#   'अटैक’',
#   'में',
#   'लेखक-निर्देशक',
#   'ने',
#   'सराहनीय',
#   'सावधानी',
#   'बरती',
#   'है'],
#  ['हॉरर',
#   'में',
#   'बैकग्राउंड',
#   'म्यूज़िक',
#   'काफी',
#   'महत्त्व',
#   'रखता',
#   'है।',
#   'उसमें',
#   'भी',
#   'फ़िल्म',
#   'सफल',
#   'होती',
#   'है।'],
#  ['हुसैन',
#   'दलाल',
#   'के',
#   'चुटीले',
#   'संवाद',
#   'ने',
#   'फिल्म',
#   'की',
#   'रफ्तार',
#   'और',
#   'धार',
#   'बनाए',
#   'रखी',
#   'हैं'],
#  ['हेड',
#   'कांस्टेबल',
#   'सोमवीर',
#   'ने',
#   'दिल्ली',
#   'सचिवालय',
#   'में',
#   'की',
#   'खुदकुशी'],
#  ['IB',
#   'को',
#   'क्या',
#   'ज़रूरत',
#   'है',
#   'किसी',
#   'भी',
#   'विशेष',
#   'सुरक्षा',
#   'कवच',
#   'प्राप्त',
#   'अघिकारी',
#   'या',
#   'नेता',
#   'की',
#   'जासूसी',
#   'करवाने',
#   'की'],
#  ['BSP',
#   'के',
#   'पूर्व',
#   'सांसद',
#   'का',
#   'बेटा',
#   'है',
#   'सरेआम',
#   'पिस्टल',
#   'लहराने',
#   'वाला',
#   'शख्स',
#   'देखिए',
#   'इस',
#   'ख़बर',
#   'से',
#   'जुड़ी',
#   'सारी',
#   'अपडेट्स',
#   '#एकऔरएकग्यारह'],
#  ['#FarmersOnWarpath',
#   'किसान',
#   'रैली',
#   'को',
#   'देखते',
#   'हुए',
#   'दिल्ली',
#   'के',
#   'अलग-अलग',
#   'इलाकों',
#   'में',
#   'सुरक्षा',
#   'के',
#   'कड़े',
#   'इंतज़ाम',
#   'किये',
#   'गए',
#   'हैं।',
#   'आज',
#   'तक',
#   'संवाददाता'],
#  ['Live:दिल्ली',
#   'के',
#   'जहांगीरपुरी',
#   'इलाके',
#   'में',
#   'टीचर',
#   'की',
#   'दिन',
#   'दहाड़े',
#   'हत्या.Chirag',
#   'Gothi|CrimeTak'],
#  ['LIVE:',
#   'SC',
#   'का',
#   'ऐतिहासिक',
#   'फैसला',
#   'सबरीमाला',
#   'मंदिर',
#   'में',
#   'महिलाओं',
#   'की',
#   'एंट्री',
#   'को',
#   'मंजूरी्'],
#  ['15अगस्त',
#   '|',
#   'मोदी',
#   'के',
#   'भाषण',
#   'से',
#   'ठीक',
#   'पहले',
#   'कैसी',
#   'है',
#   'लाल',
#   'किले',
#   'की',
#   'आंखों',
#   'देखी',
#   'तस्वीर',
#   'और',
#   'सुरक्षा',
#   'का',
#   'हाल',
#   '.सुने',
#   'हमारे',
#   'कमांडो',
#   'रिपोर्ट.'],
#  ['IIT',
#   'दिल्ली',
#   'में',
#   'एक',
#   'पूर्व',
#   'छात्र',
#   'की',
#   'मौत',
#   'से',
#   'सनसनी.',
#   'संस्थान',
#   'की',
#   'पीआरडी',
#   'बिल्डिंग',
#   'की',
#   'सातवीं',
#   'मंजिल',
#   'से',
#   'छलांग',
#   'लगाकर',
#   'अपनी',
#   'जान',
#   'दे',
#   'दी',
#   'मौके.'],
#  ['80',
#   'लाख',
#   'का',
#   'तुलसी',
#   'का',
#   'ज़र्दा',
#   'बरामद.',
#   'तीन',
#   'आरोपियों',
#   'को',
#   'दिल्ली',
#   'पुलिस',
#   'ने',
#   'किया',
#   'गिरफ्तार',
#   '#ReporterDiary',
#   'रिपोर्ट:'],
#  ['हिंदूराव',
#   'अस्पताल',
#   'के',
#   'डॉक्टर',
#   'पर',
#   'रेप',
#   'के',
#   'लग',
#   'रहे',
#   'आरोप',
#   'आरोपी',
#   'डॉक्टर',
#   'गिरफ्तार',
#   'मौके',
#   'से',
#   'संवाददाता',
#   'की',
#   'रिपोर्ट',
#   '#ReporterDiary'],
#  ['JNU',
#   'छेड़खानी',
#   'मामला:',
#   'पुलिस',
#   'ने',
#   'प्रोफेसर',
#   'अतुल',
#   'जौहरी',
#   'को',
#   'पूछताछ',
#   'के',
#   'लिए',
#   'भेजा',
#   'नोटिस',
#   '.',
#   'इस',
#   'पर',
#   'और',
#   'जानकारी',
#   'दे',
#   'रहें',
#   'हैं',
#   'हमारे',
#   'संवाददाता'],
#  ['होली',
#   'के',
#   'आसपास',
#   'हुड़दंगियों',
#   'ने',
#   'दिल्ली',
#   'पुलिस',
#   'की',
#   'नाक',
#   'में',
#   'दम',
#   'कर',
#   'रखा',
#   'है.',
#   'एलएसआर',
#   'कॉलेज',
#   'की',
#   'स्टूडेंट्स',
#   'ने',
#   'आरोप',
#   'लगाया',
#   'कि',
#   'उनके',
#   'ऊपर',
#   'हुड़दं',
#   'का',
#   'मुकदमा',
#   'किया',
#   'गया',
#   'है'],
#  ['Outer',
#   'डिस्ट्रिक्ट',
#   'पुलिस',
#   'ने',
#   'एक',
#   'शख्स',
#   'को',
#   'गिरफ्तार',
#   'कियाहै',
#   'उसके',
#   'कब्जे',
#   'से',
#   '1000000',
#   'रुपए',
#   'और',
#   '522',
#   'ग्राम',
#   'सोना',
#   'मिला',
#   'है',
#   'आरोपी',
#   '.'],
#  ['12',
#   'करोड़',
#   'रुपए',
#   'से',
#   'ज्यादा',
#   'कीमत',
#   'की',
#   'ड्रग्स',
#   'बरामद',
#   'कैप्सूल',
#   'में',
#   'छुपा',
#   'कर',
#   'लाते',
#   'थे',
#   'ड्रग्स',
#   'देखें',
#   'चिराग',
#   'गोठी',
#   'की',
#   'रिपोर्ट'],
#  ['दिल्ली',
#   'में',
#   'बरामद',
#   'हुई',
#   'एक',
#   'करोड़',
#   'से',
#   'ज्यादा',
#   'कीमत',
#   'की',
#   'लग्जरी',
#   'कार',
#   'कुल',
#   '28',
#   'गाड़ियां',
#   'हुई',
#   'बरामद.'],
#  ['7',
#   'अकटुबर',
#   'की',
#   'सुबह',
#   'दिल्ली',
#   'के',
#   'मानसरोवर',
#   'पार्क',
#   'इलाके',
#   'मे',
#   'एक',
#   'ही',
#   'परिवार',
#   'की',
#   '4',
#   'महिलाओं',
#   'समेत',
#   'एक',
#   'गार्ड',
#   'की',
#   'हत्या',
#   'कर',
#   'दी',
#   'गयी',
#   'थी..'],
#  ['#FactCheck',
#   'पुलवामा',
#   'आतंकी',
#   'हमले',
#   'के',
#   'बाद',
#   'से',
#   'सोशल',
#   'मीडिया',
#   'पर',
#   'फर्जी',
#   'जानकारी',
#   'और',
#   'वायरल',
#   'वीडियो',
#   'के',
#   'आने',
#   'का',
#   'सिलसिला',
#   'थम',
#   'नहीं',
#   'रहा'],
#  ['70',
#   'वें',
#   'गणतंत्र',
#   'पर',
#   'आज़तक',
#   'की',
#   'टीम',
#   'और',
#   'संवाददाता',
#   'जितेन्द्र',
#   'सिंह',
#   'भारत',
#   'चीन',
#   'सरहद',
#   'के',
#   'उन',
#   'इलाकों',
#   'में.'],
#  ['#70वें_गणतंत्र_दिवस',
#   'के',
#   'मौके',
#   'पर',
#   'राजनगर',
#   'फ्लाईओवर',
#   'को',
#   'ऐसे',
#   'सजाया',
#   'कि',
#   'देखते',
#   'ही',
#   'बन',
#   'रहा',
#   'है।#जयहिंद।👌.'],
#  ['LoC',
#   'पर',
#   'सेटेलाइट',
#   'गाइडेड',
#   'मोर्टार',
#   'से',
#   'सेना',
#   'को',
#   'निशाना',
#   'बनाना',
#   'चाहता',
#   'है।',
#   '@aajtak',
#   'PAK'],
#  ['12',
#   'हज़ार',
#   'आतंकवादियों',
#   'को',
#   'मौत',
#   'के',
#   'घाट',
#   'उतारने',
#   'वाले',
#   'शूरवीरों',
#   'के',
#   'पराक्रम',
#   'की',
#   'गौरव',
#   'गाथा',
#   'रात',
#   '10',
#   'बजे',
#   'आजतक',
#   'पर',
#   '#VandeMataram',
#   '@SwetaSinghAT.'],
#  ['BSF',
#   'के',
#   'DG',
#   'का',
#   'बड़ा',
#   'बयान-',
#   'देश',
#   'में',
#   'घुसे',
#   'रोहिंग्याओं',
#   'को',
#   'बंगाल',
#   'में',
#   'बसा',
#   'रही',
#   'हैं',
#   'ममता',
#   '#Rohingya'],
#  ['#पाकिस्तान',
#   'की',
#   'नेवी',
#   'के',
#   'फ्रॉग',
#   'मैन',
#   'यानी',
#   'पाक',
#   'वॉटर',
#   'विंग',
#   'के',
#   'कमांडो',
#   'और',
#   'एसएसजी',
#   'के',
#   'कमांडो',
#   'मिलकर',
#   'जैश-ए-मोहम्मद',
#   'के',
#   '50',
#   'खूंखार',
#   'आ.'],
#  ['ITBP',
#   'के',
#   'जवानों',
#   'ने',
#   'योग',
#   'दिवस',
#   'पर',
#   'लद्दाख',
#   'में',
#   '19000',
#   'फीट',
#   'की',
#   'ऊंचाई',
#   'पर',
#   'योग',
#   'किया.',
#   '(@aajtakjitendra',
#   'की',
#   'रिपोर्ट)',
#   '#ReporterDiary'],
#  ['#IndiaTodayExclusive',
#   'जिनके',
#   'दम',
#   'से',
#   'चीन',
#   'का',
#   'निकलता',
#   'है',
#   'दम',
#   'वो',
#   'है',
#   'हमारे',
#   'ITBP',
#   'जवान.',
#   '#Khabardar'],
#  ['MCD',
#   'चुनाव',
#   'में',
#   'बढ़चढ़',
#   'कर',
#   'वोट',
#   'करें।और',
#   'साफ',
#   'दिल्ली',
#   'ड़ेंगू',
#   'मुक्त',
#   'दिल्ली',
#   'बनाये।जय',
#   'हिंद'],
#  ['हिमालय', 'से', 'ऊंचा', 'है', 'हमारे', 'जवानों', 'का', 'हौसला.'],
#  ['63',
#   'राजपूत',
#   'एमएलए',
#   'के',
#   'यूपी',
#   'चुनाव',
#   'में',
#   'जीतने',
#   'के',
#   'बाद',
#   'राजनाथ',
#   'सिंह',
#   'बांछे',
#   'खिली',
#   'हुई',
#   'हैं।बन',
#   'सकते',
#   'हैं',
#   'यूपी',
#   'के',
#   'मुख्यमंत्री!'],
#  ['ISISकी',
#   'बढ़ती',
#   'कट्टरता',
#   'रोकना',
#   'विश्व',
#   'की',
#   'सभी',
#   'सरकारों',
#   'के',
#   'लिए',
#   'चुनौती',
#   'है?'],
#  ['किसी',
#   'एक',
#   'जगह',
#   'बहुत',
#   'ही',
#   'खूबसूरत',
#   'शब्द',
#   'लिखे',
#   'थे',
#   'दुनिया',
#   'में',
#   'छोड़ने',
#   'जैसा',
#   'कुछ',
#   'है',
#   'तो',
#   'दुसरों',
#   'को',
#   'नीचे',
#   'दिखाना',
#   'छोड़',
#   'दो'],
#  ['ISIS',
#   'कल्याण',
#   'मॉड्यूल',
#   'मामले',
#   'में',
#   'कुवैत',
#   'में',
#   'एक',
#   'अरेस्ट',
#   'अब्दुल्ला',
#   'हादी',
#   'अब्दुलअल',
#   'ईनीजी',
#   'को',
#   'कुवैत',
#   'सुरक्षा',
#   'एजेंसियों',
#   'ने',
#   'टैरर',
#   'फंडिंग',
#   'मामले',
#   'गिरफ्तार।'],
#  ['#पकिस्तान',
#   'है',
#   'कि',
#   'मानता',
#   'नहीं',
#   '।राजनाथ',
#   'सिंह',
#   'राज्य',
#   'सभा',
#   'में',
#   'बोले।"जोर',
#   'का',
#   'झटका',
#   'धीरे',
#   'से',
#   'दिया"।'],
#  ['हुआ',
#   'तो',
#   'हुआ-आखिरकार',
#   'वही',
#   'हुआ',
#   'जो',
#   'होना',
#   'था.',
#   'ओम',
#   'प्रकाश',
#   'राजभर',
#   'हटा',
#   'दिए',
#   'गए.अब',
#   'राजभर',
#   'की',
#   'जगह',
#   'निषाद',
#   'आएंगे.'],
#  ['J&K', 'में', 'बाढ़', 'से', 'मरने', 'वालों', 'की', 'संख्या', '150'],
#  ['#छत्तीसगढ़',
#   'की',
#   'एक',
#   'अदालत',
#   'ने',
#   '25',
#   '#माओवादियों',
#   'की',
#   '#संपत्ति',
#   '#कुर्क',
#   'करने',
#   'के',
#   'आदेश',
#   'दिए',
#   'हैं.',
#   'इन',
#   'पर',
#   'कांग्रेस',
#   'नेताओं',
#   'समेत',
#   '32',
#   'लोगों',
#   'की',
#   'हत्या',
#   'का',
#   'आरोप',
#   'है.'],
#  ['CAG',
#   'एक',
#   'सीविल',
#   'सर्वीस',
#   'संस्था',
#   'है',
#   'उसे',
#   'क्या',
#   'लेना',
#   'देना',
#   'है',
#   'राजनीती',
#   'भाजपा',
#   'कोंग्रेस',
#   'से.फिर',
#   'ओ',
#   'क्यु',
#   'झुठि',
#   'रिपोर्ट',
#   'पेश',
#   'करेगी'],
#  ['Exclusive',
#   'कश्मीर',
#   'में',
#   'पत्थर',
#   'बाजों',
#   'से',
#   'निपटने',
#   'के',
#   'लिए',
#   'सेना',
#   'और',
#   'पैरामिलिट्री',
#   'का',
#   'आने',
#   'वाला',
#   'नया',
#   'सारथी'],
#  ['#लौटकेराहुलघरकोआए',
#   'ये',
#   'छप्पन-छप्पन',
#   'का',
#   'खेल',
#   'है',
#   'एक',
#   'का',
#   'सीना',
#   'है',
#   'एक',
#   'की',
#   '#तपस्या',
#   'पूरा',
#   'देश',
#   'देख',
#   'रहा',
#   'है',
#   'सवाल',
#   'है',
#   'कौन',
#   'किसको',
#   'बना',
#   'रहा',
#   'है?',
#   '@A.'],
#  ['A',
#   'father',
#   ':लखनऊ',
#   'में',
#   'तैनात',
#   'होमगार्ड',
#   'के',
#   'बेटे',
#   'ने',
#   'crack',
#   'की',
#   'IES',
#   'परीक्षा.'],
#  ['सर्जिकल',
#   'स्ट्राइक',
#   'की',
#   'इनसाइड',
#   'स्टोरी',
#   'जानें',
#   'कैसे',
#   'पैरा',
#   'कमांडो',
#   'ने',
#   'दिया',
#   'ऑपरेशन',
#   'को',
#   'अंजाम'],
#  ['Most',
#   'Favoured',
#   'Nation',
#   'का',
#   'स्टेटस',
#   'पाकिस्तान',
#   'से',
#   'छीन',
#   'लिया',
#   'गया',
#   '।',
#   'बड़ा',
#   'क़दम',
#   'जो',
#   'अतिदेय',
#   'था',
#   '।',
#   'पहला',
#   'क़दम',
#   '।',
#   '#RIPBraveHearts',
#   '#PulwamaAttack'],
#  ['#HallaBol',
#   'प्रधानमंत्री',
#   'ने',
#   "'VIP",
#   "कल्चर'",
#   'को',
#   'खत्म',
#   'करने',
#   'के',
#   'लिए',
#   'एक',
#   'कदम',
#   'उठाया',
#   'है',
#   'हम',
#   'सबको',
#   'इस',
#   'रास्ते',
#   'पर',
#   'चलना',
#   'चाहिए',
#   ':@SambitSwaraj'],
#  ['#HallaBol',
#   'कोई',
#   'भी',
#   'ऐसा',
#   'कदम',
#   'जो',
#   'VIP',
#   'कल्चर',
#   'को',
#   'खत्म',
#   'करेगा',
#   'हम',
#   'उसका',
#   'स्वागत',
#   'करेंगे:@PavanK_Varma',
#   'लाइव'],
#  ['#HallaBol',
#   'किस',
#   'देश',
#   'में',
#   'कितने',
#   'VIP?',
#   'भारत',
#   'के',
#   'आंकड़े',
#   'देखकर',
#   'आप',
#   'आश्चर्यजनक',
#   'रह',
#   'जाएंगे.',
#   'लाइव'],
#  ['कुलभूषण',
#   'पर',
#   'सवाल',
#   'से',
#   'बिफरे',
#   'मुशर्रफ',
#   'देने',
#   'लगे',
#   'उलटे-सीधे',
#   'तर्क'],
#  ['केजरीवाल',
#   'बोले-',
#   'रामकिशन',
#   'के',
#   'सुसाइड',
#   'से',
#   'BJP',
#   'की',
#   'खोखली',
#   'देशभक्ति',
#   'सामने',
#   'आई'],
#  ['केंद्र-केजरीवाल',
#   'में',
#   'फिर',
#   'टकराव',
#   'के',
#   'आसार',
#   'AAP',
#   'ने',
#   'एलजी',
#   'को',
#   'कहा',
#   'PM',
#   'का',
#   'जासूस'],
#  ['दिल्ली',
#   'पुलिस',
#   'स्पेशल',
#   'सेल',
#   'ने',
#   'जैश',
#   'के',
#   'आतंकी',
#   'माजिद',
#   'बाबा',
#   'को',
#   'किया',
#   'गिरफ्तार.माजिद',
#   'बाबा',
#   'पर',
#   'था',
#   '2',
#   'लाख',
#   'का',
#   'ईनाम..'],
#  ['आपका',
#   'नाम',
#   'वोटर',
#   'लीस्ट',
#   'से',
#   'काट',
#   'दिया',
#   'गया',
#   "है'",
#   'इस',
#   'तरह',
#   'काल्स',
#   'लगातार',
#   'दिल्ली',
#   'वालों',
#   'को',
#   'मिल',
#   'रहे',
#   'थे',
#   'इलेक्शन',
#   'कमिशन.'],
#  ['हुर्यित',
#   'नेता',
#   'गिलानी',
#   'के',
#   'पाक-कनेक्शन',
#   'का',
#   'खुलासा.आतंकियों',
#   'के',
#   'रहुमाओं',
#   'पर',
#   'मेहरबान',
#   'थी',
#   'मनमोहन',
#   'सरकार?.'],
#  ['पाकिस्तान',
#   'से',
#   'कश्मीर',
#   'में',
#   'हो',
#   'रही',
#   'बातचीत',
#   'इंटरसेप्ट',
#   '26/11',
#   'जैसे',
#   'अटैक',
#   'की',
#   'प्लानिंग',
#   'के',
#   'इनपुट',
#   'के',
#   'बाद',
#   'एजेंसी',
#   'अलर्ट'],
#  ['जब',
#   'केरला',
#   'हाउस',
#   'में',
#   'बीफ',
#   'पार्टी',
#   'की',
#   'खबर',
#   'से',
#   'दिल्ली',
#   'पुलिस',
#   'में',
#   'मचा',
#   'हड़कंप।'],
#  ['Exclusive',
#   'भीम',
#   'आर्मी',
#   'का',
#   'फाउंडर-',
#   'सहारनपुर',
#   'दंगों',
#   'का',
#   'आरोपी',
#   'को',
#   'की',
#   'ने',
#   'हिमाचल',
#   'से',
#   'गिरफ्तार'],
#  ['नोएडा',
#   'के',
#   'नामी',
#   'इस्टिट्यूट',
#   'की',
#   'छात्रा',
#   'ने',
#   'दोस्तों',
#   'के',
#   'साथ',
#   'रची',
#   'खुद',
#   'के',
#   'अपहरण',
#   'की',
#   'साजिश',
#   'तीन',
#   'गिरफ्तार'],
#  ['Exclusive',
#   '-मुजफ्फरपुर',
#   'में',
#   'स्कूली',
#   'छात्र',
#   'ने',
#   'दौड़ाई',
#   'कार',
#   '3',
#   'बच्चो',
#   'समेत',
#   'एक',
#   'युवक',
#   'को',
#   'कुचला',
#   'गुस्साये',
#   'लोगो',
#   'ने',
#   'वाहन',
#   'में',
#   'लगाई',
#   'आग'],
#  ['26',
#   'मार्च',
#   'को',
#   'आम',
#   'आदमी',
#   'पार्टी',
#   'की',
#   'जन',
#   'सभा',
#   'के',
#   'दौरान',
#   'मंच',
#   'के',
#   'पास',
#   'देखा',
#   'गया',
#   'था',
#   'थप्पड़',
#   'मारने',
#   'वाला',
#   'शख्स',
#   'सुरेश',
#   'चौहान.',
#   'की',
#   '#Reporter.'],
#  ['45',
#   'साल',
#   'से',
#   'गांधीनगर',
#   'में',
#   'पिता',
#   'का',
#   'बिजनेस',
#   'मैं',
#   'बाहरी',
#   'कैसे:',
#   'गंभीर'],
#  ['IT',
#   'रेड',
#   'के',
#   'बाद',
#   'सवालों',
#   'के',
#   'घेरे',
#   'में',
#   'मध्यप्रदेश',
#   'के',
#   'सीएम',
#   'कमलनाथ',
#   '-',
#   'India',
#   'AajTak'],
#  ['PM',
#   'नरेंद्र',
#   'मोदी',
#   'को',
#   'बम',
#   'उड़ाने',
#   'की',
#   'धमकी',
#   'देने',
#   'वाला',
#   'अरुण',
#   'अब',
#   'पुलिस',
#   'की',
#   'हिरासत',
#   'में',
#   'है',
#   '(@AajGothi)'],
#  ['होटल',
#   'अग्निकांडः',
#   'चौथी',
#   'मंजिल',
#   'से',
#   'कूदे',
#   'IRS',
#   'सुरेश',
#   'कुमार',
#   'दर्दनाक',
#   'मौत'],
#  ['ATM',
#   'कार्ड',
#   'को',
#   'क्लोन',
#   'कर',
#   'के',
#   'पैसे',
#   'लूटने',
#   'वाली',
#   'रोमानिया',
#   'के',
#   'गैंग',
#   'की',
#   '2',
#   'युवतियों',
#   'और',
#   '3',
#   'युवकों',
#   'को',
#   'दिल्ली',
#   'पुलिस',
#   'ने',
#   'किया',
#   'गिरफ़्तार',
#   'देखिए'],
#  ['99',
#   'प्रतिशत',
#   'ब्लॉकेज',
#   'को',
#   'भी',
#   'रिमूव',
#   'कर',
#   'देता',
#   'है',
#   'पीपल',
#   'का',
#   'पत्ता'],
#  ['हिंसा-प्रति', 'हिंसा', 'को', 'रोकना', 'दुरुह', 'कार्य', 'है।'],
#  ['अनाड़ी', 'यहीं', 'मात', 'खाते', 'हैं', 'और', 'जॉब', 'गिर', 'जाता', 'है।'],
#  ['45',
#   'मिनट',
#   'की',
#   'मशक्कत',
#   'के',
#   'बाद',
#   'भी',
#   'आग',
#   'पर',
#   'काबू',
#   'नहीं',
#   'पाया',
#   'जा',
#   'सका',
#   'है।'],
#  ['अधिकतर',
#   'राजाओं',
#   'के',
#   'पतन',
#   'का',
#   'कारण',
#   'राजद्रोह',
#   'ही',
#   'रहा',
#   'है'],
#  ['हैट्रिक',
#   'जीत',
#   'में',
#   "'कोयला'",
#   'बाधा',
#   'नहीं',
#   'जिंदल',
#   'स्टील',
#   'ऐंड',
#   'पावर',
#   'के',
#   'चेयरमैन',
#   'नवीन',
#   'जिंदल',
#   'अपनी',
#   'हैट्रिक',
#   'जीत',
#   'के',
#   'प्रति',
#   'आश्वस्त',
#   'हैं।'],
#  ['4', 'साल', 'की', 'बच्ची', 'बोरवेल', 'से', 'सही', 'सलामत', 'निकली', 'है।'],
#  ['अधिकांश',
#   'हैंडपंप',
#   'खराब',
#   'दशा',
#   'में',
#   'हैं',
#   'या',
#   'तो',
#   'दूषित',
#   'जल',
#   'देते',
#   'हैं।'],
#  ['हिसार',
#   'में',
#   'पिछले',
#   '4',
#   'दिनों',
#   'से',
#   'चल',
#   'रही',
#   'बर्फीली',
#   'हवाओं',
#   'ने',
#   'लोगों',
#   'को',
#   'घरों',
#   'में',
#   'दुबकने',
#   'पर',
#   'मजबूर',
#   'कर',
#   'दिया',
#   'है।'],
#  ['हैंगसेंग',
#   'शांघाई',
#   'और',
#   'ताईवान',
#   'के',
#   'बाजारों',
#   'में',
#   'भी',
#   'भारी',
#   'गिरावट',
#   'दर्ज',
#   'की',
#   'गई।'],
#  ['हैरानी',
#   'की',
#   'बात',
#   'ये',
#   'है',
#   'कि',
#   'इस',
#   'भीषण',
#   'अग्निकांड',
#   'में',
#   'किसी',
#   'के',
#   'हताहत',
#   'की',
#   'खबर',
#   'नहीं',
#   'है।'],
#  ['अंधाधुंधगोलीबारी', 'में', 'चार', 'लोगों', 'की', 'मौत', 'हो', 'गई।'],
#  ['गौतमी',
#   'से',
#   'भी',
#   'अलग',
#   'होने',
#   'जा',
#   'रहे',
#   'कमल',
#   'हासन,',
#   '13',
#   'साल',
#   'से',
#   'थे',
#   'साथ',
#   'गौतमी',
#   'तडि़मल्\u200dला',
#   'और',
#   'कमल',
#   'हासन',
#   'पिछले',
#   'करीब',
#   '13',
#   'साल',
#   'से',
#   'साथ',
#   'रह.'],
#  ['कमल',
#   'हासन',
#   'और',
#   'गौतमी',
#   'के',
#   'बीच',
#   'तलाक़',
#   'ड्रामा',
#   'पूरा',
#   'हुआ',
#   'संगीता',
#   'से',
#   'पैदा',
#   'हुई',
#   'पुत्रि',
#   'श्रुति',
#   'हासन',
#   'का',
#   'कैरियर',
#   'बना',
#   '"तलाक़"',
#   'की',
#   'मुख्य',
#   'वजह',
#   '!!!'],
#  ['दिल्ली',
#   'की',
#   'आजादपुर',
#   'मंडी',
#   'में',
#   'मूली',
#   'किसान',
#   'को',
#   '1',
#   'सवा',
#   'रुपया',
#   'किलो',
#   'मिल',
#   'रहा',
#   'है',
#   'जबकि',
#   'इतना',
#   'ही',
#   'खर्चा',
#   'है।',
#   'हाथ',
#   'में',
#   'कुछ',
#   'नहीं',
#   'आया',
#   'बस',
#   'उम्मीद',
#   'में',
#   'मंडी',
#   'आये',
#   'हैं'],
#  ['सभी',
#   'ने',
#   'कालेधन',
#   'के',
#   'खिलाफ',
#   'पीएम',
#   'मोदी',
#   'के',
#   'निर्णायक',
#   'फैसले',
#   'का',
#   'समर्थन',
#   'किया',
#   'और',
#   'डिजिटल',
#   'प्रणाली',
#   'से',
#   'भुगतान',
#   'करने',
#   'पर',
#   'सहमति',
#   'भी',
#   'जताई',
#   'I',
#   '#digitalpayments',
#   '2/2'],
#  ['पीएम',
#   'मोदी-',
#   'हमारे',
#   'देश',
#   'के',
#   'युवआों',
#   'को',
#   'देश',
#   'को',
#   'भ्रष्टाचार',
#   'और',
#   'कालेधन',
#   'से',
#   'मुक्त',
#   'करने',
#   'के',
#   'अभियान',
#   'में',
#   'लगना',
#   'है',
#   'ji',
#   '#Youth4DigitalPaisa'],
#  ['#WeHappyWithModiJi',
#   'भारत',
#   'सरकार',
#   'ने',
#   'दशकों',
#   'से',
#   'लटके',
#   'पड़े',
#   'वन',
#   'रैंक',
#   'वन',
#   'पेंशन',
#   'के',
#   'मुद्दे',
#   'को',
#   'सुलझा',
#   'कर',
#   'बड़ी',
#   'कामयाबी',
#   'हासिल',
#   'की',
#   'है.'],
#  ['अब',
#   'केंद्र',
#   'सरकार',
#   'को',
#   'चाहिए',
#   'की',
#   'वन',
#   'रैंक',
#   'वन',
#   'पेंशन',
#   'और',
#   'सेंट्रल',
#   'पे',
#   'कमीशन',
#   'को',
#   'भारतीय',
#   'सेना',
#   'मे',
#   'पूरी',
#   'तरह',
#   'से',
#   'लागू',
#   'करे',
#   'ताकि.'],
#  ['मि.अब्दुल्ला',
#   'भौंको',
#   'मत,लड़ो.अब',
#   'तुम्हारी',
#   'जननी',
#   'कांग्रेस',
#   'नहीं',
#   'बल्कि',
#   'सत्ता',
#   'में',
#   'सरदार',
#   'पटेल',
#   'बैठे',
#   'है',
#   'नव',
#   'अवतार',
#   'में.दम',
#   'दिखाओ',
#   'तो',
#   'सही!'],
#  ['#ShauryaDiwas',
#   'अब',
#   'समय',
#   'आ',
#   'गया',
#   'है,',
#   'पीओके',
#   'भारतमे',
#   'मिलाओ;',
#   'संसद',
#   'में',
#   'कानून',
#   'बनाकर',
#   'राम',
#   'मंदिर',
#   'बनाओ!',
#   'इन्तजार',
#   'है',
#   'सरदार',
#   'पटेल',
#   'के',
#   'संकल्प',
#   'और',
#   'कार्य',
#   'का!'],
#  ['हमारी',
#   'एकता',
#   'के',
#   'बल',
#   'को',
#   'चीन',
#   'ने',
#   'दिवाली',
#   'पर',
#   'देखा',
#   'चीनी',
#   'मार्केट',
#   'धडा़म',
#   'अब',
#   'हमारे',
#   'देशवासियों',
#   'की',
#   'एकता',
#   'का',
#   'बल',
#   'नोटबन्दी',
#   'की',
#   'विरोधी',
#   'पार्टियाँ',
#   'देखेंगी',
#   'जय',
#   'भारत'],
#  ['भोपाल',
#   'और',
#   'नाभा',
#   'जेल',
#   'ब्रेक',
#   'से',
#   'भी',
#   'नहीं',
#   'चेता',
#   'सुरक्षा',
#   'तंत्र,',
#   'ग्वालियर',
#   'पुलिस',
#   'की',
#   'ये',
#   'कैसी',
#   'लापरवाही.?'],
#  ['नाभा',
#   'में',
#   'मिलीभगत',
#   'से',
#   'भागे',
#   'थे',
#   'लेकिन',
#   'भोपाल',
#   'वाले',
#   'तो',
#   'लकङी',
#   'की',
#   'चाबी',
#   'से',
#   'ताला',
#   'खोलकर',
#   'ही',
#   'भागे',
#   'थे'],
#  ['भोपाल',
#   'जेल',
#   'ब्रेक',
#   'कांड',
#   'की',
#   'जांच',
#   'शुरु',
#   'रिटायर्ड',
#   'जस्टिस',
#   'एसके',
#   'पांडे',
#   'पहुंचे',
#   'भोपाल',
#   'दफ्तर',
#   'पहुंच',
#   'कर',
#   'संभाला',
#   'कामकाज',
#   'आज',
#   'से',
#   'जांच',
#   'दल',
#   'ने',
#   'शुरु',
#   'किया',
#   'काम'],
#  ['ये',
#   'है',
#   'उत्तराखंड',
#   'के',
#   'सीएम',
#   'हरीश',
#   'रावत!',
#   'एक',
#   'महिला',
#   'इनके',
#   'पाँव',
#   'से',
#   'लिपट',
#   'कर',
#   'रो',
#   'रही',
#   'है,',
#   'शिकायत',
#   'कर',
#   'रही',
#   'है',
#   'और',
#   'ये',
#   'हँस',
#   'रहे',
#   'हैं!',
#   'ये',
#   'है',
#   'कांग्रेसी',
#   'संस्कृति!'],
#  ['दिल्ली',
#   'की',
#   '#AirQuality',
#   'में',
#   'काफी',
#   'सुधार,',
#   'LG',
#   '#NajeebJung',
#   'ने',
#   'वायु',
#   'प्रदूषण',
#   'की',
#   'स्थिति',
#   'की',
#   'समीक्षा',
#   'के',
#   'लिए',
#   'चौथी',
#   'बैठक',
#   'की।',
#   '#AirPollution',
#   '#delhipollution'],
#  ['माननीय',
#   'राज',
#   'ठाकरे',
#   'अगर',
#   'आर्मी',
#   'की',
#   'कीमत',
#   'तय',
#   'कर',
#   'दी',
#   'हो',
#   'तो',
#   'कृप्या',
#   '5',
#   'करोड़',
#   'तुरंत',
#   'दान',
#   'करें।',
#   'आपका',
#   'संबंध',
#   'तो',
#   'दाउद',
#   'के',
#   'समधि',
#   'जावेद',
#   'मियांदाद',
#   'से',
#   'बहुत',
#   'गहरा',
#   'है।'],
#  ['मुसलमान',
#   'कौम',
#   'अपनी',
#   'पे',
#   'आ',
#   'गयी',
#   'तो',
#   'न',
#   'रहेगा',
#   'हिन्दू',
#   'और',
#   'न',
#   'होगा',
#   'हिंदुस्तान',
#   ':',
#   'जावेद',
#   'मियांदाद'],
#  ['देहरादून',
#   'निवासी',
#   'ओ',
#   'पी',
#   'भट्ट',
#   'बने',
#   'टाटा',
#   'स्टील',
#   'के',
#   'चेयरमैन',
#   'टाटा',
#   'स्टील',
#   'के',
#   'निदेशक',
#   'मंडल',
#   'साइरस',
#   'मिस्त्री',
#   'को',
#   'कंपनी.'],
#  ['#NDTVBanned',
#   'पाक',
#   'स्थीत',
#   'भारतीय',
#   'दूताबास',
#   'के',
#   '8',
#   'कर्मिओ',
#   'को',
#   'जासूसी',
#   'और',
#   'आतंकबाद',
#   'फैलाने',
#   'के',
#   'आरोपमें',
#   'पाकिस्तान',
#   'छोड़ने',
#   'की',
#   'आदेश।',
#   '#PakIsMostFabouredNation'],
#  ['बराक',
#   'ओबामा.जूलियन',
#   'असांजे,',
#   'डोनाल्ड',
#   'ट्रंप',
#   'और',
#   'पुतिन',
#   'जैसे',
#   'नेताओं',
#   'को',
#   'काफी',
#   'पीछे',
#   'छोड़',
#   'कर',
#   'प्रतिष्ठित',
#   'अमेरिकी',
#   'पत्रिका',
#   'टाइम',
#   'का',
#   'पर्सन',
#   'आफ',
#   'द',
#   'ईयर.'],
#  ['भाई',
#   'किसी',
#   'के',
#   'पास',
#   'ज्यादा',
#   'पैसा',
#   'हो',
#   'तो',
#   'मुझे',
#   'डोनेट',
#   'कर',
#   'दे',
#   'जिससे',
#   'मुझ',
#   'गरीब',
#   'का',
#   'घर',
#   'ठीक',
#   'से',
#   'चल',
#   'सके',
#   'खाता',
#   'नंबर',
#   'स्टेट',
#   'बैंक',
#   'ऑफ',
#   'इंडिया',
#   '61209424022'],
#  ['लाला',
#   'कामदेव',
#   'का',
#   'पूर्ण',
#   'बहिष्कार',
#   'करे',
#   'इनको',
#   'चारा',
#   'चोर',
#   'संत',
#   'और',
#   'जिहादी',
#   'दीदी',
#   'लायक',
#   'लगने',
#   'लगा',
#   'है',
#   'बस',
#   'अपने',
#   'ब्यापार',
#   'बढ़ाने',
#   'के',
#   'लिए',
#   'बनिया',
#   'रामकिशन',
#   '#boycott'],
#  ['जिस',
#   'कश्मीर',
#   'में',
#   'दर्जनों',
#   'स्कूल',
#   'जलाए',
#   'गए',
#   'वहां',
#   '12वीं',
#   'बोर्ड',
#   'के',
#   'पहले',
#   'दिन',
#   '95%',
#   'अटेंडेंस',
#   'सबूत',
#   'है',
#   'कि',
#   'कश्मीरी',
#   'अवाम',
#   'बहकाने',
#   'वालों',
#   'को',
#   'जवाब',
#   'देना',
#   'जानती',
#   'है।'],
#  ['लीजिए',
#   'आम',
#   'आदमी',
#   'के',
#   'बाद',
#   'अब',
#   'सरकारों',
#   'पर',
#   'भी',
#   'नोटबंदी',
#   'का',
#   'प्रतिकूल',
#   'असर',
#   'होने',
#   'लगा।',
#   'दिल्ली',
#   'का',
#   'टैक्स',
#   'संग्रहण',
#   '50%',
#   'तक',
#   'गिरा।वेतन',
#   'देना',
#   'कठिन',
#   'हुआ',
#   'सरकार',
#   'के',
#   'लिए'],
#  ['इनकम',
#   'टैक्स',
#   'विभाग',
#   'ने',
#   'चार्जशीट',
#   'में',
#   'कहा,',
#   'स्विस',
#   'बैंक',
#   'में',
#   'कैप्टन',
#   'अमरिंदर',
#   'के',
#   '60',
#   'करोड़',
#   'डॉलर,',
#   'मतलब',
#   '4000',
#   'करोड़',
#   'रुपये',
#   '.'],
#  ['दिल्ली',
#   'सरकार',
#   'को',
#   'वेतन',
#   'भुगतान',
#   'की',
#   'समस्या!',
#   'टैक्स',
#   'वसूली',
#   'निचले',
#   'स्तर',
#   'पर!',
#   'नोट',
#   'बंदी',
#   'के',
#   'विरोध',
#   'मे,',
#   'कर्तव्य',
#   'पर',
#   'ध्यान',
#   'नहीं'],
#  ['डीजिटल',
#   'इंडिया',
#   'का',
#   'सबसे',
#   'बड़ा',
#   'फायदा',
#   'राज्य',
#   'सरकारे',
#   'को',
#   'टैक्स',
#   'कलेक्शन',
#   'और',
#   'बढोत्तरी',
#   'मे',
#   'ही',
#   'होगा,पर',
#   'दुखद',
#   'केजरी-ममता',
#   'विरोध',
#   'मे',
#   'लिप्त',
#   '#Youth4DigitalPaisa'],
#  ['जाकिर',
#   'नाइक',
#   'पर',
#   'हमला',
#   'मोदी',
#   'सरकार',
#   'के',
#   'मुस्लिम',
#   'विरोधी',
#   'एजेंडे',
#   'का',
#   'हिस्सा',
#   'है:',
#   'डॉ',
#   'जफ़रुल',
#   'इस्लाम'],
#  ['सात',
#   'हजार',
#   'होम',
#   'गार्ड',
#   'की',
#   'नियुक्ति',
#   'के',
#   'दरवाजे',
#   'खुले',
#   'नंबर',
#   'नियम',
#   'की',
#   'तैयारी',
#   'शुरू,',
#   '6642',
#   'पुरुष',
#   'और',
#   '301',
#   'महिलाएं',
#   'भर्ती',
#   'होंगी'],
#  ['हरियाणा',
#   'के',
#   'यमुनानगर',
#   'में',
#   'एसबीआई',
#   'के',
#   'गार्ड',
#   'की',
#   'बंदूक',
#   'से',
#   'गोलियां',
#   'चल',
#   'गईं.',
#   'इसमें',
#   'बैंक',
#   'से',
#   'पैसे',
#   'निकालने',
#   'आई',
#   'दो',
#   'महिलाएं',
#   'घायल',
#   'हो',
#   'गई'],
#  ['मोदी',
#   'जी',
#   'की',
#   'नोट',
#   'बंदी',
#   'निति',
#   'का',
#   'इरादा',
#   'ठीक',
#   'हो',
#   'सकता',
#   'है,',
#   'पर',
#   'नोट',
#   'बंदी',
#   'के',
#   'बाद',
#   'व्यवस्था',
#   'ठीक',
#   'करने',
#   'में',
#   'नाकामयाब',
#   'रही',
#   'है',
#   'मोदी',
#   'सरकार',
#   '!'],
#  ['नोट',
#   'बंदी',
#   'कर',
#   'के',
#   'सरकार',
#   'ने',
#   'अपना',
#   'मजाक',
#   'खुद',
#   'बनवा',
#   'लिया',
#   'है,',
#   'न',
#   'भ्र्ष्टाचार',
#   'कम',
#   'हो',
#   'रहा',
#   'है,',
#   'न',
#   'कालाधन',
#   'वापस',
#   'आ',
#   'रहा',
#   'है,',
#   'सिर्फ',
#   'जनता',
#   'परेशान',
#   'हो',
#   'रही',
#   'है',
#   '!'],
#  ['कंगना',
#   'ने',
#   'कहा.',
#   '‘‘मेरा',
#   'व्यक्तित्व',
#   'हमेशा',
#   'मेरे',
#   'जन्मस्थान',
#   'से',
#   'प्रभावित',
#   'रहा.',
#   'आज',
#   'भी',
#   'जब',
#   'मैं',
#   'काम',
#   'करती',
#   'हूं.',
#   'follow',
#   'our',
#   'site',
#   '.'],
#  ['पीएम',
#   'मोदी',
#   'की',
#   'मां',
#   'हीराबेन',
#   'पर',
#   'अरविंद',
#   'केजरीवाल',
#   'ने',
#   'किया',
#   'ट्वीट,',
#   'यूजर',
#   'ने',
#   'लिखा-',
#   'थोड़ी',
#   'तो',
#   'इज्\u200dजत',
#   'करो,',
#   'सबक'],
#  ['गांधीनगर:',
#   'पीएम',
#   'मोदी',
#   'की',
#   'मां',
#   'हीराबेन',
#   'ने',
#   'आम',
#   'नागरिकों',
#   'की',
#   'तरह',
#   'बैंक',
#   'से',
#   'बदलवाए',
#   'पुराने',
#   'नोट'],
#  ['नोट',
#   'एक्सचेंज',
#   'कराने',
#   'बैंक',
#   'पहुंचीं',
#   'पीएम',
#   'मोदी',
#   'की',
#   'मां',
#   'हीराबेन',
#   '.'],
#  ['रफी',
#   'गाते',
#   'नहीं,',
#   'रोते',
#   "थे.'डायलॉग",
#   'को',
#   'लेकर',
#   'ट्विटर',
#   'पर',
#   'भिड़े',
#   'करन',
#   'जौहर-'],
#  ['तेरे',
#   'बिना',
#   'गुजारा.',
#   'ऐ',
#   'दिल',
#   'है',
#   'मुश्किल.',
#   'फ़िल्म',
#   'कैसी',
#   'भी',
#   'हो.',
#   'गाना',
#   'बहुत',
#   'मस्त',
#   'है.'],
#  ['राहुल',
#   'गांधी',
#   'को',
#   'पुलिस',
#   'थाने',
#   'ले',
#   'जाया',
#   'गया,',
#   'कैंडल',
#   'मार्च',
#   'में',
#   'जंतर-मंतर',
#   'पहुंचे',
#   'थे',
#   'राहुल',
#   'गांधी.'],
#  ['#CONG',
#   'रायपुर',
#   'यूथ',
#   'कांग्रेस',
#   'का',
#   'प्रदर्शन',
#   'राहुल',
#   'गांधी',
#   'की',
#   'गिरफ्तारी',
#   'के',
#   'विरोध',
#   'में',
#   'किया',
#   'प्रदर्शन',
#   'तेलीबांधा',
#   'थाने',
#   'के',
#   'पास',
#   'पीएम',
#   'का',
#   'पुतला',
#   'लटकाया'],
#  ['गौरव',
#   'जी',
#   'आप',
#   'हो',
#   'इस',
#   'चैनल',
#   'में',
#   'जो',
#   'देश',
#   'के',
#   'शहीदों',
#   'की',
#   'बात',
#   'करतें',
#   'है',
#   'बाकि',
#   'तो',
#   'केजरीवाल',
#   'थाने',
#   'चले',
#   'गए',
#   'राहुल',
#   'गांधी',
#   'थाने',
#   'गए,बहुत',
#   'क्रांतिकारी!'],
#  ['मुद्दे',
#   'की',
#   'बात',
#   'ये',
#   'हे',
#   'की',
#   'कांग्रेस',
#   'ने',
#   'जानबूझकर',
#   'AC',
#   'हैक',
#   'होने',
#   'का',
#   'नाटक',
#   'किया',
#   'है',
#   'ताकि',
#   'जनता',
#   'मोदी',
#   'के',
#   'Cashless',
#   'India',
#   'प्रोग्राम',
#   'से',
#   'डर',
#   'कर',
#   'हाथ',
#   'पीछे',
#   'खीच',
#   'ले'],
#  ['ट्रंप',
#   'के',
#   'घर',
#   'से',
#   'उठी',
#   'मोदी',
#   'के',
#   'समर्थन',
#   'में',
#   'आवाज,',
#   'गिड़गिड़ाने',
#   'पर',
#   'भी',
#   'नहीं',
#   'मिलेगी',
#   'पाक',
#   'को',
#   'फूटी',
#   'कौड़ी'],
#  ['डोनाल्ड',
#   'ट्रंप',
#   'ने',
#   'नवाज',
#   'शरीफ',
#   'को',
#   "'शानदार",
#   "इंसान'",
#   'कहा,',
#   'पाकिस्तानियों',
#   'को',
#   'बताया-',
#   "'असाधारण'"],
#  ['आज',
#   'देशवासियों',
#   'ने',
#   "'भारत",
#   "बंद'",
#   'को',
#   'ही',
#   'बंद',
#   'कर',
#   'दिया।',
#   'साधुवाद',
#   'है',
#   'सब',
#   'दुकानदारों',
#   'को',
#   'जिन्होंने',
#   'बंद',
#   'के',
#   'विरोध',
#   'में',
#   'आज',
#   'अपनी',
#   'दूकान',
#   '२',
#   'घंटे',
#   'ज़्यादा',
#   'खुली',
#   'रखी।'],
#  ['शायद',
#   'आम',
#   'आदमी',
#   'की',
#   'नींव',
#   'ही',
#   'एक',
#   'आतंकवादी',
#   'ने',
#   'राखी',
#   'थी',
#   'उसके',
#   'आने',
#   'के',
#   'बाद',
#   'ही',
#   'बेमेल्',
#   'विवाद',
#   'हो',
#   'रहा',
#   'है',
#   'हरामखोर',
#   'पार्टी'],
#  ['यूपी',
#   'चुनाव',
#   'के',
#   'बाद',
#   'देश',
#   'के',
#   'लोकतंत्र',
#   'और',
#   'राजनीति',
#   'में',
#   'एक',
#   'बड़ा',
#   'बदलाव',
#   'आएगा।',
#   'जाति',
#   'और',
#   'परिवार',
#   'की',
#   'राजनीति',
#   'खत्म',
#   'होगीः'],
#  ['महमूद',
#   '45',
#   'साल',
#   'से',
#   'कांग्रेस',
#   'के',
#   'कार्यकर्ता',
#   'हैं',
#   'और',
#   'इनका',
#   'मानना',
#   'है',
#   'कि',
#   'मोदी',
#   'को',
#   '10',
#   'साल',
#   'मिलें',
#   'तो',
#   'देश',
#   'फिर',
#   'से',
#   'सोने',
#   'की',
#   'चिड़िया',
#   'बन',
#   'जाएगा.',
#   'जय',
#   'हो'],
#  ['भिलाई',
#   'सेक्टर',
#   'सी',
#   'जी',
#   'क्षेत्र',
#   'में',
#   '100',
#   '500',
#   'के',
#   'नोट',
#   'ए',
#   'टी',
#   'म',
#   'से',
#   'नहीं',
#   'मिल',
#   'पा',
#   'रहे',
#   'हैं',
#   'कृपया',
#   'व्यवस्था',
#   'कराएं'],
#  ['जो',
#   'ममता',
#   'हिंदुओं',
#   'को',
#   'दुर्गा',
#   'पूजा',
#   'करने',
#   'में',
#   'रोक',
#   'लगाती',
#   'है,बंग्लादेशियों',
#   'को',
#   'शरण',
#   'देती',
#   'है,उसमें',
#   'रामदेव',
#   'को',
#   'PM',
#   'नज़र',
#   'आने',
#   'लगे',
#   'तो',
#   'उनपर',
#   'सन्देह',
#   'होता',
#   'है।'],
#  ['INC',
#   'ने',
#   'सरकार',
#   'की',
#   'सर्जिकल',
#   'स्ट्राइक',
#   'का',
#   'पूरा',
#   'समर्थन',
#   'किया',
#   '&',
#   'ऐसे',
#   'हर',
#   'कदम',
#   'का',
#   'हमेशा',
#   'समर्थन',
#   'करेगी',
#   'जिससे',
#   'भारत',
#   'को',
#   'आतंकवाद',
#   'को',
#   'पराजित',
#   'करने',
#   'में',
#   'मदद',
#   'मिल',
#   'सके'],
#  ['हार्ट',
#   'ऑफ',
#   'एशिया',
#   'सम्मेलन',
#   ':',
#   'आतंक',
#   'के',
#   'मुद्दे',
#   'पर',
#   'घिरा',
#   'पाकिस्तान,',
#   'हर',
#   'तरह',
#   'के',
#   'आतंकवाद',
#   'पर',
#   'कार्रवाई',
#   'पर',
#   'दिया',
#   'गया',
#   'जोर'],
#  ['दब',
#   'गई',
#   'है',
#   'नींद',
#   'कहीं',
#   'करवटों',
#   'के',
#   'बीच',
#   'में.',
#   '.',
#   '.',
#   'दर',
#   'पे',
#   'खड़े',
#   'रहते',
#   'हैं',
#   'कुछ',
#   'ख्वाब',
#   'रात',
#   'भर.:।।'],
#  ['पाक',
#   'को',
#   'कूटनीतिक',
#   'झटका:',
#   'भारत-अफगानिस्तान',
#   'बनाएंगे',
#   'एयर',
#   'कॉरिडोर'],
#  ['भारत-अफगानिस्तान',
#   'के',
#   'बीच',
#   'जल्द',
#   'शुरू',
#   'होगी',
#   'मालवाहक',
#   'विमान',
#   'सेवा'],
#  ['इससे',
#   'पहले',
#   'श्री',
#   'Modiजी',
#   'को',
#   'अफगानिस्तान',
#   'और',
#   'सऊदी',
#   'अरब',
#   'के',
#   'सर्वोच्च',
#   'नागरिक',
#   'सम्मान',
#   'से',
#   'भी',
#   'सम्मानित',
#   'किया',
#   'जा',
#   'चुका',
#   'है',
#   '#TimePersonoftheYear'],
#  ['अरुणाचल',
#   'प्रदेश:',
#   'खोंसा',
#   'में',
#   'असम',
#   'राइफल्स',
#   'की',
#   'टुकड़ी',
#   'पर',
#   'घात',
#   'लगाकर',
#   'हमला',
#   'किया',
#   'गया।',
#   'शहीदों',
#   'की',
#   'संख्या',
#   'बढ़कर',
#   '2',
#   'हुई।'],
#  ['लद्दाख',
#   'से',
#   'लेकर',
#   'कन्याकुमारी',
#   'तक,अरुणाचल',
#   'प्रदेश',
#   'से',
#   'लेकर',
#   'गुजरात',
#   'में',
#   'रण',
#   'के',
#   'कच्छ',
#   'तक',
#   '#भाजपा_का_विजयरथ',
#   'अपनी',
#   'चाल',
#   'में',
#   'अग्रसर',
#   'है।'],
#  ['दलितो',
#   'के',
#   'मसीहा,महिलाओ',
#   'के',
#   'हितैषी,विद्वान,दार्शनिक,लेखक,संविधान',
#   'निर्माता,सामाजिक',
#   'कुरीतियो',
#   'के',
#   'मुक्ति',
#   'नायक',
#   '#अम्बेडकर',
#   'को',
#   'सलाम'],
#  ['समता,समानता,मानवता',
#   'आधारित',
#   'भारतीय',
#   'संविधान',
#   'को',
#   'कठिन',
#   'परिश्रम',
#   'से',
#   'तैयार',
#   'करने',
#   'वाले',
#   'डॉ.',
#   'अम्बेडकर',
#   'के',
#   'महापरिनिर्वाण',
#   'दिवस',
#   'पर',
#   'उन्हें',
#   'भावभीनी',
#   'श्रद्धांजलि'],
#  ['संविधान',
#   'दिवस',
#   'पर',
#   'पूंछ',
#   'से',
#   'पटियाला',
#   'तक,',
#   'हमारे',
#   'मंत्रालय',
#   'के',
#   'नेहरू',
#   'युवा',
#   'केंद्र',
#   'कार्यकर्ताओं',
#   'ने',
#   'युवाओं',
#   'के',
#   'हित',
#   'में',
#   'विभिन्न',
#   'विषयों',
#   'पर',
#   'चर्चा',
#   'की',
#   'I'],
#  ['शेख',
#   'हसीना',
#   'ने',
#   'भारत',
#   'आने',
#   'के',
#   'PM',
#   'मोदी',
#   'के',
#   'आमंत्रण',
#   'को',
#   'स्वीकार',
#   'किया'],
#  ['व्यापमं',
#   'घोटाले',
#   'में',
#   'आदिवासी',
#   'छात्रा',
#   'का',
#   'पोस्टमॉर्टम',
#   'करने',
#   'वाले',
#   'डॉक्टर',
#   'पर',
#   'दवाब',
#   'डाला',
#   'जा',
#   'रहा',
#   'है,',
#   'पोस्टमॉर्टम',
#   'में',
#   'रेप',
#   'और',
#   'हत्या',
#   'का',
#   'खुलासा',
#   'हुआ',
#   'था'],
#  ['आतंक',
#   'से',
#   'जुड़ी',
#   'आॅनलाइन',
#   'सामग्री',
#   'को',
#   'रोकने',
#   'के',
#   'लिए',
#   'एकजुट',
#   'हुईं',
#   'फेसबुक,',
#   'ट्विटर,',
#   'माइक्रोसॉफ्ट',
#   'जैसी',
#   'दिग्गज',
#   'कंपनियां'],
#  ['माइक्रोसॉफ्ट,',
#   '#twitter',
#   ',',
#   'यूट्यूब',
#   'ने',
#   'आतंकवाद',
#   'पर',
#   'अंकुश',
#   'लगाने',
#   'के',
#   'लिए',
#   'मिलाएं',
#   'हाथ',
#   '-'],
#  ['सुप्रीम',
#   'कोर्ट',
#   'का',
#   'गूगल,',
#   'याहू,',
#   'फेसबुक',
#   'और',
#   'माइक्रोसॉफ्ट',
#   'को',
#   'नोटिस'],
#  ['एयरटेल',
#   'पेमेंट',
#   'बैंक:',
#   'जितना',
#   'जमा',
#   'करेंगे,',
#   'उतना',
#   'टॉकटाइम',
#   'मिलेगा'],
#  ['मेरठ',
#   'में',
#   'केजरीवाल',
#   'का',
#   'पीएम',
#   'मोदी',
#   'पर',
#   'नोटबंदी',
#   'को',
#   'लेकर',
#   'ताबड़तोड़',
#   'हमला,',
#   'हजारों',
#   'की',
#   'संख्या',
#   'में',
#   'सुनने',
#   'पहुंचे',
#   'लोग'],
#  ['जयललिता',
#   'जी',
#   'की',
#   'अम्मा',
#   'कैंटीन,',
#   'शिक्षा',
#   'और',
#   'स्वास्थ्य',
#   'सेवाओ',
#   'की',
#   'स्कीम्स',
#   'देश',
#   'के',
#   'बाकि',
#   'सरकारों',
#   'के',
#   'लिए',
#   'एक',
#   'मिसाल',
#   'हैं.',
#   'उनको',
#   'भावपूर्ण',
#   'श्रद्धांजलि.'],
#  ['जब',
#   'विधानसभा',
#   'में',
#   'जयललिता',
#   'के',
#   'साथ',
#   'बदसलूकी',
#   'हुई',
#   'थी',
#   'तो',
#   'उन्होंने',
#   'बोला',
#   'था',
#   "'तभी",
#   'लौटूंगी',
#   'जब',
#   'ये',
#   'जगह',
#   'महिलाओं',
#   'के',
#   'लिए',
#   'सुरक्षित',
#   "हो',",
#   'मुख्यमंत्री',
#   'बन',
#   'लौटी।'],
#  ['नरेंद्र',
#   'मोदी',
#   'ने',
#   'जीता',
#   'अमेरिकी',
#   'पत्रिका',
#   'टाइम',
#   'का',
#   "'पर्सन",
#   'ऑफ',
#   'द',
#   "इयर'",
#   'ऑनलाइन',
#   'पाठक-पोल',
#   'Person',
#   'of',
#   'Year',
#   '#Time'],
#  ['एयर',
#   'इंडिया',
#   'की',
#   'क्रू',
#   'चीफ',
#   'को',
#   'कपड़ों',
#   'के',
#   'कारण',
#   'फ्लाइट',
#   'से',
#   'उतारा',
#   'गया'],
#  ['LPG',
#   'सिलिंडर्स',
#   'के',
#   'लिए',
#   'अभी',
#   '500',
#   'के',
#   'पुराने',
#   'नोटों',
#   'पर',
#   'छूट',
#   'जारी,',
#   'दे',
#   'सकते',
#   'हैं',
#   'पुराने',
#   'नोटः',
#   'वित्त',
#   'मंत्रालय'],
#  ['गोवा-',
#   'हिंदू',
#   'रीति-रिवाज',
#   'के',
#   'साथ',
#   'युवराज',
#   'की',
#   'गोवा',
#   'में',
#   'शादी',
#   'संपन्न,',
#   'शादी',
#   'में',
#   'मुकेश',
#   'अंबानी,',
#   'नीता',
#   'अंबानी,',
#   'कोहली,',
#   'लक्ष्मण',
#   'समेत',
#   'कई',
#   'क्रिकेटर',
#   'हुए',
#   'शामिल'],
#  ['घुसपैठ',
#   'रोकने',
#   'के',
#   'लिए',
#   'भारत-पाक',
#   'सीमा',
#   'पर',
#   'तकनीकी',
#   'रूप',
#   'से',
#   'उन्नत',
#   'प्रणालियां',
#   'स्थापित',
#   'करेगी',
#   'सरकार:'],
#  ['अजीज',
#   'ने',
#   'भारत-पाक',
#   'संबंधों',
#   'का',
#   'किया',
#   'जिक्र,',
#   'बोले-किसी',
#   'देश',
#   'पर',
#   'दोषारोपण',
#   'करना',
#   'सरल'],
#  ['मेरा',
#   'मोबाइल,',
#   'मेरा',
#   'बैंक,',
#   'मेरा',
#   "बटुआ'",
#   ':',
#   'बिना',
#   'कैश',
#   'के',
#   'भुगतान,',
#   'मुमकिन',
#   'है',
#   'बदले',
#   'अपने',
#   'आप',
#   'को',
#   'इंटरनेट',
#   'बैंकिंग',
#   'का',
#   'करे',
#   'इस्तेमाल'],
#  ['ट्विटर',
#   'अकाउंट',
#   'हैक',
#   'होना',
#   'तो',
#   'बस',
#   'बहाना',
#   'है।',
#   'लोगों',
#   'का',
#   'मोबाइल',
#   'बैंकिंग',
#   'से',
#   'विश्वास',
#   'उठाना',
#   'है।'],
#  ['जहाँ',
#   'एक',
#   'वेरिफाइड',
#   'और',
#   'ऑफिसियल',
#   'अकाउंट',
#   'सुरक्षित',
#   'नहीं',
#   'वहां',
#   'मोदी',
#   'मोबाइल',
#   'और',
#   'नेट',
#   'बैंकिंग',
#   'की',
#   'बात',
#   'करता',
#   'है'],
#  ['यूथ',
#   'फेस्टीवल',
#   'में',
#   'कैशलैस',
#   'व्यवस्था',
#   'की',
#   'ओर',
#   'युवाओं',
#   'का',
#   'ध्यान',
#   'आकर्षित',
#   'करने',
#   'के',
#   'लिए',
#   'इंटरनेट',
#   'बैंकिंग,',
#   'मोबाइल',
#   'बैंकिंग',
#   'के',
#   'विशेष',
#   'शिविर',
#   'आयोजित',
#   'किए',
#   'जाएंगे।'],
#  ['मोबाइल',
#   'बैंकिंग',
#   'के',
#   'प्रति',
#   'जागरूकता',
#   'लाने',
#   'के',
#   'लिये',
#   'प्रदेश',
#   'अध्यक्ष',
#   'श्री',
#   'के',
#   'नेतृत्व',
#   'में',
#   'मुखर्जी',
#   'नगर',
#   'से',
#   'जनसंपर्क',
#   'अभियान',
#   'की',
#   'शुरुआत।'],
#  ['आज',
#   'दिल्ली',
#   'के',
#   'करोल',
#   'बाग़',
#   'स्थित',
#   'गफ्फार',
#   'मार्केट',
#   'में',
#   'व्यापारियों',
#   'से',
#   'मिला',
#   'और',
#   'सरल',
#   'मोबाइल',
#   'बैंकिंग',
#   'तथा',
#   'डिजिटल',
#   'भुगतान',
#   'के',
#   'तरीके',
#   'उन्हें',
#   'सिखाएं.',
#   '#digitalIndia'],
#  ['क्रोध',
#   'भी',
#   'तब',
#   'पुण्य',
#   'बन',
#   'जाता',
#   'है,',
#   'जब',
#   'वह',
#   'धर्म',
#   'और',
#   'मर्यादा',
#   'के',
#   'लिए',
#   'किया',
#   'जाए',
#   'और',
#   'सहनशीलता',
#   'भी',
#   'तब',
#   'पाप',
#   'बन',
#   'जाती',
#   'है',
#   'जब',
#   'वह',
#   'धर्म',
#   'और',
#   'मर्यादा',
#   'को',
#   'ब.'],
#  ['जी',
#   'निशांत',
#   'वर्मा',
#   'जैसे',
#   'बदतमीज',
#   'और',
#   'वाहियात',
#   'लोगों',
#   'के',
#   'साथ',
#   'डिबेट',
#   'में',
#   'बैठकर',
#   'आप',
#   'अपना',
#   'स्तर',
#   'ना',
#   'गिराए,क्योंकि',
#   'ना',
#   'तो',
#   'इ.'],
#  ['Befitting',
#   'reply',
#   'Rahul',
#   'Gandhi',
#   'by',
#   'Ladakh',
#   'MP',
#   'claims',
#   'occupied',
#   'Indian',
#   'under',
#   'Congress',
#   'rule'],
#  ['जौनपुर',
#   'में',
#   'फूंकी',
#   'दलितों',
#   'की',
#   'बस्ती,',
#   'जेल',
#   'पहुंचे',
#   'एसपी',
#   'नेता',
#   'समेत',
#   '35',
#   'लोग',
#   'योगी',
#   'सरकार',
#   'द्वारा',
#   'मुख्य',
#   'आरोपी',
#   'नूर',
#   'आलम',
#   'और',
#   'जावेद',
#   'सिद्दीकी.'],
#  ['ना', 'मैं', 'गिरा"', 'ना', 'मेरे', 'हौंसलों', 'की', 'मीनारें', 'गिरी'],
#  ['पाकिस्तान',
#   'में',
#   'हिन्दुओ',
#   'का',
#   'गांव',
#   'की',
#   'गांव',
#   'जला',
#   'दिया',
#   'जाता',
#   'है',
#   'पर',
#   'किसी',
#   'की',
#   'आवाज',
#   'नही',
#   'निकलती',
#   'है',
#   'आखिर',
#   'कब',
#   'तक',
#   'हिन्दू',
#   'मरता',
#   'रहेगा',
#   'पा.'],
#  ['भारत',
#   'को',
#   'कोरोना',
#   'से',
#   'ज्यादा',
#   'खतरा',
#   'उन',
#   'तथाकथित',
#   'लोगों',
#   'से',
#   'है.',
#   'जो',
#   'इस',
#   'संकट',
#   'काल',
#   'में',
#   'भी',
#   'सरकार',
#   'का',
#   'साथ',
#   'देने',
#   'के',
#   'बजाए',
#   '"सरकार',
#   'की',
#   'टांग."'],
#  ['मुझे',
#   'के',
#   'प्रचार',
#   'से',
#   'एक',
#   'फूटी',
#   'कौड़ी',
#   'नहीं',
#   'मिलती',
#   '|',
#   'लेकिन',
#   'ऐसा',
#   'लगता',
#   'है',
#   'कि',
#   'मैं',
#   'सीमा',
#   'पर',
#   'देश',
#   'के',
#   'लिए',
#   'लड़',
#   'रहा',
#   'हूँ',
#   '|.'],
#  ['यह',
#   'मोहब्बत',
#   'का',
#   'बंधन',
#   'भी',
#   'कितना',
#   'अजीब',
#   'होता',
#   'है,',
#   'मिल',
#   'जाए',
#   'तो',
#   'बातें',
#   'लंबी',
#   'और',
#   'बिछड़',
#   'जाए',
#   'तो',
#   'यादें',
#   'लंबी!!',
#   '#शुभरात्रि'],
#  ['राष्ट्रीय',
#   'स्वयंसेवक',
#   'संघ',
#   '(RSS)',
#   'द्वारा',
#   '8500',
#   'ईसाई',
#   'धर्म',
#   'अपना',
#   'चुके',
#   'सिखों',
#   'को',
#   'पुनः',
#   'सिख',
#   'धर्म',
#   'में',
#   'वापसी',
#   'करवाई।'],
#  ['लद्दाख',
#   'बंजर',
#   'भूमि',
#   'है,',
#   'वँहा',
#   'घास',
#   'का',
#   'एक',
#   'तिनका',
#   'नही',
#   'उगता,',
#   'लद्दाख',
#   'को',
#   'चायना',
#   'को',
#   'दे',
#   'देना',
#   'ही',
#   'भारत',
#   'के',
#   'हित',
#   'मे',
#   'है',
#   'ये',
#   'शर्मनाक',
#   'कथन',
#   'भारत.'],
#  ['सुप्रीम',
#   'कोर्ट',
#   'ने',
#   'सरकार',
#   'से',
#   'कहा',
#   'दिल्ली',
#   'के',
#   'अस्पतालों',
#   'में',
#   'इंसानो',
#   'से',
#   'जानवरो',
#   'से',
#   'भी',
#   'बदतर',
#   'व्यवहार',
#   'हो',
#   'रहा',
#   'है।'],
#  ['हम',
#   'ख़ुद',
#   'में',
#   'कितना',
#   'उतरें',
#   'हम',
#   'ख़ुद',
#   'में',
#   'कितना',
#   'झाँकें.!!!',
#   '❤️❤️'],
#  ['हीरो',
#   'इन',
#   'लोगों',
#   'को',
#   'कहते',
#   'हैं',
#   'जो',
#   'देश',
#   'के',
#   'लिए',
#   'शहीद',
#   'हो',
#   'गए',
#   'जो',
#   'हमारे',
#   'लिए',
#   'शहीद',
#   'हो',
#   'गए',
#   'ईश्वर',
#   'इनके',
#   'परिवार',
#   'को',
#   'यह',
#   'दुख',
#   'सहने',
#   'की',
#   'शक्ति.'],
#  ['“ये',
#   'दुनिया',
#   'है',
#   'यहाँ',
#   'जीते-जी',
#   'कोई',
#   'कुछ',
#   'नहीं',
#   'सुनता.',
#   'मुझे',
#   'मरना',
#   'पड़ेगा',
#   'तब',
#   'मेरी',
#   'आवाज़',
#   'गूंजेगी.!!!”'],
#  ['अगर',
#   'आपको',
#   'अपने',
#   'जीवन',
#   'में',
#   'सफल',
#   'होना',
#   'है',
#   'तो',
#   'हार्ड',
#   'वर्क',
#   'से',
#   'ज्यादा',
#   'स्मार्ट',
#   'वर्क',
#   'पर',
#   'ध्यान',
#   'देना',
#   'होगा,',
#   'हार्ड',
#   'वर्क',
#   'कहाँ',
#   'करना',
#   'है'],
#  ['अब',
#   'कंगना',
#   'रनौत',
#   'ने',
#   'कुछ',
#   'लोगों',
#   'के',
#   'चेहरों',
#   'को',
#   'बेनकाब',
#   'करते',
#   'हुए',
#   'बड़े',
#   'खुलासे',
#   'किए',
#   'हैं',
#   '#KangnaRanaut',
#   '#JavedAkhtar',
#   '#Bollywood'],
#  ['अब',
#   'चाहे',
#   'जितने',
#   'लंबे',
#   'पोस्ट',
#   'लिखो',
#   'ना',
#   'वो',
#   'पढ़ने',
#   'आ',
#   'रहा',
#   'है',
#   'ना',
#   'उसे',
#   'अब',
#   'इसकी',
#   'जरूरत',
#   'पड़ेगी',
#   'वो',
#   'सितारा',
#   'सितारों',
#   'में',
#   'मिल',
#   'गया',
#   '😰😭'],
#  ['इतनी',
#   'बरस',
#   'रही',
#   'हो',
#   'तो',
#   'उन',
#   'पर',
#   'भी',
#   'मुंह',
#   'खोल',
#   'दो',
#   'जिन्होने',
#   'एक',
#   'काबिल',
#   'अभिनेता',
#   'को',
#   'पूरी',
#   'तरह',
#   'बर्बाद',
#   'करने',
#   'के',
#   'लिए',
#   'कमर',
#   'कस',
#   'रखी',
#   'थी',
#   'उस',
#   'भाई',
#   'भतीजवाद',
#   'पर',
#   'भी',
#   'बोलो',
#   'जिसने',
#   'एक',
#   'होनहार',
#   'अभिनेता',
#   'को',
#   'यूं',
#   'फांसी',
#   'पर',
#   'लटकने',
#   'को',
#   'मजबूर',
#   'कर',
#   'दिया'],
#  ['इन',
#   'तस्वीरों',
#   'को',
#   'देखकर',
#   'समझिए',
#   'क्यों',
#   'जरूरत',
#   'पड़ी',
#   'महेश',
#   'भट्ट',
#   'को',
#   'सुशांत',
#   'को',
#   'मानसिक',
#   'रोगी',
#   'बताने',
#   'की',
#   'पोल',
#   'खुलने',
#   'वाली',
#   'थी',
#   'और',
#   'सच',
#   'सामने',
#   'आने',
#   'वाला',
#   'था',
#   'फिलहाल',
#   'रिया',
#   'ने',
#   'ये',
#   'फोटो',
#   'इंस्टाग्राम',
#   'से',
#   'हटा',
#   'दी',
#   'है',
#   'चौंकना',
#   'मत',
#   'अगर',
#   'रिया',
#   'अब',
#   'सुशांत',
#   'पर',
#   'कोई',
#   'आरोप',
#   'लगाए',
#   'स्क्रिप्ट',
#   'मिल',
#   'चुकी',
#   'है',
#   'उसे',
#   'बस',
#   'सबके',
#   'सामने',
#   'पढ़ना',
#   'बाकी',
#   'है😡'],
#  ['इस',
#   'महामारी',
#   'ने',
#   'ना',
#   'सिर्फ',
#   'लोगो',
#   'की',
#   'आर्थिक',
#   'स्थिति',
#   'बदली',
#   'बल्कि',
#   'लोगो',
#   'की',
#   'सोच,',
#   'नजरिया,',
#   'रिश्ते',
#   'सब',
#   'बदल',
#   'दिए',
#   '.😔',
#   'बहुत',
#   'कुछ',
#   'लेकर',
#   'और',
#   'सीखा',
#   'कर',
#   'जाएगा',
#   'ये',
#   'करोना',
#   '☹️'],
#  ['ईश्वर',
#   'हमारे',
#   'यहां',
#   'भी',
#   'जल्द',
#   'से',
#   'जल्द',
#   'ऐसा',
#   'करे',
#   'यही',
#   'दुआ',
#   'है',
#   'सबकी',
#   '🙏🏻'],
#  ['एक',
#   'भी',
#   'गोली',
#   'नहीं',
#   'चली,',
#   'कंटीले',
#   'तार,',
#   'लोहे',
#   'की',
#   'रॉड,',
#   'खुकरी',
#   'और',
#   'डंडे',
#   'से',
#   'झड़प',
#   'हुई',
#   '|',
#   'हाथों',
#   'से',
#   'आँखें',
#   'नोची,',
#   'कान',
#   'फाड़े,',
#   'शरीर',
#   'का',
#   'मांस.'],
#  ['ऐसी',
#   'कोई',
#   'मुश्किल',
#   'नही',
#   'जिससे',
#   'बाहर\u200c',
#   'ना',
#   'निकला',
#   'जा',
#   'सके',
#   'नही',
#   'करना',
#   'था',
#   'ये',
#   '💔😰😰',
# ...
#   'मंगाने',
#   'की',
#   'डील',
#   'कर',
#   'ली',
#   'है,',
#   'अब',
#   'और',
#   'ज्यादा',
#   'रोयेगा',
#   'ये',
#   'फ़कीर'],
#  ['इनको',
#   'ये',
#   'समझ',
#   'नही',
#   'की',
#   'जिस',
#   'दिन',
#   'हम',
#   'अपनी',
#   'पे',
#   'आएंगे',
#   'ये',
#   'बाप',
#   'बाप',
#   'चिलायेंगे।',
#   'हाँ',
#   'अफगानिस्तान',
#   'से',
#   'भी',
#   'आगे',
#   'तक',
#   'हमारे',
#   'बाप',
#   'का',
#   'रहा',
#   'है',
#   'फारुख',
#   'साब'],
#  ['जब',
#   'पाकिस्तान',
#   'पाकों',
#   'का',
#   'है,',
#   'अफगानिस्तान',
#   'अफगानों',
#   'का',
#   'है,',
#   'तुर्की',
#   'तुर्कों',
#   'का',
#   'है,',
#   'अरब',
#   'अरबों',
#   'का',
#   'है',
#   'तो',
#   'हिंदुस्तान',
#   'सेकुलुरों',
#   'का',
#   'कैसे?'],
#  ['बुढ्ढे',
#   'को',
#   'जवान',
#   'दिखने',
#   'के',
#   'लिए',
#   '6',
#   'घंटे',
#   'का',
#   'मेकअप',
#   'कम',
#   'है',
#   'इसको',
#   '6',
#   'साल',
#   'तक',
#   'मेकअप',
#   'करना',
#   'चाहिए।',
#   'तब',
#   'तक',
#   'देश',
#   'में',
#   'असहिष्णुता',
#   'भी',
#   'ख़त्म',
#   'हो',
#   'जायेगी'],
#  ['ट्रम्प',
#   'ने',
#   'हिलेरी',
#   'पे',
#   'यू-टर्न',
#   'ले',
#   'लिया',
#   'है,',
#   'अमेरिका',
#   'वालों',
#   'को',
#   'धीरे-धीरे',
#   'पता',
#   'चलेगा,',
#   'उन्होंने',
#   'अपना',
#   'मोदी',
#   'नहीं',
#   'केजरीवाल',
#   'चुना',
#   'है.'],
#  ['डोनाल्ड',
#   'ट्रम्प',
#   'ने',
#   'कहा',
#   'था',
#   'वो',
#   'हिलेरी',
#   'को',
#   'जेल',
#   'भेजेंगे',
#   'अब',
#   'उन्होंने',
#   'यू-टर्न',
#   'ले',
#   'लिया',
#   'केजरीवाल',
#   'और',
#   'शीला',
#   'दीक्षित',
#   'स्टोरी',
#   'का',
#   'अब',
#   'हॉलीवुड',
#   'में',
#   'रीमेक',
#   'बना'],
#  ['अब',
#   'कितना',
#   'भी',
#   'पॉलिश',
#   'करो,',
#   'हक़ीक़त',
#   'यही',
#   'है',
#   'श्याम-श्वेत।',
#   'हिलेरी',
#   'रह',
#   'गई',
#   'दाना',
#   'गिनती,',
#   'और',
#   'ट्रंपवा',
#   'जोत',
#   'गया',
#   'खेत।'],
#  ['थोड़ी',
#   'देर',
#   'हो',
#   'गयी',
#   'वर्ना',
#   'हिलेरी',
#   'क्लिंटन',
#   'की',
#   'जगह',
#   'मोदी',
#   'अपनी',
#   'माता',
#   'जी',
#   'अमेरिका',
#   'में',
#   'राष्ट्रपति',
#   'के',
#   'इलेक्शन',
#   'में',
#   'खड़ी',
#   'करवा',
#   'देते।'],
#  ['आज',
#   'संविधान',
#   'दिवस',
#   'है',
#   '।आज',
#   'ही',
#   'के',
#   'दिन',
#   '4',
#   'वर्ष',
#   'पूर्व,आम',
#   'आदमी',
#   'पार्टी',
#   'के',
#   'नाम',
#   'पर',
#   'मेरे',
#   'काला',
#   'धन',
#   'का',
#   'जन्म',
#   'हुआ',
#   '#DeMonetisation',
#   'करके',
#   'मोदी',
#   'ने',
#   'सब',
#   'तबाह',
#   'कर',
#   'दिया'],
#  ['आज',
#   'शाम',
#   'कोलकाता',
#   'की',
#   'सड़कों',
#   'पे',
#   'निकला',
#   'तो',
#   'पोस्टर',
#   'दिखा.',
#   'दीदी',
#   'के',
#   'लिए',
#   'जीता',
#   'जगता',
#   'सबूत.दुकान',
#   'वाले',
#   'ने',
#   'कहा',
#   'मै',
#   '2',
#   'घंटे',
#   'ज्यादा',
#   'काम',
#   'करूँगा'],
#  ['दिक्कत',
#   'सिर्फ',
#   'चिटफण्ड',
#   'घोटाले',
#   'में',
#   'कमाए',
#   'रोकड़ो',
#   'के',
#   'एक',
#   'झटके',
#   'में',
#   'रद्दी',
#   'हो',
#   'जाने',
#   'की',
#   'है,जो',
#   'दीदी',
#   'कोलकाता',
#   'से',
#   'दिल्ली',
#   'दौड़',
#   'रही',
#   'है।'],
#  ['बेगम',
#   'मोमता',
#   'को',
#   'भारतीय',
#   'सेना',
#   'से',
#   'डरा',
#   'देख',
#   'बंगलादेश',
#   'की',
#   'शेख',
#   'हसीना',
#   'की',
#   'हँसी',
#   'ना',
#   'रुक',
#   'रही'],
#  ['वो',
#   'लोग',
#   'कर',
#   'रहे',
#   'है',
#   'जिनका',
#   'चाचा',
#   'नवाज़',
#   'शरीफ,',
#   'बुआ',
#   'शेख',
#   'हसीना',
#   'है',
#   'जो',
#   'खाए',
#   'देश',
#   'का',
#   'और',
#   'काम',
#   'करे',
#   'दुश्मनो',
#   'के',
#   'लिए,उनको',
#   'ही',
#   'PM',
#   'से',
#   'तकलीफ',
#   'है'],
#  ['एक',
#   'लडकी',
#   'मेट्रो',
#   'में',
#   'बडी',
#   'देर',
#   'से',
#   'मोदी',
#   'के',
#   'गुण',
#   'गा',
#   'रही',
#   'थी',
#   'मैने',
#   'कह',
#   'दिया',
#   'भगवान',
#   'करे',
#   'आपको',
#   'मोदी',
#   'जैसा',
#   'पति',
#   'मिले।',
#   'उसके',
#   'बाद',
#   'अब',
#   'शांत',
#   'है।'],
#  ['लखनऊ',
#   'में',
#   'जल्द',
#   'ही',
#   'मेट्रो',
#   'दौड़ेगी,',
#   'और',
#   'इस',
#   'मेट्रो',
#   'में',
#   'गति',
#   'की',
#   'ओर',
#   'का',
#   'पहला',
#   'डब्बा',
#   '"गुटखा"',
#   'खाने',
#   'वालों',
#   'के',
#   'लिए',
#   'आरक्षित',
#   'रहेगा।'],
#  ['गूगल,',
#   'माइक्रोसॉफ्ट,',
#   'रिलायंस',
#   ',',
#   'फेसबुक,एप्पल',
#   'सबके',
#   'मालिक',
#   'लड़के',
#   'हैं',
#   'आखिर',
#   'लडकियाँ',
#   'इतने',
#   'मार्क्स',
#   'लेकर',
#   'करती',
#   'क्या',
#   'हैं',
#   '?',
#   'बैंगन',
#   'का',
#   'भर्ता',
#   'बनाना,'],
#  ['मोमोता',
#   'दीदी',
#   'ने',
#   'कहा.',
#   'नोइ',
#   'करेगा',
#   'सड़क',
#   'पोर',
#   'बोन्द',
#   'बाबा',
#   '!',
#   'ऑन',
#   'लाइन',
#   'बोन्द',
#   'बुलाएगा',
#   'अब।',
#   'वोडाफोन',
#   'एयरटेल',
#   'वालों',
#   'का',
#   'टॉवर',
#   'पकड़',
#   'लेगा',
#   'हम'],
#  ['अगर',
#   'किसी',
#   'दिल्ली',
#   'वाले',
#   'का',
#   'पारा',
#   'हाई',
#   'करना',
#   'हो',
#   'तो',
#   'बस',
#   'उसके',
#   'आगे',
#   'जोर',
#   'से',
#   '"पांच',
#   'साल',
#   'केजरीवाल',
#   '"',
#   'बोल',
#   'दो'],
#  ['अरविन्द',
#   'केजरीवाल',
#   'के',
#   'भोपाल',
#   'आने',
#   'की',
#   'खबर',
#   'सुनके',
#   'व्यापम',
#   'के',
#   'खलनायक',
#   'जी',
#   'दूसरे',
#   'ग्रह',
#   'पे',
#   'जा',
#   'पहुंचे'],
#  ['अंबानी',
#   'ने',
#   'जियो',
#   'लाकर',
#   'फ्री',
#   'डाटा',
#   'दिया',
#   'ही',
#   'इसलिए',
#   'था',
#   'ताकि',
#   'ज़्यादा',
#   'से',
#   'ज़्यादा',
#   'लोग',
#   'मोदी',
#   'को',
#   'ऑनलाइन',
#   'वोट',
#   'देकर',
#   'Time',
#   'of',
#   'year',
#   'बना',
#   'सकें-केजरीवाल'],
#  ['सेना',
#   'ने',
#   'रूटीन',
#   'अभ्यास',
#   'के',
#   'बंगाल',
#   'पुलिस',
#   'से',
#   'सतत',
#   'संपर्क',
#   'के',
#   'दस्तावेज',
#   'जारी',
#   'किये.क्या',
#   'दीदी',
#   'माफ़ी',
#   'मांगेंगी.नहीं.क्योकिं',
#   'मोमता',
#   'अब',
#   'केजरीवाल',
#   'हो',
#   'गई',
#   'है!'],
#  ['इतिहास',
#   'गवाह',
#   'है,',
#   'केजरीवाल',
#   'ने',
#   'जिस',
#   'जिस',
#   'से',
#   'इस',
#   'मुद्रा',
#   'में',
#   'बात',
#   'किया',
#   'है,',
#   'उनका',
#   'क्या',
#   'हुआ,',
#   'अब',
#   'दीदी',
#   'की',
#   'बारी',
#   'है'],
#  ['केजरीवाल',
#   'और',
#   'ममता',
#   'बनर्जी',
#   'में',
#   'कडा',
#   'मुकाबला',
#   'चल',
#   'रहा',
#   'है',
#   'केजरीवाल',
#   'ने',
#   'तो',
#   'दिल्ली',
#   'पुलिस',
#   'को',
#   'ही',
#   'गालियाँ',
#   'दी',
#   'दीदी',
#   'ने',
#   'तो',
#   'फौज',
#   'कि',
#   'मां',
#   'बहन',
#   'एक',
#   'कर',
#   'दी.!!'],
#  ['अमी',
#   'मोंजुलिका.अमी',
#   'राजा',
#   'को',
#   'मारबो',
#   'दीदी',
#   'ने',
#   'केजरीवाल',
#   'को',
#   'भी',
#   'पीछे',
#   'छोड़',
#   'दिया.',
#   'जि',
#   'तो',
#   'कमालई',
#   'कर',
#   'दओ',
#   'दद्दू'],
#  ['टीआरपी',
#   'का',
#   'खेल',
#   'देखो.अस्पताल',
#   'कहता',
#   'है',
#   'वो',
#   'ज़िंदा',
#   'हैं,',
#   'मीडिया',
#   'कहता',
#   'है',
#   'नही.प्रतिस्पर्धा',
#   'है,',
#   'कौन',
#   'खबर',
#   'पहले',
#   'देगा.पर',
#   'मौत',
#   'को',
#   'तो',
#   'बक्श',
#   'दो।'],
#  ['शहंशाही',
#   'नहीं,',
#   'मुझे',
#   'फकीरी',
#   'अदा',
#   'कर',
#   'मौला.',
#   'मोदी',
#   'जी',
#   'तीन',
#   'और',
#   'फ़क़ीर',
#   '-',
#   'टाटा,',
#   'अंबानी',
#   'और',
#   'कामथ',
#   'के',
#   'साथ',
#   'रूहानी',
#   'चर्चा',
#   'करते',
#   'हुए।'],
#  ['सब',
#   'गरीब-गरीब',
#   'कर',
#   'रहे',
#   'है,',
#   'कोई',
#   'उन',
#   'गरीबों',
#   'के',
#   'बारे',
#   'में',
#   'भी',
#   'सोचो',
#   'जिनके',
#   'घर',
#   'का',
#   'खर्चा',
#   'न',
#   'जाने',
#   'कैसे',
#   'चल',
#   'रहा',
#   'होगा,',
#   'अम्बानी,',
#   'अडानी,',
#   'टाटा,',
#   'माल्या',
#   '!'],
#  ['टाइम',
#   'पर्सन',
#   'ऑफ',
#   'द',
#   'इयर',
#   ':',
#   '#मोदी',
#   'टाईम',
#   'पास',
#   'ऑफ',
#   'द',
#   'इयर',
#   ':',
#   '#केजरी'],
#  ['आज',
#   'ओवैशी',
#   'भूल',
#   'गया',
#   'है',
#   'की',
#   'उनके',
#   'पुरब्ज़',
#   'ने',
#   'चाकू',
#   'छुरी',
#   'के',
#   'नोक',
#   'पर',
#   'ही',
#   'अपना',
#   'धर्म',
#   'बदला',
#   'था',
#   'नोटः',
#   'ये',
#   'पुराने',
#   'गड़',
#   'फट्टू',
#   'है'],
#  ['#JIO',
#   'का',
#   'सच',
#   'नीता',
#   'अंबानी',
#   'ने',
#   'मन्नत',
#   'मांगी',
#   'थी',
#   'कि',
#   'अनंत',
#   'अम्बानी',
#   'अपना',
#   'वजन',
#   'कम',
#   'कर',
#   'लेगा',
#   'तो',
#   'गरीबों',
#   'में',
#   '3',
#   'महीने',
#   'Net',
#   'or',
#   'call',
#   'का',
#   'भंडारा',
#   'करवाऊँगी'],
#  ['चिंटूओं',
#   'का',
#   'एक',
#   'और',
#   'झूठ',
#   'बेनकाब',
#   'RBI',
#   'गवर्नर',
#   'की',
#   'पत्नी',
#   'की',
#   'बहन',
#   'नहीं',
#   'हैं',
#   'नीता',
#   'अंबानी'],
#  ['नीता',
#   'अंबानी',
#   'ने',
#   'मन्नत',
#   'मांगी',
#   'थी',
#   'कि',
#   'अगर',
#   'अनंत',
#   'अम्बानी',
#   'अपना',
#   'वजन',
#   'कम',
#   'कर',
#   'लेगा',
#   'तो',
#   'गरीबों',
#   'में',
#   '6',
#   'महीने',
#   'Net',
#   'or',
#   'call',
#   'का',
#   'भंडारा',
#   'करवाऊँगी'],
#  ['यदि',
#   'बैंक',
#   'की',
#   'लाइन',
#   'मे',
#   'लगने',
#   'से',
#   'हुए',
#   'मृत्यु',
#   'के',
#   'लिए',
#   'PMजिम्मेदार',
#   'है,तो',
#   'भारत-पाक',
#   'बटवारे',
#   'मे',
#   '6',
#   'लाख',
#   'की',
#   'मौत',
#   'का',
#   'जिम्मेदार',
#   'कौन?',
#   'नेहरू',
#   'गाँधी?'],
#  ['क्या',
#   'आदमी',
#   'है',
#   'पढ़ा',
#   'लिखा',
#   'गंवार,',
#   'मोबाइल',
#   'से',
#   'बेसिरपैर',
#   'ट्वीट',
#   'कर',
#   'सकता',
#   'है,',
#   'पर',
#   'उसी',
#   'मोबाइल',
#   'से',
#   'बैंकिंग',
#   'करना',
#   'नहीं',
#   'जानता'],
#  ['लाला,',
#   'तुम',
#   'किस',
#   'चक्की',
#   'का',
#   'खाते',
#   'हो?',
#   'इस',
#   'डेढ़',
#   'छँटाक',
#   'के',
#   'राशन',
#   'में',
#   'भी',
#   'तोंद',
#   'बढ़ाए',
#   'जाते',
#   'हो।'],
#  ['आराम',
#   'ज़िन्दगी',
#   'की',
#   'कुंजी,',
#   'इससे',
#   'न',
#   'तपेदिक',
#   'होती',
#   'है।',
#   'आराम',
#   'सुधा',
#   'की',
#   'एक',
#   'बूंद,',
#   'तन',
#   'का',
#   'दुबलापन',
#   'खोती',
#   'है।'],
#  ['आराम',
#   'शब्द',
#   'में',
#   '‘राम’',
#   'छिपा',
#   'जो',
#   'भव-बंधन',
#   'को',
#   'खोता',
#   'है।',
#   'आराम',
#   'शब्द',
#   'का',
#   'ज्ञाता',
#   'तो',
#   'विरला',
#   'ही',
#   'योगी',
#   'होता',
#   'है।',
#   'इसलिए',
#   'तुम्हें',
#   'समझाता',
#   'हूँ,',
#   'मेरे',
#   'अनुभव',
#   'से',
#   'काम',
#   'करो।',
#   'ये',
#   'जीवन,',
#   'यौवन',
#   'क्षणभंगुर,',
#   'आराम',
#   'करो,',
#   'आराम',
#   'करो।'],
#  ['यदि',
#   'करना',
#   'ही',
#   'कुछ',
#   'पड़',
#   'जाए',
#   'तो',
#   'अधिक',
#   'न',
#   'तुम',
#   'उत्पात',
#   'करो।',
#   'अपने',
#   'घर',
#   'में',
#   'बैठे-बैठे',
#   'बस',
#   'लंबी-लंबी',
#   'बात',
#   'करो।'],
#  ['करने-धरने',
#   'में',
#   'क्या',
#   'रक्खा',
#   'जो',
#   'रक्खा',
#   'बात',
#   'बनाने',
#   'में।',
#   'जो',
#   'ओठ',
#   'हिलाने',
#   'में',
#   'रस',
#   'है,',
#   'वह',
#   'कभी',
#   'न',
#   'हाथ',
#   'हिलाने',
#   'में।'],
#  ['तुम',
#   'मुझसे',
#   'पूछो',
#   'बतलाऊँ',
#   '—',
#   'है',
#   'मज़ा',
#   'मूर्ख',
#   'कहलाने',
#   'में।',
#   'जीवन-जागृति',
#   'में',
#   'क्या',
#   'रक्खा',
#   'जो',
#   'रक्खा',
#   'है',
#   'सो',
#   'जाने',
#   'में।'],
#  ['मैं',
#   'यही',
#   'सोचकर',
#   'पास',
#   'अक्ल',
#   'के,',
#   'कम',
#   'ही',
#   'जाया',
#   'करता',
#   'हूँ।',
#   'जो',
#   'बुद्धिमान',
#   'जन',
#   'होते',
#   'हैं,',
#   'उनसे',
#   'कतराया',
#   'करता',
#   'हूँ।'],
#  ['मेरी',
#   'सेहत',
#   'का',
#   'राज',
#   'यही',
#   'कि,',
#   'दीए',
#   'जलने',
#   'के',
#   'पहले',
#   'ही',
#   'घर',
#   'में',
#   'आ',
#   'जाया',
#   'करता',
#   'हूँ।',
#   'जो',
#   'मिलता',
#   'है,',
#   'खा',
#   'लेता',
#   'हूँ,',
#   'चुपके',
#   'सो',
#   'जाया',
#   'करता',
#   'हूँ।'],
#  ['मेरी',
#   'गीता',
#   'में',
#   'लिखा',
#   'हुआ',
#   '—',
#   'सच्चे',
#   'योगी',
#   'जो',
#   'होते',
#   'हैं,',
#   'वे',
#   'कम-से-कम',
#   'बारह',
#   'घंटे',
#   'तो',
#   'बेफ़िक्री',
#   'से',
#   'सोते',
#   'हैं।'],
#  ['जब',
#   '‘सुख',
#   'की',
#   'नींद’',
#   'कढ़ा',
#   'तकिया,',
#   'मेरे',
#   'सर',
#   'के',
#   'नीचे',
#   'आता',
#   'है,',
#   'तो',
#   'सच',
#   'कहता',
#   'हूँ',
#   'मुझको',
#   'तो',
#   'संसार',
#   'का',
#   'मोह',
#   'मिट',
#   'जाता',
#   'है।'],
#  ['मैं',
#   'मेल',
#   'ट्रेन',
#   'हो',
#   'जाता',
#   'हूँ,',
#   'बुद्धि',
#   'भी',
#   'फक-फक',
#   'करती',
#   'है।',
#   'भावों',
#   'का',
#   'रस',
#   'हो',
#   'जाता',
#   'है,',
#   'और',
#   'कविताएं',
#   'उमड़ने',
#   'लगती',
#   'है।'],
#  ['मैं',
#   'औरों',
#   'की',
#   'तो',
#   'नहीं,',
#   'बात',
#   'पहले',
#   'अपनी',
#   'ही',
#   'लेता',
#   'हूँ।',
#   'मैं',
#   'पड़ा',
#   'खाट',
#   'पर',
#   'चुभते',
#   'इन',
#   'बूटों',
#   'को',
#   'ऊँटों',
#   'की',
#   'उपमा',
#   'देता',
#   'हूँ।'],
#  ['मैं',
#   'इसीलिए',
#   'तो',
#   'कहता',
#   'हूँ',
#   'मेरे',
#   'अनुभव',
#   'से',
#   'काम',
#   'करो।',
#   'यह',
#   'खाट',
#   'बिछा',
#   'लो',
#   'आँगन',
#   'में,',
#   'लेटो,',
#   'बैठो,',
#   'आराम',
#   'करो।'],
#  ['धड़-धड़-धड़-धड़,',
#   'बम',
#   'बम',
#   'बम',
#   'बम,',
#   'काहे',
#   'लडें',
#   'हम,',
#   'मौका',
#   'देखा,',
#   'रणछोड़',
#   'चले',
#   'हम.'],
#  ['आबाद',
#   'करेंगे',
#   'हम',
#   'जहा',
#   'नया,',
#   'ये',
#   'यहा',
#   'बरबाद',
#   'करेंगे.',
#   'निपटा',
#   'लेगे',
#   'जब',
#   'ये',
#   'सब',
#   'को',
#   'सब',
#   'भस्मासुर',
#   'को',
#   'याद',
#   'करेंगे,'],
#  ['कंप्यूटर',
#   'इन्ड्स्ट्री',
#   'में',
#   'देखो',
#   'ना',
#   'सारे',
#   'गधे-घोड़े',
#   'घुसे',
#   'जा',
#   'रहे',
#   'हैं.',
#   'आधे',
#   'से',
#   'ज्यादा',
#   'तो',
#   'इसमें',
#   'गधे',
#   'हैं',
#   'और',
#   'जो',
#   'घोड़े',
#   'भी',
#   'थे',
#   'उनसे',
#   'भी',
#   'गधों',
#   'की',
#   'तरह',
#   'काम',
#   'लिया',
#   'जा',
#   'रहा',
#   'है.'],
#  ['महिला',
#   'सशक्तीकरण',
#   'के',
#   'चक्कर',
#   'में',
#   'पड़ने',
#   'वाले',
#   'बहुत',
#   'जल्दी',
#   'किसी',
#   'भी',
#   'किस्म',
#   'की',
#   'शक्ति',
#   'से',
#   'वंचित',
#   'हो',
#   'जाते',
#   'हैं।',
#   'शायद',
#   'इसीलिये',
#   'बेचारे',
#   'मनमोहन',
#   'सोनिया',
#   'जी',
#   'के',
#   'सशक्तीकरण',
#   'के',
#   'चक्कर',
#   'में',
#   'शक्ति',
#   'से',
#   'वंचित',
#   'हो',
#   'गये',
#   '.'],
#  ['तुम',
#   'जब',
#   'नही',
#   'थे,',
#   'तब',
#   'भी',
#   'ये',
#   'कंपनी',
#   'चल',
#   'रही',
#   'थी,',
#   'तुम',
#   'जब',
#   'नहीं',
#   'होगे,',
#   'तब',
#   'भी',
#   'चलेगी,',
#   'तुम',
#   'कुछ',
#   'भी',
#   'अनुभव',
#   'लेकर',
#   'यहां',
#   'नहीं',
#   'आए',
#   'थे.',
#   'जो',
#   'अनुभव',
#   'मिला',
#   'यहीं',
#   'मिला.',
#   'जो',
#   'भी',
#   'काम',
#   'किया',
#   'वो',
#   'कंपनी',
#   'के',
#   'लिए',
#   'किया,',
#   'डिग़्री',
#   'लेकर',
#   'आए',
#   'थे,',
#   'अनुभव',
#   'लेकर',
#   'जाओगे.',
#   'क्या',
#   'रक्खा',
#   'है',
#   'प्रमोशन',
#   'और',
#   'वेतन',
#   'वृद्धि',
#   'में?'],
#  ['जो',
#   'कंप्यूटर',
#   'आज',
#   'तुम्हारा',
#   'है,',
#   'वह',
#   'कल',
#   'किसी',
#   'और',
#   'का',
#   'था.',
#   'कल',
#   'किसी',
#   'और',
#   'का',
#   'होगा',
#   'और',
#   'परसों',
#   'किसी',
#   'और',
#   'का',
#   'होगा.',
#   'तुम',
#   'इसे',
#   'अपना',
#   'समझ',
#   'कर',
#   'क्यों',
#   'मगन',
#   'हो',
#   '.यही',
#   'खुशी',
#   'तुम्हारी',
#   'समस्त',
#   'परेशानियों',
#   'का',
#   'मूल',
#   'कारण',
#   'है.'],
#  ['हिन्दुस्तान',
#   'का',
#   'रुपया',
#   'अमरीका',
#   'के',
#   'डालर',
#   'के',
#   'बराबर',
#   'हो',
#   'गया',
#   'और',
#   'अमरीका',
#   'ने',
#   'आइटी',
#   'का',
#   'अफरीका',
#   'के',
#   'एक',
#   'एसे',
#   'देश',
#   'को',
#   'दिया',
#   'जो',
#   'हिन्दुस्तान',
#   'से',
#   'सस्ता',
#   'है'],
#  ['इन्हीं',
#   'से',
#   'प्रकट',
#   'होंय',
#   'दंगा,',
#   'इन्हीं',
#   'से',
#   'होय',
#   'शांति-',
#   'भंगा,',
#   'कौन',
#   'फिर',
#   'इनसे',
#   'ले',
#   'पंगा,',
#   'क्रिमिनलों',
#   'संग-करें',
#   'हुडदंग-लोग',
#   'हैं',
#   'तंग.',
#   'ऐसे',
#   'हैं',
#   'खद्दरधारी',
#   'जी.'],
#  ['प्यास',
#   'के',
#   'मारे',
#   'हम',
#   'तरसें.',
#   'मगर',
#   'ये',
#   'कहीं',
#   'नहीं',
#   'दरसें.',
#   'चुनावी',
#   'मौसम',
#   'में',
#   'बरसें.',
#   'हमारे',
#   'बीच-ऊँच',
#   'प्लस',
#   'नीच-भाव',
#   'को',
#   'सींच.',
#   'प्यार',
#   'की',
#   'नदिया',
#   'खारी',
#   'की.',
#   'एसे',
#   'हैं',
#   'खद्दरधारी',
#   'जी.'],
#  ['न',
#   'कोई',
#   'काम',
#   'करें',
#   'सच्चा',
#   'दे.',
#   'रहे',
#   'पब्लिक',
#   'को',
#   'गच्चा.',
#   'ठगाई',
#   'में',
#   'सबके',
#   'चच्चा.',
#   'घोटालानंद-नित्य',
#   'छलछंद-करें',
#   'निर्द्वंद्व.',
#   'फ़िक्र',
#   'बस',
#   'कुर्सी',
#   'प्यारी',
#   'की-आरती',
#   'खद्दरधारी',
#   'की'],
#  ['अगर',
#   '"आज',
#   'तक"',
#   'थोड़ा',
#   'और',
#   'छूट',
#   'दे',
#   'तो',
#   'माहौल',
#   'से',
#   'लग',
#   'रहा',
#   'है',
#   'कि',
#   'अंजना',
#   'कश्यप',
#   'नलिनी',
#   'सिंह',
#   'की',
#   'बाल',
#   'खीच',
#   'लेगी।',
#   '#ExitPoll2019'],
#  ['अगर',
#   'आपके',
#   'टीवी',
#   'का',
#   'स्पीकर',
#   'काम',
#   'नही',
#   'कर',
#   'रहा',
#   'तो',
#   'परेशान',
#   'हों,',
#   'नोएडा',
#   'से',
#   'न्यूज़',
#   'एंकर्स',
#   'इतने',
#   'जोर',
#   'से',
#   'चिल्ला',
#   'रहे',
#   'हैं',
#   'कि',
#   'उनकी',
#   'आवाज़',
#   'पूरब',
#   'में',
#   'म्यंमार',
#   'और',
#   'पक्षिम',
#   'में',
#   'अफ़ग़ानिस्तान',
#   'तक',
#   'जा',
#   'रही',
#   'है'],
#  ['अगर',
#   'यूपी',
#   'में',
#   'कोर्ट',
#   'ना',
#   'होता',
#   'तो',
#   'ये',
#   'लोग',
#   'भर्ती',
#   'का',
#   'भर्ता',
#   'बनाते',
#   'और',
#   'आपस',
#   'में',
#   'बाट',
#   'कर',
#   'खा',
#   'जाते।',
#   'धन्य',
#   'हो',
#   'यूपी',
#   'लाल',
#   '#कटाक्ष'],
#  ['अब',
#   'तो',
#   'माल्या',
#   'से',
#   'भी',
#   'सारा',
#   'बकाया',
#   'तभी',
#   'वसूला',
#   'जा',
#   'सकता',
#   'है',
#   'अगर',
#   'किसी',
#   'दिन',
#   'वो',
#   'बिना',
#   'हेलमेट',
#   'के',
#   'एक्टिवा',
#   'चलाते',
#   'पकड़े',
#   'जाएं।'],
#  ['अब',
#   'समझा',
#   'आप',
#   'हकला',
#   'क्यों',
#   'रहे',
#   'थे।',
#   'बच्चे',
#   'नहीं',
#   'हकलाएँगे',
#   'तो',
#   'और',
#   'कौन',
#   'हकलाएगा',
#   '🙂',
#   '#कटाक्ष',
#   '#व्यंग'],
#  ['अरे',
#   'कौन',
#   'कहेता',
#   'है',
#   'कि',
#   'देश',
#   'का',
#   'Future',
#   'देश',
#   'के',
#   'युवा',
#   'है?और',
#   'अगर',
#   'है',
#   'तो',
#   'Bright',
#   'Future',
#   'किसको',
#   'चाहिए?',
#   'देश',
#   'का',
#   'Future',
#   'तो',
#   'वो',
#   'लोग',
#   'है,जो',
#   'Parliament',
#   'बंध',
#   'रखके',
#   'लोगोके',
#   'घर-घर',
#   'जाकर',
#   'उनकी',
#   'सेवामे',
#   'जूटे',
#   'है!',
#   'हमारा',
#   'देश',
#   'विकासशील',
#   'था',
#   'और',
#   'रहेगा',
#   'उसे',
#   'विकशीत',
#   'देश',
#   'की',
#   'यादी',
#   'मे',
#   'लानेकी',
#   'हमे',
#   'कोई',
#   'दिलचस्पी',
#   'नही',
#   'है',
#   '|',
#   '#कटाक्ष'],
#  ['एक',
#   'आदमी',
#   'ने',
#   'एक',
#   '"बाबा',
#   'की',
#   'खूब',
#   'सेवा',
#   'की',
#   'ओर',
#   'उनसे',
#   'आशीर्वाद',
#   'मांगा',
#   'हे',
#   'बाबा',
#   'मैं',
#   'चाहता',
#   'हूँ',
#   'कि',
#   'मेरी',
#   'मृत्यु',
#   'राहुल',
#   'गांधी',
#   'के',
#   'प्रधान.'],
#  ['कुछ',
#   'लोग',
#   'इस',
#   'बेशर्म',
#   'को',
#   'नोबेल',
#   'प्राइज',
#   'देने',
#   'की',
#   'मांग',
#   'कर',
#   'रहे',
#   'थे'],
#  ['कोरोना',
#   'काल',
#   'में',
#   'हर',
#   'धर्म',
#   'के',
#   'लोग',
#   'अल्ल्लाह,',
#   'भगवान,',
#   'गोड',
#   'और',
#   'अन्य',
#   'को',
#   'भुलाकर',
#   'विज्ञान',
#   'पर',
#   'निर्भर',
#   'है',
#   'आखिर',
#   'क्यों?'],
#  ...]

# %%
model = Word2Vec(text_tokens,min_count=1)

# %%
model.wv['विजय']
# Out:
# array([-3.1947424e-03,  1.2637663e-03,  1.1414490e-03,  1.0167346e-03,
#        -3.2160468e-03,  1.6654595e-03, -2.9433190e-03, -6.9486992e-03,
#         3.2800385e-03,  6.9001303e-03, -4.8899013e-03,  8.3384970e-03,
#        -2.6407582e-03, -7.0006303e-03,  4.3827780e-03,  5.2663921e-03,
#        -5.8943308e-03, -6.1862255e-03, -2.8082838e-03,  1.1207531e-03,
#         9.9610933e-04, -3.9948565e-03,  2.7633149e-03,  6.6171321e-03,
#        -1.7959710e-03,  5.5295671e-03, -2.3668821e-03,  7.5577605e-05,
#         5.6774579e-03,  2.5183684e-03,  2.0886494e-03,  3.6558567e-03,
#        -5.2414322e-03,  1.8852382e-03, -3.9763786e-03,  5.9568085e-04,
#         7.7188034e-03,  7.2309282e-04,  3.4699186e-03,  5.3301910e-03,
#         7.5613434e-04,  4.9680285e-03, -9.5546705e-04,  2.8121634e-03,
#         1.1875530e-04, -6.4635987e-04,  2.3557660e-03, -4.0687300e-05,
#         6.3179559e-03, -1.6262367e-03,  6.9505948e-04,  4.5903614e-03,
#         2.2631614e-03,  3.6386726e-03, -4.0331939e-03,  1.6566974e-03,
#        -3.6152392e-03, -3.7727368e-03,  4.0868875e-03,  1.6844266e-03,
#        -2.8381823e-03,  4.8173857e-03,  2.0167043e-03,  3.3651774e-03,
#         1.0590800e-03, -3.5558536e-03, -3.4387684e-03,  2.3282769e-04,
#         1.6294243e-03, -9.4863866e-04,  4.2809325e-04, -4.1754707e-03,
#        -3.2105914e-03, -8.5279904e-04,  6.8891153e-04, -1.4890268e-04,
#         2.6992895e-03,  8.4540830e-04,  1.5529088e-04,  5.1673502e-03,
#         1.6990443e-03,  4.2371923e-04, -7.7602040e-04,  1.0985375e-03,
#        -6.1775893e-03,  6.8285980e-04, -2.8410265e-03, -3.8781583e-03,
#         6.0046776e-03, -4.1157110e-03,  4.8516975e-03,  3.5646011e-03,
#        -1.4908686e-03,  3.2997085e-03,  1.8985904e-03,  2.3081161e-03,
#         1.8001324e-03,  7.9296331e-04,  2.3594121e-03,  1.3242541e-03],
#       dtype=float32)

# %%
model.wv.most_similar('विजय',topn=5)
# Out:
# [('कार्यकर्ता', 0.627685546875),
#  ('छोड़कर', 0.6266782283782959),
#  ('चोट', 0.6248048543930054),
#  ('था,', 0.6240571737289429),
#  ('लड़ी', 0.6214770674705505)]

# %%
import random
from sklearn.decomposition import PCA
random.seed(2)

# %%
X = model.wv[model.wv.vocab]

# %%
X
# Out:
# array([[ 6.0196524e-04,  4.2760456e-03, -9.1207642e-03, ...,
#          7.5612089e-04,  1.3350611e-02, -1.7352980e-03],
#        [-8.4604342e-03,  1.5758125e-02, -2.0744717e-02, ...,
#         -7.9523716e-03,  3.1386167e-02, -5.9656654e-03],
#        [-5.4161593e-02,  9.4372734e-02, -1.0751100e-01, ...,
#         -4.5915309e-02,  1.2884010e-01, -4.5054067e-02],
#        ...,
#        [-1.8584220e-03,  5.5603650e-03, -5.2499450e-03, ...,
#          2.0864862e-03,  8.4066745e-03,  2.1543785e-03],
#        [-5.2824011e-03,  5.5721579e-03, -2.0054127e-03, ...,
#          1.8081014e-03,  2.3879330e-03, -5.1123090e-05],
#        [-2.0760153e-03,  8.1831519e-04, -7.3563977e-04, ...,
#         -2.8423192e-03,  4.9065514e-03, -2.0591652e-03]], dtype=float32)

# %%
pca = PCA(n_components=2)
result = pca.fit_transform(X)

# %%
ind = random.sample(range(0,len(X)),100)
result_random = result[ind]
all_words = list(model.wv.vocab)
words = [all_words[i] for i in ind]

# %%
words
# Out:
# ['#पाकिस्तान',
#  'करें।',
#  'कामयाबी',
#  "'आज",
#  'चाहिए!',
#  'italy,',
#  '#HarHarMahadev',
#  '#ModiTrumpMeet',
#  'सीतारमण',
#  '1951',
#  'प्रतिबंधित!.',
#  'जाते।',
#  'कसम',
#  'पर...',
#  'ndtv',
#  '😝😅😂😆😃😝😅😂',
#  'Confidence',
#  'ड्यूटी',
#  'कुचल',
#  'मांगता',
#  'हाईकोर्ट',
#  'देखो.अस्पताल',
#  'मेहता',
#  'मुबारक',
#  '#CBIInvestigationForSushant',
#  'जिहादीनी,',
#  'लेने',
#  'इमरान',
#  'लोकल',
#  'रणनीति.',
#  "'व्हाट्सएप",
#  'पोल',
#  'रागा',
#  '😁💪💪',
#  '"बालक',
#  'शाख़',
#  'होंगे,',
#  'मुआवजे',
#  'डॉलर',
#  'राहु',
#  'राहत',
#  'दिखाए',
#  'रजवाड़े',
#  'मंत्रीमंडल',
#  '#राहुल',
#  'आश्रम',
#  'रचना?',
#  'खुलासा:',
#  '#धरना_भी',
#  'क्या?',
#  'नापता',
#  'किये।',
#  'उठाऊ',
#  'नहाने',
#  'धनी,',
#  'जैसे-',
#  'रखो.',
#  'लूं.?',
#  'स्वच्छ',
#  'माहिर',
#  'बख्शा',
#  'How',
#  'जयश्रीराम',
#  'माह',
#  'साइंटिस्ट',
#  'Bandh:',
#  'India',
#  'पटेल,बाजपेई,शास्त्रीजी',
#  'बना',
#  'अपूर्णीय',
#  'गए,बहुत',
#  'हिंद',
#  'आरोपियों',
#  'धंधे',
#  'ससुरा',
#  'हे',
#  'मानसिक',
#  'पड',
#  'क्या,',
#  'चाहिए.?',
#  'जैसा',
#  '#MarkazCorona',
#  'मुम्बई',
#  'यानी',
#  'चलवाईं.उधर',
#  'लिंक',
#  ':थोराट',
#  'तन-मन',
#  'काम',
#  'इतना',
#  'समता,समानता,मानवता',
#  '#HallaBol',
#  'उचित',
#  'विकलांगों',
#  'अभी',
#  'पाकों',
#  'उड़ाऊँ!!',
#  'MP',
#  'हार्दिक',
#  'तर्ज़']

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(12,12))
plt.scatter(result_random[:,0], result_random[:,1])
for i, word in enumerate(words):
    plt.annotate(word, xy=(result_random[i, 0], result_random[i, 1]))
plt.show()
# Out:
# D:\Users\admin\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 2346 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# D:\Users\admin\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 2366 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# D:\Users\admin\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 2325 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# D:\Users\admin\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 2367 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# D:\Users\admin\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 2360 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# D:\Users\admin\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 2381 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# D:\Users\admin\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 2340 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# D:\Users\admin\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 2344 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# D:\Users\admin\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 2346 missing from current font.
#   font.set_text(s, 0, flags=flags)
# D:\Users\admin\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 2366 missing from current font.
#   font.set_text(s, 0, flags=flags)
# D:\Users\admin\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 2325 missing from current font.
#   font.set_text(s, 0, flags=flags)
# D:\Users\admin\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 2367 missing from current font.
#   font.set_text(s, 0, flags=flags)
# D:\Users\admin\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 2360 missing from current font.
#   font.set_text(s, 0, flags=flags)
# D:\Users\admin\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 2381 missing from current font.
#   font.set_text(s, 0, flags=flags)
# D:\Users\admin\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 2340 missing from current font.
#   font.set_text(s, 0, flags=flags)
# D:\Users\admin\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 2344 missing from current font.
#   font.set_text(s, 0, flags=flags)
# D:\Users\admin\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 2352 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# D:\Users\admin\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 2375 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# D:\Users\admin\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 2306 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# D:\Users\admin\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 2404 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# D:\Users\admin\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 2352 missing from current font.
#   font.set_text(s, 0, flags=flags)
# D:\Users\admin\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 2375 missing from current font.
#   font.set_text(s, 0, flags=flags)
# D:\Users\admin\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 2306 missing from current font.
#   font.set_text(s, 0, flags=flags)
# D:\Users\admin\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 2404 missing from current font.
#   font.set_text(s, 0, flags=flags)
# D:\Users\admin\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 2350 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# D:\Users\admin\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 2351 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# D:\Users\admin\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 2348 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# D:\Users\admin\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 2368 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# D:\Users\admin\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 2350 missing from current font.
#   font.set_text(s, 0, flags=flags)
# D:\Users\admin\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 2351 missing from current font.
#   font.set_text(s, 0, flags=flags)
# D:\Users\admin\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 2348 missing from current font.
#   font.set_text(s, 0, flags=flags)
# D:\Users\admin\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 2368 missing from current font.
#   font.set_text(s, 0, flags=flags)
# D:\Users\admin\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 2310 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# D:\Users\admin\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 2332 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# D:\Users\admin\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 2310 missing from current font.
#   font.set_text(s, 0, flags=flags)
# D:\Users\admin\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 2332 missing from current font.
#   font.set_text(s, 0, flags=flags)
# D:\Users\admin\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 2330 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# D:\Users\admin\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 2361 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# D:\Users\admin\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 2319 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# D:\Users\admin\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 2330 missing from current font.
#   font.set_text(s, 0, flags=flags)
# D:\Users\admin\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 2361 missing from current font.
#   font.set_text(s, 0, flags=flags)
# D:\Users\admin\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 2319 missing from current font.
#   font.set_text(s, 0, flags=flags)
# D:\Users\admin\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 2339 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# D:\Users\admin\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 2339 missing from current font.
#   font.set_text(s, 0, flags=flags)
# D:\Users\admin\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 2343 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# D:\Users\admin\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 2343 missing from current font.
#   font.set_text(s, 0, flags=flags)
# D:\Users\admin\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 55357 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# D:\Users\admin\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 56861 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# D:\Users\admin\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 56837 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# D:\Users\admin\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 56834 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# D:\Users\admin\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 56838 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# D:\Users\admin\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 56835 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# D:\Users\admin\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 55357 missing from current font.
#   font.set_text(s, 0, flags=flags)
# D:\Users\admin\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 56861 missing from current font.
#   font.set_text(s, 0, flags=flags)
# D:\Users\admin\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 56837 missing from current font.
#   font.set_text(s, 0, flags=flags)
# D:\Users\admin\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 56834 missing from current font.
#   font.set_text(s, 0, flags=flags)
# D:\Users\admin\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 56838 missing from current font.
#   font.set_text(s, 0, flags=flags)
# D:\Users\admin\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 56835 missing from current font.
#   font.set_text(s, 0, flags=flags)
# D:\Users\admin\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 2337 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# D:\Users\admin\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 2370 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# D:\Users\admin\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 2335 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# D:\Users\admin\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 2337 missing from current font.
#   font.set_text(s, 0, flags=flags)
# D:\Users\admin\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 2370 missing from current font.
#   font.set_text(s, 0, flags=flags)
# D:\Users\admin\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 2335 missing from current font.
#   font.set_text(s, 0, flags=flags)
# D:\Users\admin\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 2369 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# D:\Users\admin\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 2354 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# D:\Users\admin\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 2369 missing from current font.
#   font.set_text(s, 0, flags=flags)
# D:\Users\admin\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 2354 missing from current font.
#   font.set_text(s, 0, flags=flags)
# D:\Users\admin\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 2327 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# D:\Users\admin\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 2327 missing from current font.
#   font.set_text(s, 0, flags=flags)
# D:\Users\admin\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 2312 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# D:\Users\admin\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 2379 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# D:\Users\admin\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 2312 missing from current font.
#   font.set_text(s, 0, flags=flags)
# D:\Users\admin\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 2379 missing from current font.
#   font.set_text(s, 0, flags=flags)
# D:\Users\admin\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 2342 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# D:\Users\admin\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 2326 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# D:\Users\admin\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 2309 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# D:\Users\admin\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 2342 missing from current font.
#   font.set_text(s, 0, flags=flags)
# D:\Users\admin\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 2326 missing from current font.
#   font.set_text(s, 0, flags=flags)
# D:\Users\admin\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 2309 missing from current font.
#   font.set_text(s, 0, flags=flags)
# D:\Users\admin\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 2311 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# D:\Users\admin\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 2311 missing from current font.
#   font.set_text(s, 0, flags=flags)
# D:\Users\admin\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 2357 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# D:\Users\admin\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 
# [['Seven', 'continent', 'planet'], ['Five', 'ocean', 'planet'], ['Asia', 'largest', 'continent'], ['Pacific', 'Ocean', 'largest'], ['Ocean', 'saline', 'water']]

# %%
transformer = TfidfVectorizer()
tfidf = transformer.fit_transform(TextCorpus)

# %%
print(tfidf)
# Out:
#   (0, 8)	0.6591180018251055
#   (0, 1)	0.5317722537280788
#   (0, 6)	0.5317722537280788
#   (1, 6)	0.5568161504458247
#   (1, 2)	0.6901592662889633
#   (1, 4)	0.46220770413113277
#   (2, 1)	0.5317722537280788
#   (2, 0)	0.6591180018251055
#   (2, 3)	0.5317722537280788
#   (3, 4)	0.46220770413113277
#   (3, 3)	0.5568161504458247
#   (3, 5)	0.6901592662889633
#   (4, 4)	0.42799292268317357
#   (4, 7)	0.6390704413963749
#   (4, 9)	0.6390704413963749

# %%
transformer = TfidfVectorizer()
tfidf = transformer.fit_transform(sentences)

# %%
print(tfidf)
# Out:
#   (0, 476)	0.669457249811482
#   (0, 1287)	0.6858739926529694
#   (0, 1679)	0.2853136114473362
#   (1, 212)	0.33592081307590166
#   (1, 968)	0.31263044425737435
#   (1, 1063)	0.3605777920493781
#   (1, 1901)	0.32830944301629134
#   (1, 987)	0.14017584773887384
#   (1, 1702)	0.43379329574441555
#   (1, 1371)	0.1531404670096233
#   (1, 1842)	0.25581361153849136
#   (1, 1472)	0.2193496961112681
#   (1, 706)	0.3215456350057318
#   (1, 970)	0.3215456350057318
#   (2, 1371)	0.1278158191582227
#   (2, 1596)	0.2803700075754274
#   (2, 1574)	0.2803700075754274
#   (2, 952)	0.12798360527948463
#   (2, 750)	0.1941536261961333
#   (2, 1001)	0.5218622759462314
#   (2, 1446)	0.22691711462307218
#   (2, 745)	0.26576863049698596
#   (2, 737)	0.2916957155265457
#   (2, 381)	0.3826369251093989
#   (2, 396)	0.3826369251093989
#   :	:
#   (1379, 1869)	0.5451996511810888
#   (1379, 1324)	0.41568591139712546
#   (1380, 987)	0.11833631991655601
#   (1380, 1371)	0.12928103941258295
#   (1380, 1406)	0.2585620788251659
#   (1380, 1061)	0.23072637263585832
#   (1380, 1562)	0.42146476988887305
#   (1380, 1342)	0.2995064884744197
#   (1380, 816)	0.24157436654554212
#   (1380, 1874)	0.23072637263585832
#   (1380, 1254)	0.20675077090583333
#   (1380, 803)	0.22833817041735607
#   (1380, 1192)	0.25735973617776486
#   (1380, 804)	0.2639223294458879
#   (1380, 857)	0.2995064884744197
#   (1380, 1047)	0.3870232943118087
#   (1381, 1679)	0.3752332238949265
#   (1381, 987)	0.1614273668437936
#   (1381, 952)	0.1765890096503211
#   (1381, 1165)	0.3099115497511913
#   (1381, 1164)	0.2568500598013132
#   (1381, 1552)	0.32553851655142513
#   (1381, 1779)	0.3632849823255207
#   (1381, 1192)	0.3510748396780049
#   (1381, 626)	0.5279541509489263

# %%
sentences[1381]
# Out:
# 'दिल्ली वालों तुम्हें बिजली पानी मुफ़्त में देकर शराब, डीज़ल और पेट्रोल से पेल रहा हूँ फोन मत काटना मैं केजरीवाल बोल रहा हूँ ! #viasms'

# %%
from sklearn.decomposition import TruncatedSVD
svd = TruncatedSVD(n_components = 3)
lsa = svd.fit_transform(tfidf)

# %%
lsa
# Out:
# array([[ 0.08779335, -0.04113968,  0.18628211],
#        [ 0.17487715, -0.03315366, -0.08049556],
#        [ 0.13555238,  0.08672726, -0.04690367],
#        ...,
#        [ 0.19714189, -0.16924302, -0.06730953],
#        [ 0.26407956,  0.02348455,  0.00568857],
#        [ 0.30215152, -0.18219476,  0.17302947]])

# %% [markdown]
# # BERT

# %%
# !pip install transformers
# Out:
# Collecting transformers
#   Downloading transformers-3.0.2-py3-none-any.whl (769 kB)
# Collecting tokenizers==0.8.1.rc1
#   Downloading tokenizers-0.8.1rc1-cp37-cp37m-win_amd64.whl (1.9 MB)
# Collecting sacremoses
#   Downloading sacremoses-0.0.43.tar.gz (883 kB)
# Requirement already satisfied: requests in d:\users\admin\anaconda3\lib\site-packages (from transformers) (2.21.0)
# Requirement already satisfied: numpy in c:\users\admin\appdata\roaming\python\python37\site-packages (from transformers) (1.17.4)
# Requirement already satisfied: filelock in d:\users\admin\anaconda3\lib\site-packages (from transformers) (3.0.10)
# Requirement already satisfied: sentencepiece!=0.1.92 in d:\users\admin\anaconda3\lib\site-packages (from transformers) (0.1.85)
# Requirement already satisfied: regex!=2019.12.17 in d:\users\admin\anaconda3\lib\site-packages (from transformers) (2019.12.9)
# Requirement already satisfied: packaging in d:\users\admin\anaconda3\lib\site-packages (from transformers) (18.0)
# Requirement already satisfied: tqdm>=4.27 in d:\users\admin\anaconda3\lib\site-packages (from transformers) (4.28.1)
# Requirement already satisfied: six in d:\users\admin\anaconda3\lib\site-packages (from sacremoses->transformers) (1.12.0)
# Requirement already satisfied: click in d:\users\admin\anaconda3\lib\site-packages (from sacremoses->transformers) (6.7)
# Requirement already satisfied: joblib in d:\users\admin\anaconda3\lib\site-packages (from sacremoses->transformers) (0.14.0)
# Requirement already satisfied: certifi>=2017.4.17 in d:\users\admin\anaconda3\lib\site-packages (from requests->transformers) (2020.6.20)
# Requirement already satisfied: idna<2.9,>=2.5 in d:\users\admin\anaconda3\lib\site-packages (from requests->transformers) (2.8)
# Requirement already satisfied: urllib3<1.25,>=1.21.1 in d:\users\admin\anaconda3\lib\site-packages (from requests->transformers) (1.24.1)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in d:\users\admin\anaconda3\lib\site-packages (from requests->transformers) (3.0.4)
# Requirement already satisfied: pyparsing>=2.0.2 in d:\users\admin\anaconda3\lib\site-packages (from packaging->transformers) (2.3.0)
# Building wheels for collected packages: sacremoses
#   Building wheel for sacremoses (setup.py): started
#   Building wheel for sacremoses (setup.py): finished with status 'done'
#   Created wheel for sacremoses: filename=sacremoses-0.0.43-py3-none-any.whl size=893262 sha256=63fda56ed979db16b2aebe879f7a59ad407fd1593fb39563ba5442bb30feb2ba
#   Stored in directory: c:\users\admin\appdata\local\pip\cache\wheels\69\09\d1\bf058f7d6fa0ecba2ce7c66be3b8d012beb4bf61a6e0c101c0
# Successfully built sacremoses
# Installing collected packages: tokenizers, sacremoses, transformers
# Successfully installed sacremoses-0.0.43 tokenizers-0.8.1rc1 transformers-3.0.2

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import cross_val_score

import torch
import transformers as ppb
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('https://github.com/clairett/pytorch-sentiment-classification/raw/master/data/SST2/train.tsv', delimiter='\t', header=None)

# %%
df
# Out:
#                                                       0  1
# 0     a stirring , funny and finally transporting re...  1
# 1     apparently reassembled from the cutting room f...  0
# 2     they presume their audience wo n't sit still f...  0
# 3     this is a visually stunning rumination on love...  1
# 4     jonathan parker 's bartleby should have been t...  1
# ...                                                 ... ..
# 6915  painful , horrifying and oppressively tragic ,...  1
# 6916  take care is nicely performed by a quintet of ...  0
# 6917  the script covers huge , heavy topics in a bla...  0
# 6918  a seriously bad film with seriously warped log...  0
# 6919  a deliciously nonsensical comedy about a city ...  1
#
# [6920 rows x 2 columns]

# %%
batch_1= df[:2000]

# %%
batch_1[1].value_counts()
# Out:
# 1    1041
# 0     959
# Name: 1, dtype: int64

# %% [markdown]
# ### Pretrained-BERT

# %%
# for distillBERT
model_class, tokenizer_class, pretrained_weights = (ppb.DistilBertModel, ppb.DistilBertTokenizer, 'distilbert-base-uncased')


# for BERT
#model_class, tokenizer_class, pretrained_weights = (ppb.BertModel, ppb.BertTokenizer, 'bert-base-uncased')

#load pretrained , model/tokenizer
tokenizer = tokenizer_class.from_pretrained(pretrained_weights)
model = model_class.from_pretrained(pretrained_weights)
# Out:
# HBox(children=(IntProgress(value=0, description='Downloading', max=231508, style=ProgressStyle(description_wid…
# HBox(children=(IntProgress(value=0, description='Downloading', max=442, style=ProgressStyle(description_width=…
# HBox(children=(IntProgress(value=0, description='Downloading', max=267967963, style=ProgressStyle(description_…

# %%
# tokenization
tokenized = batch_1[0].apply((lambda x: tokenizer.encode(x, add_special_tokens=True)))

# %%
#padding
max_len = 0
for i in tokenized.values:
    if len(i)>max_len:
        max_len = len(i)
        
padded = np.array([i + [0]*(max_len - len(i)) for i in tokenized.values])

# %%
np.array(padded).shape
# Out:
# (2000, 59)

# %%
# masking
attention_mask = np.where(padded != 0, 1,0)
attention_mask.shape
# Out:
# (2000, 59)

# %%
input_ids = torch.tensor(padded)

attention_mask = torch.tensor(attention_mask)

with torch.no_grad():
    last_hidden_states = model(input_ids, attention_mask=attention_mask)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-49-987ce1ddc865> in <module>
#       4
#       5 with torch.no_grad():
# ----> 6     last_hidden_states = model(input_ids, attention_mask=attention_mask)
#
# D:\Users\admin\Anaconda3\lib\site-packages\torch\nn\modules\module.py in __call__(self, *input, **kwargs)
#     539             result = self._slow_forward(*input, **kwargs)
#     540         else:
# --> 541             result = self.forward(*input, **kwargs)
#     542         for hook in self._forward_hooks.values():
#     543             hook_result = hook(self, input, result)
#
# D:\Users\admin\Anaconda3\lib\site-packages\transformers\modeling_distilbert.py in forward(self, input_ids, attention_mask, head_mask, inputs_embeds, output_attentions, output_hidden_states)
#     461
#     462         if inputs_embeds is None:
# --> 463             inputs_embeds = self.embeddings(input_ids)  # (bs, seq_length, dim)
#     464         tfmr_output = self.transformer(
#     465             x=inputs_embeds,
#
# D:\Users\admin\Anaconda3\lib\site-packages\torch\nn\modules\module.py in __call__(self, *input, **kwargs)
#     539             result = self._slow_forward(*input, **kwargs)
#     540         else:
# --> 541             result = self.forward(*input, **kwargs)
#     542         for hook in self._forward_hooks.values():
#     543             hook_result = hook(self, input, result)
#
# D:\Users\admin\Anaconda3\lib\site-packages\transformers\modeling_distilbert.py in forward(self, input_ids)
#      91         position_ids = position_ids.unsqueeze(0).expand_as(input_ids)  # (bs, max_seq_length)
#      92
# ---> 93         word_embeddings = self.word_embeddings(input_ids)  # (bs, max_seq_length, dim)
#      94         position_embeddings = self.position_embeddings(position_ids)  # (bs, max_seq_length, dim)
#      95
#
# D:\Users\admin\Anaconda3\lib\site-packages\torch\nn\modules\module.py in __call__(self, *input, **kwargs)
#     539             result = self._slow_forward(*input, **kwargs)
#     540         else:
# --> 541             result = self.forward(*input, **kwargs)
#     542         for hook in self._forward_hooks.values():
#     543             hook_result = hook(self, input, result)
#
# D:\Users\admin\Anaconda3\lib\site-packages\torch\nn\modules\sparse.py in forward(self, input)
#     112         return F.embedding(
#     113             input, self.weight, self.padding_idx, self.max_norm,
# --> 114             self.norm_type, self.scale_grad_by_freq, self.sparse)
#     115
#     116     def extra_repr(self):
#
# D:\Users\admin\Anaconda3\lib\site-packages\torch\nn\functional.py in embedding(input, weight, padding_idx, max_norm, norm_type, scale_grad_by_freq, sparse)
#    1482         # remove once script supports set_grad_enabled
#    1483         _no_grad_embedding_renorm_(weight, input, max_norm, norm_type)
# -> 1484     return torch.embedding(weight, input, padding_idx, scale_grad_by_freq, sparse)
#    1485
#    1486
#
# RuntimeError: Expected tensor for argument #1 'indices' to have scalar type Long; but got torch.IntTensor instead (while checking arguments for embedding)

# %%
# train test split
train_features, test_features, train_labels, test_labels = train_test_split(features, labels)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-50-3e1a5aeaf730> in <module>
#       1 # train test split
# ----> 2 train_features, test_features, train_labels, test_labels = train_test_split(features, labels)
#
# NameError: name 'features' is not defined

# %%
lr_clf = LogisticRegression()
lr_clf.fit(train_features, train_labels)

# %%
lr_clf.score(test_features, test_labels)

# %%
from sklearn.dummy import DummyClassifier
clf = DummyClassifier()

scores = cross_val_score(clf, train_features, train_labels)
print("Dummy classifier score: %0.3f (+/- %0.2f)" % (scores.mean(), scores.std() * 2))

# %% [markdown]
# # LaBSE
# Language-agnostic BERT sentence embedding model supporting 109 languages.
# https://tfhub.dev/google/LaBSE/1

# %%
# !pip install tensorflow_hub
# Out:
# Collecting tensorflow_hub
#   Downloading tensorflow_hub-0.8.0-py2.py3-none-any.whl (101 kB)
# Requirement already satisfied: six>=1.12.0 in d:\users\admin\anaconda3\lib\site-packages (from tensorflow_hub) (1.12.0)
# Requirement already satisfied: protobuf>=3.8.0 in d:\users\admin\anaconda3\lib\site-packages (from tensorflow_hub) (3.11.1)
# Requirement already satisfied: numpy>=1.12.0 in c:\users\admin\appdata\roaming\python\python37\site-packages (from tensorflow_hub) (1.17.4)
# Requirement already satisfied: setuptools in d:\users\admin\anaconda3\lib\site-packages (from protobuf>=3.8.0->tensorflow_hub) (42.0.2)
# Installing collected packages: tensorflow-hub
# Successfully installed tensorflow-hub-0.8.0

# %%
import numpy as np
import tensorflow as tf
import tensorflow_hub as hub

def get_model(model_url, max_seq_length):
  labse_layer = hub.KerasLayer(model_url, trainable=True)

  # Define input.
  input_word_ids = tf.keras.layers.Input(shape=(max_seq_length,), dtype=tf.int32,
                                         name="input_word_ids")
  input_mask = tf.keras.layers.Input(shape=(max_seq_length,), dtype=tf.int32,
                                     name="input_mask")
  segment_ids = tf.keras.layers.Input(shape=(max_seq_length,), dtype=tf.int32,
                                      name="segment_ids")

  # LaBSE layer.
  pooled_output,  _ = labse_layer([input_word_ids, input_mask, segment_ids])

  # The embedding is l2 normalized.
  pooled_output = tf.keras.layers.Lambda(lambda x: tf.nn.l2_normalize(x))(pooled_output)

  # Define model.
  return tf.keras.Model(
        inputs=[input_word_ids, input_mask, segment_ids],
        outputs=pooled_output), labse_layer

max_seq_length = 64
labse_model, labse_layer = get_model(
    model_url="https://tfhub.dev/google/LaBSE/1", max_seq_length=max_seq_length)
# Out:
# INFO:absl:Using C:\Users\admin\AppData\Local\Temp\tfhub_modules to cache modules.
# INFO:absl:Downloading TF-Hub Module 'https://tfhub.dev/google/LaBSE/1'.
# INFO:absl:Downloading https://tfhub.dev/google/LaBSE/1: 4.98MB
# INFO:absl:Downloading https://tfhub.dev/google/LaBSE/1: 14.98MB
# INFO:absl:Downloading https://tfhub.dev/google/LaBSE/1: 34.98MB
# INFO:absl:Downloading https://tfhub.dev/google/LaBSE/1: 44.98MB
# INFO:absl:Downloading https://tfhub.dev/google/LaBSE/1: 64.98MB
# INFO:absl:Downloading https://tfhub.dev/google/LaBSE/1: 84.98MB
# INFO:absl:Downloading https://tfhub.dev/google/LaBSE/1: 104.98MB
# INFO:absl:Downloading https://tfhub.dev/google/LaBSE/1: 124.98MB
# INFO:absl:Downloading https://tfhub.dev/google/LaBSE/1: 144.98MB
# INFO:absl:Downloading https://tfhub.dev/google/LaBSE/1: 164.98MB
# INFO:absl:Downloading https://tfhub.dev/google/LaBSE/1: 184.98MB
# INFO:absl:Downloading https://tfhub.dev/google/LaBSE/1: 194.98MB
# INFO:absl:Downloading https://tfhub.dev/google/LaBSE/1: 204.98MB
# INFO:absl:Downloading https://tfhub.dev/google/LaBSE/1: 214.98MB
# INFO:absl:Downloading https://tfhub.dev/google/LaBSE/1: 224.98MB
# INFO:absl:Downloading https://tfhub.dev/google/LaBSE/1: 244.98MB
# INFO:absl:Downloading https://tfhub.dev/google/LaBSE/1: 254.98MB
# INFO:absl:Downloading https://tfhub.dev/google/LaBSE/1: 264.98MB
# INFO:absl:Downloading https://tfhub.dev/google/LaBSE/1: 284.98MB
# INFO:absl:Downloading https://tfhub.dev/google/LaBSE/1: 294.98MB
# INFO:absl:Downloading https://tfhub.dev/google/LaBSE/1: 314.98MB
# INFO:absl:Downloading https://tfhub.dev/google/LaBSE/1: 324.98MB
# INFO:absl:Downloading https://tfhub.dev/google/LaBSE/1: 334.98MB
# INFO:absl:Downloading https://tfhub.dev/google/LaBSE/1: 344.98MB
# INFO:absl:Downloading https://tfhub.dev/google/LaBSE/1: 354.98MB
# INFO:absl:Downloading https://tfhub.dev/google/LaBSE/1: 364.98MB
# INFO:absl:Downloading https://tfhub.dev/google/LaBSE/1: 374.98MB
# INFO:absl:Downloading https://tfhub.dev/google/LaBSE/1: 394.98MB
# INFO:absl:Downloading https://tfhub.dev/google/LaBSE/1: 404.98MB
# INFO:absl:Downloading https://tfhub.dev/google/LaBSE/1: 414.98MB
# INFO:absl:Downloading https://tfhub.dev/google/LaBSE/1: 424.98MB
# INFO:absl:Downloading https://tfhub.dev/google/LaBSE/1: 434.98MB
# INFO:absl:Downloading https://tfhub.dev/google/LaBSE/1: 444.98MB
# INFO:absl:Downloading https://tfhub.dev/google/LaBSE/1: 464.98MB
# INFO:absl:Downloading https://tfhub.dev/google/LaBSE/1: 474.98MB
# INFO:absl:Downloading https://tfhub.dev/google/LaBSE/1: 484.98MB
# INFO:absl:Downloading https://tfhub.dev/google/LaBSE/1: 494.98MB
# INFO:absl:Downloading https://tfhub.dev/google/LaBSE/1: 504.98MB
# INFO:absl:Downloading https://tfhub.dev/google/LaBSE/1: 514.98MB
# INFO:absl:Downloading https://tfhub.dev/google/LaBSE/1: 524.98MB
# INFO:absl:Downloading https://tfhub.dev/google/LaBSE/1: 544.98MB
# INFO:absl:Downloading https://tfhub.dev/google/LaBSE/1: 554.98MB
# INFO:absl:Downloading https://tfhub.dev/google/LaBSE/1: 574.98MB
# INFO:absl:Downloading https://tfhub.dev/google/LaBSE/1: 584.98MB
# INFO:absl:Downloading https://tfhub.dev/google/LaBSE/1: 604.98MB
# INFO:absl:Downloading https://tfhub.dev/google/LaBSE/1: 624.98MB
# INFO:absl:Downloading https://tfhub.dev/google/LaBSE/1: 634.98MB
# INFO:absl:Downloading https://tfhub.dev/google/LaBSE/1: 644.98MB
# INFO:absl:Downloading https://tfhub.dev/google/LaBSE/1: 664.98MB
# INFO:absl:Downloading https://tfhub.dev/google/LaBSE/1: 674.98MB
# INFO:absl:Downloading https://tfhub.dev/google/LaBSE/1: 684.98MB
# INFO:absl:Downloading https://tfhub.dev/google/LaBSE/1: 694.98MB
# INFO:absl:Downloading https://tfhub.dev/google/LaBSE/1: 704.98MB
# INFO:absl:Downloading https://tfhub.dev/google/LaBSE/1: 714.98MB
# INFO:absl:Downloading https://tfhub.dev/google/LaBSE/1: 724.98MB
# INFO:absl:Downloading https://tfhub.dev/google/LaBSE/1: 734.98MB
# INFO:absl:Downloading https://tfhub.dev/google/LaBSE/1: 744.98MB
# INFO:absl:Downloading https://tfhub.dev/google/LaBSE/1: 754.98MB
# INFO:absl:Downloading https://tfhub.dev/google/LaBSE/1: 764.98MB
# INFO:absl:Downloading https://tfhub.dev/google/LaBSE/1: 774.98MB
# INFO:absl:Downloading https://tfhub.dev/google/LaBSE/1: 784.98MB
# INFO:absl:Downloading https://tfhub.dev/google/LaBSE/1: 794.98MB
# INFO:absl:Downloading https://tfhub.dev/google/LaBSE/1: 804.98MB
# INFO:absl:Downloading https://tfhub.dev/google/LaBSE/1: 814.98MB
# INFO:absl:Downloading https://tfhub.dev/google/LaBSE/1: 824.98MB
# INFO:absl:Downloading https://tfhub.dev/google/LaBSE/1: 834.98MB
# INFO:absl:Downloading https://tfhub.dev/google/LaBSE/1: 844.98MB
# INFO:absl:Downloading https://tfhub.dev/google/LaBSE/1: 854.98MB
# INFO:absl:Downloading https://tfhub.dev/google/LaBSE/1: 864.98MB
# INFO:absl:Downloading https://tfhub.dev/google/LaBSE/1: 874.98MB
# INFO:absl:Downloading https://tfhub.dev/google/LaBSE/1: 894.98MB
# INFO:absl:Downloading https://tfhub.dev/google/LaBSE/1: 914.98MB
# INFO:absl:Downloading https://tfhub.dev/google/LaBSE/1: 934.98MB
# INFO:absl:Downloading https://tfhub.dev/google/LaBSE/1: 944.98MB
# INFO:absl:Downloading https://tfhub.dev/google/LaBSE/1: 964.98MB
# INFO:absl:Downloading https://tfhub.dev/google/LaBSE/1: 974.98MB
# INFO:absl:Downloading https://tfhub.dev/google/LaBSE/1: 984.98MB
# INFO:absl:Downloading https://tfhub.dev/google/LaBSE/1: 994.98MB
# INFO:absl:Downloading https://tfhub.dev/google/LaBSE/1: 1004.98MB
# INFO:absl:Downloading https://tfhub.dev/google/LaBSE/1: 1014.98MB
# INFO:absl:Downloading https://tfhub.dev/google/LaBSE/1: 1.00GB
# INFO:absl:Downloading https://tfhub.dev/google/LaBSE/1: 1.01GB
# INFO:absl:Downloading https://tfhub.dev/google/LaBSE/1: 1.02GB
# INFO:absl:Downloading https://tfhub.dev/google/LaBSE/1: 1.03GB
# INFO:absl:Downloading https://tfhub.dev/google/LaBSE/1: 1.04GB
# INFO:absl:Downloading https://tfhub.dev/google/LaBSE/1: 1.05GB
# INFO:absl:Downloading https://tfhub.dev/google/LaBSE/1: 1.06GB
# INFO:absl:Downloading https://tfhub.dev/google/LaBSE/1: 1.08GB
# INFO:absl:Downloading https://tfhub.dev/google/LaBSE/1: 1.09GB
# INFO:absl:Downloading https://tfhub.dev/google/LaBSE/1: 1.10GB
# INFO:absl:Downloading https://tfhub.dev/google/LaBSE/1: 1.11GB
# INFO:absl:Downloading https://tfhub.dev/google/LaBSE/1: 1.12GB
# INFO:absl:Downloading https://tfhub.dev/google/LaBSE/1: 1.13GB
# INFO:absl:Downloading https://tfhub.dev/google/LaBSE/1: 1.14GB
# INFO:absl:Downloading https://tfhub.dev/google/LaBSE/1: 1.15GB
# INFO:absl:Downloading https://tfhub.dev/google/LaBSE/1: 1.16GB
# INFO:absl:Downloading https://tfhub.dev/google/LaBSE/1: 1.17GB
# INFO:absl:Downloading https://tfhub.dev/google/LaBSE/1: 1.19GB
# INFO:absl:Downloading https://tfhub.dev/google/LaBSE/1: 1.20GB
# INFO:absl:Downloading https://tfhub.dev/google/LaBSE/1: 1.21GB
# INFO:absl:Downloading https://tfhub.dev/google/LaBSE/1: 1.23GB
# INFO:absl:Downloading https://tfhub.dev/google/LaBSE/1: 1.24GB
# INFO:absl:Downloading https://tfhub.dev/google/LaBSE/1: 1.25GB
# INFO:absl:Downloading https://tfhub.dev/google/LaBSE/1: 1.26GB
# INFO:absl:Downloading https://tfhub.dev/google/LaBSE/1: 1.27GB
# INFO:absl:Downloading https://tfhub.dev/google/LaBSE/1: 1.28GB
# INFO:absl:Downloading https://tfhub.dev/google/LaBSE/1: 1.30GB
# INFO:absl:Downloading https://tfhub.dev/google/LaBSE/1: 1.32GB
# INFO:absl:Downloading https://tfhub.dev/google/LaBSE/1: 1.33GB
# INFO:absl:Downloading https://tfhub.dev/google/LaBSE/1: 1.34GB
# INFO:absl:Downloading https://tfhub.dev/google/LaBSE/1: 1.35GB
# INFO:absl:Downloading https://tfhub.dev/google/LaBSE/1: 1.36GB
# INFO:absl:Downloading https://tfhub.dev/google/LaBSE/1: 1.37GB
# INFO:absl:Downloading https://tfhub.dev/google/LaBSE/1: 1.38GB
# INFO:absl:Downloading https://tfhub.dev/google/LaBSE/1: 1.40GB
# INFO:absl:Downloading https://tfhub.dev/google/LaBSE/1: 1.41GB
# INFO:absl:Downloading https://tfhub.dev/google/LaBSE/1: 1.42GB
# INFO:absl:Downloading https://tfhub.dev/google/LaBSE/1: 1.43GB
# INFO:absl:Downloading https://tfhub.dev/google/LaBSE/1: 1.44GB
# INFO:absl:Downloading https://tfhub.dev/google/LaBSE/1: 1.45GB
# INFO:absl:Downloading https://tfhub.dev/google/LaBSE/1: 1.47GB
# INFO:absl:Downloading https://tfhub.dev/google/LaBSE/1: 1.48GB
# INFO:absl:Downloading https://tfhub.dev/google/LaBSE/1: 1.49GB
# INFO:absl:Downloading https://tfhub.dev/google/LaBSE/1: 1.50GB
# INFO:absl:Downloading https://tfhub.dev/google/LaBSE/1: 1.53GB
# INFO:absl:Downloading https://tfhub.dev/google/LaBSE/1: 1.55GB
# INFO:absl:Downloading https://tfhub.dev/google/LaBSE/1: 1.56GB
# INFO:absl:Downloading https://tfhub.dev/google/LaBSE/1: 1.57GB
# INFO:absl:Downloading https://tfhub.dev/google/LaBSE/1: 1.58GB
# INFO:absl:Downloading https://tfhub.dev/google/LaBSE/1: 1.60GB
# INFO:absl:Downloading https://tfhub.dev/google/LaBSE/1: 1.62GB
# INFO:absl:Downloading https://tfhub.dev/google/LaBSE/1: 1.64GB
# INFO:absl:Downloading https://tfhub.dev/google/LaBSE/1: 1.66GB
# INFO:absl:Downloading https://tfhub.dev/google/LaBSE/1: 1.68GB
# INFO:absl:Downloading https://tfhub.dev/google/LaBSE/1: 1.71GB
# INFO:absl:Downloading https://tfhub.dev/google/LaBSE/1: 1.73GB
# INFO:absl:Downloading https://tfhub.dev/google/LaBSE/1: 1.74GB
# INFO:absl:Downloading https://tfhub.dev/google/LaBSE/1: 1.75GB
# INFO:absl:Downloading https://tfhub.dev/google/LaBSE/1: 1.76GB
# INFO:absl:Downloaded https://tfhub.dev/google/LaBSE/1, Total size: 1.76GB
# INFO:absl:Downloaded TF-Hub Module 'https://tfhub.dev/google/LaBSE/1'.

# %%
labse_layer.trainable_weights
# Out:
# [<tf.Variable 'word_embeddings/embeddings:0' shape=(501153, 768) dtype=float32, numpy=
#  array([[ 0.1450539 ,  0.1004533 ,  0.32873732, ..., -0.02519294,
#          -0.25684324, -0.13764848],
#         [ 0.17883968,  0.09033906,  0.05298597, ..., -0.10745545,
#          -0.02190481,  0.1581681 ],
#         [ 0.06838818,  0.15970434,  0.02646791, ..., -0.08131849,
#          -0.00097793, -0.07945561],
#         ...,
#         [-0.01236441, -0.00905201, -0.08602996, ...,  0.1805602 ,
#          -0.09508027, -0.1964608 ],
#         [ 0.14766602, -0.07067809, -0.13616177, ...,  0.24741043,
#           0.05352141,  0.08631153],
#         [ 0.21324238,  0.19581641, -0.2679865 , ..., -0.07359634,
#          -0.19162585,  0.02319536]], dtype=float32)>,
#  <tf.Variable 'position_embedding/embeddings:0' shape=(512, 768) dtype=float32, numpy=
#  array([[-0.07474913, -0.00326191, -0.02836927, ...,  0.03472469,
#          -0.009886  , -0.04295505],
#         [-0.02356442,  0.02619372, -0.01268659, ...,  0.01480523,
#           0.01421093,  0.00793992],
#         [-0.01903036,  0.01165782, -0.02328596, ..., -0.04190445,
#           0.00850102,  0.00500658],
#         ...,
#         [-0.02037198, -0.0185785 ,  0.00208779, ..., -0.04012084,
#           0.01391856,  0.00668859],
#         [-0.04159646, -0.03631347,  0.01659288, ...,  0.05731035,
#           0.01900014, -0.01761516],
#         [-0.078742  ,  0.06613262, -0.07993769, ...,  0.0088903 ,
#          -0.14165926,  0.02304826]], dtype=float32)>,
#  <tf.Variable 'type_embeddings/embeddings:0' shape=(2, 768) dtype=float32, numpy=
#  array([[-0.04954204,  0.0039415 , -0.02377121, ..., -0.00632126,
#           0.02696976,  0.00428086],
#         [-0.04372664,  0.01311462, -0.03351942, ..., -0.00360414,
#           0.03079298, -0.00126711]], dtype=float32)>,
#  <tf.Variable 'embeddings/layer_norm/gamma:0' shape=(768,) dtype=float32, numpy=
#  array([0.52777404, 0.5795102 , 0.62074715, 0.5110927 , 0.58703965,
#         0.594628  , 0.5546646 , 0.12152728, 0.5389122 , 0.5410818 ,
#         0.5737312 , 0.55650353, 0.54059726, 0.5827837 , 0.5664801 ,
#         0.58042455, 0.46356827, 0.6061725 , 0.5859871 , 0.5546764 ,
#         0.5540701 , 0.5193629 , 0.13152532, 0.55240893, 0.53728855,
#         0.5701935 , 0.10570752, 0.5740154 , 0.6006805 , 0.50991595,
#         0.5525154 , 0.52114236, 0.53140754, 0.565093  , 0.5317087 ,
#         0.12602203, 0.5576522 , 0.59482205, 0.61875874, 0.56195724,
#         -4.80514988e-02, -2.54247002e-02,  1.42785059e-02,  1.24219330e-02,
#         -2.04537641e-02,  3.51178586e-01, -1.22571744e-01,  3.82380188e-02,
#          4.95863333e-02, -1.53110430e-01, -3.70671302e-02,  3.39858122e-02,
#         -4.56034690e-02,  1.67075824e-03, -6.56056255e-02, -2.16899067e-02],
#        dtype=float32)>,
#  <tf.Variable 'transformer/layer_0/self_attention/query/kernel:0' shape=(768, 12, 64) dtype=float32, numpy=
#  array([[[ 0.10558642, -0.04771115, -0.17849638, ..., -0.10766626,
#           -0.0123089 ,  0.07857739],
#          [ 0.00287565,  0.08640175,  0.14117865, ..., -0.10249514,
#           -0.14693598, -0.05052669],
#          [-0.03017146,  0.06333268, -0.00810069, ...,  0.09891868,
#           -0.08692978, -0.05270353],
#          ...,
#          [ 0.0272505 , -0.09501868,  0.06038643, ...,  0.00948417,
#           -0.04189231,  0.02150836],
#          [ 0.08900265,  0.00448218,  0.09606058, ..., -0.06664928,
#            0.14451596, -0.01238969],
#          [-0.0806388 ,  0.0039175 ,  0.03108851, ...,  0.11733339,
#            0.05457796, -0.00359708]],
#
#         [[ 0.03903606,  0.11935092,  0.09948116, ...,  0.04863123,
#           -0.02273435, -0.16477151],
#          [-0.11368391, -0.07244016, -0.01015637, ...,  0.01635592,
#            0.02679226,  0.08068842],
#          [ 0.04678961,  0.12115757,  0.07735224, ...,  0.03428918,
#           -0.12660132,  0.14541791],
#          ...,
#          [ 0.07147144, -0.06790028,  0.0209263 , ..., -0.10554587,
#           -0.0823286 ,  0.01322483],
#          [-0.03705747,  0.00221081,  0.04715752, ...,  0.06807711,
#            0.07963296,  0.02575568],
#          [-0.02503717, -0.05453508, -0.00782406, ..., -0.01490496,
#           -0.02228542,  0.05850271]],
#
#         [[ 0.04843102,  0.0637154 , -0.14041814, ..., -0.01784923,
#            0.13834722, -0.0279854 ],
#          [-0.02823746, -0.05736298,  0.12489867, ...,  0.01291447,
#            0.00776132,  0.05129545],
#          [-0.06992201, -0.15989877,  0.00865157, ...,  0.0635692 ,
#            0.02844592, -0.16801265],
#          ...,
#          [ 0.01162744, -0.02197664,  0.03771114, ..., -0.0330766 ,
#           -0.03860009, -0.02326316],
#          [ 0.02509636,  0.06110464, -0.00148659, ...,  0.03759278,
#           -0.06751499, -0.01053766],
#          [ 0.02353427, -0.00621391,  0.00540982, ..., -0.00772201,
#           -0.05076233, -0.08100008]],
#
#         ...,
#
#         [[ 0.0820479 , -0.11890855,  0.11994334, ...,  0.28765592,
#           -0.38360348,  0.12789215],
#          [-0.041196  ,  0.06707901,  0.00381852, ..., -0.03438895,
#           -0.06090528,  0.00576649],
#          [ 0.05516158,  0.23902363,  0.07216328, ...,  0.09419451,
#            0.01683511, -0.00608863],
#          ...,
#          [-0.01393263,  0.00425433,  0.06002222, ..., -0.0339238 ,
#           -0.09023344, -0.01066647],
#          [-0.06905529, -0.07976121,  0.00659196, ..., -0.09768005,
#            0.17289287, -0.01183931],
#          [-0.00916676,  0.04308391,  0.11344315, ..., -0.13224371,
#         -4.95171687e-03, -3.74073419e-03,  4.79449140e-04, -7.86554441e-03,
#          3.38776945e-03,  3.11993608e-05, -7.52476091e-03, -1.53362751e-03,
#         -4.32094093e-03, -2.80272029e-03,  1.89896324e-03, -5.13032917e-03,
#         -1.78552160e-04, -1.09230564e-03, -4.44628764e-03, -1.18472229e-03,
#          8.28693737e-04, -2.90981750e-03, -3.84149700e-03, -7.52234738e-03,
#          1.84525677e-03, -2.34499690e-03, -9.66636650e-03, -4.60321922e-03,
#          1.30270503e-03, -6.95000077e-03, -4.63125622e-03, -5.40679600e-03,
#         -3.02211847e-03, -3.62736126e-03,  2.55078054e-03,  3.14348354e-03],
#        dtype=float32)>]

# %%
abc=tf.saved_model.load("LaBSE")
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-84-4381adda8314> in <module>
# ----> 1 abc=tf.saved_model.load("LaBSE")
#
# D:\Users\admin\Anaconda3\lib\site-packages\tensorflow_core\python\saved_model\load.py in load(export_dir, tags)
#     515     ValueError: If `tags` don't match a MetaGraph in the SavedModel.
#     516   """
# --> 517   return load_internal(export_dir, tags)
#     518
#     519
#
# D:\Users\admin\Anaconda3\lib\site-packages\tensorflow_core\python\saved_model\load.py in load_internal(export_dir, tags, loader_cls)
#     524     # sequences for nest.flatten, so we put those through as-is.
#     525     tags = nest.flatten(tags)
# --> 526   saved_model_proto = loader_impl.parse_saved_model(export_dir)
#     527   if (len(saved_model_proto.meta_graphs) == 1
#     528       and saved_model_proto.meta_graphs[0].HasField("object_graph_def")):
#
# D:\Users\admin\Anaconda3\lib\site-packages\tensorflow_core\python\saved_model\loader_impl.py in parse_saved_model(export_dir)
#      81                   (export_dir,
#      82                    constants.SAVED_MODEL_FILENAME_PBTXT,
# ---> 83                    constants.SAVED_MODEL_FILENAME_PB))
#      84
#      85
#
# OSError: SavedModel file does not exist at: LaBSE/{saved_model.pbtxt|saved_model.pb}

# %%
#labse_model.save('LaBSE.h5')
labse_model.save_weights("laBSE_weight.h5")

labse_layer.trainable_weights

# %%
json_config = labse_model.to_json()
new_model = tf.keras.models.model_from_json(json_config)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-77-cbc4752db0b6> in <module>
#       1 json_config = labse_model.to_json()
# ----> 2 new_model = tf.keras.models.model_from_json(json_config)
#
# D:\Users\admin\Anaconda3\lib\site-packages\tensorflow_core\python\keras\saving\model_config.py in model_from_json(json_string, custom_objects)
#      94   config = json.loads(json_string)
#      95   from tensorflow.python.keras.layers import deserialize  # pylint: disable=g-import-not-at-top
# ---> 96   return deserialize(config, custom_objects=custom_objects)
#
# D:\Users\admin\Anaconda3\lib\site-packages\tensorflow_core\python\keras\layers\serialization.py in deserialize(config, custom_objects)
#     100       module_objects=globs,
#     101       custom_objects=custom_objects,
# --> 102       printable_module_name='layer')
#
# D:\Users\admin\Anaconda3\lib\site-packages\tensorflow_core\python\keras\utils\generic_utils.py in deserialize_keras_object(identifier, module_objects, custom_objects, printable_module_name)
#     189             custom_objects=dict(
#     190                 list(_GLOBAL_CUSTOM_OBJECTS.items()) +
# --> 191                 list(custom_objects.items())))
#     192       with CustomObjectScope(custom_objects):
#     193         return cls.from_config(cls_config)
#
# D:\Users\admin\Anaconda3\lib\site-packages\tensorflow_core\python\keras\engine\network.py in from_config(cls, config, custom_objects)
#     904     """
#     905     input_tensors, output_tensors, created_layers = reconstruct_from_config(
# --> 906         config, custom_objects)
#     907     model = cls(inputs=input_tensors, outputs=output_tensors,
#     908                 name=config.get('name'))
#
# D:\Users\admin\Anaconda3\lib\site-packages\tensorflow_core\python\keras\engine\network.py in reconstruct_from_config(config, custom_objects, created_layers)
#    1840   # First, we create all layers and enqueue nodes to be processed
#    1841   for layer_data in config['layers']:
# -> 1842     process_layer(layer_data)
#    1843   # Then we process nodes in order of layer depth.
#    1844   # Nodes that cannot yet be processed (if the inbound node
#
# D:\Users\admin\Anaconda3\lib\site-packages\tensorflow_core\python\keras\engine\network.py in process_layer(layer_data)
#    1822       from tensorflow.python.keras.layers import deserialize as deserialize_layer  # pylint: disable=g-import-not-at-top
#    1823
# -> 1824       layer = deserialize_layer(layer_data, custom_objects=custom_objects)
#    1825       created_layers[layer_name] = layer
#    1826
#
# D:\Users\admin\Anaconda3\lib\site-packages\tensorflow_core\python\keras\layers\serialization.py in deserialize(config, custom_objects)
#     100       module_objects=globs,
#     101       custom_objects=custom_objects,
# --> 102       printable_module_name='layer')
#
# D:\Users\admin\Anaconda3\lib\site-packages\tensorflow_core\python\keras\utils\generic_utils.py in deserialize_keras_object(identifier, module_objects, custom_objects, printable_module_name)
#     178     config = identifier
#     179     (cls, cls_config) = class_and_config_for_serialized_keras_object(
# --> 180         config, module_objects, custom_objects, printable_module_name)
#     181
#     182     if hasattr(cls, 'from_config'):
#
# D:\Users\admin\Anaconda3\lib\site-packages\tensorflow_core\python\keras\utils\generic_utils.py in class_and_config_for_serialized_keras_object(config, module_objects, custom_objects, printable_module_name)
#     163     cls = module_objects.get(class_name)
#     164     if cls is None:
# --> 165       raise ValueError('Unknown ' + printable_module_name + ': ' + class_name)
#     166   return (cls, config['config'])
#     167
#
# ValueError: Unknown layer: KerasLayer

# %%
import pickle

# %%
import keras
import tensorflow as tf
lab= tf. .load_model ("laBSE_weight.h5")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-64-bfb6af664ed4> in <module>
#       1 import keras
#       2 import tensorflow as tf
# ----> 3 lab= tf.models.load_model ("laBSE_weight.h5")
#
# AttributeError: module 'tensorflow' has no attribute 'models'

# %%
# !pip install bert-for-tf2

import bert

vocab_file = labse_layer.resolved_object.vocab_file.asset_path.numpy()
do_lower_case = labse_layer.resolved_object.do_lower_case.numpy()
tokenizer = bert.bert_tokenization.FullTokenizer(vocab_file, do_lower_case)

def create_input(input_strings, tokenizer, max_seq_length):

  input_ids_all, input_mask_all, segment_ids_all = [], [], []
  for input_string in input_strings:
    # Tokenize input.
    input_tokens = ["[CLS]"] + tokenizer.tokenize(input_string) + ["[SEP]"]
    input_ids = tokenizer.convert_tokens_to_ids(input_tokens)
    sequence_length = min(len(input_ids), max_seq_length)

    # Padding or trancation.
    if len(input_ids) >= max_seq_length:
      input_ids = input_ids[:max_seq_length]
    else:
      input_ids = input_ids + [0] * (max_seq_length - len(input_ids))

    input_mask = [1] * sequence_length + [0] * (max_seq_length - sequence_length)

    input_ids_all.append(input_ids)
    input_mask_all.append(input_mask)
    segment_ids_all.append([0] * max_seq_length)

  return np.array(input_ids_all), np.array(input_mask_all), np.array(segment_ids_all)

def encode(input_text):
  input_ids, input_mask, segment_ids = create_input(
    input_text, tokenizer, max_seq_length)
  return labse_model([input_ids, input_mask, segment_ids])

english_sentences = ["dog", "Puppies are nice.", "I enjoy taking long walks along the beach with my dog."]
italian_sentences = ["cane", "I cuccioli sono carini.", "Mi piace fare lunghe passeggiate lungo la spiaggia con il mio cane."]
japanese_sentences = ["犬", "子犬はいいです", "私は犬と一緒にビーチを散歩するのが好きです"]

english_embeddings = encode(english_sentences)
italian_embeddings = encode(italian_sentences)
japanese_embeddings = encode(japanese_sentences)

# English-Italian similarity
print (np.matmul(english_embeddings, np.transpose(italian_embeddings)))

# English-Japanese similarity
print (np.matmul(english_embeddings, np.transpose(japanese_embeddings)))

# Italian-Japanese similarity
print (np.matmul(italian_embeddings, np.transpose(japanese_embeddings)))
# Out:
# Collecting bert-for-tf2
#   Downloading bert-for-tf2-0.14.4.tar.gz (40 kB)
# Collecting py-params>=0.9.6
#   Downloading py-params-0.9.7.tar.gz (6.8 kB)
# Collecting params-flow>=0.8.0
#   Downloading params-flow-0.8.2.tar.gz (22 kB)
# Requirement already satisfied: numpy in c:\users\admin\appdata\roaming\python\python37\site-packages (from params-flow>=0.8.0->bert-for-tf2) (1.17.4)
# Requirement already satisfied: tqdm in d:\users\admin\anaconda3\lib\site-packages (from params-flow>=0.8.0->bert-for-tf2) (4.28.1)
# Building wheels for collected packages: bert-for-tf2, py-params, params-flow
#   Building wheel for bert-for-tf2 (setup.py): started
#   Building wheel for bert-for-tf2 (setup.py): finished with status 'done'
#   Created wheel for bert-for-tf2: filename=bert_for_tf2-0.14.4-py3-none-any.whl size=30117 sha256=ad13913f9c605f0b6bc14d5226c3ea6635410770a7aa1b1b11d0dd163bf98932
#   Stored in directory: c:\users\admin\appdata\local\pip\cache\wheels\6c\c9\9c\363182ea34a736dae336eeaf0dd4a7eec3c6a5afe32373e1fe
#   Building wheel for py-params (setup.py): started
#   Building wheel for py-params (setup.py): finished with status 'done'
#   Created wheel for py-params: filename=py_params-0.9.7-py3-none-any.whl size=7306 sha256=1c07076778db9702aec500af412cad30e69937555da40dd4dcd140a8bedddfae
#   Stored in directory: c:\users\admin\appdata\local\pip\cache\wheels\47\3d\2d\bbffcfd6b9f4b8b5cbf07e7520ac2676192fe9431240c13ee8
#   Building wheel for params-flow (setup.py): started
#   Building wheel for params-flow (setup.py): finished with status 'done'
#   Created wheel for params-flow: filename=params_flow-0.8.2-py3-none-any.whl size=19479 sha256=d319bd995d283e90fcad9e458f77d5051b295d83db8be4399e2a73c8cd1dfbb9
#   Stored in directory: c:\users\admin\appdata\local\pip\cache\wheels\0e\fc\d2\a44fff33af0f233d7def6e7de413006d57c10e10ad736fe8f5
# Successfully built bert-for-tf2 py-params params-flow
# Installing collected packages: py-params, params-flow, bert-for-tf2
# Successfully installed bert-for-tf2-0.14.4 params-flow-0.8.2 py-params-0.9.7
# [[0.13908088 0.09686013 0.17586625]
#  [0.02312452 0.24519987 0.12865761]
#  [0.03928326 0.12375419 0.45677465]]
# [[0.25250548 0.15815058 0.17978224]
#  [0.07738895 0.20116895 0.12501355]
#  [0.1195756  0.15101422 0.37853092]]
# [[0.10367964 0.05264979 0.05517671]
#  [0.08405211 0.21575871 0.1613812 ]
#  [0.13475645 0.18133149 0.43222862]]
