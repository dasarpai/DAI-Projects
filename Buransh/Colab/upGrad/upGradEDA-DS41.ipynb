# %%
# import pandas as pd
# import requests
# from io import StringIO

# url='https://drive.google.com/file/d/0B6GhBwm5vaB2ekdlZW5WZnppb28/view?usp=sharing'
# url ='https://drive.google.com/file/d/1B8B6BK9T47e14BW8EWVXaRww1hdxoveZ/view?usp=sharing'

# file_id = url.split('/')[-2]
# dwn_url='https://drive.google.com/uc?export=download&id=' + file_id
# url2 = requests.get(dwn_url).text
# csv_raw = StringIO(url2)
# df = pd.read_csv(csv_raw)
# print(df.head())
# Out:
#                                                                                                       <!DOCTYPE html><html><head><title>Google Drive - Virus scan warning</title><meta http-equiv="content-type" content="text/html; charset=utf-8"/><style nonce="LJ169414oam97aZBmVXyFA">/* Copyright 2022 Google Inc. All Rights Reserved. */
# .goog-inline-block{position:relative;display:-m... sans-serif;margin:0}.grecaptcha-badge{visibilit...  .uc-warning-caption{color:#222;font-size:16px}...

# %%
url2
# Out:
# '<!DOCTYPE html><html><head><title>Google Drive - Virus scan warning</title><meta http-equiv="content-type" content="text/html; charset=utf-8"/><style nonce="W2qQRBue3eq4yh5HNJ9BwQ">/* Copyright 2022 Google Inc. All Rights Reserved. */\n.goog-inline-block{position:relative;display:-moz-inline-box;display:inline-block}* html .goog-inline-block{display:inline}*:first-child+html .goog-inline-block{display:inline}.goog-link-button{position:relative;color:#15c;text-decoration:underline;cursor:pointer}.goog-link-button-disabled{color:#ccc;text-decoration:none;cursor:default}body{color:#222;font:normal 13px/1.4 arial,sans-serif;margin:0}.grecaptcha-badge{visibility:hidden}.uc-main{padding-top:50px;text-align:center}#uc-dl-icon{display:inline-block;margin-top:16px;padding-right:1em;vertical-align:top}#uc-text{display:inline-block;max-width:68ex;text-align:left}.uc-error-caption,.uc-warning-caption{color:#222;font-size:16px}#uc-download-link{text-decoration:none}.uc-name-size a{color:#15c;tex
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
df_app=pd.read_csv('/content/drive/MyDrive/DS-Data/upgrad/application_data.csv')
df_cols=pd.read_csv('/content/drive/MyDrive/DS-Data/upgrad/columns_description.csv', encoding='cp1252')
df_prevapp=pd.read_csv('/content/drive/MyDrive/DS-Data/upgrad/previous_application.csv')

# %%
import seaborn as sns
g = sns.FacetGrid(df_app, col="DAYS_BIRTH", hue="TARGET", palette="Set1", col_wrap=2)
g.map(plt.hist, 'value', bins=bins, ec="k")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-10-ef1b10f3216f> in <module>()
#       1 import seaborn as sns
# ----> 2 g = sns.FacetGrid(df_app, col="DAYS_BIRTH", hue="TARGET", palette="Set1", col_wrap=2)
#       3 g.map(plt.hist, 'value', bins=bins, ec="k")
#
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# /usr/local/lib/python3.7/dist-packages/seaborn/axisgrid.py in __init__(self, data, row, col, hue, col_wrap, sharex, sharey, height, aspect, palette, row_order, col_order, hue_order, hue_kws, dropna, legend_out, despine, margin_titles, xlim, ylim, subplot_kws, gridspec_kws, size)
# ...

# %%
df_app[df_app.TARGET==0].DAYS_BIRTH.hist()
df_app[df_app.TARGET==1].DAYS_BIRTH.hist()

# %%
df_app.shape, df_cols.shape, df_prevapp.shape
# Out:
# ((307511, 122), (160, 5), (1670214, 37))

# %%
tab= df_cols[  df_cols['Table']=='application_data'][['Table','Row','Description']]

for row in range(tab.shape[0]):
  print(tab.at[row,'Row'], "==>",tab.at[row,'Description'])
# Out:
# SK_ID_CURR ==> ID of loan in our sample
# TARGET ==> Target variable (1 - client with payment difficulties: he/she had late payment more than X days on at least one of the first Y installments of the loan in our sample, 0 - all other cases)
# NAME_CONTRACT_TYPE ==> Identification if loan is cash or revolving
# CODE_GENDER ==> Gender of the client
# FLAG_OWN_CAR ==> Flag if the client owns a car
# FLAG_OWN_REALTY ==> Flag if client owns a house or flat
# CNT_CHILDREN ==> Number of children the client has
# AMT_INCOME_TOTAL ==> Income of the client
# AMT_CREDIT ==> Credit amount of the loan
# AMT_ANNUITY ==> Loan annuity
# AMT_GOODS_PRICE ==> For consumer loans it is the price of the goods for which the loan is given
# NAME_TYPE_SUITE ==> Who was accompanying client when he was applying for the loan
# NAME_INCOME_TYPE ==> Clients income type (businessman, working, maternity leave,…)
# NAME_EDUCATION_TYPE ==> Level of highest education the client achieved
# ...
