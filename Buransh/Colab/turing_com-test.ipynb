# %%
import numpy as np

def calPoints(ops) -> int:
        """
        :type ops: List[str] - List of operations
        :rtype: int - Sum of scores after performing all operations
        """
        result = None
        l1=[]
        prev=None

        def isops(letter):
          if letter in ("+","D","C"):
            return True
          else:
            return False

        def doops(letter,l1):
          if letter=="D":
            l1.append( l1[-1]*2)
          elif letter=="C":
            l1.pop()
          elif letter=="+":
            l1.append(l1[-1]+l1[-2])
          #return l1

        for i,letter in enumerate(ops):
          if isops(letter):
            doops(letter,l1)
          else:
            l1.append(float(letter))
        print(l1)

        return np.array(l1).sum()

ops = ["5","-2","4","C","D","9","+","+"]
if __name__ == '__main__':
        #line = input()
        #ops = line.strip().split()

        print(calPoints(ops))
# Out:
# [5.0, -2.0, -4.0, 9.0, 5.0, 14.0]
# 27.0

# %%
from typing import List

def solution(cals: [int], d: int, min: int, max: int) -> int:
  # write your solution here
  score=0
  total=0
  for cal in cals[:d]:
    if cal<min:
      score-=1
    elif cal>max:
      score+=1
  print (score)

  return score

# R E A D M E
# DO NOT CHANGE the code below, we use it to grade your submission. If changed your submission will be failed automatically.
if __name__ == '__main__':
    line = [1,2,3,4,5] #input()
    k= line #2[int(str) for str in line.strip().split()]
    n = 5 # number of days
    b = 3 # min calory
    d = 3 # max calory
    # n = int(input())
    # b = int(input())
    # d = int(input())
    print(solution(k, n, b, d))
# Out:
# 0
# 0
