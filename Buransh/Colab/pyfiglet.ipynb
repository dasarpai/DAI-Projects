# %%
# !pip install pyfiglet
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 16.5 MB/s eta 0:00:00
# ...

# %%
import pyfiglet
text = pyfiglet.figlet_format("Hari Thapliyal",font="puffy")
print(text)
# Out:
#  _   _
# ( ) ( )              _
# | |_| |   _ _  _ __ (_)
# |  _  | /'_` )( '__)| |
# | | | |( (_| || |   | |
# (_) (_)`\__,_)(_)   (_)
#
#
#  _____  _                    _                     _
# (_   _)( )                  (_ )  _               (_ )
#   | |  | |__     _ _  _ _    | | (_) _   _    _ _  | |
#   | |  |  _ `\ /'_` )( '_`\  | | | |( ) ( ) /'_` ) | |
#   | |  | | | |( (_| || (_) ) | | | || (_) |( (_| | | |
#   (_)  (_) (_)`\__,_)| ,__/'(___)(_)`\__, |`\__,_)(___)
#                      | |            ( )_| |
#                      (_)            `\___/'

# %%
text = pyfiglet.figlet_format("हरि थपलियाल",font="puffy")
print(text)
