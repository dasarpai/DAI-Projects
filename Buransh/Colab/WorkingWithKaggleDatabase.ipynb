# %%
# Hari Thapliyal Notebook

# %% [markdown]
# # Getting Competion Dataset from Kaggle

# %%
! pip install -q kaggle
! mkdir ~/.kaggle
! cp /content/drive/MyDrive/kaggle.json ~/.kaggle/
! chmod 600 ~/.kaggle/kaggle.json
# Out:
# mkdir: cannot create directory ‘/root/.kaggle’: File exists

# %%
# Goto to https://www.kaggle.com/YOUR-KAGGLE-ACCOUNT/account%20=%3E%20account%20==%3E%20API%20=%3E%20Create%20New%20API%20Token
# kaggle.json will be download on your machine.
# Upload this file in colab.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
! kaggle datasets list
# Out:
# ref                                                        title                                           size  lastUpdated          downloadCount  voteCount  usabilityRating
# ---------------------------------------------------------  ---------------------------------------------  -----  -------------------  -------------  ---------  ---------------
# salvatorerastelli/spotify-and-youtube                      Spotify and Youtube                              9MB  2023-03-20 15:43:25           6441        246  1.0
# erdemtaha/cancer-data                                      Cancer Data                                     49KB  2023-03-22 07:57:00           2229         56  1.0
# ulrikthygepedersen/fastfood-nutrition                      Fastfood Nutrition                              12KB  2023-03-21 10:02:41           2344         48  1.0
# ...

# %% [markdown]
# # Upload a Specific Dataset

# %%
#if your kaggle dataset url is https://www.kaggle.com/datasets/miracle9to9/files1 then 
#!kaggle datasets download -d miracle9to9/files1
# !kaggle datasets download -d fedesoriano/company-bankruptcy-prediction
# Out:
# ...
#   0% 0.00/4.63M [00:00<?, ?B/s]
# 100% 4.63M/4.63M [00:00<00:00, 68.5MB/s]
