# %%
import pandas as pd

# %%
df  = pd.read_xml("/content/drive/MyDrive/DS-Data/hbqa/hbqa-papers.xml")
df
# Out:
#          SourceType                                              Title  Year  \
# 0   Journal Article  Academic Journal of Science and Technology Aut...  2022
# 1   Journal Article  Answer-Focused and Position-Aware Neural Netwo...  2019
# 2   Journal Article  Automatic Question Generation using Sequence t...  2020
# 3   Journal Article  Enhancing Human Summaries for Question-Answer ...  2023
# 4   Journal Article  Automatic Evaluation of Descriptive Answers Us...  2022
# ..              ...                                                ...   ...
# 89  Journal Article  Novel Event Detection and Classification for H...  2019
# 90  Journal Article  Normalisation of historical text using context...  2013
# 91  Journal Article  Book Review Natural Language Processing for Hi...  2014
# 92           Report                    The Text as a Historical Object  2000
# 93         web_page  Mahabharata Translation by Ganguly Accessed on...  1896
#
# ...

# %%
df.columns
# Out:
# Index(['SourceType', 'Title', 'Year', 'StandardNumber', 'Volume', 'Issue',
#        'Author', 'URL', 'Tag', 'JournalName', 'Month', 'Publisher', 'Pages',
#        'City'],
#       dtype='object')

# %%
df[df['Title'].str.lower().str.contains('survey')]
# Out:
#                 SourceType                                              Title  \
# 10  Conference Proceedings  Survey on Automatic Text Summarization and Tra...
# 11  Conference Proceedings  Pretrained Language Models for Text Generation...
# 17         Journal Article                          A Survey on Deep Learning
# 19         Journal Article  A survey on question answering systems with cl...
#
#     Year StandardNumber Volume Issue  Author  \
# 10  2020  9781450388054   None  None     NaN
# 11  2021       10450823   None  None     NaN
# 17  2019      0360-0300     51     5     NaN
# 19  2016       13191578     28     3     NaN
#
#                                                   URL  \
# 10     https://dl.acm.org/doi/10.1145/3437802.3437832
# 11                                               None
# 17             https://dl.acm.org/doi/10.1145/3234150
# 19  https://linkinghub.elsevier.com/retrieve/pii/S...
#
#                                                   Tag  \
# ...
