slokas-with-hindi-meaning/', 
'https://www.ramcharit.in/valmiki-ramayana-uttarkanda-sarga-chapter-29-slokas-with-hindi-meaning/', 
'https://www.ramcharit.in/valmiki-ramayana-uttarkanda-sarga-chapter-30-slokas-with-hindi-meaning/', ]

# %%
# URL of the website to read from
url = 'https://www.ramcharit.in/हनुमान-जी-के-1008-नाम-हिंदी-में'
url = 'https://www.ramcharit.in/valmiki-ramayana-bala-kanda-in-sanskrit-with-hindi-meaning-pdf/'
#url = 'https://www.ramcharit.in/valmiki-ramayana-balakanda-sarga-chapter-19-slokas-with-hindi-meaning/'
url = ramayana['balkand'][11]

# %% [markdown]
# # Create a file and put put extracted in that file

# %%
def get_text(url):
  import requests
  from bs4 import BeautifulSoup
  # Send a GET request to the URL and store the response
  headers = {
      'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3',
      'Accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,*/*;q=0.8'
  }

  response = requests.get(url, headers=headers)

  # Use BeautifulSoup to parse the HTML content of the response
  soup = BeautifulSoup(response.content, 'html.parser')

  text = (soup.get_text().replace('\n\n',' ').replace('\t\t',' '))
  return text

# %%
# # create ramayana text file

# import time 
# with open('ramayana.txt', 'w') as file:
#   for k,v in ramayana.items():
#     print (k, len(v))
#     for url in v:
#       print(k, url)

#       # Write some text to the file
#       text = "URL: " + url + '\n' + get_text(url)
#       file.write(text)
#       time.sleep(1)

# %% [markdown]
# # Create dataframe from the file created

# %%
with open('ramayana.txt', 'r') as file:
  text = file.readlines()

# %%
import pandas as pd 
df = pd.DataFrame(text)
df['junk']=''

# %%
pd.set_option('display.max_colwidth',100)

# %%
df.drop_duplicates(inplace=True)
df
# Out:
# ...
#                                                                                                          0  \
# 0      URL: https://www.ramcharit.in/valmiki-ramayana-balakanda-sarga-chapter-1-slokas-with-hindi-meani...
# 1           वाल्मीकि रामायण बालकाण्ड सर्ग 1 हिंदी अर्थ सहित valmiki ramayana balakanda 1               ...
# 2                                                                                                       \n
# 3                                                                                     Skip to content   \n
# 4                                                                                               Latest: \n
# ...                                                                                                    ...
# 87809  श्रीराम! उस समय वह रावणकुमार रावण के सुन्दर अन्तःपुर में माता-पिता को महान् हर्ष प्रदान करता हुआ...
# 87810                        इत्यार्षे श्रीमद्रामायणे वाल्मीकीये आदिकाव्ये उत्तरकाण्डे द्वादशः सर्गः॥१२॥\n
# ...

# %%
# Identify junk rows and remove those

# %%
df['junk']=df[0].apply(lambda x: 1 if 'thoughts on' in x else 0)
df=df[df.junk!=1]

df['junk']=df[0].apply(lambda x: 1 if 'One thought on' in x else 0)
df=df[df.junk!=1]

df['junk']=df[0].apply(lambda x: 1 if ', 2020' in x else 0)
df=df[df.junk!=1]

df['junk']=df[0].apply(lambda x: 1 if ', 2021' in x else 0)
df=df[df.junk!=1]

df['junk']=df[0].apply(lambda x: 1 if ', 2022' in x else 0)
df=df[df.junk!=1]

df['junk']=df[0].apply(lambda x: 1 if ', 2023' in x else 0)
df=df[df.junk!=1]

df['junk']=df[0].apply(lambda x: 1 if 'Pingback' in x else 0)

df=df[df.junk!=1]

# %%
#Save the clean file

df[0].to_csv('ramayana_clean1.txt')

# %%
df.sample(10000)
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
df.index

# %% [markdown]
# # Experiments

# %%
import requests
from bs4 import BeautifulSoup
# Send a GET request to the URL and store the response
headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3',
    'Accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,*/*;q=0.8'
}

#response = requests.get(url, headers=headers)
response = requests.get(url)

# %%
# Use BeautifulSoup to parse the HTML content of the response
soup = BeautifulSoup(response.content, 'html.parser')

text = soup.get_text().replace('\n\n',' ').replace('\t\t',' ')
print(text)

# %%
# Find all the text in the HTML content and print it
text = soup.get_text()
print(text)

# %%
soup.find_all()

# %%
# new_soup = soup.copy()
[soup.span.replace_with(soup.span.text) for soup in soup.select('p > span[style="color: #ff0000;"]')]

# %%
#spans = soup.find_all('span', {'style': 'color: #ff0000;', 'class': 'bold'})
spans = soup.find_all('a')

# Loop through each span and print its text
for span in spans:
    print(span)
    #url = span.get('href')
    alt_text = span.get('em')
    #print('URL:', url)
    print('Alt Text:', alt_text)

# %%
# Find all the hyperlink tags in the HTML content
hyperlinks = soup.find_all('span')


# Loop through each hyperlink and print the URL and alt text
for hyperlink in hyperlinks:
    url = hyperlink.get('href')
    alt_text = hyperlink.get('alt', '')
    print('URL:', url)
    print('Alt Text:', alt_text)

# %%
# import time 
# for k,v in ramayana.items():
#   print (k, len(v))
#   for link in v:
#     print(k, link)
#     time.sleep(2)
