# %%
class Point:
  def __init__(self, x, y):
    self.x = x
    self.y = y

  def __add__(self, other):
    if isinstance(other, Point):
        return Point(self.x + other.x, self.y + other.y)
    else:
        raise TypeError("Unsupported operand type: {} + {}".format(type(self), type(other)))

  def __mul__(self, other):
    if isinstance(other, Point):
        return Point(self.x * other.x, self.y * other.y)
    else:
        raise TypeError("Unsupported operand type: {} * {}".format(type(self), type(other)))

  def __truediv__(self, other):
    if isinstance(other, Point):
        if other.x != 0 or other.y != 0:
            return Point(self.x / other.x, self.y / other.y)
        else:
            raise ZeroDivisionError("Division by zero!")
    else:
        raise TypeError("Unsupported operand type: {} / {}".format(type(self), type(other)))

  def __str__(self):
    return "Point({}, {})".format(self.x, self.y)

# Create two Point objects
p1 = Point(2, 3)
p2 = Point(4, 5)

# Use the addition operator with Point objects
p3 = p1 + p2
p4 = p1 * p2
p5 = p1 / p2

# Print the result
print (p1, p2)
print(p3)  # Output: Point(6, 8)
print(p4)  
print(p5)
# Out:
# Point(2, 3) Point(4, 5)
# Point(6, 8)
# Point(8, 15)
# Point(0.5, 0.6)

# %%
dir(Point)
# Out:
# ['__add__',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__truediv__',
#  '__weakref__']

# %%
p4= Point(10,15)
p5 = p3+p4
print(p5)
# Out:
# Point(16, 23)
