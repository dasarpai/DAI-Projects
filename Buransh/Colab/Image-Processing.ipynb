# %%
# Creating Image

# %%
img
# Out:
# <PIL.Image.Image image mode=RGB size=100x100 at 0x7FC03B64AB00>

# %%
from PIL import Image
import numpy as np

# Create a new image with 100x100 pixels
img = Image.new('RGB', (100, 100), color = 'red')

# Get the pixel values of the image
pixels = np.array(img.load())

# Print the pixel values of the first row of the image
pixels[:,:,1]
# for i in range(img.size[0]):
#     print(pixels[i,0])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-11-2290ec63ad63> in <cell line: 11>()
#       9
#      10 # Print the pixel values of the first row of the image
# ---> 11 pixels[:,:,1]
#      12 # for i in range(img.size[0]):
#      13 #     print(pixels[i,0])
#
# IndexError: too many indices for array: array is 0-dimensional, but 3 were indexed

# %%
img.show()
# Out:
# <PIL.Image.Image image mode=RGB size=100x100 at 0x7FA468E7EB30>

# %%
img.size
# Out:
# (100, 100)

# %%
from PIL import Image

# Create a new image with 100x100 pixels
img = Image.open('/content/drive/MyDrive/DS-Data/images/Cat03.jpg')

# Get the pixel values of the image
pixels = img.load()

# Print the pixel values of the first row of the image
for i in range(img.size[0]):
    print(pixels[i,0])

# %%
img.size
# Out:
# (1200, 1199)

# %%
import numpy as np
img1 = np.array(img)
img1.shape
# Out:
# (1199, 1200, 3)

# %%
img1[:,:,0]
# Out:
# array([[218, 217, 216, ..., 230, 230, 230],
#        [218, 217, 216, ..., 231, 231, 231],
#        [218, 216, 216, ..., 232, 232, 232],
#        ...,
#        [182, 182, 184, ..., 226, 226, 225],
#        [181, 182, 183, ..., 227, 226, 225],
#        [181, 182, 183, ..., 226, 226, 225]], dtype=uint8)

# %%
import matplotlib.pyplot as plt

fig, axs = plt.subplots(1, 3, figsize=(20, 5))
axs[0].hist(img1[:,:,0])
axs[1].hist(img1[:,:,1])
axs[2].hist(img1[:,:,2])
plt.show()

# %%
img1[:,:,0].mean(),img1[:,:,1].mean(), img1[:,:,2].mean()
# Out:
# (175.87335001390048, 148.84099457881567, 120.71229913817069)

# %%
img1[:,:,0].std(),img1[:,:,1].std(), img1[:,:,2].std()
# Out:
# (48.82226738871668, 59.17555539947876, 67.62441567764263)

# %%
np.median(img1[:,:,0]), np.median(img1[:,:,1]), np.median(img1[:,:,2])
# Out:
# (182.0, 149.0, 113.0)
